# %%
from src import analysis_utils as utils
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
import seaborn as sns; sns.set()
import pandas as pd
from scipy.stats import poisson
# %matplotlib inline 
# %load_ext autoreload
# %autoreload

# %% [markdown]
# <B> Experiment 18: Negative control </B>, 47 tRNAEFTu, 7 ribosomes, 0 tRNAsynth, 0 aa, 85nm side (phi=~0.22).
# No collisions between tRNA-tRNA, ribosome-ribosome, and tRNA-ribosome (free diffusion with no volume exclusion) using an effective diffusion coefficient for tRNA-efTu (43 diffusion). Shown at 3 different time scales (1ms, 10ms, 100ms)

# %%
expt18_df=utils.readSimData("data/expt18_47tRNAEfTu_7ribosome_0tRNASynth_0aa_85nmSidelength_20180426.xls")
expt18_df_split = utils.timeSplitter(expt18_df, scale="log")
fig,ax=plt.subplots(3,2,figsize=(10,10))
expt18_df_incorr=list()
for i,val in enumerate(expt18_df_split):
    expt18_df_incorr.append(utils.countIncorrectRibosomeCollisions(pd.concat(expt18_df_split[0:i+1]),np.arange(0,5),np.arange(48,55)));
    ax[i,0].hist(expt18_df_incorr[-1][0],bins=10,range=(1,1000));
    ax[i,1].hist(expt18_df_incorr[-1][3],bins=10,range=(1,1000));
# Out:
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)

# %%
fig,ax=plt.subplots(3,2,figsize=(10,10))
for i,val in enumerate(expt18_df_split):
    ax[i,0].hist(expt18_df_incorr[-1][0],bins=10,range=(1,20));
    ax[i,1].hist(expt18_df_incorr[-1][3],bins=10,range=(1,20));
    
print(np.average(expt18_df_incorr[-1][0][1]))
# Out:
# 44.386990337

# %% [markdown]
# At long enough timescales, sampling follows a poisson-like distribution if there is no crowding effects. This is an interesting detail, as current models just use the mean sampling time even though the distribution is so wide. Will need to consider where the effects of such a distribution would matter most.

# %%
expt18_collisions=utils.countRibosomeCollisions(expt18_df,np.arange(1,5),np.arange(48,55))
for i in range(3):
    plt.bar(.1*i+np.arange(1,5),expt18_collisions[1:5,i], width=0.1, label="tRNA "+str(i))
# Out:
# Computing tRNA collision count [rib,tRNA]: (7, 4)

# %% [markdown]
# Experiment 20: negative control; same as 18 but have non-natural bounce that's 2x radius of tRNA+radius of ribosome

# %%
expt20_df=utils.readSimData("data/expt20_47tRNAEfTu_7ribosome_0tRNASynth_0aa_85nmSidelength_20180430.xls")
expt20_df_split = utils.timeSplitter(expt20_df, scale="log")
fig,ax=plt.subplots(3,1,figsize=(10,10))
#expt20_df_incorr=list()
for i,val in enumerate(expt20_df_split):
    #expt20_df_incorr.append(utils.countIncorrectRibosomeCollisions(pd.concat(expt20_df_split[0:i+1]),np.arange(0,5),np.arange(48,55)));
    ax[i].hist(expt20_df_incorr[-1][0],bins=10,range=(1,100));
    #ax[i,1].hist(expt20_df_incorr[-1][3],bins=10,range=(1,200));
print(np.average(expt20_df_incorr[-1][0][1]))
# Out:
# 46.3397260274

# %%
s=np.random.poisson(46, 10000)
count, bins, ignored = plt.hist(s, 14, normed=True)
plt.show()

# %% [markdown]
# <B>Experiment 19: Positive Control</B>, 188 tRNA, 7 ribosomes, hard sphere closed boundary. Do with same volume as negative control (85nm side). Volume excluding. Phi = 0.62 (4x more tRNA than usual). Used tRNA diffusion coefficient of 47 instead of 43

# %%
expt19_df=utils.readSimData("data/expt19_188tRNAEfTu_7ribosome_0tRNASynth_0aa_85nmSidelength_20180426.xls")
expt19_df_split = utils.timeSplitter(expt19_df, scale="log")
fig,ax=plt.subplots(3,2,figsize=(10,10))
for i,val in enumerate(expt19_df_split):
    expt19_df_incorr=utils.countIncorrectRibosomeCollisions(pd.concat(expt19_df_split[0:i+1]),np.arange(0,5),np.arange(189,196));
    ax[i,0].hist(expt19_df_incorr[0],bins=10,range=(1,1000));
    ax[i,1].hist(expt19_df_incorr[3],bins=10,range=(1,1000));
# Out:
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)

# %%
expt19_df=utils.readSimData("data/expt19_188tRNAEfTu_7ribosome_0tRNASynth_0aa_85nmSidelength_20180426.xls")
expt19_df_split = utils.timeSplitter(expt19_df, scale="log")
fig,ax=plt.subplots(3,2,figsize=(10,10))
expt19_df_incorr=list()
for i,val in enumerate(expt19_df_split):
    expt19_df_incorr.append(utils.countIncorrectRibosomeCollisions(pd.concat(expt19_df_split[0:i+1]),np.arange(0,5),np.arange(189,196)));
    ax[i,0].hist(expt19_df_incorr[-1][0],bins=10,range=(1,1000),log=True);
    ax[i,1].hist(expt19_df_incorr[-1][3],bins=10,range=(1,1000),log=True);
# Out:
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)

# %%
fig,ax=plt.subplots(3,2,figsize=(10,10))
for i,val in enumerate(expt19_df_incorr):
    ax[i,0].hist(expt19_df_incorr[i][0],bins=np.logspace(0,np.log10(20000),5),range=(1,20),log=False)
    ax[i,0].set_xscale("log")
    ax[i,1].hist(expt19_df_incorr[i][3],bins=10,range=(1,20),log=False);
np.std(expt19_df_incorr[2][0][1])
np.average(expt19_df_incorr[2][0][1])
# Out:
# 225.07004883737881

# %% [markdown]
# Note: It isn't that there is no long tail in the positive control above. It's that there's so much caging, that either the tRNA is always immediately interacting with the ribosome, or it has a gap of 10k+ wrong interactions before the correct one can arrive again.

# %% [markdown]
# <B>Experiment 10</B>: Biologically relevant concentration. 47 tRNAEFTu, 7 ribosomes, 8 tRNAsynth, 863 aa, 85nm side (phi=~0.22)

# %%
expt10_df=utils.readSimData("data/expt10_47tRNAEfTu_7ribosome_8tRNASynth_863aa_85nmSidelength_20180424.xls")
expt10_df_split = utils.timeSplitter(expt10_df, scale="log")
fig,ax=plt.subplots(3,2,figsize=(10,10))
expt10_df_incorr=list()
for i,val in enumerate(expt10_df_split):
    expt10_df_incorr.append(utils.countIncorrectRibosomeCollisions(pd.concat(expt10_df_split[0:i+1]),np.arange(0,5),np.arange(48,55)));
    ax[i,0].hist(expt10_df_incorr[-1][0],bins=10,range=(1,1000));
    ax[i,1].hist(expt10_df_incorr[-1][3],bins=10,range=(1,1000));
# Out:
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)

# %%
expt10_df=utils.readSimData("data/expt10_47tRNAEfTu_7ribosome_8tRNASynth_863aa_85nmSidelength_20180424.xls")
expt10_df_split = utils.timeSplitter(expt10_df, scale="log")
fig,ax=plt.subplots(3,2,figsize=(10,10))
expt10_df_incorr=list()
for i,val in enumerate(expt10_df_split-1):
    expt10_df_incorr.append(utils.countIncorrectRibosomeCollisions(pd.concat(expt10_df_split[0:i+1]),np.arange(0,5),np.arange(48,55)));
    ax[i,0].hist(expt10_df_incorr[-1][0],bins=10,range=(1,1000));
    ax[i,1].hist(expt10_df_incorr[-1][3],bins=10,range=(1,1000));
# Out:
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-37efe4cc8e35> in <module>()
#       4 expt10_df_incorr=list()
#       5 for i,val in enumerate(expt10_df_split):
# ----> 6     expt10_df_incorr.append(utils.countIncorrectRibosomeCollisions(pd.concat(expt10_df_split[0:i+1]),np.arange(0,5),np.arange(48,55)));
#       7     ax[i,0].hist(expt10_df_incorr[-1][0],bins=10,range=(1,1000));
#       8     ax[i,1].hist(expt10_df_incorr[-1][3],bins=10,range=(1,1000));
#
# /Users/Akshay/Dropbox/Life/Research/Endy Lab/Research/Simulations/TranslationDynamics/results/src/analysis_utils.py in countIncorrectRibosomeCollisions(df, tRNA_IDList, ribosome_IDList, tRNAInclusionList)
#     115             #Check to ensure the reactant is being considered as a tRNA & Check to see if the reactant is a repeat reactant, in which case ignore.
#     116             # If reactant is previous reactant then keeping prev rxn var same is ok. If reactantA not on tRNA list, then keeping prev rxn var same also ok.
# --> 117             if rxn_i["reactantA"] in tRNAInclusionList and rxn_i["reactantA"]!=prevtRNAID:
#     118                 for t_index, tRNAID in enumerate(tRNA_IDList):    #For each reaction, iterate through each tRNA.
#     119                     #Increment the incorrect collision count for each tRNA that wasn't involved
#
# /Users/Akshay/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     601         key = com._apply_if_callable(key, self)
#     602         try:
# --> 603             result = self.index.get_value(self, key)
#     604
#     605             if not is_scalar(result):
#
# /Users/Akshay/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_value(self, series, key)
#    2161                 pass
#    2162
# -> 2163         s = _values_from_object(series)
#    2164         k = _values_from_object(key)
#    2165
#
# pandas/lib.pyx in pandas.lib.values_from_object (pandas/lib.c:4652)()
#
# /Users/Akshay/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in get_values(self)
#     391     def get_values(self):
#     392         """ same as values (but handles sparseness conversions); is a view """
# --> 393         return self._data.get_values()
#     394
#     395     @property
#
# KeyboardInterrupt:

# %%
expt10_collisions=utils.countRibosomeCollisions(expt10_df,np.arange(1,5),np.arange(48,55))
for i in range(3):
    plt.bar(.1*i+np.arange(1,5),expt10_collisions[1:5,i], width=0.1, label="tRNA "+str(i))
# Out:
# Computing tRNA collision count [rib,tRNA]: (7, 4)

# %%
np.average(expt10_df_incorr[-1][3][2])
# Out:
# 44.429882044560941

# %% [markdown]
# The tail ends slightly sooner than with the no-crowding system. This is slightly unexpected since I would have expected a longer tail distribution due to caging -- will need to investigate. Overall there are also just fewer collisions than with no crowders (negative control).
#
# Conclusions: within a 80nm side box, tRNA-EFTus stay non uniform on the order of 10ms (though this happens even without crowding), which is surprinsingly long. This means that with more crowding or other methods of holding tRNAs-EfTu (such as many ribosomes locally that require a certain tRNA; or some sort of transient binding events to hold tRNA in place), tRNA-EfTus could be localized for longer (see positive control). We also see that the relative ratios of tRNAs-EfTus are extremely important in holding tRNAs in a volume/relative interaction with ribosome.
#
# Another interesting observation is that geminate reactions (whereby a tRNA-EfTu that just collides with a ribosome is much more likely to immediately collide again before another tRNA-EfTu enters) are quite common, and suggest that once a correct tRNA gets to the ribosome it will keep going back in until it goes through the 1.4x neccessary for KPR (without leaving the local area). This feature could further localize tRNAs (and would support the idea that there are pockets of ribosomes all needing a certain tRNA/that tRNAs are still around for the next ribosome to come by same amino acid -- an idea that's further supported if some tRNAs can be incorporated rapidly at order ~5-10ms).
#
# If we find that translation could go faster, this might suggest that tRNAs usually travel unbound and get loaded by EfTu only near their ribosome site.
#
# If we somehow find that this model predicts known translation rates, we can start playing around with the cell composition to stress test/map phase diagram and build a synthetic cell (e.g., that expresses fast or slow or not at all or only certain proteins, or different proteins differentially based on aa composition).
#
# #Need metrics: like average collision, "disparity btwn low and high", so can combine all these
# #graphs into a couple of line graphs over various parameters

# %%
print(disparity(expt10_df_incorr[2][3][-1]))
print(disparity(expt18_df_incorr[2][3][-1]))
len(expt19_df_incorr[0])
#disparity(expt19_df_incorr[0][2])
# Out:
# (922, 2)
# (3439, 43)
# 7

# %% [markdown]
# <B> Experiment 14: Extra Negative control </B>, 47 tRNAEFTu, 7 ribosomes, 0 tRNAsynth, 0 aa, 85nm side (phi=~0.22).
# No collisions between tRNA-tRNA, ribosome-ribosome, and tRNA-ribosome (free diffusion with no volume exclusion) using an effective diffusion coefficient for tRNA-efTu (2.5 instead of 43)

# %%
expt14_df=utils.readSimData("data/expt14_47tRNAEfTu_7ribosome_0tRNASynth_0aa_85nmSidelength_20180424.xls")
expt14_df_incorr=utils.countIncorrectRibosomeCollisions(expt14_df,np.arange(0,5),np.arange(48,55));
fig,ax=plt.subplots(2,1)
ax[0].hist(expt14_df_incorr[0],bins=10,range=(1,1000));
ax[1].hist(expt14_df_incorr[3],bins=10,range=(1,1000));
# Out:
# Initial ribosome x tRNA x collisionGapNumber has shape: (7, 5, 0)

# %%
def disparity(col):
    low=0
    high=0
    for i in range(len(col)):
        if col[i]<10:
            low+=1
        if col[i]>700:
            high+=1
    return low, high

# %%
def avg(col):
    tot=0
    for i in range(len(col)):
        tot+=(sum(col[i])/len(col[i]))
    return tot/len(col)
