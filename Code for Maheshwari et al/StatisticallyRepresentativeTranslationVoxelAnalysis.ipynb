# %% [markdown]
# ## Calculate cognate ternary complex distribution for a given tRNA and codon distribution (i.e., at a given growth rate)

# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Growth rate = 0.6
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


ribs=[4,8,9,9,8,7]
#These scaling factors scale all kinetic parametesr; 200 = normal simulation; 67 = 3x faster; 50x = 4x faster
scalingFactorList = [200,67]
rxndiff_list = list()


for _, scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}

    rxndiff=dict()

    gr_sim = dict()

    data = "191003_2140/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1738/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor,NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1817/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor,NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1934/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor,NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['06'] = transportRxnResults[1:]


    #Growth rate = 1.0
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_0018/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_2012/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_2115/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_2238/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['10'] = transportRxnResults[1:]

    #Growth rate = 1.5
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_0104/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_0916/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1041/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1206/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['15'] = transportRxnResults[1:]

    #Growth rate = 2.0
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_1129/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1348/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1428/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1506/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['20'] = transportRxnResults[1:]

    #Growth rate = 2.5
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_1217/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1556/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1714/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1757/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['25'] = transportRxnResults[1:]

    #Growth rate = 3.0
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191003_2210/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_0908/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_0951/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1033/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}


    transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['30'] = transportRxnResults[1:]

    rxndiff_list.append(rxndiff)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Starting scaling =  200
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 545
# Computing...
# Computing...
# Computing...
# missing expt
# 804
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 618.48000568442
# Unweighted search time ( 2  cognate) 258.9350308864562
# Unweighted search time ( 3  cognate) 173.64913028427355
# Unweighted search time ( 4  cognate) 143.91515783779377
# Unweighted search time ( 5  cognate) 127.27776722090194
# Unweighted search time ( 6  cognate) 104.34941738686803
# Unweighted search time ( 7  cognate) 74.27410282099623
# Unweighted search time ( 8  cognate) 74.97019237806587
# Unweighted search time ( 9  cognate) 47.20134096887209
# Unweighted search time ( 10  cognate) 53.122942487546965
# Unweighted search time ( 11  cognate) 41.241939568109714
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [241.98979332634306]  +/-  [15.02609607042069]
# Reaction time:  [13.412612161823342]  +/-  [1.1653301793139563]
# Search time:  [255.4024054881664]  +/-  [15.82499006018569]
# Computing...
# /Users/akshay/Documents/TranslationDynamics/src/analysis_utils.py:760: RuntimeWarning: invalid value encountered in double_scalars
#   print('Unweighted search time (', str(i), ' cognate)', np.array(search_vals/p_codon_count_hist_weighted_avg[i]))
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 218
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 559.1070493168892
# Unweighted search time ( 2  cognate) 290.13448789177227
# Unweighted search time ( 3  cognate) 167.24708678667523
# Unweighted search time ( 4  cognate) 141.70068654120288
# Unweighted search time ( 5  cognate) 98.07796327542741
# Unweighted search time ( 6  cognate) 71.56924141728716
# Unweighted search time ( 7  cognate) 64.72757728083309
# Unweighted search time ( 8  cognate) 47.25891491094983
# Unweighted search time ( 9  cognate) 48.97992174600948
# Unweighted search time ( 10  cognate) 48.13863836156065
# Unweighted search time ( 11  cognate) 33.53696664339929
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [37.28437899088406]  +/-  [2.3756795218364313]
# Reaction time:  [5.740395977325158]  +/-  [0.4191801379708523]
# Search time:  [43.0247749682092]  +/-  [2.753910254457903]
# Computing...
# Computing...
# Computing...
# missing expt
# 202
# Computing...
# Computing...
# missing expt
# 462
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 510
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 447
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 95.60580534538302
# Unweighted search time ( 2  cognate) 40.17308435609624
# Unweighted search time ( 3  cognate) 29.43378602768081
# Unweighted search time ( 4  cognate) 19.395689904912597
# Unweighted search time ( 5  cognate) 20.481355203326235
# Unweighted search time ( 6  cognate) 12.81997453532327
# Unweighted search time ( 7  cognate) 11.224427416165911
# Unweighted search time ( 8  cognate) 10.105203332115739
# Unweighted search time ( 9  cognate) 8.60859183897167
# Unweighted search time ( 10  cognate) 5.927947599348187
# Unweighted search time ( 11  cognate) 6.14991527293131
# Unweighted search time ( 12  cognate) 5.6346671785350475
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [34.0684632727773]  +/-  [2.111797449729312]
# Reaction time:  [4.501978088093038]  +/-  [0.2990725706010023]
# Search time:  [38.57044136087035]  +/-  [2.3787032564248802]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 597
# Computing...
# missing expt
# 650
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 433
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 70.68555198102221
# Unweighted search time ( 2  cognate) 36.505177872929835
# Unweighted search time ( 3  cognate) 27.181929745258618
# Unweighted search time ( 4  cognate) 18.62010936677686
# Unweighted search time ( 5  cognate) 13.664369499833583
# Unweighted search time ( 6  cognate) 11.035556063586437
# Unweighted search time ( 7  cognate) 9.58838054114934
# Unweighted search time ( 8  cognate) 7.935902577216773
# Unweighted search time ( 9  cognate) 6.226087804893963
# Unweighted search time ( 10  cognate) 5.909502569455727
# Unweighted search time ( 11  cognate) 5.697633950484349
# Unweighted search time ( 12  cognate) 4.5080954869536
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [27.81282665881571]  +/-  [1.7269297515222368]
# Reaction time:  [3.256522723128216]  +/-  [0.26594248487244115]
# Search time:  [31.06934938194392]  +/-  [1.9644031526644956]

# %%
#309.71956917927196 -> cognum - 10 nr
#292.87333323031953 --> cognum - 2 nr

rxndiff = rxndiff_list[0]
print([rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff])
print([rxndiff[d][0][0] for d in rxndiff])
print([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
# Out:
# [297.7690828218327, 287.0317555046732, 214.16154690692883, 170.798688582851, 157.50219704468827, 135.1109224900536] [15.82499006018569, 18.932319519302787, 11.582631775363398, 8.220618561989044, 7.10059912538712, 5.863884903244429]
# [241.98979332634306, 216.29638404953016, 148.7915624889631, 111.29650086910964, 101.69677914955025, 83.02328180376576]
# [55.779289495489614, 70.73537145514294, 65.36998441796574, 59.502187713741364, 55.805417895138035, 52.08764068628781]

# %%
scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}


transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 597
# Computing...
# missing expt
# 650
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 433
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 211.00146341363575
# Unweighted search time ( 2  cognate) 108.97058438771204
# Unweighted search time ( 3  cognate) 81.14001683109859
# Unweighted search time ( 4  cognate) 55.58236841495304
# Unweighted search time ( 5  cognate) 40.78912479557734
# Unweighted search time ( 6  cognate) 32.941929200122274
# Unweighted search time ( 7  cognate) 28.622005248665197
# Unweighted search time ( 8  cognate) 23.689239725751502
# Unweighted search time ( 9  cognate) 18.585319093136118
# Unweighted search time ( 10  cognate) 17.64028915285567
# Unweighted search time ( 11  cognate) 17.007847019537866
# Unweighted search time ( 12  cognate) 13.45698738548096
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [83.02328180376576]  +/-  [5.155009095424843]
# Reaction time:  [9.72096335262154]  +/-  [0.7938581637983319]
# Search time:  [92.74424515638732]  +/-  [5.863884903244429]

# %%
scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}


transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 209.63402361785987
# Unweighted search time ( 2  cognate) 106.40776770299672
# Unweighted search time ( 3  cognate) 81.34521182396033
# Unweighted search time ( 4  cognate) 56.151941096479284
# Unweighted search time ( 5  cognate) 40.28374669861445
# Unweighted search time ( 6  cognate) 33.44906306039061
# Transport time:  [81.88700519475263]  +/-  [5.101529314434425]
# Reaction time:  [9.678075682546131]  +/-  [0.7938342298020548]
# Search time:  [91.56508087729878]  +/-  [5.811213430547994]

# %%
cogrxn_scaling = 1
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,color='black')
gr3elong = rxndiff['30'][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
#hfont = {'fontname':'Arial'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
#ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')

#for _,rxndiff in enumerate(rxndiff_list[4:6]):


##Plot 1x
rxndiff = rxndiff_list[0]
cogrxn_scaling = 1
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,color='black')
gr3elong = rxndiff['30'][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)
#ax1.plot([phi_list[-1]]*100, np.linspace(gr3elong+0.1*gr3elong, gr3elong-0.05*gr3elong, 100),color='black',linewidth=5)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i_2 = np.polyval(y_model, x_sweep_i)

###Plot 3x (faster kinetics)
rxndiff = rxndiff_list[1]
cogrxn_scaling = 3
#ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff],np.array([rxndiff[d][5][0] for d in rxndiff]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=4,elinewidth=2,mfc='white',color='black')
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i_2 = np.polyval(y_model, x_sweep_i)


ax1.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=30)

### Plot minus-physics event based simulation results for elongation latency
eventbased_elong = np.array([55.141020648144746, 54.92576033577197, 53.695364911027724, 53.695364911027724, 53.31056584258094, 53.88883027781689]  )
eventbased_elong_sem = np.array([0.20995772209584967, 0.21234967588820844, 0.2098744749887588, 0.2098744749887588, 0.20656872508675034, 0.2044934905656416]  ) 
#ax1.errorbar(phi_list,eventbased_elong+(1000/1475+1000/1529+1000/209+1000/200+1000/32),eventbased_elong_sem,marker='^',markersize=12,markeredgewidth=4,zorder=2,linewidth=4,elinewidth=2,mfc='white',color='red')


#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/15,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
ax1.set_ylim(0,320)

cogrxn_scaling = 3
rxndiff = rxndiff_list[1]
#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling,rxndiff['30'][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
#ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
rxndiff = rxndiff_list[0]
cogrxn_scaling = 1
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,color='black')
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[rxndiff[d][0][0] for d in rxndiff],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)

ax2.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')
ax2.set_ylabel('Transport latency (ms)',fontsize=30)
#ax2.set_yticks(np.arange(0, 320, 25))
ax2.set_ylim(0,320)

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
print('\n\nTransport latency SEM: \n', [rxndiff[d][3][0] for d in rxndiff])


### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
rxndiff = rxndiff_list[0]
cogrxn_scaling = 1
ax3.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')
ax3.set_ylabel('Reaction latency (ms)',fontsize=30)
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,color='black')
ax3.set_ylim(0,320)
#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff])
print('\n\nReaction latency SEM: \n',[rxndiff[d][4][0] for d in rxndiff])

experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling,rxndiff['10'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling,rxndiff['30'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling],experimental_vals))



##### Plot Da (Subplot 4) ######

##Plot Damkohler number predicted by our simulation
bmTrans = np.array([rxndiff[d][0][0] for d in rxndiff])
bmRxn = np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff])
bmTransSEM = np.array([rxndiff[d][3][0] for d in rxndiff])
bmRxnSEM = np.array([rxndiff[d][4][0] for d in rxndiff])
bm_Da_var = (bmTrans**2/bmRxn**2)*(bmTransSEM**2/bmTrans**2+bmRxnSEM**2/bmRxn**2)
print(bm_Da_var)
#ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='lightgray')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff]),bm_Da_var,marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='lightgray')
ax4.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')

ax4.set_ylabel('Da',fontsize=30)

## Plot pre-load Da
preload_trans = np.array([33.74284457225605, 30.79535421491456, 28.41837423120376, 28.41837423120376, 29.880803131700848, 30.348156273430067]  )
preload_rxn =  np.array([3.4728765998532096, 7.223193723596804, 7.698872192697686, 7.698872192697686, 7.028604657612665, 5.981192103230661] )
#ax4.scatter(phi_list, preload_trans/(preload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='^',color='#0683b4')
ax4.errorbar(phi_list, preload_trans/(preload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling),0,marker='^',markersize=12,markeredgewidth=5,zorder=2,linewidth=4,elinewidth=2,linestyle='dashed',color='#0683b4')

### Plot pre-sort+pre-load Da
presortpreload_trans=np.array([33.74284457225605,20.687161489577235,11.799669483397304,8.526157833741172, 6.793431015552404,  4.365653617395993 ])
presortpreload_rxn = np.array([3.4728765998532096 ,3.7044491956164287,2.0154935837434715 ,1.4734473402223076,1.197461275409742,0.995607322412692])
#ax4.scatter(phi_list, presortpreload_trans /(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='s',color='#bf7200')
ax4.errorbar(phi_list, presortpreload_trans/(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling),0,marker='s',markersize=12,markeredgewidth=5,zorder=2,linewidth=4,elinewidth=2,linestyle='dashed',color='#bf7200')


#Plot inferred experimental values of Damkohler number (using data from literature)
#ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
#ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number BM-only: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling for d in rxndiff]))
#experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
#print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0]/(rxndiff['06'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling),rxndiff['30'][0][0]/(rxndiff['30'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32))],experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload: \n',preload_trans/(preload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling))
#experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
#print('\tPredicted/Experimental: ',np.divide(np.array( [34.01663109406401, 30.805382022214264])/(np.array([3.537059926602166,  6.120797969362092] )+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload-presort: \n',presortpreload_trans/(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling))
#experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
#print('\tPredicted/Experimental: ',np.divide([presortpreload_trans/(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling)][0],experimental_vals[0]))

##Gap in time
cogrxn_scaling = 1
print('\nGap in time: ',np.array([1000/12,1000/15,1000/18,1000/19,1000/20,1000/21])-(1000/1475+1000/1529+1000/209+1000/200+1000/32)/cogrxn_scaling)

####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=30,color='black',labelpad=15)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)

plt.tight_layout(pad=4.0)
# w/ nr cog [99.68209073058092, 96.08510966284744, 71.67357293796721, 57.14700074609796, 52.692667138759106, 45.19157515983268]
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [99.68209073058092, 96.08510966284744, 71.67357293796721, 57.14700074609796, 52.692667138759106, 45.19157515983268]
# [5.301374969821371, 6.34233276725091, 3.880185799327241, 2.753910254457903, 2.3787032564248802, 1.9644031526644956]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [83.2585613612184, 48.3136725138132]
# 	Predicted/Experimental:  [1.19725935 1.51998436]
#
#
# Transport latencies:
#  [241.98979332634306, 216.29638404953016, 148.7915624889631, 111.29650086910964, 101.69677914955025, 83.02328180376576]
#
#
# Transport latency SEM:
#  [15.02609607042069, 16.78354800954726, 10.03590710312862, 7.091571679799831, 6.303865405961744, 5.155009095424843]
#
#
# Reaction latencies:
#  [55.779289495489614, 70.73537145514294, 65.36998441796574, 59.502187713741364, 55.805417895138035, 52.08764068628781]
#
#
# Reaction latency SEM:
#  [1.1653301793139563, 2.3896904099865064, 1.7394942942704879, 1.2512839939428426, 0.892753942092544, 0.7938581637983319]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [247.5939488636649, 78.6462818652395, 78.6462818652395]
# 	Predicted/Experimental:  [0.22528535 0.89941151 0.66230265]
# [0.08078306 0.06696991 0.02723834 0.01575146 0.01361022 0.01038479]
#
#
# Damkohler number BM-only:
#  [4.33834485 3.05782496 2.27614499 1.87046065 1.82234598 1.59391519]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [247.5939488636649, 78.6462818652395, 78.6462818652395]
#
#
# Damkohler number preload:
#  [0.73610761 0.62100089 0.56762334 0.56762334 0.60493233 0.62770411]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [247.5939488636649, 78.6462818652395, 78.6462818652395]
#
#
# Damkohler number preload-presort:
#  [0.73610761 0.4490266  0.26586508 0.19448297 0.1559409  0.10067859]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [247.5939488636649, 78.6462818652395, 78.6462818652395]
#
# Gap in time:  [40.966656   24.29998933 13.18887822 10.26490161  7.63332267  5.25237029]

# %%
trans_std = np.array([rxndiff[d][3][0] for d in rxndiff])
rxn_std = np.array([rxndiff[d][4][0] for d in rxndiff])
trans_mean = np.array([rxndiff[d][0][0] for d in rxndiff])
rxn_mean = np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
(trans_std**2)/(rxn_std)**2-(trans_mean*rxn_mean)**2
# Out:
# array([-77040162.87010546, -93142106.17532182, -37382949.01491204,
#        -16506994.64600998, -13184403.81670385,  -7476241.68346991])

# %%
rxndiff = rxndiff_list[3]
[rxndiff[d][2][0] for d in rxndiff]
# Out:
# [249.41296517060263,
#  239.41298785910692,
#  167.44396585949244,
#  125.16188585321969,
#  112.51554862109174,
#  90.56978989205734]

# %%
from matplotlib.font_manager import findfont, FontProperties
font = findfont(FontProperties(family=['sans-serif']))
font
# Out:
# '/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %% [markdown]
# ## Plot Kinetic Scaling Data

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff_1=dict()

data = "200511_1738/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=3000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['3000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2104/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=2000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['2000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2155/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=1000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['1000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2229/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=800)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['800'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "200511_2302/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=600)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['600'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "200512_0110/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=400)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['400'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "191003_2210/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['200'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_1452/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['100'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_1716/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=50)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['50'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_2150/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=25)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['25'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 302.0577987498192
# Unweighted search time ( 2  cognate) 210.539111769609
# Unweighted search time ( 3  cognate) 121.95352441679339
# Unweighted search time ( 4  cognate) 92.1461625371936
# Unweighted search time ( 5  cognate) 52.661484553204154
# Unweighted search time ( 6  cognate) 49.34151672014158
# Transport time:  [130.4719558365002]  +/-  [7.994521875954328]
# Reaction time:  [14.214160735727061]  +/-  [1.0724649362589136]
# Search time:  [144.68611657222726]  +/-  [8.928458473397846]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 336.34208545752426
# Unweighted search time ( 2  cognate) 168.6917751225493
# Unweighted search time ( 3  cognate) 98.49776749018133
# Unweighted search time ( 4  cognate) 64.27135420643324
# Unweighted search time ( 5  cognate) 52.87950182267324
# Unweighted search time ( 6  cognate) 37.55814387973275
# Transport time:  [123.75834688692315]  +/-  [8.524099664607576]
# Reaction time:  [14.238031595996457]  +/-  [1.0468017556426537]
# Search time:  [137.99637848291962]  +/-  [9.423774509786218]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 289.80595589076165
# Unweighted search time ( 2  cognate) 116.68883608676987
# Unweighted search time ( 3  cognate) 90.13548072407092
# Unweighted search time ( 4  cognate) 58.565784676914625
# Unweighted search time ( 5  cognate) 50.435911528612245
# Unweighted search time ( 6  cognate) 42.394968985293396
# Transport time:  [103.50032337226371]  +/-  [7.112878731055965]
# Reaction time:  [11.474475856834962]  +/-  [0.8657354712768305]
# Search time:  [114.97479922909868]  +/-  [7.900400301880175]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 269.62464707370947
# Unweighted search time ( 2  cognate) 122.83797898576483
# Unweighted search time ( 3  cognate) 94.10294787045737
# Unweighted search time ( 4  cognate) 56.685481663531654
# Unweighted search time ( 5  cognate) 56.69820342102304
# Unweighted search time ( 6  cognate) 36.295192011355965
# Transport time:  [100.2525295639428]  +/-  [6.547562842044303]
# Reaction time:  [11.709835290363948]  +/-  [0.8109767253006647]
# Search time:  [111.96236485430676]  +/-  [7.2664365414157075]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate)
d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],zorder=2,s=250,color='black')
ax1.errorbar(x,[rxndiff_1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],[rxndiff_1[d][5][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax1.plot(np.linspace(9000, 0, 100),trendpoly(np.linspace(9000, 0, 100)),zorder=1,linewidth=4,color='black')
ax1.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax1.set_ylabel('Elongation latency (ms)',size=25,color='black')
ax1.set_xscale('log')
ax1.set_xticks((100,1000,10000))

ax2.scatter(x,[rxndiff_1[d][0][0] for d in rxndiff_1],zorder=2,s=250,color='black')
ax2.errorbar(x,[rxndiff_1[d][0][0] for d in rxndiff_1],[rxndiff_1[d][3][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][0][0] for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax2.plot(np.linspace(9000, 0, 100),trendpoly(np.linspace(9000, 0, 100)),zorder=1,linewidth=4,color='black')
ax2.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax2.set_ylabel('Transport latency (ms)',size=25,color='black')
ax2.set_xscale('log')
ax2.set_xticks((100,1000,10000))

ax3.scatter(x,[rxndiff_1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],zorder=2,s=250,color='black')
ax3.errorbar(x,[rxndiff_1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],[rxndiff_1[d][4][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],2)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(9000, 0, 100),trendpoly(np.linspace(9000, 0, 100)),zorder=1,linewidth=4,color='black')
ax3.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax3.set_ylabel('Reaction latency (ms)',size=25,color='black')
ax3.set_xscale('log')
ax3.set_xticks((100,1000,10000))

#######################
voxlen = 0.0677
D = 56*0.284
mixTime = []
t1 = 1/717
scalingTime = []
scaling = np.arange(0,9000,1)

for i in scaling:
    scalingTime.append(t1/i*1e3)
    mixTime.append((0.0059)**2/(6*D)*1e3)

ax4.plot(scaling,mixTime,'grey',linewidth=4,linestyle='dashed',color='black')
ax4.plot(scaling,scalingTime,'black',linewidth=4)
ax4.set_yscale('log')
ax4.set_xlabel('Kinetic rate scaling',size=25)
ax4.set_ylabel('Time (ms)',size=25)
ax4.set_xscale('log')
print(scalingTime[925:950])
#######################

for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.tick_params(axis='both', which='major',width=4, labelsize=30)
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout(pad=3.0)
# Out:
# /Users/akshay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in true_divide
# [0.0015077839345621772, 0.001506155658174961, 0.001504530894789659, 0.001502909633049584, 0.0015012918616469472, 0.0014996775693225956, 0.0014980667448657506, 0.0014964593771137488, 0.0014948554549517835, 0.0014932549673126487, 0.0014916579031764854, 0.0014900642515705276, 0.0014884740015688514, 0.0014868871422921257, 0.001485303662907363, 0.0014837235526276745, 0.001482146800712023, 0.0014805733964649828, 0.001479003329236494, 0.0014774365884216247, 0.0014758731634603322, 0.001474313043837224, 0.001472756219081324, 0.0014712026787658374, 0.0014696524125079177]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

rxndiff_1=dict()

#scaleArr = [1,2,4,8,16,32]
scaleArr = np.logspace(0,5,40)/200

for _,scale in enumerate(scaleArr):
    data = "191003_2210/"
    gr_sim = dict()
    NR_scaledrates = {'k1r':718*scale,'k2f':1475*scale,'k2r_nr':1120*scale,'k3_nr':6*scale,'k4':209*scale}
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,ribosomeNum=7,scaling=200/scale, NR_scaling = NR_scaledrates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}
    rxndiff_1[scale] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 42200.27420791001
# Unweighted search time ( 2  cognate) 21794.107270766133
# Unweighted search time ( 3  cognate) 16227.996152292977
# Unweighted search time ( 4  cognate) 11116.468910651132
# Unweighted search time ( 5  cognate) 8645.219022801679
# Unweighted search time ( 6  cognate) 6924.044152787747
# Transport time:  [16563.788992998092]  +/-  [1031.163649208703]
# Reaction time:  [1935.615136509226]  +/-  [158.76684596041093]
# Search time:  [18499.40412950732]  +/-  [1172.9292118980616]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 31413.052854620095
# Unweighted search time ( 2  cognate) 16223.10414966606
# Unweighted search time ( 3  cognate) 12079.800675013968
# Unweighted search time ( 4  cognate) 8274.880483512534
# Unweighted search time ( 5  cognate) 6435.330746094386
# Unweighted search time ( 6  cognate) 5154.122076600851
# Transport time:  [12329.758252120055]  +/-  [767.5779085686962]
# Reaction time:  [1440.8337785642955]  +/-  [118.18291263645736]
# Search time:  [13770.592030684353]  +/-  [873.1054008430642]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 23383.257773196856
# Unweighted search time ( 2  cognate) 12076.15916769813
# Unweighted search time ( 3  cognate) 8991.965675681316
# Unweighted search time ( 4  cognate) 6159.65803387699
# Unweighted search time ( 5  cognate) 4790.3334447840525
# Unweighted search time ( 6  cognate) 3836.6269482067787
# Transport time:  [9178.029173405237]  +/-  [571.3698755260702]
# Reaction time:  [1072.5282822471718]  +/-  [87.97303211981225]
# Search time:  [10250.557455652412]  +/-  [649.9224620254847]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 17406.036490907667
# Unweighted search time ( 2  cognate) 8989.25501244194
# Unweighted search time ( 3  cognate) 6693.442128435677
# Unweighted search time ( 4  cognate) 4585.128109447522
# Unweighted search time ( 5  cognate) 3565.8298579555776
# Unweighted search time ( 6  cognate) 2855.909527538359
# Transport time:  [6831.944132096204]  +/-  [425.3164807673818]
# Reaction time:  [798.3689259189156]  +/-  [65.4853921578346]
# Search time:  [7630.313058015122]  +/-  [483.7894787778181]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate)

# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 1.0232224553016414
# Unweighted search time ( 2  cognate) 0.5284381268290937
# Unweighted search time ( 3  cognate) 0.3934778528551534
# Unweighted search time ( 4  cognate) 0.26953854740347555
# Unweighted search time ( 5  cognate) 0.20961913873061894
# Unweighted search time ( 6  cognate) 0.16788552926467487
# Transport time:  [0.4016235574164459]  +/-  [0.02500273398382183]
# Reaction time:  [0.046928253781562485]  +/-  [0.0038492418760297763]
# Search time:  [0.44855181119800835]  +/-  [0.028439794539224857]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 0.7616903708925339
# Unweighted search time ( 2  cognate) 0.39337127218755163
# Unweighted search time ( 3  cognate) 0.292906429114197
# Unweighted search time ( 4  cognate) 0.20064531530569318
# Unweighted search time ( 5  cognate) 0.1560412368418955
# Unweighted search time ( 6  cognate) 0.12497444079556867
# Transport time:  [0.29897109031226865]  +/-  [0.018612197821452653]
# Reaction time:  [0.03493246769058351]  +/-  [0.0028652998275525057]
# Search time:  [0.3339035580028522]  +/-  [0.021170680123433566]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 0.5670110390938813
# Unweighted search time ( 2  cognate) 0.29283016623043684
# Unweighted search time ( 3  cognate) 0.2180430424052021
# Unweighted search time ( 4  cognate) 0.14936255043748076
# Unweighted search time ( 5  cognate) 0.11615890208959692
# Unweighted search time ( 6  cognate) 0.09303227183074415
# Transport time:  [0.22255861591748863]  +/-  [0.013855208588412543]
# Reaction time:  [0.026003040825548256]  +/-  [0.0021328727490204868]
# Search time:  [0.2485616567430369]  +/-  [0.015759694545081637]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 0.4220955794278181
# Unweighted search time ( 2  cognate) 0.21798934748251422
# Unweighted search time ( 3  cognate) 0.1623162120485379
# Unweighted search time ( 4  cognate) 0.11118867047209306
# Unweighted search time ( 5  cognate) 0.08647127772912973
# Unweighted search time ( 6  cognate) 0.06925515047172874
# Transport time:  [0.1656786752025007]  +/-  [0.010314199511244331]
# Reaction time:  [0.01935615136509226]  +/-  [0.0015876684596041097]
# Search time:  [0.18503482656759299]  +/-  [0.011731863470932833]

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(1,1,figsize=(4,4))
arr = np.array([rxndiff_1[scale][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)/scale for scale in rxndiff_1])
print(arr)
ax1.scatter(scaleArr,arr,zorder=2,s=0,color='blue')
ax1.errorbar(scaleArr,arr,[rxndiff_1[d][5][0] for d in rxndiff_1][0:40],zorder=1,linewidth=2,elinewidth=2,color='blue')

for _,axes in enumerate([ax1]):
    #Plot experimental measurements of elongation latency from literature
    axes.plot(np.linspace(0, 100,1000),[1000/21]*1000,markevery=199,linewidth=2,alpha=0.3,color='green')
    axes.plot([1]*1000,np.linspace(0,20001,1000),linestyle='--',color='blue')
    
    axes.spines['left'].set_linewidth(2)
    axes.spines['bottom'].set_linewidth(2)
    axes.spines['top'].set_linewidth(2)
    axes.spines['right'].set_linewidth(2)
    #axes.set_ylim(0,150)
   # axes.set_xlim(0,33)
    axes.tick_params(which='major',length=6,direction='in')
    axes.tick_params(which='minor',length=4,direction='in')
    axes.tick_params(axis='both', which='major', labelsize=12)
    axes.tick_params(axis='both', which='minor', labelsize=8)
    axes.set_xlabel('Kinetic rate scaling',size=18,color='black')
    axes.set_ylabel('Elongation latency (ms)',fontsize=18)
    axes.set_yscale('log')
    axes.set_xscale('log')

    axes.set_ylim(0,20001)
    axes.set_xlim(0.01,100)
#[142.90817693  88.50768914  65.90387683  53.0390105   48.42274577]
#[134.64866017  88.50768914  65.43720363  53.90196088  48.1343395 ]
#[134.64866017  56.98404288  25.90696494  12.30723364   5.9920699 2.95566352]
#3.0: [134.25614973  67.43188967  33.71596523  16.85800301   8.4290219
# 4.21453134]
#1.5: [200.51288728 100.25649249  50.1282951   25.0641964   12.53214705
#   6.26612238]
# Out:
# [2.69727396e+04 2.00779760e+04 1.49456499e+04 1.11252474e+04
#  8.28141499e+03 6.16452220e+03 4.58874890e+03 3.41577430e+03
#  2.54263511e+03 1.89268750e+03 1.40887930e+03 1.04874201e+03
#  7.80662905e+02 5.81110099e+02 4.32566921e+02 3.21994305e+02
#  2.39686228e+02 1.78417717e+02 1.32810645e+02 9.88616381e+01
#  7.35906664e+01 5.47794528e+01 4.07767560e+01 3.03534244e+01
#  2.25945016e+01 1.68189123e+01 1.25196775e+01 9.31941170e+00
#  6.93719692e+00 5.16392316e+00 3.84393310e+00 2.86135851e+00
#  2.12994933e+00 1.58550275e+00 1.18022744e+00 8.78548484e-01
#  6.53984611e-01 4.86823688e-01 3.62392389e-01 2.69768181e-01]
# /Users/akshay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.

# %% [markdown]
# ## Plot MSD

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "190927_0408/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'
time = 6.21607E-07


plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+'190930_1418/',0,20,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

#for i in range(len(slopes)):
#    plt.text(0.3,-0.3,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
#    plt.text(0.32,-0.38-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
#    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
#print(diff_list)

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn',size=30,pad=20)
# Out:
# [55.134, 34.82, 25.175, 20.8, 17.342, 16.581, 15.932]
# Text(0.5, 1.0, 'Smoldyn')

# %%
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "20200511_LAMMPS_MSD/" 
slopes = list()

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

length = 0.0059**2
time = 6.21607E-07
res_steps=1

df_outputs = pd.read_csv(path+data+"MSD_dil.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_06_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_10_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='purple',label="gr=1.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_15_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='blue',label="gr=1.5",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_20_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='red',label="gr=2.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_25_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='brown',label="gr=2.5",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_trans_30_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='orange',label="gr=3.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])


leg = ax.legend(fontsize=15)

ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+'0.0',color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('LAMMPS',size=30,pad=20)
#32.7 and 15
#31.6
# Out:
# [55.998, 32.721, 25.06, 19.769, 17.368, 15.415, 14.977]
# Text(0.5, 1.0, 'LAMMPS')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "200523_2242/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+'190930_1418/',0,20,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])

ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn (no crowders)',size=30,pad=20)
# Out:
# [55.134, 51.426, 47.636, 40.991, 38.963, 34.479, 31.233]
# Text(0.5, 1.0, 'Smoldyn (no crowders)')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "200524_1247/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=1
k=0
start=0
end=-1
species = 'tRNA'

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['green','purple','blue','red','brown','orange']

#MSD_vals=MSD(path+'190930_1418/',0,20,species)
#ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
#slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
#slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)
ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn (No overlap resolution)',size=30,pad=20)
# Out:
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# [31.931, 25.412, 21.14, 19.246, 18.604, 17.75]
# Text(0.5, 1.0, 'Smoldyn (No overlap resolution)')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "190927_0408/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'crowder'
time = 6.21607E-07


plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+'190930_1418/',0,20,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

#for i in range(len(slopes)):
#    plt.text(0.3,-0.3,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
#    plt.text(0.32,-0.38-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
#    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
#print(diff_list)

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.35)
ax.set_title('Smoldyn',size=30,pad=20)
# Out:
# [166.241, 135.933, 122.0, 109.601, 98.978, 94.237, 91.399]
# Text(0.5, 1.0, 'Smoldyn')

# %%
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "20200511_LAMMPS_MSD/2/" 
slopes = list()

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

length = 0.0059**2
time = 6.21607E-07
res_steps=1

df_outputs = pd.read_csv(path+data+"MSD_dil.csv",header=None)
ax.plot(df_outputs[0]*time,np.array(df_outputs[2]*length)*2.95,color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],(df_outputs[2]*length)*2.95,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_dr_06_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[3]*length,color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[3]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_dr_10_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[3]*length,color='purple',label="gr=1.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[3]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_dr_15_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[3]*length,color='blue',label="gr=1.5",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[3]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_dr_20_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[3]*length,color='red',label="gr=2.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[3]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_dr_25_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[3]*length,color='brown',label="gr=2.5",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[3]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_trans_30_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[3]*length,color='orange',label="gr=3.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[3]*length,rcond=None)[0][0])


leg = ax.legend(fontsize=15)

ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+'0.0',color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
#ax.set_xlim(0,1500)
ax.set_xlim(0,500*time)
ax.set_ylim(0,1)
ax.set_title('LAMMPS',size=30,pad=20)
#131.2 vs 138.5
# Out:
# [165.194, 131.642, 114.183, 100.095, 90.017, 83.94, 80.097]
# Text(0.5, 1.0, 'LAMMPS')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "190927_0408/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'
time = 6.21607E-07


plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+data,10,11,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))


leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

#for i in range(len(slopes)):
#    plt.text(0.3,-0.3,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
#    plt.text(0.32,-0.38-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
#    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
#print(diff_list)

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn',size=30,pad=20)
# Out:
# 1
# [array([   0.        ,    1.52077458,    3.18775169,    4.28946365,
#           6.21869547,    7.46065589,    8.51074748,    9.067014  ,
#          10.85430934,   13.91432985,   16.83875201,   19.29095797,
#          21.46166013,   23.11477218,   24.16727249,   26.9471307 ,
#          27.48973748,   30.16946118,   33.49906636,   37.34902353,
#          39.08595483,   42.105086  ,   45.12314233,   44.943937  ,
#          46.09976378,   46.7536148 ,   51.47065336,   54.40741193,
#          56.78718604,   55.34540474,   57.72126073,   61.75692275,
#          62.06582663,   60.91453237,   60.73289544,   61.80025683,
#          63.26524201,   63.15313412,   63.50089496,   63.6007494 ,
#          63.16190779,   62.85950077,   64.44522258,   67.07677506,
#          65.94010859,   68.8144083 ,   71.15151474,   68.73812784,
#          69.16854655,   68.46747285,   73.16850588,   70.76961797,
#          68.2719626 ,   71.31657335,   74.04612283,   76.22479154,
#          78.21467287,   78.82772348,   78.60678962,   84.4745948 ,
#          85.48023241,   87.84438476,   89.27852112,   89.34063142,
#          88.6528211 ,   93.5561419 ,   91.63638681,   94.31108156,
#          95.75089892,   98.73570559,   99.58624472,  102.95882256,
#         104.32068335,  104.33788623,  108.04274192,  109.45818971,
#         110.59601143,  112.99728451,  112.58911049,  115.6707904 ,
#         117.65715295,  114.93147675,  117.37763553,  120.7712209 ,
#         118.75179191,  122.50125968,  125.86878657,  125.9737927 ,
#         125.68132942,  128.81332863,  128.71777028,  134.01617565,
#         139.18681067,  138.84078883,  136.38731033,  142.46662868,
#         144.38898436,  145.23762267,  145.160106  ,  144.99309869,
#         148.09402407,  153.38965439,  155.95891559,  159.15566064,
#         161.96129971,  161.55971728,  164.46201092,  163.65292852,
#         166.82619236,  167.99205737,  168.75236277,  167.57610593,
#         170.16433284,  167.76766852,  174.41476507,  168.33276114,
#  1241.97778797 1234.75242435 1229.48748686 1237.37157573 1236.18670071
#  1233.96769152 1228.61932309 1228.12720283 1233.50874071 1235.66923644
#  1224.21886831 1224.52259702 1230.41206875 1233.64941776 1232.51780363
#  1229.81259528 1229.5192239  1226.32278945 1233.58022877 1245.33304736
#  1239.3205677  1249.85391383 1247.9142328  1246.24306354 1235.14402434
#  1233.12198254 1244.93052183 1264.39264445 1265.2911727  1252.98708795
#  1256.18308786 1257.58759165 1257.29619691 1263.507846   1273.94934952
#  1277.75950195 1284.72055064 1290.34354979 1308.49680847 1308.15656735
#  1316.99268424 1327.60059086 1311.99266573 1310.92379637 1299.57001155
#  1294.49549953 1294.99700275 1276.15288653 1273.4685094  1271.68585408
#  1275.95708636 1288.20481093 1297.86600009 1293.33432555 1277.31257064
#  1287.36148543 1288.78060636 1274.62347506 1262.30447072 1261.81352345
#  1269.06128477 1271.20648831 1279.78760919 1297.6197034  1300.54275967
#  1302.12511143 1293.00931681 1310.87762544 1300.89021767 1295.46094443
#  1289.78902716 1300.38548559 1306.74214669 1323.60345713]
# [26.327]
# Text(0.5, 1.0, 'Smoldyn')

# %%
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c7247d4dfe1d> in <module>
#       3 data = "191003_2210/"
#       4 for i in range(1,7):
# ----> 5     sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
#       6     gr_sim[i] = (CellLatencies(sim_i))
#       7
#
# NameError: name 'scalingFactor' is not defined

# %%
 #Growth rate = 3.0; 
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()


ribs=[4,8,9,9,8,7]
scalingFactorList = [25,50,100,200,400,800,1600]
scalingFactor=200
rxndiff_list = list()


#1x

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 48.6571524029898 0.23362734586466136
# Unweighted search time ( 2  cognate) 21.206488798512847 0.19695715750267984
# Unweighted search time ( 3  cognate) 11.678742662778603 0.146900067572797
# Unweighted search time ( 4  cognate) 5.046604320128014 0.09578870475411874
# Unweighted search time ( 5  cognate) 2.169274338692015 0.05331496040276733
# Unweighted search time ( 6  cognate) 0.8599596257820293 0.02585404944063069
# Unweighted search time ( 7  cognate) 0.2880690774376749 0.010123204398825995
# Unweighted search time ( 8  cognate) 0.07856625067090639 0.003404129087178109
# Unweighted search time ( 9  cognate) 0.021057630082689644 0.0012152766804081382
# Unweighted search time ( 10  cognate) 0.006250997313716871 0.00035432345897279453
# Unweighted search time ( 11  cognate) 0.001313012709885851 7.62609602032902e-05
# Unweighted search time ( 12  cognate) 0.0 0.0
# Unweighted search time ( 13  cognate) 0.0 0.0
# Unweighted search time ( 14  cognate) 0.0 0.0
# Unweighted search time ( 15  cognate) 0.0 0.0
# Transport time:  [80.42959440644235]  +/-  [5.0034308463082535]
# Reaction time:  [9.58388471065582]  +/-  [0.7826025342221099]
# Search time:  [90.01347911709819]  +/-  [5.701694527757469]
