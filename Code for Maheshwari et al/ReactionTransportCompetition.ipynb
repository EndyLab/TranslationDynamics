# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

crowder_repeatreaction = list()
crowder_repeatreaction_stderr = list()
nocrowder_repeatreaction = list()
nocrowder_repeatreaction_stderr = list()

##### Measurements made from translation voxels with a single cognate ternary complex

##########

data = "191003_2140/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])

data = "191004_0018/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])


data = "191004_0104/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])

data = "191004_1129/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])


data = "191004_1217/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])


data = "191003_2210/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])




###No crowder.

data = "191009_1223/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])


data = "191009_1256/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])


data = "191009_1333/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])

data = "191009_1410/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])

data = "191009_1447/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])

data = "191007_1601/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])
# Out:
# (9.808988764044944, 0.8040695391832502)
# (5.773139745916516, 0.28012679187989353)
# (4.17339312406577, 0.18255878150007618)
# (2.920656634746922, 0.12601106631062414)
# (2.1863270777479893, 0.0926340578439691)
# (1.8375, 0.09977313423898326)
# (4.793706293706293, 0.31819691743379347)
# (3.1376404494382024, 0.13677663490607622)
# (1.998792270531401, 0.08910697389005746)
# missing expt
# 65
# (1.248968363136176, 0.060060748451209026)
# missing expt
# 90
# (0.9463350785340314, 0.053086410893688415)
# missing expt
# 85
# (0.7840909090909091, 0.0470400417034676)

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = '/Users/Akshay/Documents/TranslationDynamics/data/'
data = '191010_1846' #'200708_1100'

gr=[3.0] #0.6,1.0,1.5,2.0,2.5,3.0]# doubling rate
vox =[0.0677*1/0.0059] #0.101*1/0.0059,0.0929*1/0.0059,0.0842*1/0.0059,0.0774*1/0.0059,0.072*1/0.0059,0.0677*1/0.0059] 
expnum = 100

max_dist = []
for i in range(len(vox)):
     max_dist.append(vox[i]/2)
print('max_dist, ', max_dist)

dist = {}
distancesAvg = []
distancesStd = []
for i in range(0,len(gr)):
    print('gr:', gr[i])
    dist[gr[i]] = calcPairDistances(path+data+'/',expnum*5,expnum*(5+1),3,11, max_dist[i]) #experiment number hardcoded & species hardcoded (3,11) for tRNA-rib (closest ribosome to tRNA, averaged across all tRNA); 11-11 for rib-rib; 4-4 crowder-corwder
    distancesAvg.append(np.average(dist[gr[i]]))
    distancesStd.append(np.std(dist[gr[i]])/np.sqrt((len(dist[gr[i]]))-1))
distancesAvg = np.array(distancesAvg)
distancesStd=np.array(distancesStd)
print('Average distances: ', distancesAvg)
print('Standard deviations: ', distancesStd)
print((distancesAvg-(0.339*2))*5.9)
ribosome_crowder = [ 0.06220219, -0.02384976, -0.09152914, -0.18000547, -0.19814492, -0.20797733]
crowder_ribosome = [19.26130005, 10.88150617,  7.93337979,  6.3722814,   5.66859135,  5.28247547]

tRNA_crowder = 1.35481843
crowder_crowder = 0.6
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# max_dist,  [5.737288135593221]
# gr: 3.0
# Error on expt  561
# Error on expt  563
# Error on expt  566
# Error on expt  567
# Error on expt  568
# Error on expt  569
# Error on expt  570
# Error on expt  573
# Error on expt  575
# Error on expt  577
# Error on expt  578
# Error on expt  580
# Error on expt  583
# Error on expt  584
# Error on expt  585
# Error on expt  587
# Error on expt  589
# Error on expt  592
# Error on expt  594
# Error on expt  595
# Error on expt  596
# Error on expt  597
# Error on expt  598
# Average distances:  [3.72174977]
# Standard deviations:  [0.00945468]
# [17.95812364]

# %%
((-3.31718295/5.9+1.339)-(0.339*2))*5.9
# Out:
# 0.5827170499999998

# %%
ribosome_singletimestep_motion = np.sqrt(6*56*0.454545*(6.21607E-07*1e-4))*1000
tRNA_singletimestep_motion = np.sqrt(6*56*(6.21607E-07*1e-4))*1000
crowder_singletimestep_motion = np.sqrt((6*56*5.9/2*(6.21607E-07*1e-4)))*1000
print(ribosome_singletimestep_motion,tRNA_singletimestep_motion,crowder_singletimestep_motion, ' nanometers')
# Out:
# 0.0974352332997874 0.14451987821749643 0.24822104229899608  nanometers

# %%
from analysis_utils import *
import matplotlib.pyplot as pltn
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload
fig, ax = plt.subplots(1,1,figsize=(11,9.8))
ax2 = ax.twinx()
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])

norm_nearesttRNARib_edgeedge=(distancesAvg-3.2)*5.9
print(norm_nearesttRNARib_edgeedge)
norm_nearesttRNARib_edgeedge_std = np.sqrt(distancesStd**2*5.9**2)
ax.errorbar(phi_list,norm_nearesttRNARib_edgeedge, norm_nearesttRNARib_edgeedge_std,marker='s',markersize=14,markeredgewidth=5,linewidth=5,color='black')
ax.set_ylabel('Nearest ribosome (nm)$\:\u25A0} $',size=40,color='black',labelpad=20)
ax.tick_params(axis='both', which='major',width=4, labelsize=25)
ax2.set_xlim(0.11,0.44)
ax2.set_xticks(np.arange(0.15,0.41, 0.05))
ax.set_ylim(2,17)

ax.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=40,color='black',labelpad=10)

viscosity = np.array([1.39863657335865,1.83806930502154,2.33803169161992,2.76564578636052,3.15041649073887,3.41838735611281
])/1.39863657335865
ax2.tick_params(axis='both', which='major',width=4, labelsize=25)
ax2.set_ylabel('Viscosity ($\eta_{0}/\eta_{0,\mu=0.6}}$) $\: \u25B2$',size=40,color='black',labelpad=20)
ax2.plot(phi_list,viscosity,marker='^',markersize=14,markeredgewidth=5,linewidth=5,color='black')
ax2.set_ylim(0.9,2.55)
ax2.set_yticks(np.arange(1.0,2.6,0.5))

ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(5)
ax.spines['right'].set_linewidth(5)


ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=25)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=40,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)

plt.tight_layout()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-237d44f5ee8f> in <module>
#      12        0.42317604])
#      13
# ---> 14 norm_nearesttRNARib_edgeedge=(distancesAvg-3.2)*5.9
#      15 print(norm_nearesttRNARib_edgeedge)
#      16 norm_nearesttRNARib_edgeedge_std = np.sqrt(distancesStd**2*5.9**2)
#
# NameError: name 'distancesAvg' is not defined

# %%
fig, ax = plt.subplots(1,1,figsize=(11,9.8))
ax2 = ax.twinx()

ax2.plot(phi_list,[4-1,8-1,9-1,9-1,8-1,7-1],marker='^',markersize=14,markeredgewidth=5,linewidth=5,color='black')
ax2.set_ylabel('Mismatching ribosomes $(\#) \\: \u25B2$',size=40,color='black',labelpad=20)
ax2.tick_params(axis='both', which='major',width=4, labelsize=25)
ax2.set_xlim(0.11,0.44)
ax2.set_ylim(2.5,8.5)
ax2.set_xticks(np.arange(0.15,0.41,0.05))


ax.errorbar(phi_list,crowder_repeatreaction,
            crowder_repeatreaction_stderr, marker='s',markersize=14,markeredgewidth=5,linewidth=5,color='black')
ax.set_ylabel('Repeat reactions $(\#)\\: \u25A0 $',size=40,color='black',labelpad=20)
ax.tick_params(axis='both', which='major',width=4, labelsize=25)
ax.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=40,color='black',labelpad=10)



#0.0322, 0.0909, 0.141, 0.175, 0.200, 0.218

ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(5)
ax.spines['right'].set_linewidth(5)

#ax.set_title('Reaction Time Trade-off',size=45,y=1.05)


ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=25)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=40,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)

plt.tight_layout()

# %%
from analysis_utils import *
from itertools import groupby

# %load_ext autoreload
# %reload_ext autoreload

rib_gr = [4,8,9,9,8,7]
repeatreactions_preload = list()
repeatreactions_preload_stderr=list()
for i in rib_gr:
    results = eventbased_sim(1,1,True, bias=1, repeatTracker=True)
    count_repeats = [sum(1 for _ in group) for _, group in groupby(results[-1])]
    repeatreactions_preload.append(np.average(count_repeats)-1)
    repeatreactions_preload_stderr.append(np.std(count_repeats)/np.sqrt(len(count_repeats)-1))
    print(np.average(count_repeats)-1)
    print(repeatreactions_preload_stderr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.0250533240266122
# [0.00016214174018925579]
# 0.0250533240266122
# [0.00016214174018925579, 0.00016214174018925579]
# 0.0250533240266122
# [0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579]
# 0.0250533240266122
# [0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579]
# 0.0250533240266122
# [0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579]
# 0.0250533240266122
# [0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579, 0.00016214174018925579]

# %%
fig, ax = plt.subplots(1,1,figsize=(12,10))

phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])

#phi_list = [0.132,0.224,0.302,0.356,0.395,0.423]
gr_list = [0.6,1.0,1.5,2.0,2.5,3.0]
ax.errorbar(phi_list,np.array(crowder_repeatreaction),np.array(crowder_repeatreaction_stderr),marker='o',markersize=12,markeredgewidth=5,linewidth=5,color='black',label='Crowders')
ax.errorbar(phi_list,repeatreactions_preload,repeatreactions_preload_stderr,marker='^',markersize=12,markeredgewidth=5,linewidth=5,color='red', mfc='white',label='Instantaneous Transport')
ax.errorbar(phi_list,np.array(nocrowder_repeatreaction),np.array(nocrowder_repeatreaction_stderr),marker='x',markersize=12,markeredgewidth=5,linewidth=5,color='#0683b4',label='No Crowders')

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.set_ylim(-0.5,11)
ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(5)
ax.spines['right'].set_linewidth(5)

ax.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=40,color='black',labelpad=10)
#ax.set_xlabel('$\phi_{\mathrm{voxel}}$',size=45,color='black')
ax.set_ylabel('Repeat Reactions $(\#)$',size=40,color='black')
print(np.array(crowder_repeatreaction),np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)-np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)/np.array(nocrowder_repeatreaction))
ax.set_xlim(0.11,0.44)

ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=30)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=40,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)

ax.legend(bbox_to_anchor=(1.02, 1.35), prop={'size': 25},ncol=2)
# Out:
# [9.80898876 5.77313975 4.17339312 2.92065663 2.18632708 1.8375    ] [4.79370629 3.13764045 1.99879227 1.24896836 0.94633508 0.78409091]
# [5.01528247 2.6354993  2.17460085 1.67168827 1.239992   1.05340909]
# [2.04622231 1.83996218 2.08795741 2.33845526 2.31030966 2.34347826]

# %%
fig, ax = plt.subplots(1,1,figsize=(3,2.5))

phi_list = [0.132,0.224,0.302,0.356,0.395,0.423]
#gr_list = [0.6,1.0,1.5,2.0,2.5,3.0]
ax.errorbar(phi_list,repeatreactions_preload,repeatreactions_preload_stderr,marker='^',markersize=6,markeredgewidth=2.5,linewidth=2.5,color='red',mfc='white',label='No physics')

ax.tick_params(axis='both', which='major',width=4, labelsize=15)
ax.set_ylim(0,0.05)
ax.spines['left'].set_linewidth(2.5)
ax.spines['bottom'].set_linewidth(2.5)
ax.spines['top'].set_linewidth(2.5)
ax.spines['right'].set_linewidth(2.5)

print(np.array(crowder_repeatreaction),np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)-np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)/np.array(nocrowder_repeatreaction))
ax.set_xlim(0.11,0.44)
ax.set_xticks(np.arange(0.15,0.41, 0.1))
# Out:
# [9.80898876 5.77313975 4.17339312 2.92065663 2.18632708 1.8375    ] [4.79370629 3.13764045 1.99879227 1.24896836 0.94633508 0.78409091]
# [5.01528247 2.6354993  2.17460085 1.67168827 1.239992   1.05340909]
# [2.04622231 1.83996218 2.08795741 2.33845526 2.31030966 2.34347826]
# ...

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

##### Measurements made from translation voxels with a single cognate ternary complex

##########

###Crowders, gr = 3.0
repeatreactions_overlapcheck = list()
repeatreactions_overlapcheck_err = list()
data = "191003_2210/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

###No crowders, gr = 3.0
data = "191007_1601/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)

###No crowders, gr = 3.0, only 1 overlap resolution step
data = "200524_1328/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)

###Crowders, gr = 3.0, only 1 overlap resolution step
data = "200524_1408/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

###Crowders, gr = 3.0, only 1 overlap resolution step, no small threshold after overlap correction
data = "200525_2126/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)

###Crowders, gr = 3.0, only 1 overlap resolution step, reflection instead of entropic exclusion
data = "200603_1105/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
# Out:
# (1.8375, 0.09977313423898326)
# missing expt
# 85
# (0.7840909090909091, 0.0470400417034676)
# (0.8189300411522634, 0.053397006172789065)
# missing expt
# 94
# (1.3414239482200647, 0.06868689416341653)
# (1.281055900621118, 0.06415090660619556)
# (1.861198738170347, 0.08993182841637899)

# %%
fig,ax = plt.subplots(1,1,figsize=(4,9.3))
errorkw=dict(lw=5, capsize=0, capthick=0)

bars = ax.bar(['+','-'],repeatreactions_overlapcheck,yerr=repeatreactions_overlapcheck_err,color=['grey','grey'],error_kw=errorkw)
bars[0].set_edgecolor("black")
bars[0].set_linewidth(5)
#bars[1].set_hatch('/')
bars[1].set_edgecolor("black")
bars[1].set_linewidth(5)

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

ax.set_xlabel('Overlap resolution',fontsize=40,labelpad=10)
ax.set_ylabel('Repeat Reactions $(\#)$',fontsize=40,labelpad=10)
# Out:
# Text(0, 0.5, 'Repeat Reactions $(\\#)$')

# %%
#ribosome-ribosome distances
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = '/Users/Akshay/Documents/TranslationDynamics/data/'
data = '191010_1846' #'200708_1100'

gr=[0.6,1.0,1.5,2.0,2.5,3.0] #0.6,1.0,1.5,2.0,2.5,3.0]# doubling rate
vox =[0.101*1/0.0059,0.0929*1/0.0059,0.0842*1/0.0059,0.0774*1/0.0059,0.072*1/0.0059,0.0677*1/0.0059] #0.101*1/0.0059,0.0929*1/0.0059,0.0842*1/0.0059,0.0774*1/0.0059,0.072*1/0.0059,0.0677*1/0.0059] 
expnum = 100

max_dist = []
for i in range(len(vox)):
     max_dist.append(vox[i]/2)
print('max_dist, ', max_dist)

dist = {}
distancesAvg = []
distancesStd = []
for i in range(0,len(gr)):
    print('gr:', gr[i])
    dist[gr[i]] = calcPairDistances(path+data+'/',expnum*i,expnum*(i+1),11,11, max_dist[i]) #experiment number hardcoded & species hardcoded (3,11)
    distancesAvg.append(np.average(dist[gr[i]]))
    distancesStd.append(np.std(dist[gr[i]])/np.sqrt((len(dist[gr[i]]))-1))
distancesAvg = np.array(distancesAvg)
distancesStd=np.array(distancesStd)
norm_nearestRibRib_edgeedge=(distancesAvg-4.4)*5.9
norm_nearestRibRib_edgeedge_std = np.sqrt(distancesStd**2*5.9**2)

print('Average distances (surface-to-surface, nm): ', norm_nearestRibRib_edgeedge)
print('Standard deviations: ', norm_nearestRibRib_edgeedge_std)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# max_dist,  [8.559322033898306, 7.872881355932203, 7.135593220338983, 6.559322033898305, 6.101694915254237, 5.737288135593221]
# gr: 0.6
# gr: 1.0
# gr: 1.5
# gr: 2.0
# gr: 2.5
# gr: 3.0
# Error on expt  561
# Error on expt  563
# Error on expt  566
# Error on expt  567
# Error on expt  568
# Error on expt  569
# Error on expt  570
# Error on expt  573
# Error on expt  575
# Error on expt  577
# Error on expt  578
# Error on expt  580
# Error on expt  583
# Error on expt  584
# Error on expt  585
# Error on expt  587
# Error on expt  589
# Error on expt  592
# Error on expt  594
# Error on expt  595
# Error on expt  596
# Error on expt  597
# Error on expt  598
# Average distances (surface-to-surface, nm):  [13.44098544  5.44730399  2.80339397  1.22261102  0.55304215  0.99469526]
# Standard deviations:  [0.43583021 0.18302549 0.11074029 0.08708292 0.0867991  0.07730504]

# %%
# Out:
# 0.0
