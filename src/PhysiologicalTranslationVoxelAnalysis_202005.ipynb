# %% [markdown]
# ## Calculate cognate ternary complex distribution for a given tRNA and codon distribution (i.e., at a given growth rate)

# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]

rxndiff=dict()

#p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

# %%
#Growth rate = 0.6
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1738/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1817/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1934/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)

search_list = transportRxnResults[0]
rxndiff['06'] = transportRxnResults[1:]


#Growth rate = 1.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_0018/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2012/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2115/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_2238/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon)

search_list = transportRxnResults[0]
rxndiff['10'] = transportRxnResults[1:]

#Growth rate = 1.5
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_0104/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_0916/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1041/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1206/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

search_list = transportRxnResults[0]
rxndiff['15'] = transportRxnResults[1:]

#Growth rate = 2.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_1129/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1348/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1428/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1506/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

search_list = transportRxnResults[0]
rxndiff['20'] = transportRxnResults[1:]

#Growth rate = 2.5
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_1217/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1556/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1714/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1757/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['25'] = transportRxnResults[1:]

#Growth rate = 3.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}


transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 20
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 545
# Computing...
# Computing...
# Computing...
# missing expt
# 804
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.6950635850616
# Unweighted search time ( 2  cognate) 172.8331350778929
# Unweighted search time ( 3  cognate) 120.30314389849795
# Unweighted search time ( 4  cognate) 95.84486115037801
# Unweighted search time ( 5  cognate) 90.00181629104335
# Unweighted search time ( 6  cognate) 68.66961539258227
# Unweighted search time ( 7  cognate) 51.082634440085805
# Unweighted search time ( 8  cognate) 52.0401348919299
# Unweighted search time ( 9  cognate) 31.30225674888329
# Unweighted search time ( 10  cognate) nan
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [149.01773147919138]  +/-  [8.064947626930309]
# Reaction time:  [12.434688944094166]  +/-  [1.059480835916528]
# Search time:  [161.45242042328553]  +/-  [8.811664976416418]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 218
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 389.29162033299633
# Unweighted search time ( 2  cognate) 195.26409530851538
# Unweighted search time ( 3  cognate) 115.34566994307103
# Unweighted search time ( 4  cognate) 99.51536542228068
# Unweighted search time ( 5  cognate) 68.9457861981281
# Unweighted search time ( 6  cognate) 51.8572232535522
# Unweighted search time ( 7  cognate) 42.36324950612762
# Unweighted search time ( 8  cognate) 34.93646336215733
# Unweighted search time ( 9  cognate) 31.488883741736444
# Unweighted search time ( 10  cognate) 33.00739226279752
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [138.80495672015704]  +/-  [10.662928887887867]
# Reaction time:  [27.990019258329617]  +/-  [2.3641643164091435]
# Search time:  [166.79497597848663]  +/-  [12.823001706445188]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 29
# missing expt
# 35
# missing expt
# 67
# missing expt
# 77
# Computing...
# missing expt
# 128
# missing expt
# 193
# Computing...
# Computing...
# missing expt
# 308
# Computing...
# Computing...
# missing expt
# 590
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 271.474693309938
# Unweighted search time ( 2  cognate) 145.60632549023543
# Unweighted search time ( 3  cognate) 106.52609173286244
# Unweighted search time ( 4  cognate) 53.94149452496741
# Unweighted search time ( 5  cognate) 56.31490189964474
# Unweighted search time ( 6  cognate) 42.99186461828626
# Unweighted search time ( 7  cognate) 36.28613022163495
# Unweighted search time ( 8  cognate) 22.83701652752771
# Unweighted search time ( 9  cognate) 26.817579616195165
# Unweighted search time ( 10  cognate) 25.316357862972335
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [95.1480615499187]  +/-  [6.504062026913687]
# Reaction time:  [22.605364803183786]  +/-  [1.7088636588852473]
# Search time:  [117.7534263531025]  +/-  [8.03461484965252]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 327
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 200.2249530232702
# Unweighted search time ( 2  cognate) 108.36198572461856
# Unweighted search time ( 3  cognate) 64.79356745270022
# Unweighted search time ( 4  cognate) 56.21415298033057
# Unweighted search time ( 5  cognate) 35.70904091917134
# Unweighted search time ( 6  cognate) 32.117417490905076
# Unweighted search time ( 7  cognate) 27.076662289821474
# Unweighted search time ( 8  cognate) 26.64127795783609
# Unweighted search time ( 9  cognate) 17.740805025167063
# Unweighted search time ( 10  cognate) 13.493403162365626
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) 14.274962433395446
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [69.83139219547633]  +/-  [4.336025843328736]
# Reaction time:  [16.917707181168957]  +/-  [1.2365995156018983]
# Search time:  [86.74909937664528]  +/-  [5.4740280581988]
# Computing...
# Computing...
# Computing...
# missing expt
# 202
# Computing...
# Computing...
# missing expt
# 462
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 510
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 447
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 200.1169937894533
# Unweighted search time ( 2  cognate) 84.02792722842413
# Unweighted search time ( 3  cognate) 61.07896381228009
# Unweighted search time ( 4  cognate) 40.48318424533152
# Unweighted search time ( 5  cognate) 40.73540242572679
# Unweighted search time ( 6  cognate) 26.343668227923853
# Unweighted search time ( 7  cognate) 23.692638573720732
# Unweighted search time ( 8  cognate) 20.72395640321115
# Unweighted search time ( 9  cognate) 16.560329391048032
# Unweighted search time ( 10  cognate) 13.230331478053984
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [65.87566807077555]  +/-  [3.9841959958281317]
# Reaction time:  [13.204170788954157]  +/-  [0.875804023930366]
# Search time:  [79.0798388597297]  +/-  [4.771341335213066]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 597
# Computing...
# missing expt
# 650
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 433
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 145.7835388506996
# Unweighted search time ( 2  cognate) 73.66729336133365
# Unweighted search time ( 3  cognate) 57.14791895679198
# Unweighted search time ( 4  cognate) 36.894644278725536
# Unweighted search time ( 5  cognate) 28.287419667432513
# Unweighted search time ( 6  cognate) 23.846215413415507
# Unweighted search time ( 7  cognate) 21.179634435796125
# Unweighted search time ( 8  cognate) 16.141486737862376
# Unweighted search time ( 9  cognate) 12.15933004051406
# Unweighted search time ( 10  cognate) 13.980471834927602
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [53.36737433223895]  +/-  [3.1983694012431445]
# Reaction time:  [9.610074938867754]  +/-  [0.7933618671300685]
# Search time:  [62.97744927110671]  +/-  [3.91029320830014]

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=30)

#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/15,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
ax2.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax2.set_ylabel('Transport latency (ms)',fontsize=30)
ax2.set_yticks(np.arange(0, 226, 25))

#Plot inferred experimental values of transport latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
exptl_trans = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
experimental_vals = [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of transport latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))



### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
ax3.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax3.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax3.set_ylabel('Reaction latency (ms)',fontsize=30)

#Plot inferred experimental values of reaction latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/1529+1000/209+1000/200+1000/32]*len(phi_list),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax3.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax3.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
exptl_rxn = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



##### Plot Da (Subplot 4) ######

##Plot Damkohler number predicted by our simulation
ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='lightgray')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='lightgray')
ax4.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax4.set_ylabel('Da',fontsize=30)

## Plot pre-load, pre-load+pre-sort results
ax4.scatter(phi_list, np.array( [34.01663109406401, 30.41369509254369, 29.154101488155067, 28.491437978874004, 28.409508968849106, 30.805382022214264] 
)/(np.array([3.537059926602166, 7.085786360511388, 7.812818601943163, 7.686728426387252, 6.542742485140954, 6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='^',color='#0683b4')
ax4.errorbar(phi_list, np.array( [34.01663109406401, 30.41369509254369, 29.154101488155067, 28.491437978874004, 28.409508968849106, 30.805382022214264] 
)/(np.array([3.537059926602166, 7.085786360511388, 7.812818601943163, 7.686728426387252, 6.542742485140954, 6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='#0683b4')


presorttrans=np.array([34.01663109406401,20.007025364980883,11.68166201748362,8.274169505141892, 7.074660404155837,  4.926203750197745])
presortrxn = np.array([3.537059926602166,3.5651502846900125,2.0426277448724632,1.4374991110185171,1.2407775100632652,1.025038678927513])
ax4.scatter(phi_list, presorttrans /(presortrxn+(1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='s',color='#bf7200')
ax4.errorbar(phi_list, presorttrans/(presortrxn+(1000/1529+1000/209+1000/200+1000/32)),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='#bf7200')

#naivetrans= np.array([0.08]*6)
#naiverxn = np.array([42]*6)
#ax4.scatter(phi_list,naivetrans/naiverxn,zorder=2,s=250,marker='o',color='black')
#ax4.errorbar(phi_list,naivetrans/naiverxn,0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')


#Plot inferred experimental values of Damkohler number (using data from literature)
ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number BM-only: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0]/(rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32)),rxndiff['30'][0][0]/(rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32))],experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload: \n',np.array( [34.01663109406401, 30.41369509254369, 29.154101488155067, 28.491437978874004, 28.409508968849106, 30.805382022214264] 
)/(np.array([3.537059926602166, 7.085786360511388, 7.812818601943163, 7.686728426387252, 6.542742485140954, 6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide(np.array( [34.01663109406401, 30.805382022214264] 
)/(np.array([3.537059926602166,  6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)),experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload-presort: \n',presorttrans/(presortrxn+(1000/1529+1000/209+1000/200+1000/32)))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([presorttrans/(presortrxn+(1000/1529+1000/209+1000/200+1000/32))][0],experimental_vals[0]))


####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Growth rate (dbl/hr)',size=30,color='black',labelpad=20)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)


plt.tight_layout(pad=4.0)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [203.14113165525688, 208.483687210458, 159.44213758507385, 128.43781060861664, 120.76855009170106, 104.66616050307806]
# [8.811664976416418, 12.823001706445188, 8.03461484965252, 5.4740280581988, 4.771341335213066, 3.91029320830014]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [83.2585613612184, 48.3136725138132]
# 	Predicted/Experimental:  [2.4398828 2.166388 ]
#
#
# Transport latencies:
#  [149.01773147919138, 138.80495672015704, 95.1480615499187, 69.83139219547633, 65.87566807077555, 53.36737433223895]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of transport latency [40.756741883632365, 7.382133422833235]
# 	Predicted/Experimental:  [3.65627193 7.22926169]
#
#
# Reaction latencies:
#  [54.12340017606553, 69.67873049030098, 64.29407603515514, 58.60641841314032, 54.89288202092552, 51.298786170839115]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [41.688711231971354, 41.68871123197134, 41.68871123197134]
# 	Predicted/Experimental:  [1.29827473 1.67140524 1.23051984]
#
#
# Damkohler number BM-only:
#  [2.75329582 1.99207069 1.47988847 1.19153148 1.20007669 1.04032431]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [2.81625442 5.87496558]
#
#
# Damkohler number preload:
#  [0.75215149 0.62355732 0.58895355 0.57703664 0.58902452 0.64433588]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [0.76935066 3.63872214]
#
#
# Damkohler number preload-presort:
#  [0.75215149 0.44210648 0.26712336 0.19185942 0.16479722 0.11533063]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [0.76935066 0.45221596 0.27323157 0.19624659 0.16856558 0.11796785]

# %%
trans_std = np.array([rxndiff[d][3][0] for d in rxndiff])
rxn_std = np.array([rxndiff[d][4][0] for d in rxndiff])
trans_mean = np.array([rxndiff[d][0][0] for d in rxndiff])
rxn_mean = np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
(trans_std**2)/(rxn_std)**2-(trans_mean*rxn_mean)**2
# Out:
# array([-67391591.96089843, -98677060.67412502, -37860045.26273775,
#        -15909416.45576779, -12932371.91322429,  -7667074.7603853 ])

# %% [markdown]
# ### Simulation with pre-sorting bias

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


###### Growth rate = 0.6
gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1738/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1817/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1934/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon,bias=3)

search_list = transportRxnResults[0]
rxndiff['06'] = transportRxnResults[1:]

###### Growth rate = 1.0
gr_sim = dict()

data = "191004_0018/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2012/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2115/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_2238/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon,bias=3.5)

search_list = transportRxnResults[0]
rxndiff['10'] = transportRxnResults[1:]

###### Growth rate = 1.5
gr_sim = dict()

data = "191004_0104/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_0916/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1041/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1206/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon,bias=4)

search_list =  transportRxnResults[0]
rxndiff['15'] = transportRxnResults[1:]

######Growth rate = 2.0
gr_sim = dict()

data = "191004_1129/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1348/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1428/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1506/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon,bias=4)

search_list = transportRxnResults[0]
rxndiff['20'] = transportRxnResults[1:]

#####Growth rate = 2.5
gr_sim = dict()

data = "191004_1217/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1556/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1714/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1757/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon,bias=4.5)

search_list = transportRxnResults[0]
rxndiff['25'] = transportRxnResults[1:]


#####Growth rate = 3.0
gr_sim = dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon,bias=4.5)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 20
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 545
# Computing...
# Computing...
# Computing...
# missing expt
# 804
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.6950635850616
# Unweighted search time ( 2  cognate) 172.8331350778929
# Unweighted search time ( 3  cognate) 120.30314389849792
# Unweighted search time ( 4  cognate) 95.84486115037801
# Unweighted search time ( 5  cognate) 90.00181629104335
# Unweighted search time ( 6  cognate) 68.66961539258227
# Unweighted search time ( 7  cognate) 51.0826344400858
# Unweighted search time ( 8  cognate) 52.0401348919299
# Unweighted search time ( 9  cognate) 31.30225674888329
# Unweighted search time ( 10  cognate) nan
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) 19.882620253037565
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [150.03711881028067]  +/-  [8.169368120223893]
# Reaction time:  [12.504181194417876]  +/-  [1.073395717850394]
# Search time:  [162.5413000046985]  +/-  [8.92706679517124]
# Computing...
# /Users/akshay/Documents/TranslationDynamics/src/analysis_utils.py:502: RuntimeWarning: invalid value encountered in double_scalars
#   print('Unweighted search time (', str(i), ' cognate)', np.array(search_vals/p_codon_count_hist_weighted_avg[i]))
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 218
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 389.29162033299633
# Unweighted search time ( 2  cognate) 195.26409530851538
# Unweighted search time ( 3  cognate) 115.34566994307103
# Unweighted search time ( 4  cognate) 99.51536542228065
# Unweighted search time ( 5  cognate) 68.9457861981281
# Unweighted search time ( 6  cognate) 51.8572232535522
# Unweighted search time ( 7  cognate) 42.36324950612762
# Unweighted search time ( 8  cognate) 34.93646336215733
# Unweighted search time ( 9  cognate) 31.488883741736444
# Unweighted search time ( 10  cognate) 33.00739226279752
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [139.19219676802226]  +/-  [10.552019709187139]
# Reaction time:  [28.109682292941503]  +/-  [2.3521613564657757]
# Search time:  [167.30187906096376]  +/-  [12.697538359855935]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 29
# missing expt
# 35
# missing expt
# 67
# missing expt
# 77
# Computing...
# missing expt
# 128
# missing expt
# 193
# Computing...
# Computing...
# missing expt
# 308
# Computing...
# Computing...
# missing expt
# 590
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 271.474693309938
# Unweighted search time ( 2  cognate) 145.60632549023543
# Unweighted search time ( 3  cognate) 106.52609173286244
# Unweighted search time ( 4  cognate) 53.94149452496741
# Unweighted search time ( 5  cognate) 56.314901899644745
# Unweighted search time ( 6  cognate) 42.99186461828626
# Unweighted search time ( 7  cognate) 36.28613022163495
# Unweighted search time ( 8  cognate) 22.83701652752771
# Unweighted search time ( 9  cognate) 26.81757961619516
# Unweighted search time ( 10  cognate) 25.316357862972335
# Unweighted search time ( 11  cognate) 22.149406681818288
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [95.33833199983114]  +/-  [6.49062460251981]
# Reaction time:  [22.653463160482122]  +/-  [1.7068881478053037]
# Search time:  [117.99179516031329]  +/-  [8.018470809087123]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 327
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 200.2249530232702
# Unweighted search time ( 2  cognate) 108.36198572461856
# Unweighted search time ( 3  cognate) 64.79356745270022
# Unweighted search time ( 4  cognate) 56.21415298033055
# Unweighted search time ( 5  cognate) 35.70904091917134
# Unweighted search time ( 6  cognate) 32.117417490905076
# Unweighted search time ( 7  cognate) 27.076662289821474
# Unweighted search time ( 8  cognate) 26.64127795783609
# Unweighted search time ( 9  cognate) 17.740805025167063
# Unweighted search time ( 10  cognate) nan
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) 14.274962433395448
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [69.92947845119627]  +/-  [4.359753312713848]
# Reaction time:  [16.965655425139737]  +/-  [1.2441134797289322]
# Search time:  [86.89513387633602]  +/-  [5.50534712511241]
# Computing...
# Computing...
# Computing...
# missing expt
# 202
# Computing...
# Computing...
# missing expt
# 462
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 510
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 447
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 200.1169937894533
# Unweighted search time ( 2  cognate) 84.02792722842412
# Unweighted search time ( 3  cognate) 61.07896381228008
# Unweighted search time ( 4  cognate) 40.48318424533152
# Unweighted search time ( 5  cognate) 40.73540242572678
# Unweighted search time ( 6  cognate) 26.343668227923853
# Unweighted search time ( 7  cognate) 23.692638573720732
# Unweighted search time ( 8  cognate) 20.72395640321115
# Unweighted search time ( 9  cognate) 16.560329391048032
# Unweighted search time ( 10  cognate) 13.230331478053982
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [66.95338837923254]  +/-  [4.073001763434675]
# Reaction time:  [13.429097286288886]  +/-  [0.895662841817405]
# Search time:  [80.38248566552141]  +/-  [4.87862157219648]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 597
# Computing...
# missing expt
# 650
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 433
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 145.7835388506996
# Unweighted search time ( 2  cognate) 73.66729336133365
# Unweighted search time ( 3  cognate) 57.14791895679198
# Unweighted search time ( 4  cognate) 36.894644278725536
# Unweighted search time ( 5  cognate) 28.287419667432513
# Unweighted search time ( 6  cognate) 23.84621541341551
# Unweighted search time ( 7  cognate) 21.179634435796125
# Unweighted search time ( 8  cognate) 16.141486737862376
# Unweighted search time ( 9  cognate) 12.15933004051406
# Unweighted search time ( 10  cognate) 13.980471834927602
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [53.230297930990574]  +/-  [3.168262775468436]
# Reaction time:  [9.564871422733017]  +/-  [0.7811203137136121]
# Search time:  [62.7951693537236]  +/-  [3.867143744482967]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Elongation\: latency,\: [ms]$',fontsize=30)

#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/15,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))
print('\nExperimental: ', [1000/12,1000/15,1000/18,1000/19,1000/20,1000/21])


####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
ax2.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax2.set_ylabel(r'$Transport\: latency\: [ms]$',fontsize=30)
ax2.set_yticks(np.arange(0, 226, 25))

#Plot inferred experimental values of transport latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
exptl_trans = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
experimental_vals = [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of transport latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))

print('\ngap', np.array([1000/12,1000/15,1000/18,1000/19,1000/20,1000/21])-np.ones(6)*(1000/1529+1000/209+1000/200+1000/32))

### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
ax3.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax3.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax3.set_ylabel(r'$Reaction\: latency\: [ms]$',fontsize=30)

#Plot inferred experimental values of reaction latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/1529+1000/209+1000/200+1000/32]*len(phi_list),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax3.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax3.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
exptl_rxn = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))





##### Plot Da (Subplot 4) ######

#Plot Damkohler number predicted by our simulation
ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='black')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax4.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax4.set_ylabel(r'$Da$',fontsize=30)

#Plot inferred experimental values of Damkohler number (using data from literature)
ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0]/(rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32)),rxndiff['30'][0][0]/(rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32))],experimental_vals))


####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black',labelpad=20)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)


plt.tight_layout(pad=4.0)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [204.23001123666987, 208.9905902929351, 159.68050639228466, 128.58384510830737, 122.07119689749277, 104.48388058569496]
# [8.92706679517124, 12.697538359855935, 8.018470809087123, 5.50534712511241, 4.87862157219648, 3.867143744482967]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [83.2585613612184, 48.3136725138132]
# 	Predicted/Experimental:  [2.45296109 2.16261516]
#
# Experimental:  [83.33333333333333, 66.66666666666667, 55.55555555555556, 52.63157894736842, 50.0, 47.61904761904762]
#
#
# Transport latencies:
#  [150.03711881028067, 139.19219676802226, 95.33833199983114, 69.92947845119627, 66.95338837923254, 53.230297930990574]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of transport latency [40.756741883632365, 7.382133422833235]
# 	Predicted/Experimental:  [3.68128344 7.21069302]
#
# gap [41.6446221  24.97795543 13.86684432 10.94286772  8.31128877  5.93033639]
#
#
# Reaction latencies:
#  [54.192892426389236, 69.79839352491287, 64.34217439245349, 58.6543666571111, 55.11780851826025, 51.253582654704374]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [41.688711231971354, 41.68871123197134, 41.68871123197134]
# 	Predicted/Experimental:  [1.29994166 1.67427564 1.22943553]
#
#
# Damkohler number:
#  [2.76857558 1.99420344 1.48173936 1.19222971 1.21473241 1.03856736]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [2.83188358 5.86504364]

# %% [markdown]
# ## Plot Kinetic Scaling Data

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff_1=dict()

data = "200511_1738/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=3000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['3000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2104/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=2000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['2000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2155/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=1000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['1000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2229/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=800)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['800'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "200511_2302/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=600)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['600'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "200512_0110/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=400)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['400'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "191003_2210/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['200'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_1452/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['100'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_1716/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=50)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['50'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_2150/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=25)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['25'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 205.13237429774028
# Unweighted search time ( 2  cognate) 144.59190505119136
# Unweighted search time ( 3  cognate) 81.26668864745206
# Unweighted search time ( 4  cognate) 60.837067379907914
# Unweighted search time ( 5  cognate) 37.67149050362579
# Unweighted search time ( 6  cognate) 33.502621291680235
# Transport time:  [81.83669057565481]  +/-  [5.033841738234685]
# Reaction time:  [13.831119702480198]  +/-  [1.0415593217703352]
# Search time:  [95.66781027813502]  +/-  [5.942335642049048]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 233.0755660515408
# Unweighted search time ( 2  cognate) 112.33663469145259
# Unweighted search time ( 3  cognate) 69.54496412891159
# Unweighted search time ( 4  cognate) 45.1119332698582
# Unweighted search time ( 5  cognate) 36.56218849166321
# Unweighted search time ( 6  cognate) 26.15598344749219
# Transport time:  [80.38073244658453]  +/-  [5.372772258785973]
# Reaction time:  [14.186611328092557]  +/-  [1.0503322518643492]
# Search time:  [94.56734377467708]  +/-  [6.2808271021736575]
# Computing...
# Computing...
# Computing...
# Computing...

# %%
import matplotlib.pyplot as plt

fig, [ax1,ax2,ax3,ax4] = plt.subplots(1,4,figsize=(27,6))
x=[3000,2000,1000,800,600,400,200,100,50,25]

ax1.scatter(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],zorder=2,s=250,color='black')
ax1.errorbar(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],[rxndiff_1[d][5][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax1.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax1.set_ylabel('Elongation latency (ms)',size=25,color='black')
ax1.set_xscale('log')
ax1.set_xticks((10,100,1000,3000))


ax2.scatter(x,[rxndiff_1[d][0][0] for d in rxndiff_1],zorder=2,s=250,color='black')
ax2.errorbar(x,[rxndiff_1[d][0][0] for d in rxndiff_1],[rxndiff_1[d][3][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][0][0] for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax2.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax2.set_ylabel('Transport latency (ms)',size=25,color='black')
ax2.set_xscale('log')
ax2.set_xticks((10,100,1000,3000))


ax3.scatter(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],zorder=2,s=250,color='black')
ax3.errorbar(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],[rxndiff_1[d][4][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],2)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax3.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax3.set_ylabel('Reaction latency (ms)',size=25,color='black')
ax3.set_xscale('log')
ax3.set_xticks((10,100,1000,3000))

#######################
voxlen = 0.0677
D = 56*0.284
mixTime = []
t1 = 1/717
scalingTime = []
scaling = np.arange(0,3000,1)

for i in scaling:
    scalingTime.append(t1/i*1e3)
    mixTime.append((0.012)**2/(6*D)*1e3)
    
ax4.plot(scaling,mixTime,'grey',linewidth=4,linestyle='dashed',color='black')
ax4.plot(scaling,scalingTime,'black',linewidth=4)
ax4.set_yscale('log')
ax4.set_xlim(0,3000)
ax4.set_xlabel('Kinetic rate scaling',size=25)
ax4.set_ylabel('Time (ms)',size=25)

print(scalingTime[925:950])
#######################

for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.tick_params(axis='both', which='major',width=4, labelsize=30)
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout(pad=3.0)
# Out:
# /Users/akshay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:47: RuntimeWarning: divide by zero encountered in true_divide
# [0.0015077839345621772, 0.001506155658174961, 0.001504530894789659, 0.001502909633049584, 0.0015012918616469472, 0.0014996775693225956, 0.0014980667448657506, 0.0014964593771137488, 0.0014948554549517835, 0.0014932549673126487, 0.0014916579031764854, 0.0014900642515705276, 0.0014884740015688514, 0.0014868871422921257, 0.001485303662907363, 0.0014837235526276745, 0.001482146800712023, 0.0014805733964649828, 0.001479003329236494, 0.0014774365884216247, 0.0014758731634603322, 0.001474313043837224, 0.001472756219081324, 0.0014712026787658374, 0.0014696524125079177]

# %%
fig, ax1 = plt.subplots(1,1,figsize=(6,6))

voxlen = 0.0677
D = 56*0.284
mixTime = []
t1 = 1/717
scalingTime = []
scaling = np.arange(0,3000,1)

for i in scaling:
    scalingTime.append(t1/i*1e3)
    mixTime.append((0.012)**2/(6*D)*1e3)
    
ax1.plot(scaling,mixTime,'grey',linewidth=4,linestyle='dashed',color='black')
ax1.plot(scaling,scalingTime,'black',linewidth=4)
plt.yscale('log')
ax1.set_xlim(0,3000)

ax1.set_xlabel('Kinetic rate scaling',size=25)
ax1.set_ylabel('Time (ms)',size=25)

ax1.spines['left'].set_linewidth(4)
ax1.spines['bottom'].set_linewidth(4)
ax1.spines['top'].set_linewidth(4)
ax1.spines['right'].set_linewidth(4)
ax1.tick_params(axis='both', which='major', labelsize=20)
print(scalingTime[925:950])
# Out:
# /Users/akshay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# [0.0015077839345621772, 0.001506155658174961, 0.001504530894789659, 0.001502909633049584, 0.0015012918616469472, 0.0014996775693225956, 0.0014980667448657506, 0.0014964593771137488, 0.0014948554549517835, 0.0014932549673126487, 0.0014916579031764854, 0.0014900642515705276, 0.0014884740015688514, 0.0014868871422921257, 0.001485303662907363, 0.0014837235526276745, 0.001482146800712023, 0.0014805733964649828, 0.001479003329236494, 0.0014774365884216247, 0.0014758731634603322, 0.001474313043837224, 0.001472756219081324, 0.0014712026787658374, 0.0014696524125079177]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "190927_0408/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+'190930_1418/',0,20,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(linregress(MSD_vals[2][start:end],MSD_vals[1][start:end])[0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn',size=30,pad=20)
# Out:
# [55.185, 35.404, 25.088, 20.27, 17.426, 16.591, 15.903]
# Text(0.5, 1.0, 'Smoldyn')

# %%
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "20200511_LAMMPS_MSD/" 
slopes = list()

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['green','purple','blue','red','brown','orange']

length = 0.0059**2
time = 6.21607E-07


df_outputs = pd.read_csv(path+data+"MSD_gr_06_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='green',label="gr=0.6",linewidth=3)
slopes.append(linregress(df_outputs[0]*time,df_outputs[2]*length)[0])

df_outputs = pd.read_csv(path+data+"MSD_gr_10_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='purple',label="gr=1.0",linewidth=3)
slopes.append(linregress(df_outputs[0]*time,df_outputs[2]*length)[0])

df_outputs = pd.read_csv(path+data+"MSD_gr_15_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='blue',label="gr=1.5",linewidth=3)
slopes.append(linregress(df_outputs[0]*time,df_outputs[2]*length)[0])

df_outputs = pd.read_csv(path+data+"MSD_gr_20_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='red',label="gr=2.0",linewidth=3)
slopes.append(linregress(df_outputs[0]*time,df_outputs[2]*length)[0])

df_outputs = pd.read_csv(path+data+"MSD_gr_25_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='brown',label="gr=2.5",linewidth=3)
slopes.append(linregress(df_outputs[0]*time,df_outputs[2]*length)[0])

df_outputs = pd.read_csv(path+data+"MSD_gr_30_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='orange',label="gr=3.0",linewidth=3)
slopes.append(linregress(df_outputs[0]*time,df_outputs[2]*length)[0])


leg = ax.legend(fontsize=15)

ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.08,0.85-0.07*i,str(np.round(np.array(slopes)/6,1)[i])+'+/- 0.0',color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)/6,3)[i])
print(diff_list)


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('LAMMPS',size=30,pad=20)
# Out:
# [32.222, 24.735, 19.313, 17.145, 15.041, 15.045]
# Text(0.5, 1.0, 'LAMMPS')
