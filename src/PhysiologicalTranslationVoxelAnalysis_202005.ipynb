# %% [markdown]
# ## Calculate cognate ternary complex distribution for a given tRNA and codon distribution (i.e., at a given growth rate)

# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]

rxndiff=dict()

#p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Growth rate = 0.6
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1738/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1817/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1934/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)

search_list = transportRxnResults[0]
rxndiff['06'] = transportRxnResults[1:]


#Growth rate = 1.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_0018/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2012/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2115/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_2238/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon)

search_list = transportRxnResults[0]
rxndiff['10'] = transportRxnResults[1:]

#Growth rate = 1.5
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_0104/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_0916/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1041/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1206/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

search_list = transportRxnResults[0]
rxndiff['15'] = transportRxnResults[1:]

#Growth rate = 2.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_1129/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1348/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1428/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1506/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

search_list = transportRxnResults[0]
rxndiff['20'] = transportRxnResults[1:]

#Growth rate = 2.5
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_1217/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1556/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1714/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1757/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['25'] = transportRxnResults[1:]

#Growth rate = 3.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}


transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 20
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 545
# Computing...
# Computing...
# Computing...
# missing expt
# 804
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.2174549476847
# Unweighted search time ( 2  cognate) 172.79784510750903
# Unweighted search time ( 3  cognate) 120.58636576565199
# Unweighted search time ( 4  cognate) 95.81530417847716
# Unweighted search time ( 5  cognate) 89.95536036041196
# Unweighted search time ( 6  cognate) 68.74195471437629
# Unweighted search time ( 7  cognate) 50.97741511223031
# Unweighted search time ( 8  cognate) 52.0730617764394
# Unweighted search time ( 9  cognate) 31.28438871782044
# Unweighted search time ( 10  cognate) 36.965100976449776
# Unweighted search time ( 11  cognate) 29.350016178995403
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [150.79783255179626]  +/-  [8.2381646900032]
# Reaction time:  [12.566116582849313]  +/-  [1.0816512174425774]
# Search time:  [163.14656900675362]  +/-  [8.960277271810961]
# Computing...
# /Users/akshay/Documents/TranslationDynamics/src/analysis_utils.py:502: RuntimeWarning: invalid value encountered in double_scalars
#   transport_phi.append(np.sum(transport_vals_list))
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 218
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 388.7647362979782
# Unweighted search time ( 2  cognate) 195.6436206382346
# Unweighted search time ( 3  cognate) 115.25881005883188
# Unweighted search time ( 4  cognate) 99.56782568899345
# Unweighted search time ( 5  cognate) 68.9147813570249
# Unweighted search time ( 6  cognate) 51.855551388771694
# Unweighted search time ( 7  cognate) 42.3560962094539
# Unweighted search time ( 8  cognate) 34.94450414525642
# Unweighted search time ( 9  cognate) 31.492211614795085
# Unweighted search time ( 10  cognate) 33.009074922780414
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [139.62977536118726]  +/-  [10.737504907391456]
# Reaction time:  [28.19277383818889]  +/-  [2.368518126686616]
# Search time:  [167.77142745074693]  +/-  [12.939022098159846]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 29
# missing expt
# 35
# missing expt
# 67
# missing expt
# 77
# Computing...
# missing expt
# 128
# missing expt
# 193
# Computing...
# Computing...
# missing expt
# 308
# Computing...
# Computing...
# missing expt
# 590
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 271.5043454790646
# Unweighted search time ( 2  cognate) 145.7982724166633
# Unweighted search time ( 3  cognate) 106.4295756813262
# Unweighted search time ( 4  cognate) 53.96223852097369
# Unweighted search time ( 5  cognate) 56.313300743631196
# Unweighted search time ( 6  cognate) 43.04309870350351
# Unweighted search time ( 7  cognate) 36.23376311889633
# Unweighted search time ( 8  cognate) 22.833707591380808
# Unweighted search time ( 9  cognate) 26.85039539105953
# Unweighted search time ( 10  cognate) nan
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [96.09251938238768]  +/-  [6.512075677013807]
# Reaction time:  [22.81641569733625]  +/-  [1.73632853255703]
# Search time:  [118.91518788984483]  +/-  [8.1012550395369]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 327
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 199.9660728617999
# Unweighted search time ( 2  cognate) 108.44494973296881
# Unweighted search time ( 3  cognate) 64.79910737112777
# Unweighted search time ( 4  cognate) 56.199324241678916
# Unweighted search time ( 5  cognate) 35.65441569439769
# Unweighted search time ( 6  cognate) 32.09887855660315
# Unweighted search time ( 7  cognate) 27.044058371547035
# Unweighted search time ( 8  cognate) 26.625319265810752
# Unweighted search time ( 9  cognate) 17.75112426622095
# Unweighted search time ( 10  cognate) 13.469619142304097
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [68.57807135022867]  +/-  [4.209980643965964]
# Reaction time:  [16.61831817648159]  +/-  [1.205822056291387]
# Search time:  [85.11624018594128]  +/-  [5.292818049598891]
# Computing...
# Computing...
# Computing...
# missing expt
# 202
# Computing...
# Computing...
# missing expt
# 462
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 510
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 447
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 200.24870112470467
# Unweighted search time ( 2  cognate) 84.04848786523176
# Unweighted search time ( 3  cognate) 61.129867771442264
# Unweighted search time ( 4  cognate) 40.47251044240489
# Unweighted search time ( 5  cognate) 40.76288255733592
# Unweighted search time ( 6  cognate) 26.38523289666308
# Unweighted search time ( 7  cognate) 23.70582923121978
# Unweighted search time ( 8  cognate) 20.718005625593506
# Unweighted search time ( 9  cognate) 16.538558192003553
# Unweighted search time ( 10  cognate) 13.222602154863036
# Unweighted search time ( 11  cognate) nan
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [66.16582256556448]  +/-  [3.9865347216494147]
# Reaction time:  [13.28706703963214]  +/-  [0.8711675026520579]
# Search time:  [79.49505509314591]  +/-  [4.825134201703736]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 597
# Computing...
# missing expt
# 650
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 433
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 145.7371264316534
# Unweighted search time ( 2  cognate) 73.59810306327188
# Unweighted search time ( 3  cognate) 57.17019931163617
# Unweighted search time ( 4  cognate) 36.87761209691188
# Unweighted search time ( 5  cognate) 28.262985816026163
# Unweighted search time ( 6  cognate) 23.85800035050954
# Unweighted search time ( 7  cognate) 21.175485763286026
# Unweighted search time ( 8  cognate) 16.12513759922362
# Unweighted search time ( 9  cognate) 12.176101616946406
# Unweighted search time ( 10  cognate) 13.95070765255563
# Unweighted search time ( 11  cognate) 11.55008333999652
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [54.02391682481395]  +/-  [3.23189424358964]
# Reaction time:  [9.735687135413487]  +/-  [0.8061632959166656]
# Search time:  [63.725365562459075]  +/-  [3.9185247163787857]

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=30)

#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/15,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
ax2.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax2.set_ylabel('Transport latency (ms)',fontsize=30)
ax2.set_yticks(np.arange(0, 226, 25))

#Plot inferred experimental values of transport latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
exptl_trans = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
experimental_vals = [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of transport latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))



### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
ax3.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax3.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax3.set_ylabel('Reaction latency (ms)',fontsize=30)

#Plot inferred experimental values of reaction latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/1529+1000/209+1000/200+1000/32]*len(phi_list),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax3.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax3.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
exptl_rxn = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



##### Plot Da (Subplot 4) ######

##Plot Damkohler number predicted by our simulation
ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='black')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax4.set_xlabel('Voxel volume fraction $(\phi_{vox})$',size=30,color='black')
ax4.set_ylabel(r'$Da$',fontsize=30)

## Plot pre-load, pre-load+pre-sort results
ax4.scatter(phi_list, np.array( [34.01663109406401, 30.41369509254369, 29.154101488155067, 28.491437978874004, 28.409508968849106, 30.805382022214264] 
)/(np.array([3.537059926602166, 7.085786360511388, 7.812818601943163, 7.686728426387252, 6.542742485140954, 6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='o',color='black')
ax4.errorbar(phi_list, np.array( [34.01663109406401, 30.41369509254369, 29.154101488155067, 28.491437978874004, 28.409508968849106, 30.805382022214264] 
)/(np.array([3.537059926602166, 7.085786360511388, 7.812818601943163, 7.686728426387252, 6.542742485140954, 6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')


presorttrans=np.array([34.01663109406401,20.007025364980883,11.68166201748362,8.274169505141892, 7.074660404155837,  4.926203750197745])
presortrxn = np.array([3.537059926602166,3.5651502846900125,2.0426277448724632,1.4374991110185171,1.2407775100632652,1.025038678927513])
ax4.scatter(phi_list, presorttrans /(presortrxn+(1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='o',color='black')
ax4.errorbar(phi_list, presorttrans/(presortrxn+(1000/1529+1000/209+1000/200+1000/32)),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

#naivetrans= np.array([0.08]*6)
#naiverxn = np.array([42]*6)
#ax4.scatter(phi_list,naivetrans/naiverxn,zorder=2,s=250,marker='o',color='black')
#ax4.errorbar(phi_list,naivetrans/naiverxn,0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')


#Plot inferred experimental values of Damkohler number (using data from literature)
ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number BM-only: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0]/(rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32)),rxndiff['30'][0][0]/(rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32))],experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload: \n',np.array( [34.01663109406401, 30.41369509254369, 29.154101488155067, 28.491437978874004, 28.409508968849106, 30.805382022214264] 
)/(np.array([3.537059926602166, 7.085786360511388, 7.812818601943163, 7.686728426387252, 6.542742485140954, 6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide(np.array( [34.01663109406401, 30.805382022214264] 
)/(np.array([3.537059926602166,  6.120797969362092] 
)+(1000/1529+1000/209+1000/200+1000/32)),experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload-presort: \n',presorttrans/(presortrxn+(1000/1529+1000/209+1000/200+1000/32)))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([presorttrans/(presortrxn+(1000/1529+1000/209+1000/200+1000/32))][0],experimental_vals[0]))


####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Growth rate (dbl/hr)',size=30,color='black',labelpad=20)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)


plt.tight_layout(pad=4.0)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# Elongation latencies:
#  [204.83528023872498, 209.46013868271828, 160.6038991218162, 126.80495141791263, 121.18376632511726, 105.41407679443043]
# [8.960277271810961, 12.939022098159846, 8.1012550395369, 5.292818049598891, 4.825134201703736, 3.9185247163787857]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [83.2585613612184, 48.3136725138132]
# 	Predicted/Experimental:  [2.46023084 2.18186843]
#
#
# Transport latencies:
#  [150.79783255179626, 139.62977536118726, 96.09251938238768, 68.57807135022867, 66.16582256556448, 54.02391682481395]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of transport latency [40.756741883632365, 7.382133422833235]
# 	Predicted/Experimental:  [3.69994817 7.31819838]
#
#
# Reaction latencies:
#  [54.25482781482067, 69.88148507016025, 64.50512692930761, 58.30702940845295, 54.9757782716035, 51.424398367384846]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [41.688711231971354, 41.68871123197134, 41.68871123197134]
# 	Predicted/Experimental:  [1.30142732 1.67626878 1.23353294]
#
#
# Damkohler number BM-only:
#  [2.7794362  1.99809399 1.48968809 1.17615444 1.20354499 1.05055029]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [2.84299254 5.93271421]
#
#
# Damkohler number preload:
#  [0.75215149 0.62355732 0.58895355 0.57703664 0.58902452 0.64433588]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [0.76935066 3.63872214]
#
#
# Damkohler number preload-presort:
#  [0.75215149 0.44210648 0.26712336 0.19185942 0.16479722 0.11533063]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [0.76935066 0.45221596 0.27323157 0.19624659 0.16856558 0.11796785]

# %%
trans_std = np.array([rxndiff[d][3][0] for d in rxndiff])
rxn_std = np.array([rxndiff[d][4][0] for d in rxndiff])
trans_mean = np.array([rxndiff[d][0][0] for d in rxndiff])
rxn_mean = np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
(trans_std**2)/(rxn_std)**2-(trans_mean*rxn_mean)**2
# Out:
# array([-67553209.03720616, -95961478.16181259, -36141550.53487577,
#        -16540928.52089875, -12825948.53810835,  -7511097.31162275])

# %% [markdown]
# ### Simulation with pre-sorting bias

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


###### Growth rate = 0.6
gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1738/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1817/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1934/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon,bias=3)

search_list = transportRxnResults[0]
rxndiff['06'] = transportRxnResults[1:]

###### Growth rate = 1.0
gr_sim = dict()

data = "191004_0018/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2012/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2115/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_2238/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon,bias=3.5)

search_list = transportRxnResults[0]
rxndiff['10'] = transportRxnResults[1:]

###### Growth rate = 1.5
gr_sim = dict()

data = "191004_0104/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_0916/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1041/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1206/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon,bias=4)

search_list =  transportRxnResults[0]
rxndiff['15'] = transportRxnResults[1:]

######Growth rate = 2.0
gr_sim = dict()

data = "191004_1129/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1348/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1428/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1506/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon,bias=4)

search_list = transportRxnResults[0]
rxndiff['20'] = transportRxnResults[1:]

#####Growth rate = 2.5
gr_sim = dict()

data = "191004_1217/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1556/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1714/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1757/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon,bias=4.5)

search_list = transportRxnResults[0]
rxndiff['25'] = transportRxnResults[1:]


#####Growth rate = 3.0
gr_sim = dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon,bias=4.5)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 20
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 545
# Computing...
# Computing...
# Computing...
# missing expt
# 804
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.501420737303
# Unweighted search time ( 2  cognate) 172.4388606831235
# Unweighted search time ( 3  cognate) 120.06399161892267
# Unweighted search time ( 4  cognate) 95.64493937760629
# Unweighted search time ( 5  cognate) 89.65176403987405
# Unweighted search time ( 6  cognate) 68.26122630173839
# Unweighted search time ( 7  cognate) 50.76727360591036
# Unweighted search time ( 8  cognate) 51.700490796373664
# Unweighted search time ( 9  cognate) 30.907542397686495
# Unweighted search time ( 10  cognate) 36.552019870061464
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 145.20468940475016
# Unweighted search time ( 2  cognate) 73.2652199492664
# Unweighted search time ( 3  cognate) 56.60380263296557
# Unweighted search time ( 4  cognate) 36.362538514682385
# Unweighted search time ( 5  cognate) 27.946575214909863
# Unweighted search time ( 6  cognate) 23.362071009166357
# Unweighted search time ( 7  cognate) 20.673595351227736
# Unweighted search time ( 8  cognate) 15.67939983255703
# Unweighted search time ( 9  cognate) 11.76972418758253
# Unweighted search time ( 10  cognate) 13.512180765421364
# Unweighted search time ( 11  cognate) 11.095985016881395
# Unweighted search time ( 12  cognate) 8.939035520088453
# Unweighted search time ( 13  cognate) 9.485239002911596
# Unweighted search time ( 14  cognate) 7.476512990341072
# Unweighted search time ( 15  cognate) 5.892129013642448
# Unweighted search time ( 16  cognate) 5.903535089396864
# Unweighted search time ( 17  cognate) 5.987262740869799
# Unweighted search time ( 18  cognate) 5.226946291491051
# Unweighted search time ( 19  cognate) 5.189808856478217
# Unweighted search time ( 20  cognate) 4.579062754830329
# Unweighted search time ( 21  cognate) 3.9892947669350716
# Unweighted search time ( 22  cognate) 3.3122514637240417
# Unweighted search time ( 23  cognate) 3.4444813714736866
# Unweighted search time ( 24  cognate) 2.6106065842203665
# Unweighted search time ( 25  cognate) 1.9844553718615703
# Unweighted search time ( 26  cognate) 2.776213819009765
# Unweighted search time ( 27  cognate) 2.8040303905844257
# Unweighted search time ( 28  cognate) 2.701765066992257
# Unweighted search time ( 29  cognate) 2.228294597829024
# Unweighted search time ( 30  cognate) 1.9727991601526913
# Unweighted search time ( 31  cognate) 1.2268880177477353
# Unweighted search time ( 32  cognate) 1.6289772313788127
# Unweighted search time ( 33  cognate) 1.109849776052869
# Transport time:  [5.487745548770933]  +/-  [0.7424497449426012]
# Reaction time:  [0.8585479716231029]  +/-  [0.19333414917219796]
# Search time:  [6.345273425384681]  +/-  [0.8477731646803862]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Elongation\: latency,\: [ms]$',fontsize=30)

#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/15,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))
print('\nExperimental: ', [1000/12,1000/15,1000/18,1000/19,1000/20,1000/21])


####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
ax2.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax2.set_ylabel(r'$Transport\: latency\: [ms]$',fontsize=30)
ax2.set_yticks(np.arange(0, 226, 25))

#Plot inferred experimental values of transport latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
exptl_trans = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
experimental_vals = [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of transport latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))

print('\ngap', np.array([1000/12,1000/15,1000/18,1000/19,1000/20,1000/21])-np.ones(6)*(1000/1529+1000/209+1000/200+1000/32))

### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
ax3.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax3.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax3.set_ylabel(r'$Reaction\: latency\: [ms]$',fontsize=30)

#Plot inferred experimental values of reaction latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/1529+1000/209+1000/200+1000/32]*len(phi_list),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax3.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax3.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
exptl_rxn = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))





##### Plot Da (Subplot 4) ######

#Plot Damkohler number predicted by our simulation
ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='black')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax4.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax4.set_ylabel(r'$Da$',fontsize=30)

#Plot inferred experimental values of Damkohler number (using data from literature)
ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0]/(rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32)),rxndiff['30'][0][0]/(rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32))],experimental_vals))


####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black',labelpad=20)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)


plt.tight_layout(pad=4.0)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [85.47709651460329, 68.44932676672427, 57.482448238569226, 53.529790344232424, 49.174307460504856, 48.033984657356044]
# [4.8071477417628685, 3.2131388680962027, 1.9866741185284043, 1.4876219775604103, 0.9730419132802205, 0.8477731646803862]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [83.2585613612184, 48.3136725138132]
# 	Predicted/Experimental:  [1.02664633 0.994211  ]
#
# Experimental:  [83.33333333333333, 66.66666666666667, 55.55555555555556, 52.63157894736842, 50.0, 47.61904761904762]
#
#
# Transport latencies:
#  [40.47912155450889, 22.8033055891336, 12.960397519803056, 9.83733004504459, 6.301940562193839, 5.487745548770933]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of transport latency [40.756741883632365, 7.382133422833235]
# 	Predicted/Experimental:  [0.99318836 0.74338206]
#
# gap [41.6446221  24.97795543 13.86684432 10.94286772  8.31128877  5.93033639]
#
#
# Reaction latencies:
#  [45.00216362746926, 45.6741905105759, 44.52802026480418, 43.6924217078964, 42.871326150460476, 42.547259203594464]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [41.688711231971354, 41.68871123197134, 41.68871123197134]
# 	Predicted/Experimental:  [1.07948081 1.09560092 1.02059426]
#
#
# Damkohler number:
#  [0.89949279 0.4992602  0.29106162 0.22514957 0.14699663 0.12898   ]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9776445632211279, 0.1770775158233203]
# 	Predicted/Experimental:  [0.92006116 0.72838158]

# %% [markdown]
# ## Plot Kinetic Scaling Data

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "190916_1101/"
gr_sim = dict()
rxndiff_1=dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=1000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['3000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "191114_2050/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=600)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['1800'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "190917_0105/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['600'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "190918_1046/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['300'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "190921_2357/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=20)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['60'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "190921_2258/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=10)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['30'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 30.50066879315302
# Unweighted search time ( 2  cognate) 25.72743096286461
# Unweighted search time ( 3  cognate) 24.38154720051826
# Unweighted search time ( 4  cognate) 10.284986529304513
# Unweighted search time ( 5  cognate) 17.40129555273629
# Unweighted search time ( 6  cognate) 11.93360422050764
# Transport time:  [0.10213832648991646]  +/-  [0.010076892055114839]
# Reaction time:  [18.305194004620674]  +/-  [2.11215943322825]
# Search time:  [18.393143254330603]  +/-  [2.1246508491240736]
# Computing...
# missing expt
# 21
# missing expt
# 49
# missing expt
# 54
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 20.813349826608626
# Unweighted search time ( 2  cognate) 14.72939024256608
# Unweighted search time ( 3  cognate) 9.682829066355122
# Unweighted search time ( 4  cognate) 5.411069873523299
# Unweighted search time ( 5  cognate) 3.906439852940071
# Unweighted search time ( 6  cognate) 3.5321394804492363
# Transport time:  [0.09691046802073813]  +/-  [0.009375712822885851]
# Reaction time:  [10.088774368656939]  +/-  [1.1865441922161206]
# Search time:  [10.186211859249848]  +/-  [1.200734118179946]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 24.64934852695362
# Unweighted search time ( 2  cognate) 8.763632623367643
# Unweighted search time ( 3  cognate) 6.302722966506283
# Unweighted search time ( 4  cognate) 4.2488791610148535
# Unweighted search time ( 5  cognate) 3.516936817994707
# Unweighted search time ( 6  cognate) 3.382708758608162
# Transport time:  [0.260367848688653]  +/-  [0.02627026764023302]
# Reaction time:  [8.959096650982323]  +/-  [1.0397712434888364]
# Search time:  [9.23269160299069]  +/-  [1.0515120137657723]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 20.169802002805714
# Unweighted search time ( 2  cognate) 12.464999719489525
# Unweighted search time ( 3  cognate) 5.289165055622074
# Unweighted search time ( 4  cognate) 5.218124064297119
# Unweighted search time ( 5  cognate) 3.291014430982104
# Unweighted search time ( 6  cognate) 3.1888581304567705
# Transport time:  [0.48798633462314883]  +/-  [0.05469537120810086]
# Reaction time:  [8.173035200013302]  +/-  [1.0756208568375345]
# Search time:  [8.665555743757297]  +/-  [1.1209812320640253]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 31.257154649941878
# Unweighted search time ( 2  cognate) 13.233825975676504
# Unweighted search time ( 3  cognate) 8.601173949959266
# Unweighted search time ( 4  cognate) 6.796214675912576
# Unweighted search time ( 5  cognate) 4.891551578848606
# Unweighted search time ( 6  cognate) 3.7549084417444005
# Transport time:  [2.881352875683208]  +/-  [0.28583192479284836]
# Reaction time:  [9.42176716038769]  +/-  [1.0705840494594476]
# Search time:  [12.29406591682608]  +/-  [1.311135941836335]
# Computing...
# missing expt
# 58
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 30.011545564512506
# Unweighted search time ( 2  cognate) 16.699843247061715
# Unweighted search time ( 3  cognate) 11.222856716676434
# Unweighted search time ( 4  cognate) 7.013239615938395
# Unweighted search time ( 5  cognate) 4.898718634357852
# Unweighted search time ( 6  cognate) 4.624266664833517
# Transport time:  [4.594271163286185]  +/-  [0.47359822046609745]
# Reaction time:  [8.34060151517841]  +/-  [0.9825815610611567]
# Search time:  [12.93634899947125]  +/-  [1.4160060757876365]

# %%
import matplotlib.pyplot as plt

fig, [ax1,ax2,ax3] = plt.subplots(1,3,figsize=(20,6))
x=[3000,1800,600,300,60,30]

ax1.scatter(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],zorder=2,s=250,color='black')
ax1.errorbar(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],[rxndiff_1[d][5][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax1.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax1.set_ylabel('Elongation latency (ms)',size=25,color='black')

ax2.scatter(x,[rxndiff_1[d][0][0] for d in rxndiff_1],zorder=2,s=250,color='black')
ax2.errorbar(x,[rxndiff_1[d][0][0] for d in rxndiff_1],[rxndiff_1[d][3][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][0][0] for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax2.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax2.set_ylabel('Transport latency (ms)',size=25,color='black')

ax3.scatter(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],zorder=2,s=250,color='black')
ax3.errorbar(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],[rxndiff_1[d][4][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax3.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax3.set_ylabel('Reaction latency (ms)',size=25,color='black')

for _,axes in enumerate([ax1,ax2,ax3]):
    axes.tick_params(axis='both', which='major',width=4, labelsize=30)
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout(pad=3.0)

# %%
#####Extra check code, delete
#Growth rate = 0.6
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
    gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)

search_list = transportRxnResults[0]
rxndiff['06'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# 708.4290998937108
#  0.06089999998855333
# 1490.9433996973735
#  0.1460999999680972
# 1071.1058998027609
#  0.09609999998156482
# 6572.7396087102325
#  0.6449000008812282
# 6162.244107879982
#  0.5994000008268578
# 2451.282700373731
#  0.22470000005203872
# 1032.6022998124256
#  0.11159999997795822
# 2369.5091002083036
#  0.22750000003188386
# 844.6522998595989
#  0.10099999998613285
# 1925.3346995869301
#  0.19009999996571025
# 2487.8451004476915
#  0.25730000005566644
# 1080.8603998001538
#  0.13349999997564055
# 6097.752007759094
#  0.5621000007264598
# 4659.645804840507
#  0.40900000049224694
# 1683.8620996487819
#  0.1502999999671637
# 747.0950998830665
#  0.0561999999918692
# 2056.72149957564
#  0.20189999996751062
# 4540.459204599505
#  0.434300000476846
# 1855.6785996055373
#  0.2115999999580671
# 762.5655998800092
#  0.067599999988748
# 1985.6050995731985
#  0.1979999999596771
# 6391.621808343822
#  0.5575000007693705
# 1122.0547997899303
#  0.10049999997883363
# 2533.263100539535
#  0.24710000006135147
# 5083.745705698361
#  0.4210000004971204
# missing expt
# 25
# missing expt
# 26
# 6124.534507803595
#  0.5564000007587768
# 2523.5298005363975
#  0.23420000005273423
# 5920.432507396068
#  0.5125000005968587
# missing expt
# 30
# 3181.3987018518824
#  0.2740000001619247
# 1790.848599622094
#  0.16529999996089662
# 5450.089406439378
#  0.49510000063518156
# 3048.471601581724
#  0.3107000001313396
# 6022.684307597587
#  0.5608000007510903
# missing expt
# 35
# 1001.5090998202245
#  0.10789999998480049
# 11051.748191752298
#  1.098799999365296
# 258.94310000653206
#  0.013000000000031875
# 3524.3630025529537
#  0.30060000025534706
# 4320.566304155136
#  0.4289000003993535
# 955.5440998317661
#  0.06639999999151414
# 1030.0477998130627
#  0.09229999998651905
# 3567.4631026317115
#  0.3471000002750235
# 3540.89870257772
#  0.3147000001739446
# 3236.484701961933
#  0.27680000014904715
# 3191.4314018718082
#  0.7189000000767614
# 6677.570308922281
#  0.00380000000001246
# 783.6747998749049
#  0.07129999999397718
# 2232.0883999307193
#  0.20080000000358655
# 556.2145999299573
#  0.03779999999573391
# 1079.948599800533
#  0.12429999997934793
# 1119.1615997907038
#  0.09569999997528811
# 120.31140000287111
#  0.009500000000102204
# 412.64479996804806
#  0.031699999997464534
# 807.08829986874
#  0.06669999999237497
# 21.353099999963554
#  0.0015999999999980474
# 1096.3502997964194
#  0.11429999998119111
# 319.02479999154656
#  0.029399999999689674
# 512.1806999425105
#  0.0549999999957933
# 1455.837499706181
#  0.1206999999796956
# 172.91450000465716
#  0.018500000000742034
# 53.326900000646916
#  0.0034999999999931752
# 669.7062999035202
#  0.05509999999165194
# 360.8989999810363
#  0.032499999996833395
# 2.739300000001359
#  0.0
# 798.3335998712149
#  0.066099999991728
# 7.868199999994994
#  0.0
# 275.8001000023921
#  0.04310000000117942
# 114.00740000266113
#  0.01250000000049667
# 318.20899999173764
#  0.0399999999985825
# 390.25609997367036
#  0.020699999997673357
# 819.8296998658361
#  0.07889999998516473
# 130.750400003217
#  0.012100000000331068
# 29.14119999994541
#  0.0
# 45.47620000038641
#  0.005400000000058469
# 1661.2400996546303
#  0.13029999996746433
# 736.8841998866557
#  0.06619999998960058
# 1.7383999999998239
#  0.0
# 1391.617499722299
#  0.14199999997637747
# 1.4501999999998414
#  0.0
# 772.8546998763684
#  0.06359999998542243
# Unweighted search time ( 1  cognate) 387.6381066518251
# Unweighted search time ( 2  cognate) 172.8071982017827
# Unweighted search time ( 3  cognate) 120.25402213057993
# Unweighted search time ( 4  cognate) 95.90590883959958
# Unweighted search time ( 5  cognate) 89.98799518156254
# Unweighted search time ( 6  cognate) 68.61281763002705
# Transport time:  [145.636619134952]  +/-  [12.94700392433381]
# Reaction time:  [12.163248926124554]  +/-  [1.7627049807814195]
# Search time:  [157.8122253603991]  +/-  [14.076224780283633]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.78146870575404
# Unweighted search time ( 2  cognate) 172.50591639516296
# Unweighted search time ( 3  cognate) 120.36322808660586
# Unweighted search time ( 4  cognate) 95.93589019902876
# Unweighted search time ( 5  cognate) 89.91083256181207
# Unweighted search time ( 6  cognate) 68.70798042101721
# Transport time:  [145.54368657347996]  +/-  [12.630880150186943]
# Reaction time:  [12.16849205336821]  +/-  [1.7332348414440235]
# Search time:  [157.75009728375932]  +/-  [13.712179039927433]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.5144576974602
# Unweighted search time ( 2  cognate) 172.9686225106621
# Unweighted search time ( 3  cognate) 120.20251223961132
# Unweighted search time ( 4  cognate) 95.85165953555567
# Unweighted search time ( 5  cognate) 90.08079259493962
# Unweighted search time ( 6  cognate) 68.62628051652959
# Transport time:  [149.9145149529633]  +/-  [8.113452517223942]
# Reaction time:  [12.499716985175255]  +/-  [1.069389140584588]
# Search time:  [162.36281907133548]  +/-  [8.982572190204145]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.70098693819926
# Unweighted search time ( 2  cognate) 172.67044557966847
# Unweighted search time ( 3  cognate) 120.14649977331707
# Unweighted search time ( 4  cognate) 95.82983824285569
# Unweighted search time ( 5  cognate) 89.98893654998925
# Unweighted search time ( 6  cognate) 68.77603967605535
# Transport time:  [146.95652712358086]  +/-  [7.868293667268015]
# Reaction time:  [12.27546481951212]  +/-  [1.0484757105762819]
# Search time:  [159.27464261523886]  +/-  [8.665137326500362]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# missing expt
# 26
# missing expt
# 89
# Computing...
# missing expt
# 107
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 393.9380102894129
# Unweighted search time ( 2  cognate) 172.78867570041484
# Unweighted search time ( 3  cognate) 120.34316452990507
# Unweighted search time ( 4  cognate) 95.77678972671276
# Unweighted search time ( 5  cognate) 90.04081438981576
# Unweighted search time ( 6  cognate) 68.59146359480366
# Transport time:  [149.39875693128388]  +/-  [8.121673599288652]
# Reaction time:  [12.466696472972464]  +/-  [1.0673733497620226]
# Search time:  [161.83522368741544]  +/-  [8.87457957994421]

# %%
np.random.seed(42)
pickups = np.random.randint(0,500 , size=10000)
sample = np.random.choice(pickups, size=30)
sample2 = np.random.choice(pickups, size=30)
sample3 = np.random.choice(pickups, size=30)
sample4 = np.random.choice(pickups, size=30)
mean1 = np.mean(sample)
mean2 = np.mean(sample2)
mean3 = np.mean(sample3)
mean4 = np.mean(sample4)

# %%
print(np.std([mean1,mean2,mean3,mean4]))
print(np.mean((int(mean1),int(mean2),int(mean3),int(mean4))))
# Out:
# 19.848040765330524
# 243.5

# %%
fullsample = np.concatenate((sample,sample2,sample3,sample4))
print(np.std(fullsample)/(np.sqrt(len(fullsample))))
print(np.mean(fullsample))
# Out:
# 12.310141389054737
# 244.01666666666668
