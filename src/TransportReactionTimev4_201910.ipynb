# %%
import numpy as np

ptRNA = [0.0521, 0.0099, 0.0762, 0.0102, 0.0139, 0.0067, 0.0191, 0.0384, 0.0255, 0.0123, 0.0141,\
 0.0757, 0.0343, 0.0699, 0.0102, 0.0557, 0.0717, 0.0151, 0.0107, 0.0307, \
 0.0165, 0.0309, 0.0113, 0.0166, 0.0144, 0.0115, 0.0093, 0.0035, 0.0208, 0.0055, 0.0226, \
 0.0123, 0.0017, 0.0087, 0.0176, 0.0147, 0.0151, 0.0326, 0.0616,0.0203]
ptRNA = np.divide(ptRNA,sum(ptRNA))

tRNA_tags = ["Ala1B", "Ala2", "Arg2", "Arg3", "Arg4", "Arg5", "Asn", "Asp1", "Cys", "Gln1", "Gln2", \
"Glu2", "Gly2", "Gly3", "His", "Ile1", "Leu1", "Leu2", "Leu3", "Leu4", "Leu5", "Lys", \
"Met_m", "Phe", "Pro1", "Pro2", "Pro3", "Sel_Cys", "Ser1", "Ser2", "Ser3", "Ser5", "Thr1", \
"Thr2", "Thr3", "Thr4", "Trp", "Tyr1pTyr2", "Val1", "Val2ApB"]

ptRNA_dict = dict(zip(tRNA_tags, ptRNA))

codons_Ec = ["GGG", "GGA", "GGU", "GGC", "GAG", "GAA", "GAU", "GAC", "GUG", "GUA", "GUU", \
"GUC", "GCG", "GCA", "GCU", "GCC", "AGG", "AGA", "AGU", "AGC", "AAG", "AAA", \
"AAU", "AAC", "AUG", "AUA", "AUU", "AUC", "ACG", "ACA", "ACU", "ACC", "UGG", \
"UGA", "UGU", "UGC", "UAU", "UAC", "UUG", "UUA", "UUU", "UUC", "UCG", "UCA", \
"UCU", "UCC", "CGG", "CGA", "CGU", "CGC", "CAG", "CAA", "CAU", "CAC", "CUG", \
"CUA", "CUU", "CUC", "CCG", "CCA", "CCU", "CCC"]

pcodons_Ec =[0.00483, 0.00272, 0.03847, 0.03579, 0.01665, 0.05335, 0.02436, \
0.02885, 0.02150, 0.01594, 0.03146, 0.01130, 0.03047, 0.02223, \
0.02898, 0.01989, 0.00009, 0.00113, 0.00401, 0.01203, 0.01214, \
0.04464, 0.00984, 0.02808, 0.02247, 0.00093, 0.02148, 0.03685, \
0.00757, 0.00350, 0.01394, 0.02663, 0.00981, 0.00031, 0.00425, \
0.00531, 0.01073, 0.01628, 0.00666, 0.00616, 0.01261, 0.02279, \
0.00608, 0.00391, 0.01318, 0.01120, 0.00176, 0.00133, 0.03126, \
0.02235, 0.02938, 0.01024, 0.00927, 0.01396, 0.06041, 0.00216, \
0.00573, 0.00622, 0.02965, 0.00655, 0.00501, 0.00332]
pcodons_Ec = np.divide(pcodons_Ec,sum(pcodons_Ec))

pcodon_dict = dict(zip(codons_Ec, pcodons_Ec))

#Note AUA does not have an assigned tRNA
codon_dict={'GGG': ['Gly2'], 'GGA': ['Gly2'], 'GGU': ['Gly3'], 'GGC': ['Gly3'], \
'GAG': ['Glu2'], 'GAA': ['Glu2'], 'GAU': ['Asp1'], 'GAC': ['Asp1'], \
'GUG': ['Val1'], 'GUA': ['Val1'], 'GUU': ['Val1','Val2ApB'], \
'GUC': ['Val2ApB'], 'GCG': ['Ala1B'], 'GCA': ['Ala1B'], 'GCU': ['Ala1B'], \
'GCC': ['Ala2'], 'AGG': ['Arg5'], 'AGA': ['Arg4'], 'AGU': ['Ser3'], \
'AGC': ['Ser3'], 'AAG': ['Lys'], 'AAA': ['Lys'], 'AAU': ['Asn'], \
'AAC': ['Asn'], 'AUG': ['Met_m'], 'AUA': [], 'AUU': ['Ile1'], \
'AUC': ['Ile1'], 'ACG': ['Thr2','Thr4'], 'ACA': ['Thr4'], \
'ACU': ['Thr1','Thr4','Thr3'], 'ACC': ['Thr3','Thr1'], \
'UGG': ['Trp'], 'UGA': ['Sel_Cys'], 'UGU': ['Cys'], 'UGC': ['Cys'], \
'UAU': ['Tyr1pTyr2'], 'UAC': ['Tyr1pTyr2'], 'UUG': ['Leu5','Leu4'], \
'UUA': ['Leu5'], 'UUU': ['Phe'], 'UUC': ['Phe'], 'UCG': ['Ser1','Ser2'], \
'UCA': ['Ser1'], 'UCU': ['Ser5','Ser1'], 'UCC': ['Ser5'], 'CGG': ['Arg3'], \
'CGA': ['Arg2'], 'CGU': ['Arg2'], 'CGC': ['Arg2'], 'CAG': ['Gln2'], \
'CAA': ['Gln1'], 'CAU': ['His'], 'CAC': ['His'], 'CUG': ['Leu1','Leu3'], \
'CUA': ['Leu3'], 'CUU': ['Leu2'], 'CUC': ['Leu2'], 'CCG': ['Pro1','Pro3'], \
'CCA': ['Pro3'], 'CCU': ['Pro2','Pro3'], 'CCC': ['Pro2']}

cells = 1
TU = 9500*20
time = 180
tRNA_distrib_arr = list()
codon_count = {}
codon_time = {}
codon_time_avg = {}
codon_time_weighted_avg={}
codon_count_hist = {}
codon_count_hist_weighted_avg = np.zeros(42)
p_codon_tRNA = {}

for key in codon_dict:
    codon_count[key] = []
    codon_time[key] = []
    codon_time_avg[key] = []
    codon_time_weighted_avg[key]=[]
    codon_count_hist[key]=[]
    p_codon_tRNA[key] = []

# Construct dictionary that assigns probability of all tRNA specific to a certain codon
# to that codon (p_codon_tRNA)
for codon in codon_dict:
    p_codon_tRNA_i = 0
    for tRNA in codon_dict[codon]:
        p_codon_tRNA_i += ptRNA_dict[tRNA]
    p_codon_tRNA[codon].append(p_codon_tRNA_i)

for cell in range(cells):
    # Generate distribution for cognate tRNA count for each codon
    for i in range(TU):
            
        #Construct translation unit with random tRNA (weighted by specific tRNA abundances)
        #and 1 random codon (weighted by codon probabilities).
        tRNA_vox = list(np.random.choice(tRNA_tags,42,p=ptRNA))
        codon_vox = np.random.choice(codons_Ec, 1)

        #Count how many cognate tRNA appeared in the translation unit (for given codon) and record in codon_count
        codon_count_i = 0
        for tRNA in codon_dict[codon_vox[0]]:
            codon_count_i += tRNA_vox.count(tRNA)
        codon_count[codon_vox[0]].append(codon_count_i)
    
    for codon in codon_count:
        #Generate histogram of cognate tRNA counts for each codon
        codon_count_hist[codon] = np.histogram(codon_count[codon], bins=np.arange(0,43))[0]/sum(np.histogram(codon_count[codon], bins=np.arange(0,43))[0])
        
        #Weight histogram by codon probabilities to generate weighted average histogram for all codon
        codon_count_hist_weighted_avg += codon_count_hist[codon]*pcodon_dict[codon]
    p_codon_count_hist_weighted_avg = codon_count_hist_weighted_avg
    print(p_codon_count_hist_weighted_avg)
# Out:
# [2.47040575e-01 2.55337405e-01 1.95448299e-01 1.36977061e-01
#  8.41576295e-02 4.75645501e-02 2.08336017e-02 8.50357868e-03
#  3.07231108e-03 7.77734883e-04 2.13907493e-04 5.34153412e-05
#  0.00000000e+00 1.99307159e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel('# of cognate tRNA per TU',fontsize=25)
plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,8)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=20)
# Out:
# 0.987359121808305
# [2.47040575e-01 2.55337405e-01 1.95448299e-01 1.36977061e-01
#  8.41576295e-02 4.75645501e-02 2.08336017e-02 8.50357868e-03
#  3.07231108e-03 7.77734883e-04 2.13907493e-04 5.34153412e-05
#  0.00000000e+00 1.99307159e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8507089620400916

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
def transportRxnCalc(gr):
    colors = ['darkblue','#D43F3A']
    gr_i_list = ['gr_1']
    phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
    markers = ['*','^']
    transport_phi = list()
    reaction_phi = list()
    search_phi = list()
    transport_std_phi =list()
    rxn_std_phi =list()
    search_std_phi =list()
    search_list = list()
    for j,gr_i in enumerate(gr_i_list):
        transport_vals_list = list()
        reaction_vals_list = list()
        search_vals_list = list()
        transport_std_list = list()
        rxn_std_list = list()
        search_std_list = list()
        
        #for range(1,7)
        for i in range(list(gr_dict['gr_1'].keys())[0],list(gr_dict['gr_1'].keys())[-1]+1):
            transport_vals = gr[gr_i][i].bootavg_transportT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            rxn_vals = gr[gr_i][i].bootavg_rxnT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            search_vals = gr[gr_i][i].bootavg_searchT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            
            transport_std = gr[gr_i][i].bootstd_transportT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            rxn_std = gr[gr_i][i].bootstd_rxnT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            search_std = gr[gr_i][i].bootstd_searchT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])

            transport_vals_list.append(np.array(transport_vals))
            reaction_vals_list.append(np.array(rxn_vals))
            search_vals_list.append(np.array(search_vals))
            
            transport_std_list.append(np.array(transport_std))
            rxn_std_list.append(np.array(rxn_std))
            search_std_list.append(np.array(search_std))
            
            search_list.append(np.array(gr[gr_i][i].searchT)*1000/1608733)
            print('Unweighted search time (', str(i), ' cognate)', np.array(search_vals/p_codon_count_hist_weighted_avg[i]))
        transport_phi.append(np.sum(transport_vals_list))
        reaction_phi.append(np.sum(reaction_vals_list))
        search_phi.append(np.sum(search_vals_list))
        
        transport_std_phi.append(np.sum(transport_std_list))
        rxn_std_phi.append(np.sum(rxn_std_list))
        search_std_phi.append(np.sum(search_std_list))

    print("Transport time: ", transport_phi, " +/- ", transport_std_phi)
    print("Reaction time: ", reaction_phi, " +/- ", rxn_std_phi)
    print("Search time: ", search_phi, " +/- ", search_std_phi)
    
    return search_list,transport_phi, reaction_phi, search_phi, transport_std_phi,rxn_std_phi,search_std_phi
rxndiff=dict()

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191001_0409/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

    
gr_dict = {'gr_1':gr_sim}
a=transportRxnCalc(gr_dict)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 192.84098580756205
# Unweighted search time ( 2  cognate) 106.19750824610132
# Unweighted search time ( 3  cognate) 68.73198063358596
# Unweighted search time ( 4  cognate) 54.24957046919016
# Unweighted search time ( 5  cognate) 36.49779242517108
# Unweighted search time ( 6  cognate) 26.568196890271306
# Transport time:  [73.3806285496979]  +/-  [7.136147841404716]
# Reaction time:  [13.297595605401698]  +/-  [1.7894176666022574]
# Search time:  [86.62325565952646]  +/-  [8.790373833396485]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191001_0339/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
a=transportRxnCalc(gr_dict)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 206.4470504649891
# Unweighted search time ( 2  cognate) 96.50184459493715
# Unweighted search time ( 3  cognate) 53.522274105483255
# Unweighted search time ( 4  cognate) 53.98396388907941
# Unweighted search time ( 5  cognate) 37.472560282930004
# Unweighted search time ( 6  cognate) 30.865393635912852
# Transport time:  [74.11111531119816]  +/-  [7.0986622593435635]
# Reaction time:  [12.115149346100205]  +/-  [1.320584165698035]
# Search time:  [86.26384474869549]  +/-  [8.141811169495536]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191008_0117/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
a=transportRxnCalc(gr_dict)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 72
# missing expt
# 78
# test
# missing expt
# 199
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 501.2047038582296
# Unweighted search time ( 2  cognate) 212.02638765561133
# Unweighted search time ( 3  cognate) 159.718512619134
# Unweighted search time ( 4  cognate) 127.4613284125958
# Unweighted search time ( 5  cognate) 131.73782664807416
# Unweighted search time ( 6  cognate) 84.18904732653245
# Transport time:  [196.0204379698916]  +/-  [18.1426633438063]
# Reaction time:  [14.865852991854108]  +/-  [2.0011216401101217]
# Search time:  [210.86824271658222]  +/-  [19.584696748613446]

# %%
#Order of running cells matters: must run from growth rate 0.6 to 3.0 sequentially to construct rxndiff dictionary in correct order
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191003_2140/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['06'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 26
# missing expt
# 89
# test
# missing expt
# 107
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 522.2100277508936
# Unweighted search time ( 2  cognate) 229.00602940464657
# Unweighted search time ( 3  cognate) 159.6566121777017
# Unweighted search time ( 4  cognate) 127.09043253560948
# Unweighted search time ( 5  cognate) 119.08559064124371
# Unweighted search time ( 6  cognate) 90.71170115249488
# Transport time:  [201.52406820717252]  +/-  [17.429379934624265]
# Reaction time:  [16.814881488895775]  +/-  [2.385729388379609]
# Search time:  [218.1744911199356]  +/-  [19.151234635306537]
# Unweighted search time ( 1  cognate) 522.2100277508936
# Unweighted search time ( 2  cognate) 229.00602940464657
# Unweighted search time ( 3  cognate) 159.6566121777017
# Unweighted search time ( 4  cognate) 127.09043253560948
# Unweighted search time ( 5  cognate) 119.08559064124371
# Unweighted search time ( 6  cognate) 90.71170115249488
# Transport time:  [201.52406820717252]  +/-  [17.429379934624265]
# Reaction time:  [16.814881488895775]  +/-  [2.385729388379609]
# Search time:  [218.1744911199356]  +/-  [19.151234635306537]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_0018/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['10'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 517.3298077389225
# Unweighted search time ( 2  cognate) 259.0803507864832
# Unweighted search time ( 3  cognate) 153.1718140713935
# Unweighted search time ( 4  cognate) 131.7975269482065
# Unweighted search time ( 5  cognate) 91.13521597333369
# Unweighted search time ( 6  cognate) 68.45786035531714
# Transport time:  [183.36323507028234]  +/-  [20.794460386114622]
# Reaction time:  [37.15256800466917]  +/-  [4.845642789225116]
# Search time:  [220.5817170797564]  +/-  [25.092361965257567]
# Unweighted search time ( 1  cognate) 517.3298077389225
# Unweighted search time ( 2  cognate) 259.0803507864832
# Unweighted search time ( 3  cognate) 153.1718140713935
# Unweighted search time ( 4  cognate) 131.7975269482065
# Unweighted search time ( 5  cognate) 91.13521597333369
# Unweighted search time ( 6  cognate) 68.45786035531714
# Transport time:  [183.36323507028234]  +/-  [20.794460386114622]
# Reaction time:  [37.15256800466917]  +/-  [4.845642789225116]
# Search time:  [220.5817170797564]  +/-  [25.092361965257567]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_0104/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['15'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 360.2360309517516
# Unweighted search time ( 2  cognate) 192.55059116825933
# Unweighted search time ( 3  cognate) 140.96355023380931
# Unweighted search time ( 4  cognate) 71.11000012852858
# Unweighted search time ( 5  cognate) 74.24271171184432
# Unweighted search time ( 6  cognate) 56.59104186815171
# Transport time:  [128.86672826164005]  +/-  [13.97253904554685]
# Reaction time:  [30.768611149544668]  +/-  [3.7497730089674044]
# Search time:  [159.56617476796484]  +/-  [17.21233680294632]
# Unweighted search time ( 1  cognate) 360.2360309517516
# Unweighted search time ( 2  cognate) 192.55059116825933
# Unweighted search time ( 3  cognate) 140.96355023380931
# Unweighted search time ( 4  cognate) 71.11000012852858
# Unweighted search time ( 5  cognate) 74.24271171184432
# Unweighted search time ( 6  cognate) 56.59104186815171
# Transport time:  [128.86672826164005]  +/-  [13.97253904554685]
# Reaction time:  [30.768611149544668]  +/-  [3.7497730089674044]
# Search time:  [159.56617476796484]  +/-  [17.21233680294632]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_1129/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['20'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 265.1081216887299
# Unweighted search time ( 2  cognate) 143.1208450491353
# Unweighted search time ( 3  cognate) 85.51367213822965
# Unweighted search time ( 4  cognate) 74.11906021006446
# Unweighted search time ( 5  cognate) 46.77723126156583
# Unweighted search time ( 6  cognate) 42.104707284661515
# Transport time:  [94.02038478831801]  +/-  [9.658348819739308]
# Reaction time:  [22.95819861330361]  +/-  [2.6863563243366664]
# Search time:  [116.73492949511795]  +/-  [12.092038197105348]
# Unweighted search time ( 1  cognate) 265.1081216887299
# Unweighted search time ( 2  cognate) 143.1208450491353
# Unweighted search time ( 3  cognate) 85.51367213822965
# Unweighted search time ( 4  cognate) 74.11906021006446
# Unweighted search time ( 5  cognate) 46.77723126156583
# Unweighted search time ( 6  cognate) 42.104707284661515
# Transport time:  [94.02038478831801]  +/-  [9.658348819739308]
# Reaction time:  [22.95819861330361]  +/-  [2.6863563243366664]
# Search time:  [116.73492949511795]  +/-  [12.092038197105348]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_1217/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['25'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# missing expt
# 202
# test
# test
# missing expt
# 462
# test
# Unweighted search time ( 1  cognate) 265.4082878959546
# Unweighted search time ( 2  cognate) 111.16869202562876
# Unweighted search time ( 3  cognate) 80.42520293618176
# Unweighted search time ( 4  cognate) 53.12912919107203
# Unweighted search time ( 5  cognate) 53.58153408181576
# Unweighted search time ( 6  cognate) 34.45386630334628
# Transport time:  [89.99546911093269]  +/-  [8.901813545559065]
# Reaction time:  [18.22383888672505]  +/-  [1.9810995551946442]
# Search time:  [108.21864697169785]  +/-  [10.610931444685157]
# Unweighted search time ( 1  cognate) 265.4082878959546
# Unweighted search time ( 2  cognate) 111.16869202562876
# Unweighted search time ( 3  cognate) 80.42520293618176
# Unweighted search time ( 4  cognate) 53.12912919107203
# Unweighted search time ( 5  cognate) 53.58153408181576
# Unweighted search time ( 6  cognate) 34.45386630334628
# Transport time:  [89.99546911093269]  +/-  [8.901813545559065]
# Reaction time:  [18.22383888672505]  +/-  [1.9810995551946442]
# Search time:  [108.21864697169785]  +/-  [10.610931444685157]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191003_2210/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['30'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 193.50805692654166
# Unweighted search time ( 2  cognate) 97.50257270318752
# Unweighted search time ( 3  cognate) 75.35462491997365
# Unweighted search time ( 4  cognate) 48.25520551254747
# Unweighted search time ( 5  cognate) 37.06770360913733
# Unweighted search time ( 6  cognate) 31.03992280319433
# Transport time:  [72.03916235568978]  +/-  [7.163253554828825]
# Reaction time:  [13.091034088601893]  +/-  [1.6609126343050593]
# Search time:  [85.23596075222612]  +/-  [8.67273978191621]
# Unweighted search time ( 1  cognate) 193.50805692654166
# Unweighted search time ( 2  cognate) 97.50257270318752
# Unweighted search time ( 3  cognate) 75.35462491997365
# Unweighted search time ( 4  cognate) 48.25520551254747
# Unweighted search time ( 5  cognate) 37.06770360913733
# Unweighted search time ( 6  cognate) 31.03992280319433
# Transport time:  [72.03916235568978]  +/-  [7.163253554828825]
# Reaction time:  [13.091034088601893]  +/-  [1.6609126343050593]
# Search time:  [85.23596075222612]  +/-  [8.67273978191621]

# %%
[d for d in rxndiff]
# Out:
# ['06', '10', '15', '20', '25', '30']

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}


colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
markers = ['*','^']

fig,[ax1,ax2,ax]= plt.subplots(1,3,figsize=(28,7))
twin1 = ax1.twiny()
twin1a = ax1.twiny()
twin2 = ax2.twiny()
twin2a = ax2.twiny()

for _,axes in enumerate([ax,ax1,ax2,twin1,twin1a,twin2,twin2a]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.1,0.5)
    
ax1.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='^',color='black',label='Rodnina kinetic parameters')
#ax1.plot(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.scatter(phi_list,[rxndiff[d][0][0]/3 for d in rxndiff],zorder=2,s=200,marker='s',color='black',label='Ehrenberg kinetic parameters')
#ax1.plot(phi_list,[rxndiff[d][0][0]/3 for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.errorbar(phi_list,[rxndiff[d][0][0]/3 for d in rxndiff],[rxndiff[d][3][0]/3 for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$\phi_{ voxel}$',fontsize=25)
ax1.set_ylabel("Transport time (ms)",fontsize=25)
ax1.legend()
ax1.legend( prop={'size': 15})


ax2.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='^',color='black')
#ax2.plot(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.scatter(phi_list,[rxndiff[d][1][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=200,marker='s',color='black')
#ax2.plot(phi_list,[rxndiff[d][1][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0]/3 for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

ax2.set_xlabel('$\phi_{ voxel}$',fontsize=25)
ax2.set_ylabel("Reaction time(ms)",fontsize=25)

ax.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='^',color='black')
#ax.plot(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax.scatter(phi_list,[rxndiff[d][2][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=200,marker='s',color='black')
#ax.plot(phi_list,[rxndiff[d][2][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax.errorbar(phi_list,[rxndiff[d][2][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0]/3 for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax.scatter(phi_list,[1000/12,1000/16,1000/18,1000/20,1000/21,1000/22],zorder=2,s=200,marker='o',color='black',label='Empirical bulk elongation')
ax.plot(phi_list,[1000/12,1000/16,1000/18,1000/20,1000/21,1000/22],zorder=1,linewidth=4,color='black')
ax.set_xlabel('$\phi_{ voxel}$',fontsize=25)
ax.set_ylabel("Elongation time (ms)",fontsize=25)
ax.legend()
ax.legend( prop={'size': 15})

twin1.plot([rxndiff[d][0] for d in rxndiff], [rxndiff[d][0] for d in rxndiff],linewidth=0)
twin1.spines['bottom'].set_position(('outward', 75))
twin1.xaxis.set_ticks_position("bottom")
twin1.xaxis.set_label_position("bottom")
twin1.set_xlabel('$Relative\: Viscosity\:(η_{r,0})$',fontsize=25)
twin1.set_xticks(phi_list)
twin1.set_xticklabels([19.9, 27.0, 31.5, 32.4, 31.8, 28.9],rotation=40)

twin1a.plot([rxndiff[d][0] for d in rxndiff], [rxndiff[d][0] for d in rxndiff],linewidth=0)
twin1a.spines['bottom'].set_position(('outward', 175))
twin1a.xaxis.set_ticks_position("bottom")
twin1a.xaxis.set_label_position("bottom")
twin1a.set_xlabel('$L_{vox}\:[nm] $',fontsize=25)
twin1a.set_xticks(phi_list)
twin1a.set_xticklabels([101,93,84,77,72,68])

twin2.plot([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff], [rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],linewidth=0)
twin2.spines['bottom'].set_position(('outward', 75))
twin2.xaxis.set_ticks_position("bottom")
twin2.xaxis.set_label_position("bottom")
twin2.set_xlabel('$\# \:Ribosomes \:per \:voxel$',fontsize=25)
twin2.set_xticks(phi_list)
twin2.set_xticklabels(np.array([4,8,9,9,8,7]))


twin2a.plot([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff], [rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],linewidth=0)
twin2a.spines['bottom'].set_position(('outward', 150))
twin2a.xaxis.set_ticks_position("bottom")
twin2a.xaxis.set_label_position("bottom")
twin2a.set_xticks(phi_list)
twin2a.set_xlabel('$\u25A0\:\phi_{crowder}/\phi_{ribosome}$',fontsize=25)
twin2a.set_xticklabels(np.array([round(0.06434998409146828/0.0322,2),round(0.08752983986220697/0.0909,2),round(0.10039264723107891/0.141,2),round(0.10253311875190417/0.175,2),round(0.09787505368673738/0.200,2),round(0.0886440269099349/0.218,2)])
,rotation=40);
#the secondary rise in transport time could be because the
#decrease in crowding is reducing facilitiated mixing of 
#not only cognate away from incorrect repeats,
#but also incorrect cognates repeat reacting and blocking the cognate ribosome!
#I should also get a graph to show that cognate blocking point. Can compare the 
#2nd and 5th point which have same ribosomes, but 2nd has more crowders (though)
#different voxel size. 2nd maybe faster bcz facilitated mixing

#plt.text(0.66,38,'$\u25B2\:$',fontsize=22)
#plt.text(0.68,37.8,'Rodnina kinetic parameters',style='italic',fontsize=20)
#plt.text(0.659,36,'$\u25A0\:$',fontsize=20)
#plt.text(0.679,35.8,'Ehrenberg kinetic parameters',style='italic',fontsize=20)
#plt.text(0.659,34,'$\u25CF\:$',fontsize=22)
#plt.text(0.679,33.9,'Experimental bulk rate',style='italic',fontsize=20)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}


colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
markers = ['*','^']

fig,[ax1,ax2,ax]= plt.subplots(1,3,figsize=(25,8))

for _,axes in enumerate([ax,ax1,ax2,twin1,twin1a,twin2,twin2a]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
ax1.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='^',color='black',label='Rodnina kinetic parameters')
#ax1.plot(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.scatter(phi_list,[rxndiff[d][0][0]/3 for d in rxndiff],zorder=2,s=200,marker='s',color='black',label='Ehrenberg kinetic parameters')
#ax1.plot(phi_list,[rxndiff[d][0][0]/3 for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.errorbar(phi_list,[rxndiff[d][0][0]/3 for d in rxndiff],[rxndiff[d][3][0]/3 for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Transport\: time,\:\tau_{trans}\: [ms]$',fontsize=30)
ax1.legend()
ax1.legend( prop={'size': 15})
ax1.set_title('Transport',fontsize=45)
ax1.set_yticks(np.arange(25, 201, 25))


ax2.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='^',color='black')
#ax2.plot(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.scatter(phi_list,[rxndiff[d][1][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=200,marker='s',color='black')
#ax2.plot(phi_list,[rxndiff[d][1][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0]/3 for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

ax2.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax2.set_ylabel(r'$Reaction\: time,\:\tau_{rxn}\: [ms]$',fontsize=30)
ax2.set_title('Reaction',fontsize=45)


ax.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='^',color='black')
#ax.plot(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax.scatter(phi_list,[rxndiff[d][2][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=200,marker='s',color='black')
#ax.plot(phi_list,[rxndiff[d][2][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=1,linewidth=4,linestyle='dashed',color='black')
ax.errorbar(phi_list,[rxndiff[d][2][0]/3+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0]/3 for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=10,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')


ax.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax.set_ylabel(r'$Elongation\: time,\:\tau_{elong}\: [ms]$',fontsize=30)
ax.legend()
ax.legend( prop={'size': 15})
ax.set_title('Total',fontsize=45)



ax1 = ax1.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))

ax1 = ax.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))

ax1 = ax2.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))


plt.tight_layout()

#the secondary rise in transport time could be because the
#decrease in crowding is reducing facilitiated mixing of 
#not only cognate away from incorrect repeats,
#but also incorrect cognates repeat reacting and blocking the cognate ribosome!
#I should also get a graph to show that cognate blocking point. Can compare the 
#2nd and 5th point which have same ribosomes, but 2nd has more crowders (though)
#different voxel size. 2nd maybe faster bcz facilitated mixing
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}


colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
markers = ['*','^']

fig,[ax,ax2,ax1]= plt.subplots(1,3,figsize=(25,8))



#######
ax.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

ax.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax.set_ylabel(r'$Elongation\: time,\: [ms]$',fontsize=30)
print([rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],expt))
#print(np.subtract(y_hat_sweep_i,1000/1529+1000/209+1000/200+1000/32))


######
for _,axes in enumerate([ax,ax1,ax2]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
ax1.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black',label='Rodnina kinetic parameters')
ax1.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Transport\: time\: [ms]$',fontsize=30)
ax1.set_yticks(np.arange(0, 226, 25))

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,hatch="XX",edgecolor='black',alpha=0.3,facecolor='green')
print([rxndiff[d][0][0] for d in rxndiff])
#print(y_hat_sweep_i)
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],expt))
true_trans = y_hat_sweep_i



#######
ax2.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

ax2.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax2.set_ylabel(r'$Reaction\: time\: [ms]$',fontsize=30)

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/1529+1000/209+1000/200+1000/32]*len(x),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
true_rxn = y_hat_sweep_i



ax.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax.set_ylabel(r'$Elongation\: time\:[ms]$',fontsize=30)
print([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],expt))


ax1 = ax1.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)


ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)


ax1 = ax2.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)


plt.tight_layout()

print("Elongation time, ", ([rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
print("Transport time ", [rxndiff[d][0][0] for d in rxndiff])
print("Reaction time ", [rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print("Da sim: ",  np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
#print("Da reality: ",true_trans/true_rxn)

#the secondary rise in transport time could be because the
#decrease in crowding is reducing facilitiated mixing of 
#not only cognate away from incorrect repeats,
#but also incorrect cognates repeat reacting and blocking the cognate ribosome!
#I should also get a graph to show that cognate blocking point. Can compare the 
#2nd and 5th point which have same ribosomes, but 2nd has more crowders (though)
#different voxel size. 2nd maybe faster bcz facilitated mixing
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [259.863202351907, 262.27042831172776, 201.2548859999362, 158.42364072708932, 149.90735820366922, 126.92467198419749]
# [82.44545311560373, 49.07084465480462]
# [3.15194098 2.58655976]
# [201.52406820717252, 183.36323507028234, 128.86672826164005, 94.02038478831801, 89.99546911093269, 72.03916235568978]
# [40.75674188363234, 7.382133422833249]
# [4.94455785 9.75858309]
# [58.50359272086713, 78.84127923664053, 72.45732238151604, 64.64690984527496, 59.912550118696416, 54.779745320573255]
# [41.688711231971375, 41.68871123197137, 41.68871123197137]
# [1.40334376 1.89119013 1.31401868]
# Elongation time,  [259.863202351907, 262.27042831172776, 201.2548859999362, 158.42364072708932, 149.90735820366922, 126.92467198419749]
# Transport time  [201.52406820717252, 183.36323507028234, 128.86672826164005, 94.02038478831801, 89.99546911093269, 72.03916235568978]
# Reaction time  [58.50359272086713, 78.84127923664053, 72.45732238151604, 64.64690984527496, 59.912550118696416, 54.779745320573255]
# Da sim:  [3.44464432 2.32572628 1.77851905 1.45436781 1.50211381 1.31506932]

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}


colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
markers = ['*','^']

fig,ax1= plt.subplots(1,1,figsize=(8,2))


######
for _,axes in enumerate([ax1]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(0)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(0)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    axes.get_xaxis().set_ticks([])
    
ax1.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black',label='Rodnina kinetic parameters')
ax1.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
#ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$\tau_{transp}\: [ms]$',fontsize=25)
ax1.set_yticks(np.arange(50, 226, 50))

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)

print([rxndiff[d][0][0] for d in rxndiff])
#print(y_hat_sweep_i)
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],expt))
true_trans = y_hat_sweep_i
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [201.52406820717252, 183.36323507028234, 128.86672826164005, 94.02038478831801, 89.99546911093269, 72.03916235568978]
# [40.75674188363234, 7.382133422833249]
# [4.94455785 9.75858309]

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}


colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
markers = ['*','^']

fig,ax2= plt.subplots(1,1,figsize=(8,2))


######
for _,axes in enumerate([ax2]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(0)
    axes.spines['right'].set_linewidth(0)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    axes.get_xaxis().set_ticks([])

ax2.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_yticks(np.arange(50, 90, 10))

ax2.set_ylabel(r'$\tau_{rxn}\: [ms]$',size=25,color='black')
#ax2.set_ylabel(r'$Reaction\: time\: [ms]$',fontsize=30)

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/1529+1000/209+1000/200+1000/32]*len(x),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
true_rxn = y_hat_sweep_i

print([rxndiff[d][0][0] for d in rxndiff])
#print(y_hat_sweep_i)
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],expt))
true_trans = y_hat_sweep_i
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [201.52406820717252, 183.36323507028234, 128.86672826164005, 94.02038478831801, 89.99546911093269, 72.03916235568978]
# [41.688711231971375, 41.68871123197137]
# [4.8340201  1.72802565]

# %%
fig,ax1=plt.subplots(1,1,figsize=(8.5,8))

for _,axes in enumerate([ax1]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
ax1.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='^',color='black',label='Rodnina kinetic parameters')
ax1.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Da$',fontsize=30)
#ax1.set_yticks(np.arange(0, 226, 25))

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)

ax1.plot(x_sweep_i,true_trans/true_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax1.fill_between(x_sweep_i, true_trans/true_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
print([rxndiff[d][0][0] for d in rxndiff])
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],expt))

ax1 = ax1.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black')
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)
# Out:
# [201.52406820717252, 183.36323507028234, 128.86672826164005, 94.02038478831801, 89.99546911093269, 72.03916235568978]
# [40.75674188363234, 7.382133422833249]
# [4.94455785 9.75858309]
# [Text(0, 1, '0.6'),
#  Text(0, 1, '1.0'),
#  Text(0, 1, '1.5'),
#  Text(0, 1, '2.0'),
#  Text(0, 1, '2.5'),
#  Text(0, 1, '3.0')]

# %%
x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)

elong_empir=list()

for i in range(len(x)):
    print(x_sweep_i[np.abs(x_sweep_i-x[i]).argmin()],y_hat_sweep_i[np.abs(x_sweep_i-x[i]).argmin()])
    elong_empir.append(y_hat_sweep_i[np.abs(x_sweep_i-x[i]).argmin()])

print(elong_empir)
print(elong_empir-np.array((1000/1529+1000/209+1000/200+1000/32)))
# Out:
# 0.13172292 82.44545311560373
# 0.22362255243243243 64.80173984744593
# 0.3018101762162162 54.953890127858514
# 0.35578297621621624 50.92539189171946
# 0.3945850432432433 49.42689484353585
# 0.42317604 49.07084465480462
# [82.44545311560373, 64.80173984744593, 54.953890127858514, 50.92539189171946, 49.42689484353585, 49.07084465480462]
# [40.75674188 23.11302862 13.2651789   9.23668066  7.73818361  7.38213342]

# %%
print([rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
# Out:
# [259.5387679125794, 261.9626853605742, 200.99823132492574, 158.14946883794846, 149.5797439370685, 126.7114369897665]
# [19.019761433736456, 25.03967369749926, 17.15955904335685, 12.091930180964793, 10.72742391147397, 8.62651849552703]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "190916_1101/"
gr_sim = dict()
rxndiff_1=dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=1000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
transportRxnCalc(gr_dict)
rxndiff_1['3000'] = transportRxnCalc(gr_dict)[1:]


data = "191114_2050/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=600)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
transportRxnCalc(gr_dict)
rxndiff_1['1800'] = transportRxnCalc(gr_dict)[1:]


data = "190917_0105/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
transportRxnCalc(gr_dict)
rxndiff_1['600'] = transportRxnCalc(gr_dict)[1:]


data = "190918_1046/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
transportRxnCalc(gr_dict)
rxndiff_1['300'] = transportRxnCalc(gr_dict)[1:]

data = "190921_2357/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=20)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
transportRxnCalc(gr_dict)
rxndiff_1['60'] = transportRxnCalc(gr_dict)[1:]


data = "190921_2258/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=10)
    gr_sim[i] = (CellLatencies(sim_i))
    
gr_dict = {'gr_1':gr_sim}
transportRxnCalc(gr_dict)
rxndiff_1['30'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 265.5071754526627
# Unweighted search time ( 2  cognate) 226.525332445005
# Unweighted search time ( 3  cognate) 196.27234202166724
# Unweighted search time ( 4  cognate) 104.27241847996498
# Unweighted search time ( 5  cognate) 156.48686666882833
# Unweighted search time ( 6  cognate) 116.97297358565713
# Transport time:  [133.6443218157066]  +/-  [13.216483318867164]
# Reaction time:  [23.898980659236244]  +/-  [2.737039575092804]
# Search time:  [157.60822809899688]  +/-  [15.446755925292942]
# Unweighted search time ( 1  cognate) 265.5071754526627
# Unweighted search time ( 2  cognate) 226.525332445005
# Unweighted search time ( 3  cognate) 196.27234202166724
# Unweighted search time ( 4  cognate) 104.27241847996498
# Unweighted search time ( 5  cognate) 156.48686666882833
# Unweighted search time ( 6  cognate) 116.97297358565713
# Transport time:  [133.6443218157066]  +/-  [13.216483318867164]
# Reaction time:  [23.898980659236244]  +/-  [2.737039575092804]
# Search time:  [157.60822809899688]  +/-  [15.446755925292942]
# test
# missing expt
# 21
# missing expt
# 49
# missing expt
# 54
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 183.55181316545307
# Unweighted search time ( 2  cognate) 133.81334814079858
# Unweighted search time ( 3  cognate) 83.75972038653494
# Unweighted search time ( 4  cognate) 48.25952626096251
# Unweighted search time ( 5  cognate) 37.966886108159
# Unweighted search time ( 6  cognate) 35.265229074366715
# Transport time:  [77.59110842133984]  +/-  [7.508854448945071]
# Reaction time:  [13.457035313993572]  +/-  [1.5929628901038146]
# Search time:  [91.09638225924388]  +/-  [8.960739914350517]
# Unweighted search time ( 1  cognate) 183.55181316545307
# Unweighted search time ( 2  cognate) 133.81334814079858
# Unweighted search time ( 3  cognate) 83.75972038653494
# Unweighted search time ( 4  cognate) 48.25952626096251
# Unweighted search time ( 5  cognate) 37.966886108159
# Unweighted search time ( 6  cognate) 35.265229074366715
# Transport time:  [77.59110842133984]  +/-  [7.508854448945071]
# Reaction time:  [13.457035313993572]  +/-  [1.5929628901038146]
# Search time:  [91.09638225924388]  +/-  [8.960739914350517]
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 202.05292532283784
# Unweighted search time ( 2  cognate) 84.9471749458489
# Unweighted search time ( 3  cognate) 60.79734393037365
# Unweighted search time ( 4  cognate) 45.90360048655482
# Unweighted search time ( 5  cognate) 34.17655928482238
# Unweighted search time ( 6  cognate) 33.243244883310716
# Transport time:  [70.46565129986426]  +/-  [7.075322660305273]
# Reaction time:  [12.186816348231071]  +/-  [1.4029537374087209]
# Search time:  [82.70359942822535]  +/-  [8.322472194143854]
# Unweighted search time ( 1  cognate) 202.05292532283784
# Unweighted search time ( 2  cognate) 84.9471749458489
# Unweighted search time ( 3  cognate) 60.79734393037365
# Unweighted search time ( 4  cognate) 45.90360048655482
# Unweighted search time ( 5  cognate) 34.17655928482238
# Unweighted search time ( 6  cognate) 33.243244883310716
# Transport time:  [70.46565129986426]  +/-  [7.075322660305273]
# Reaction time:  [12.186816348231071]  +/-  [1.4029537374087209]
# Search time:  [82.70359942822535]  +/-  [8.322472194143854]
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 170.70482248336788
# Unweighted search time ( 2  cognate) 104.61144031032053
# Unweighted search time ( 3  cognate) 56.03980485923643
# Unweighted search time ( 4  cognate) 48.56980529142186
# Unweighted search time ( 5  cognate) 32.84968911653415
# Unweighted search time ( 6  cognate) 29.3365362096165
# Transport time:  [66.64986568908995]  +/-  [7.45367885443181]
# Reaction time:  [11.244959223598912]  +/-  [1.477612764863845]
# Search time:  [77.97080836265432]  +/-  [8.683243418429404]
# Unweighted search time ( 1  cognate) 170.70482248336788
# Unweighted search time ( 2  cognate) 104.61144031032053
# Unweighted search time ( 3  cognate) 56.03980485923643
# Unweighted search time ( 4  cognate) 48.56980529142186
# Unweighted search time ( 5  cognate) 32.84968911653415
# Unweighted search time ( 6  cognate) 29.3365362096165
# Transport time:  [66.64986568908995]  +/-  [7.45367885443181]
# Unweighted search time ( 3  cognate) 63.656972505086046
# Unweighted search time ( 4  cognate) 53.099345853436304
# Unweighted search time ( 5  cognate) 39.1306285537227
# Unweighted search time ( 6  cognate) 26.92353335380655
# Transport time:  [79.65004186715244]  +/-  [8.707073955255076]
# Reaction time:  [13.062520892232607]  +/-  [1.6316660015429225]
# Search time:  [92.79988334123865]  +/-  [10.128843281249651]
# test
# missing expt
# 58
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 159.19330568536236
# Unweighted search time ( 2  cognate) 96.1343592295139
# Unweighted search time ( 3  cognate) 67.4892658019863
# Unweighted search time ( 4  cognate) 41.3360393251621
# Unweighted search time ( 5  cognate) 30.995116401863392
# Unweighted search time ( 6  cognate) 27.367287270492586
# Transport time:  [62.75823855732986]  +/-  [6.462896272221431]
# Reaction time:  [11.496966760353832]  +/-  [1.3536690088082337]
# Search time:  [74.20495490781583]  +/-  [7.560221326306743]
# Unweighted search time ( 1  cognate) 159.19330568536236
# Unweighted search time ( 2  cognate) 96.1343592295139
# Unweighted search time ( 3  cognate) 67.4892658019863
# Unweighted search time ( 4  cognate) 41.3360393251621
# Unweighted search time ( 5  cognate) 30.995116401863392
# Unweighted search time ( 6  cognate) 27.367287270492586
# Transport time:  [62.75823855732986]  +/-  [6.462896272221431]
# Reaction time:  [11.496966760353832]  +/-  [1.3536690088082337]
# Search time:  [74.20495490781583]  +/-  [7.560221326306743]

# %%
fig, ax = plt.subplots(1,1,figsize=(12,10))
x=[3000,1800,600,300,60,30]
ax.scatter(x,[rxndiff_1[d][0][0] for d in rxndiff_1],zorder=2,s=250,marker='^',color='black',label='Rodnina kinetic parameters')
ax.errorbar(x,[rxndiff_1[d][0][0] for d in rxndiff_1],[rxndiff_1[d][3][0] for d in rxndiff_1],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.set_xlabel('Kinetic rate scaling',size=45,color='black')
ax.set_ylabel('Transport time (ms)',size=45,color='black')
ax.legend()
ax.legend( prop={'size': 20})

fig, ax = plt.subplots(1,1,figsize=(12,10))
x=[3000,1800,600,300,60,30]
ax.scatter(x,[rxndiff_1[d][1][0] for d in rxndiff_1],zorder=2,s=250,marker='^',color='black',label='Rodnina kinetic parameters')
ax.errorbar(x,[rxndiff_1[d][1][0] for d in rxndiff_1],[rxndiff_1[d][4][0] for d in rxndiff_1],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.set_xlabel('Kinetic rate scaling',size=45,color='black')
ax.set_ylabel('Incorrect reaction time (ms)',size=45,color='black')
ax.legend()
ax.legend( prop={'size': 20})

fig, ax = plt.subplots(1,1,figsize=(12,10))
x=[3000,1800,600,300,60,30]

ax.scatter(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],zorder=2,s=250,marker='^',color='black')
ax.errorbar(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],[rxndiff_1[d][5][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
x = np.linspace(3000, 0, 100)
ax.plot(x,trendpoly(x),zorder=1,linewidth=4,linestyle='dashed',color='black')

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.set_xlabel('Kinetic rate scaling',size=45,color='black')
ax.set_ylabel('Elongation time (ms)',size=45,color='black')
ax.legend()
ax.legend( prop={'size': 20})


def calc_R2(x,y,y_hat):
    SS_tot = np.sum((y-np.average(y))**2) #Sum of squares total (proportional to variance; n times larger than variance)
    SS_err = np.sum((y-y_hat)**2) # Sum of squared errors
    return 1-SS_err/SS_tot
#print(calc_R2(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],trendpoly(x)))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1]
# Out:
# [192.18485908804703,
#  116.50510197799451,
#  113.05228770829305,
#  124.3332512852057,
#  109.87563237066587]

# %%
rxndiff_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-393-2568e22181d8> in <module>
# ----> 1 rxndiff_1
#
# NameError: name 'rxndiff_1' is not defined

# %%
import pandas as pd
my_cols=["time","rxn","x","y","z","reactantA","productA","productB","productC"]
df=pd.read_csv('/Users/Akshay/Documents/TranslationDynamics/data/191003_2140/expt-10-Reactions-20191003.csv',sep=' ',header=None,names=my_cols)

df1=df.loc[df['rxn'].isin(["rxn23"])]
a=df1[df1["productA"]==45]
a
# Out:
#           time    rxn          x          y          z  reactantA  productA  \
# 0       0.0002  rxn23  16.868666  10.734221  16.743342       12.0        45
# 2      10.9345  rxn23   0.994349  11.599961   0.472630       12.0        45
# 4      17.7828  rxn23   3.973929  11.646419   1.442708       38.0        45
# 6      24.0060  rxn23   4.074365  10.830490   1.755679       38.0        45
# 8      37.5066  rxn23   4.396449  12.612292  17.544943       38.0        45
# 10     49.5733  rxn23   5.284144  13.949743  15.744733       38.0        45
# 12     61.3270  rxn23   3.554823  13.321353  14.480202       38.0        45
# 14     78.3418  rxn23   2.016041  14.977651  15.203401       38.0        45
# 16     79.3525  rxn23   1.971412  15.379026  15.494198       38.0        45
# 18     94.4317  rxn23   1.257665  16.434669  16.119949       38.0        45
# 20    101.5726  rxn23   0.811923  16.332231  15.419148       38.0        45
# 22    117.3787  rxn23   2.607701  16.340820  15.305108       23.0        45
# 24    120.1996  rxn23   1.480712  15.458697  15.628993       23.0        45
# 27    160.0984  rxn23  15.558812  12.693935  14.542471       23.0        45
# 39    178.9045  rxn23  14.512861  11.727903  14.569380       23.0        45
# 41    186.2962  rxn23  14.944624  13.236621  13.763768       23.0        45
# 45    188.7571  rxn23  16.201997  13.784472  15.170349       23.0        45
# 49    203.6209  rxn23  15.558688  15.274998  16.661724       23.0        45
# 51    213.2027  rxn23   0.332036  14.726184   0.907312       23.0        45
# 20      38.45       NaN
# 22      23.45       NaN
# 24      23.45       NaN
# 27      23.45       NaN
# 39      23.45       NaN
# 41      23.45       NaN
# 45      23.45       NaN
# 49      23.45       NaN
# 51      23.45       NaN
# 55      23.45       NaN
# 57      14.45       NaN
# 59      14.45       NaN
# 61      14.45       NaN
# 63      14.45       NaN
# 65      14.45       NaN
# 67      12.45       NaN
# 71      12.45       NaN
# 73       5.45       NaN
# 75       5.45       NaN
# 77       5.45       NaN
# 79       5.45       NaN
# 81       5.45       NaN
# 83       5.45       NaN
# 85       5.45       NaN
# 95       5.45       NaN
# 101      5.45       NaN
# 110      5.45       NaN
# 112      5.45       NaN
# 114      5.45       NaN
# 116     28.45       NaN
# 118      4.45       NaN
# 120     27.45       NaN
# 122     27.45       NaN
# 124     27.45       NaN
# 126     27.45       NaN
# 128     27.45       NaN
# 130     27.45       NaN
# 132     27.45       NaN
# 134     27.45       NaN
# 136     27.45       NaN
# 138      5.45       NaN
# 140     27.45       NaN
# 142     27.45       NaN
# 144     27.45       NaN
# 146     27.45       NaN
# 148     27.45       NaN
# 150     27.45       NaN
# 152     27.45       NaN
# 154     27.45       NaN
# 156     36.45       NaN
# 158     36.45       NaN
# 160     36.45       NaN
# 162     36.45       NaN
# 164     36.45       NaN
# 166     36.45       NaN
# 168     36.45       NaN
# 170     25.45       NaN
# 172     25.45       NaN
# 174     25.45       NaN
# 176     25.45       NaN
# 178     22.45       NaN
# 180     25.45       NaN
# 182     25.45       NaN
# 184     25.45       NaN
# 186     25.45       NaN
# 188     25.45       NaN
# 190     25.45       NaN
# 192     25.45       NaN
# 194     37.45       NaN
# 196     37.45       NaN
# 198     37.45       NaN
# 200     37.45       NaN
# 202     38.45       NaN
# 204     38.45       NaN
# 206     19.45       NaN
# 208     19.45       NaN
# 210     23.45       NaN
# 212     23.45       NaN
# 214     32.45       NaN
# 216     32.45       NaN
# 218     32.45       NaN
# 220     32.45       NaN
# 222     32.45       NaN
# 224     32.45       NaN
# 226     32.45       NaN
# 228     32.45       NaN
# 230     32.45       NaN
# 232     32.45       NaN
# 234     32.45       NaN
# 236     32.45       NaN
# 238     32.45       NaN
# 240     32.45       NaN
# 242     32.45       NaN
# 244     32.45       NaN
# 246     32.45       NaN
# 248     32.45       NaN
# 250     32.45       NaN
# 252     41.45       NaN
# 254     41.45       NaN
# 256     41.45       NaN
# 258     41.45       NaN
# 260     41.45       NaN
# 262     41.45       NaN
# 264     41.45       NaN
# 266     41.45       NaN
# 268     41.45       NaN
# 270      5.45       NaN
# 272      5.45       NaN
# 274      5.45       NaN
# 276      5.45       NaN
# 278      5.45       NaN
# 280      5.45       NaN
# 282      5.45       NaN
# 284      5.45       NaN
# 286      5.45       NaN
# 288      5.45       NaN
# 290      5.45       NaN
# 292      5.45       NaN
# 294     19.45       NaN
# 296     19.45       NaN
# 298     19.45       NaN
# 300     19.45       NaN
# 302     19.45       NaN
# 304     19.45       NaN
# 306     19.45       NaN
# 308     17.45       NaN
# 310     17.45       NaN
# 312     17.45       NaN
# 314     17.45       NaN
# 316     17.45       NaN
# 318     17.45       NaN
# 320     17.45       NaN
# 322     17.45       NaN
# 324     24.45       NaN
# 326     24.45       NaN
# 328     31.45       NaN
# 331     31.45       NaN
# 333     31.45       NaN
# 335     31.45       NaN
# 339     30.45       NaN
# 353     30.45       NaN
# 355     30.45       NaN
# 367     30.45       NaN
# 369     44.45       NaN
# 371     44.45       NaN
# 373     44.45       NaN
# 376     44.45       NaN
# 378     44.45       NaN
# 380     44.45       NaN
# 382     44.45       NaN
# 384     44.45       NaN
# 386     44.45       NaN
# 388     44.45       NaN
# 390     44.45       NaN
# 392     44.45       NaN
# 394     44.45       NaN
# 396     44.45       NaN
# 398     44.45       NaN
# 400     44.45       NaN
# 402     29.45       NaN
# 404     44.45       NaN
# 406     44.45       NaN
# 408     44.45       NaN
# 410     44.45       NaN
# 412     44.45       NaN
# 414     36.45       NaN
# 416     36.45       NaN
# 418     36.45       NaN
# 420     36.45       NaN
# 422     36.45       NaN
# 424     36.45       NaN
# 426     36.45       NaN
# 428     36.45       NaN
# 430     36.45       NaN
# 432     36.45       NaN
# 434     36.45       NaN
# 436     33.45       NaN
# 438     33.45       NaN
# 440      7.45       NaN
# 442      7.45       NaN
# 444      7.45       NaN
# 446      7.45       NaN
# 448      7.45       NaN
# 450      7.45       NaN
# 452      7.45       NaN
# 454      7.45       NaN
# 456     13.45       NaN
# 458     13.45       NaN
# 460     13.45       NaN
# 462     13.45       NaN
# 467     13.45       NaN
# 469     13.45       NaN
# 475     13.45       NaN
# 479      8.45       NaN
# 481      8.45       NaN
# 483     17.45       NaN
# 487     17.45       NaN
# 489     13.45       NaN
# 493     13.45       NaN
# 496     10.45       NaN
# 498     10.45       NaN
# 500     10.45       NaN
# 502     10.45       NaN
# 504     10.45       NaN
# 506     10.45       NaN
# 508     10.45       NaN
# 510     10.45       NaN
# 512     41.45       NaN
# 514     41.45       NaN
# 516     41.45       NaN
# 518     41.45       NaN
# 520     41.45       NaN
# 522     41.45       NaN
# 524     41.45       NaN
# 526     28.45       NaN
# 528     28.45       NaN
# 530     28.45       NaN
# 532     28.45       NaN
# 534     28.45       NaN
# 536     28.45       NaN
# 538     28.45       NaN
# 540     28.45       NaN
# 542     17.45       NaN

# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)
my_cols=["time","rxn","x","y","z","reactantA","productA","productB","productC"]
df=pd.read_csv('/Users/Akshay/Documents/TranslationDynamics/data/191003_2140/expt-10-Reactions-20191003.csv',sep=' ',header=None,names=my_cols)

df2=df.loc[df['rxn'].isin(["rxn24"])]
df2
# Out:
#           time    rxn          x          y          z  reactantA  productA  \
# 1      10.9341  rxn24   0.989177  11.607650   0.487360      12.45        12
# 3      17.7820  rxn24   2.423462  11.740002   0.911402      12.45        12
# 5      24.0056  rxn24   4.136733  10.850978   1.808339      38.45        38
# 7      37.5035  rxn24   4.522987  12.639350   0.239641      38.45        38
# 9      49.5731  rxn24   5.278381  13.976752  15.762370      38.45        38
# 11     61.3238  rxn24   3.502399  13.223003  14.565792      38.45        38
# 13     78.3395  rxn24   2.095555  14.979078  15.347103      38.45        38
# 529  2412.5021  rxn24  10.135069  14.529300  13.011147      28.45        28
# 531  2424.2440  rxn24   8.926344  13.994136  13.025071      28.45        28
# 533  2424.4561  rxn24   8.952605  14.024290  12.824557      28.45        28
# 535  2460.1584  rxn24   9.362123  13.711861   9.854732      28.45        28
# 537  2466.2103  rxn24   9.912374  13.386794   9.281100      28.45        28
# 539  2470.5951  rxn24  10.581915  13.838918   9.802064      28.45        28
# 541  2477.7546  rxn24   9.940790  14.094460  10.865086      28.45        28
# 543  2483.8863  rxn24  10.944163  16.307694  12.131999      17.45        17
#
#      productB  productC
# 1        45.0       NaN
# 3        45.0       NaN
# 5        45.0       NaN
# 7        45.0       NaN
# 9        45.0       NaN
# 11       45.0       NaN
# 13       45.0       NaN
# 15       45.0       NaN
# 17       45.0       NaN
# 19       45.0       NaN
# 21       45.0       NaN
# 23       45.0       NaN
# 26       45.0       NaN
# 38       45.0       NaN
# 40       45.0       NaN
# 44       45.0       NaN
# 48       45.0       NaN
# 50       45.0       NaN
# 54       45.0       NaN
# 56       45.0       NaN
# 58       45.0       NaN
# 60       45.0       NaN
# 62       45.0       NaN
# 64       45.0       NaN
# 66       45.0       NaN
# 70       45.0       NaN
# 72       45.0       NaN
# 74       45.0       NaN
# 76       45.0       NaN
# 78       45.0       NaN
# 80       45.0       NaN
# 82       45.0       NaN
# 84       45.0       NaN
# 94       45.0       NaN
# 100      45.0       NaN
# 109      45.0       NaN
# 111      45.0       NaN
# 113      45.0       NaN
# 115      45.0       NaN
# 117      45.0       NaN
# 119      45.0       NaN
# 121      45.0       NaN
# 123      45.0       NaN
# 125      45.0       NaN
# 127      45.0       NaN
# 129      45.0       NaN
# 131      45.0       NaN
# 133      45.0       NaN
# 135      45.0       NaN
# 137      45.0       NaN
# 139      45.0       NaN
# 141      45.0       NaN
# 143      45.0       NaN
# 145      45.0       NaN
# 147      45.0       NaN
# 149      45.0       NaN
# 151      45.0       NaN
# 153      45.0       NaN
# 155      45.0       NaN
# 157      45.0       NaN
# 159      45.0       NaN
# 161      45.0       NaN
# 163      45.0       NaN
# 165      45.0       NaN
# 167      45.0       NaN
# 169      45.0       NaN
# 171      45.0       NaN
# 173      45.0       NaN
# 175      45.0       NaN
# 177      45.0       NaN
# 179      45.0       NaN
# 181      45.0       NaN
# 183      45.0       NaN
# 185      45.0       NaN
# 187      45.0       NaN
# 189      45.0       NaN
# 191      45.0       NaN
# 193      45.0       NaN
# 195      45.0       NaN
# 197      45.0       NaN
# 199      45.0       NaN
# 201      45.0       NaN
# 203      45.0       NaN
# 205      45.0       NaN
# 207      45.0       NaN
# 209      45.0       NaN
# 211      45.0       NaN
# 213      45.0       NaN
# 215      45.0       NaN
# 217      45.0       NaN
# 219      45.0       NaN
# 221      45.0       NaN
# 223      45.0       NaN
# 225      45.0       NaN
# 227      45.0       NaN
# 229      45.0       NaN
# 231      45.0       NaN
# 233      45.0       NaN
# 235      45.0       NaN
# 237      45.0       NaN
# 239      45.0       NaN
# 241      45.0       NaN
# 243      45.0       NaN
# 245      45.0       NaN
# 247      45.0       NaN
# 249      45.0       NaN
# 251      45.0       NaN
# 253      45.0       NaN
# 255      45.0       NaN
# 257      45.0       NaN
# 259      45.0       NaN
# 261      45.0       NaN
# 263      45.0       NaN
# 265      45.0       NaN
# 267      45.0       NaN
# 269      45.0       NaN
# 271      45.0       NaN
# 273      45.0       NaN
# 275      45.0       NaN
# 277      45.0       NaN
# 279      45.0       NaN
# 281      45.0       NaN
# 283      45.0       NaN
# 285      45.0       NaN
# 287      45.0       NaN
# 289      45.0       NaN
# 291      45.0       NaN
# 293      45.0       NaN
# 295      45.0       NaN
# 297      45.0       NaN
# 299      45.0       NaN
# 301      45.0       NaN
# 303      45.0       NaN
# 305      45.0       NaN
# 307      45.0       NaN
# 309      45.0       NaN
# 311      45.0       NaN
# 313      45.0       NaN
# 315      45.0       NaN
# 317      45.0       NaN
# 319      45.0       NaN
# 321      45.0       NaN
# 323      45.0       NaN
# 325      45.0       NaN
# 327      45.0       NaN
# 330      45.0       NaN
# 332      45.0       NaN
# 334      45.0       NaN
# 338      45.0       NaN
# 352      45.0       NaN
# 354      45.0       NaN
# 366      45.0       NaN
# 368      45.0       NaN
# 370      45.0       NaN
# 372      45.0       NaN
# 375      45.0       NaN
# 377      45.0       NaN
# 379      45.0       NaN
# 381      45.0       NaN
# 383      45.0       NaN
# 385      45.0       NaN
# 387      45.0       NaN
# 389      45.0       NaN
# 391      45.0       NaN
# 393      45.0       NaN
# 395      45.0       NaN
# 397      45.0       NaN
# 399      45.0       NaN
# 401      45.0       NaN
# 403      45.0       NaN
# 405      45.0       NaN
# 407      45.0       NaN
# 409      45.0       NaN
# 411      45.0       NaN
# 413      45.0       NaN
# 415      45.0       NaN
# 417      45.0       NaN
# 419      45.0       NaN
# 421      45.0       NaN
# 423      45.0       NaN
# 425      45.0       NaN
# 427      45.0       NaN
# 429      45.0       NaN
# 431      45.0       NaN
# 433      45.0       NaN
# 435      45.0       NaN
# 437      45.0       NaN
# 439      45.0       NaN
# 441      45.0       NaN
# 443      45.0       NaN
# 445      45.0       NaN
# 447      45.0       NaN
# 449      45.0       NaN
# 451      45.0       NaN
# 453      45.0       NaN
# 455      45.0       NaN
# 457      45.0       NaN
# 459      45.0       NaN
# 461      45.0       NaN
# 466      45.0       NaN
# 468      45.0       NaN
# 474      45.0       NaN
# 478      45.0       NaN
# 480      45.0       NaN
# 482      45.0       NaN
# 486      45.0       NaN
# 488      45.0       NaN
# 492      45.0       NaN
# 495      45.0       NaN
# 497      45.0       NaN
# 499      45.0       NaN
# 501      45.0       NaN
# 503      45.0       NaN
# 505      45.0       NaN
# 507      45.0       NaN
# 509      45.0       NaN
# 511      45.0       NaN
# 513      45.0       NaN
# 515      45.0       NaN
# 517      45.0       NaN
# 519      45.0       NaN
# 521      45.0       NaN
# 523      45.0       NaN
# 525      45.0       NaN
# 527      45.0       NaN
# 529      45.0       NaN
# 531      45.0       NaN
# 533      45.0       NaN
# 535      45.0       NaN
# 537      45.0       NaN
# 539      45.0       NaN
# 541      45.0       NaN
# 543      45.0       NaN
