# %%
import numpy as np

ptRNA = [0.0521, 0.0099, 0.0762, 0.0102, 0.0139, 0.0067, 0.0191, 0.0384, 0.0255, 0.0123, 0.0141,\
 0.0757, 0.0343, 0.0699, 0.0102, 0.0557, 0.0717, 0.0151, 0.0107, 0.0307, \
 0.0165, 0.0309, 0.0113, 0.0166, 0.0144, 0.0115, 0.0093, 0.0035, 0.0208, 0.0055, 0.0226, \
 0.0123, 0.0017, 0.0087, 0.0176, 0.0147, 0.0151, 0.0326, 0.0616,0.0203]
ptRNA = np.divide(ptRNA,sum(ptRNA))

tRNA_tags = ["Ala1B", "Ala2", "Arg2", "Arg3", "Arg4", "Arg5", "Asn", "Asp1", "Cys", "Gln1", "Gln2", \
"Glu2", "Gly2", "Gly3", "His", "Ile1", "Leu1", "Leu2", "Leu3", "Leu4", "Leu5", "Lys", \
"Met_m", "Phe", "Pro1", "Pro2", "Pro3", "Sel_Cys", "Ser1", "Ser2", "Ser3", "Ser5", "Thr1", \
"Thr2", "Thr3", "Thr4", "Trp", "Tyr1pTyr2", "Val1", "Val2ApB"]

ptRNA_dict = dict(zip(tRNA_tags, ptRNA))

codons_Ec = ["GGG", "GGA", "GGU", "GGC", "GAG", "GAA", "GAU", "GAC", "GUG", "GUA", "GUU", \
"GUC", "GCG", "GCA", "GCU", "GCC", "AGG", "AGA", "AGU", "AGC", "AAG", "AAA", \
"AAU", "AAC", "AUG", "AUA", "AUU", "AUC", "ACG", "ACA", "ACU", "ACC", "UGG", \
"UGA", "UGU", "UGC", "UAU", "UAC", "UUG", "UUA", "UUU", "UUC", "UCG", "UCA", \
"UCU", "UCC", "CGG", "CGA", "CGU", "CGC", "CAG", "CAA", "CAU", "CAC", "CUG", \
"CUA", "CUU", "CUC", "CCG", "CCA", "CCU", "CCC"]

pcodons_Ec =[0.00483, 0.00272, 0.03847, 0.03579, 0.01665, 0.05335, 0.02436, \
0.02885, 0.02150, 0.01594, 0.03146, 0.01130, 0.03047, 0.02223, \
0.02898, 0.01989, 0.00009, 0.00113, 0.00401, 0.01203, 0.01214, \
0.04464, 0.00984, 0.02808, 0.02247, 0.00093, 0.02148, 0.03685, \
0.00757, 0.00350, 0.01394, 0.02663, 0.00981, 0.00031, 0.00425, \
0.00531, 0.01073, 0.01628, 0.00666, 0.00616, 0.01261, 0.02279, \
0.00608, 0.00391, 0.01318, 0.01120, 0.00176, 0.00133, 0.03126, \
0.02235, 0.02938, 0.01024, 0.00927, 0.01396, 0.06041, 0.00216, \
0.00573, 0.00622, 0.02965, 0.00655, 0.00501, 0.00332]
pcodons_Ec = np.divide(pcodons_Ec,sum(pcodons_Ec))

pcodon_dict = dict(zip(codons_Ec, pcodons_Ec))

#Note AUA does not have an assigned tRNA
codon_dict={'GGG': ['Gly2'], 'GGA': ['Gly2'], 'GGU': ['Gly3'], 'GGC': ['Gly3'], \
'GAG': ['Glu2'], 'GAA': ['Glu2'], 'GAU': ['Asp1'], 'GAC': ['Asp1'], \
'GUG': ['Val1'], 'GUA': ['Val1'], 'GUU': ['Val1','Val2ApB'], \
'GUC': ['Val2ApB'], 'GCG': ['Ala1B'], 'GCA': ['Ala1B'], 'GCU': ['Ala1B'], \
'GCC': ['Ala2'], 'AGG': ['Arg5'], 'AGA': ['Arg4'], 'AGU': ['Ser3'], \
'AGC': ['Ser3'], 'AAG': ['Lys'], 'AAA': ['Lys'], 'AAU': ['Asn'], \
'AAC': ['Asn'], 'AUG': ['Met_m'], 'AUA': [], 'AUU': ['Ile1'], \
'AUC': ['Ile1'], 'ACG': ['Thr2','Thr4'], 'ACA': ['Thr4'], \
'ACU': ['Thr1','Thr4','Thr3'], 'ACC': ['Thr3','Thr1'], \
'UGG': ['Trp'], 'UGA': ['Sel_Cys'], 'UGU': ['Cys'], 'UGC': ['Cys'], \
'UAU': ['Tyr1pTyr2'], 'UAC': ['Tyr1pTyr2'], 'UUG': ['Leu5','Leu4'], \
'UUA': ['Leu5'], 'UUU': ['Phe'], 'UUC': ['Phe'], 'UCG': ['Ser1','Ser2'], \
'UCA': ['Ser1'], 'UCU': ['Ser5','Ser1'], 'UCC': ['Ser5'], 'CGG': ['Arg3'], \
'CGA': ['Arg2'], 'CGU': ['Arg2'], 'CGC': ['Arg2'], 'CAG': ['Gln2'], \
'CAA': ['Gln1'], 'CAU': ['His'], 'CAC': ['His'], 'CUG': ['Leu1','Leu3'], \
'CUA': ['Leu3'], 'CUU': ['Leu2'], 'CUC': ['Leu2'], 'CCG': ['Pro1','Pro3'], \
'CCA': ['Pro3'], 'CCU': ['Pro2','Pro3'], 'CCC': ['Pro2']}

cells = 1
TU = 9500*20
time = 180
tRNA_distrib_arr = list()
codon_count = {}
codon_time = {}
codon_time_avg = {}
codon_time_weighted_avg={}
codon_count_hist = {}
codon_count_hist_weighted_avg = np.zeros(42)
p_codon_tRNA = {}

for key in codon_dict:
    codon_count[key] = []
    codon_time[key] = []
    codon_time_avg[key] = []
    codon_time_weighted_avg[key]=[]
    codon_count_hist[key]=[]
    p_codon_tRNA[key] = []

# Construct dictionary that assigns probability of all tRNA specific to a certain codon
# to that codon (p_codon_tRNA)
for codon in codon_dict:
    p_codon_tRNA_i = 0
    for tRNA in codon_dict[codon]:
        p_codon_tRNA_i += ptRNA_dict[tRNA]
    p_codon_tRNA[codon].append(p_codon_tRNA_i)

bias=18
for cell in range(cells):
    # Generate distribution for cognate tRNA count for each codon
    for i in range(TU):
            
        #Construct translation unit with random tRNA (weighted by specific tRNA abundances)
        #and 1 random codon (weighted by codon probabilities).
        codon_vox = np.random.choice(codons_Ec, 1)
        cognatetRNA = codon_dict[codon_vox[0]]
        biased_ptRNA = ptRNA.copy()
        for _,tRNA_i in enumerate(cognatetRNA):
            biased_ptRNA[tRNA_tags.index(tRNA_i)]=biased_ptRNA[tRNA_tags.index(tRNA_i)]*bias
        biased_ptRNA = biased_ptRNA/sum(biased_ptRNA)
        tRNA_vox = list(np.random.choice(tRNA_tags,42,p=biased_ptRNA))

        #Count how many cognate tRNA appeared in the translation unit (for given codon) and record in codon_count
        codon_count_i = 0
        for tRNA in codon_dict[codon_vox[0]]:
            codon_count_i += tRNA_vox.count(tRNA)
        codon_count[codon_vox[0]].append(codon_count_i)
    
    for codon in codon_count:
        #Generate histogram of cognate tRNA counts for each codon
        codon_count_hist[codon] = np.histogram(codon_count[codon], bins=np.arange(0,43))[0]/sum(np.histogram(codon_count[codon], bins=np.arange(0,43))[0])
        
        #Weight each cognate tRNA histogram by corresponding codon probabilities to generate a weighted distribution of # of cognate tRNA for any given codon
        codon_count_hist_weighted_avg += codon_count_hist[codon]*pcodon_dict[codon]
    p_codon_count_hist_weighted_avg = codon_count_hist_weighted_avg
    print(p_codon_count_hist_weighted_avg)
# Out:
# [9.79916172e-04 3.21309935e-04 1.34636015e-03 3.79889165e-03
#  7.82647432e-03 1.43106637e-02 2.11770659e-02 2.82115523e-02
#  3.26094919e-02 3.74512236e-02 3.84502111e-02 3.92514272e-02
#  3.82624165e-02 3.77998366e-02 3.69862053e-02 3.52830562e-02
#  3.48447313e-02 3.54506080e-02 3.57785566e-02 3.71446564e-02
#  3.81825571e-02 4.13440814e-02 4.55880687e-02 4.79933126e-02
#  5.08241464e-02 5.12749099e-02 4.96123907e-02 4.51141972e-02
#  3.71466522e-02 2.85379299e-02 2.05905571e-02 1.28311379e-02
#  7.23888639e-03 3.79406056e-03 1.72368928e-03 6.01861220e-04
#  2.33146884e-04 5.43452560e-05 2.94144311e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg)
plt.xlabel('# of cognate tRNA per TU',fontsize=20)
plt.ylabel('Probability',fontsize=20)
print(sum(p_codon_count_hist_weighted_avg[0:34]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
# Out:
# 0.9973575429288117
# [9.79916172e-04 3.21309935e-04 1.34636015e-03 3.79889165e-03
#  7.82647432e-03 1.43106637e-02 2.11770659e-02 2.82115523e-02
#  3.26094919e-02 3.74512236e-02 3.84502111e-02 3.92514272e-02
#  3.82624165e-02 3.77998366e-02 3.69862053e-02 3.52830562e-02
#  3.48447313e-02 3.54506080e-02 3.57785566e-02 3.71446564e-02
#  3.81825571e-02 4.13440814e-02 4.55880687e-02 4.79933126e-02
#  5.08241464e-02 5.12749099e-02 4.96123907e-02 4.51141972e-02
#  3.71466522e-02 2.85379299e-02 2.05905571e-02 1.28311379e-02
#  7.23888639e-03 3.79406056e-03 1.72368928e-03 6.01861220e-04
#  2.33146884e-04 5.43452560e-05 2.94144311e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 18.443103323149582

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
def transportRxnCalc(gr):
    colors = ['darkblue','#D43F3A']
    gr_i_list = ['gr_1']
    phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
    markers = ['*','^']
    transport_phi = list()
    reaction_phi = list()
    search_phi = list()
    transport_std_phi =list()
    rxn_std_phi =list()
    search_std_phi =list()
    search_list = list()
    for j,gr_i in enumerate(gr_i_list):
        transport_vals_list = list()
        reaction_vals_list = list()
        search_vals_list = list()
        transport_std_list = list()
        rxn_std_list = list()
        search_std_list = list()
        
        #for range(1,7)
        for i in range(list(gr_dict['gr_1'].keys())[0],list(gr_dict['gr_1'].keys())[-1]+1):
            transport_vals = gr[gr_i][i].bootavg_transportT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            rxn_vals = gr[gr_i][i].bootavg_rxnT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            search_vals = gr[gr_i][i].bootavg_searchT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            
            transport_std = gr[gr_i][i].bootstd_transportT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            rxn_std = gr[gr_i][i].bootstd_rxnT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])
            search_std = gr[gr_i][i].bootstd_searchT*1000/1608733*p_codon_count_hist_weighted_avg[i]/(1-p_codon_count_hist_weighted_avg[0])

            transport_vals_list.append(np.array(transport_vals))
            reaction_vals_list.append(np.array(rxn_vals))
            search_vals_list.append(np.array(search_vals))
            
            transport_std_list.append(np.array(transport_std))
            rxn_std_list.append(np.array(rxn_std))
            search_std_list.append(np.array(search_std))
            
            search_list.append(np.array(gr[gr_i][i].searchT)*1000/1608733)
            print('Unweighted search time (', str(i), ' cognate)', np.array(search_vals/p_codon_count_hist_weighted_avg[i]))
            print('Weighted search time (', str(i), ' cognate)', np.array(search_vals))

        transport_phi.append(np.sum(transport_vals_list))
        reaction_phi.append(np.sum(reaction_vals_list))
        search_phi.append(np.sum(search_vals_list))
        
        transport_std_phi.append(np.sum(transport_std_list))
        rxn_std_phi.append(np.sum(rxn_std_list))
        search_std_phi.append(np.sum(search_std_list))

    print("Transport time: ", transport_phi, " +/- ", transport_std_phi)
    print("Reaction time: ", reaction_phi, " +/- ", rxn_std_phi)
    print("Search time: ", search_phi, " +/- ", search_std_phi)
    
    return search_list,transport_phi, reaction_phi, search_phi, transport_std_phi,rxn_std_phi,search_std_phi
rxndiff=dict()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Order of running cells matters: must run from growth rate 0.6 to 3.0 sequentially to construct rxndiff dictionary in correct order
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


gr_sim = dict()

data = "191003_2140/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1738/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1817/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1934/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    

gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['06'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 26
# missing expt
# 89
# test
# missing expt
# 107
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 522.4484551639373
# Weighted search time ( 1  cognate) 134.64764485168158
# Unweighted search time ( 2  cognate) 229.72261521238403
# Weighted search time ( 2  cognate) 44.583537586535044
# Unweighted search time ( 3  cognate) 159.42887250256098
# Weighted search time ( 3  cognate) 21.563716666115543
# Unweighted search time ( 4  cognate) 126.72185731648167
# Weighted search time ( 4  cognate) 10.938304084084532
# Unweighted search time ( 5  cognate) 118.97841560967082
# Weighted search time ( 5  cognate) 5.345230772380764
# Unweighted search time ( 6  cognate) 90.76966073333341
# Weighted search time ( 6  cognate) 1.924225004008443
# Transport time:  [201.88142547931662]  +/-  [17.57362935319007]
# Reaction time:  [16.863376973719248]  +/-  [2.3974989993378837]
# Search time:  [219.0026589648059]  +/-  [19.024111415119172]
# Unweighted search time ( 1  cognate) 522.4484551639373
# Weighted search time ( 1  cognate) 134.64764485168158
# Unweighted search time ( 2  cognate) 229.72261521238403
# Weighted search time ( 2  cognate) 44.583537586535044
# Unweighted search time ( 3  cognate) 159.42887250256098
# Weighted search time ( 3  cognate) 21.563716666115543
# Unweighted search time ( 4  cognate) 126.72185731648167
# Weighted search time ( 4  cognate) 10.938304084084532
# Unweighted search time ( 5  cognate) 118.97841560967082
# Weighted search time ( 5  cognate) 5.345230772380764
# Unweighted search time ( 6  cognate) 90.76966073333341
# Weighted search time ( 6  cognate) 1.924225004008443
# Transport time:  [201.88142547931662]  +/-  [17.57362935319007]
# Reaction time:  [16.863376973719248]  +/-  [2.3974989993378837]
# Search time:  [219.0026589648059]  +/-  [19.024111415119172]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"



gr_sim = dict()

data = "191004_0018/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2012/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_2115/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_2238/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))



gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['10'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) -18.339264807707973
# Weighted search time ( 1  cognate) -318.6113140794752
# Unweighted search time ( 2  cognate) -9.17657510645086
# Weighted search time ( 2  cognate) -96.38055867339607
# Unweighted search time ( 3  cognate) -5.407684690679202
# Weighted search time ( 3  cognate) -31.905394624884643
# Unweighted search time ( 4  cognate) -4.667815692442006
# Weighted search time ( 4  cognate) -15.260967535884442
# Unweighted search time ( 5  cognate) -3.225422070398431
# Weighted search time ( 5  cognate) -5.0894710744767115
# Unweighted search time ( 6  cognate) -2.423247101348123
# Weighted search time ( 6  cognate) -1.7607670024711122
# Transport time:  [-389.8201503546411]  +/-  [-45.075002574901745]
# Reaction time:  [-78.82605379430562]  +/-  [-10.345892764288779]
# Search time:  [-469.0084729905882]  +/-  [-54.5145136713605]
# Unweighted search time ( 1  cognate) -18.339264807707973
# Weighted search time ( 1  cognate) -318.6113140794752
# Unweighted search time ( 2  cognate) -9.17657510645086
# Weighted search time ( 2  cognate) -96.38055867339607
# Unweighted search time ( 3  cognate) -5.407684690679202
# Weighted search time ( 3  cognate) -31.905394624884643
# Unweighted search time ( 4  cognate) -4.667815692442006
# Weighted search time ( 4  cognate) -15.260967535884442
# Unweighted search time ( 5  cognate) -3.225422070398431
# Weighted search time ( 5  cognate) -5.0894710744767115
# Unweighted search time ( 6  cognate) -2.423247101348123
# Weighted search time ( 6  cognate) -1.7607670024711122
# Transport time:  [-389.8201503546411]  +/-  [-45.075002574901745]
# Reaction time:  [-78.82605379430562]  +/-  [-10.345892764288779]
# Search time:  [-469.0084729905882]  +/-  [-54.5145136713605]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


gr_sim = dict()

data = "191004_0104/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_0916/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1041/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1206/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))





gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['15'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) -12.753414700095517
# Weighted search time ( 1  cognate) -221.56734521277502
# Unweighted search time ( 2  cognate) -6.832663112375915
# Weighted search time ( 2  cognate) -71.76270889288146
# Unweighted search time ( 3  cognate) -4.994622306858526
# Weighted search time ( 3  cognate) -29.468322363032964
# Unweighted search time ( 4  cognate) -2.519923949012464
# Weighted search time ( 4  cognate) -8.23864524922108
# Unweighted search time ( 5  cognate) -2.6289626073853336
# Weighted search time ( 5  cognate) -4.1483033395737
# Unweighted search time ( 6  cognate) -2.005405912863363
# Weighted search time ( 6  cognate) -1.457157446290079
# Transport time:  [-271.5678725199307]  +/-  [-29.203958971716794]
# Reaction time:  [-64.95287244045153]  +/-  [-7.7921158401492185]
# Search time:  [-336.64248250377426]  +/-  [-36.375765685788735]
# Unweighted search time ( 1  cognate) -12.753414700095517
# Weighted search time ( 1  cognate) -221.56734521277502
# Unweighted search time ( 2  cognate) -6.832663112375915
# Weighted search time ( 2  cognate) -71.76270889288146
# Unweighted search time ( 3  cognate) -4.994622306858526
# Weighted search time ( 3  cognate) -29.468322363032964
# Unweighted search time ( 4  cognate) -2.519923949012464
# Weighted search time ( 4  cognate) -8.23864524922108
# Unweighted search time ( 5  cognate) -2.6289626073853336
# Weighted search time ( 5  cognate) -4.1483033395737
# Unweighted search time ( 6  cognate) -2.005405912863363
# Weighted search time ( 6  cognate) -1.457157446290079
# Transport time:  [-271.5678725199307]  +/-  [-29.203958971716794]
# Reaction time:  [-64.95287244045153]  +/-  [-7.7921158401492185]
# Search time:  [-336.64248250377426]  +/-  [-36.375765685788735]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


gr_sim = dict()

data = "191004_1129/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1348/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1428/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1506/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

    
gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['20'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 265.7276386617896
# Weighted search time ( 1  cognate) 67.9086333697344
# Unweighted search time ( 2  cognate) 143.53280879172206
# Weighted search time ( 2  cognate) 28.352756929063087
# Unweighted search time ( 3  cognate) 85.68761070639819
# Weighted search time ( 3  cognate) 11.695750558780388
# Unweighted search time ( 4  cognate) 74.38160293483601
# Weighted search time ( 4  cognate) 6.205600910085829
# Unweighted search time ( 5  cognate) 46.88133625597709
# Weighted search time ( 5  cognate) 2.1144708712905333
# Unweighted search time ( 6  cognate) 42.214538967151164
# Weighted search time ( 6  cognate) 0.9168324569691556
# Transport time:  [94.08236347134613]  +/-  [9.66812906220811]
# Reaction time:  [22.970032586022466]  +/-  [2.687669995477305]
# Search time:  [117.19404509592341]  +/-  [12.19276374353268]
# Unweighted search time ( 1  cognate) 265.7276386617896
# Weighted search time ( 1  cognate) 67.9086333697344
# Unweighted search time ( 2  cognate) 143.53280879172206
# Weighted search time ( 2  cognate) 28.352756929063087
# Unweighted search time ( 3  cognate) 85.68761070639819
# Weighted search time ( 3  cognate) 11.695750558780388
# Unweighted search time ( 4  cognate) 74.38160293483601
# Weighted search time ( 4  cognate) 6.205600910085829
# Unweighted search time ( 5  cognate) 46.88133625597709
# Weighted search time ( 5  cognate) 2.1144708712905333
# Unweighted search time ( 6  cognate) 42.214538967151164
# Weighted search time ( 6  cognate) 0.9168324569691556
# Transport time:  [94.08236347134613]  +/-  [9.66812906220811]
# Reaction time:  [22.970032586022466]  +/-  [2.687669995477305]
# Search time:  [117.19404509592341]  +/-  [12.19276374353268]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191004_1217/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1556/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191106_1714/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191106_1757/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['25'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# missing expt
# 202
# test
# test
# missing expt
# 462
# test
# test
# missing expt
# 2
# missing expt
# 35
# missing expt
# 72
# missing expt
# 94
# test
# test
# test
# test
# test
# missing expt
# 510
# test
# test
# test
# test
# test
# test
# test
# test
# missing expt
# 447
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 200.1335426757534
# Weighted search time ( 1  cognate) 0.06430489564383575
# Unweighted search time ( 2  cognate) 83.6686475440247
# Weighted search time ( 2  cognate) 0.11264813298239428
# Unweighted search time ( 3  cognate) 60.707517329618696
# Weighted search time ( 3  cognate) 0.2306212803839018
# Unweighted search time ( 4  cognate) 39.947796326301564
# Weighted search time ( 4  cognate) 0.3126504018895956
# Unweighted search time ( 5  cognate) 40.41314338769618
# Weighted search time ( 5  cognate) 0.5783389051811841
# Unweighted search time ( 6  cognate) 25.92835993666319
# Weighted search time ( 6  cognate) 0.5490865876597547
# Unweighted search time ( 7  cognate) 19.180889344987698
# Weighted search time ( 7  cognate) 0.5411226629037263
# Unweighted search time ( 8  cognate) 20.230297432878583
# Weighted search time ( 8  cognate) 0.6596997202489894
# Unweighted search time ( 9  cognate) 16.126846444588928
# Weighted search time ( 9  cognate) 0.6039701318094384
# Unweighted search time ( 10  cognate) 12.82980228640237
# Weighted search time ( 10  cognate) 0.4933086069084863
# Unweighted search time ( 11  cognate) 13.788904225096177
# Weighted search time ( 11  cognate) 0.5412341700842455
# Unweighted search time ( 12  cognate) 11.817068144893698
# Weighted search time ( 12  cognate) 0.4521495835411829
# Unweighted search time ( 13  cognate) 11.506777242834513
# Weighted search time ( 13  cognate) 0.43495429958512777
# Unweighted search time ( 14  cognate) 8.334674806332865
# Weighted search time ( 14  cognate) 0.30826799358596463
# Unweighted search time ( 15  cognate) 8.915794542430703
# Weighted search time ( 15  cognate) 0.3145764799303545
# Unweighted search time ( 16  cognate) 8.732404638226356
# Weighted search time ( 16  cognate) 0.30427829348778473
# Unweighted search time ( 17  cognate) 5.073103247127532
# Weighted search time ( 17  cognate) 0.17984459475766326
# Unweighted search time ( 18  cognate) 6.307849767271715
# Weighted search time ( 18  cognate) 0.22568575971076377
# Unweighted search time ( 19  cognate) 4.798252620744702
# Weighted search time ( 19  cognate) 0.17822944481104225
# Unweighted search time ( 20  cognate) 5.855308694959494
# Weighted search time ( 20  cognate) 0.22357065849827412
# Unweighted search time ( 21  cognate) 4.583893306388471
# Weighted search time ( 21  cognate) 0.1895168580296802
# Unweighted search time ( 22  cognate) 4.25484754736507
# Weighted search time ( 22  cognate) 0.19397028215224946
# Unweighted search time ( 23  cognate) 4.03888370534321
# Weighted search time ( 23  cognate) 0.19383940821879922
# Unweighted search time ( 24  cognate) 3.0581354342034017
# Weighted search time ( 24  cognate) 0.1554271229275134
# Unweighted search time ( 25  cognate) 3.4232568621870327
# Weighted search time ( 25  cognate) 0.17552718710237544
# Unweighted search time ( 26  cognate) 2.644670524274364
# Weighted search time ( 26  cognate) 0.13120842742421684
# Unweighted search time ( 27  cognate) 3.194143031181031
# Weighted search time ( 27  cognate) 0.1441011984340803
# Unweighted search time ( 28  cognate) 2.383581172783676
# Weighted search time ( 28  cognate) 0.08854206086820393
# Unweighted search time ( 29  cognate) 2.283301372019062
# Weighted search time ( 29  cognate) 0.06516069453590849
# Unweighted search time ( 30  cognate) 1.578689628355338
# Weighted search time ( 30  cognate) 0.03250609892244914
# Unweighted search time ( 31  cognate) 1.9716553511471235
# Weighted search time ( 31  cognate) 0.025298581739423755
# Unweighted search time ( 32  cognate) 1.8105669378133658
# Weighted search time ( 32  cognate) 0.013106488363320573
# Unweighted search time ( 33  cognate) 1.2461504157368486
# Weighted search time ( 33  cognate) 0.004727970141824562
# Transport time:  [7.336487384092189]  +/-  [0.9471834411002669]
# Reaction time:  [1.3855002150574958]  +/-  [0.26445096544318897]
# Search time:  [8.721474982463755]  +/-  [1.0945274430070293]
# Unweighted search time ( 1  cognate) 200.1335426757534
# Weighted search time ( 1  cognate) 0.06430489564383575
# Unweighted search time ( 2  cognate) 83.6686475440247
# Weighted search time ( 2  cognate) 0.11264813298239428
# Unweighted search time ( 3  cognate) 60.707517329618696
# Weighted search time ( 3  cognate) 0.2306212803839018
# Unweighted search time ( 4  cognate) 39.947796326301564
# Weighted search time ( 4  cognate) 0.3126504018895956
# Unweighted search time ( 5  cognate) 40.41314338769618
# Weighted search time ( 5  cognate) 0.5783389051811841
# Unweighted search time ( 6  cognate) 25.92835993666319
# Weighted search time ( 6  cognate) 0.5490865876597547
# Unweighted search time ( 7  cognate) 19.180889344987698
# Weighted search time ( 7  cognate) 0.5411226629037263
# Unweighted search time ( 8  cognate) 20.230297432878583
# Weighted search time ( 8  cognate) 0.6596997202489894
# Unweighted search time ( 9  cognate) 16.126846444588928
# Weighted search time ( 9  cognate) 0.6039701318094384
# Unweighted search time ( 10  cognate) 12.82980228640237
# Weighted search time ( 10  cognate) 0.4933086069084863
# Unweighted search time ( 11  cognate) 13.788904225096177
# Weighted search time ( 11  cognate) 0.5412341700842455
# Unweighted search time ( 12  cognate) 11.817068144893698
# Weighted search time ( 12  cognate) 0.4521495835411829
# Unweighted search time ( 13  cognate) 11.506777242834513
# Weighted search time ( 13  cognate) 0.43495429958512777
# Unweighted search time ( 14  cognate) 8.334674806332865
# Weighted search time ( 14  cognate) 0.30826799358596463
# Unweighted search time ( 15  cognate) 8.915794542430703
# Weighted search time ( 15  cognate) 0.3145764799303545
# Unweighted search time ( 16  cognate) 8.732404638226356
# Weighted search time ( 16  cognate) 0.30427829348778473
# Unweighted search time ( 17  cognate) 5.073103247127532
# Weighted search time ( 17  cognate) 0.17984459475766326
# Unweighted search time ( 18  cognate) 6.307849767271715
# Weighted search time ( 18  cognate) 0.22568575971076377
# Unweighted search time ( 19  cognate) 4.798252620744702
# Weighted search time ( 19  cognate) 0.17822944481104225
# Unweighted search time ( 20  cognate) 5.855308694959494
# Weighted search time ( 20  cognate) 0.22357065849827412
# Unweighted search time ( 21  cognate) 4.583893306388471
# Weighted search time ( 21  cognate) 0.1895168580296802
# Unweighted search time ( 22  cognate) 4.25484754736507
# Weighted search time ( 22  cognate) 0.19397028215224946
# Unweighted search time ( 23  cognate) 4.03888370534321
# Weighted search time ( 23  cognate) 0.19383940821879922
# Unweighted search time ( 24  cognate) 3.0581354342034017
# Weighted search time ( 24  cognate) 0.1554271229275134
# Unweighted search time ( 25  cognate) 3.4232568621870327
# Weighted search time ( 25  cognate) 0.17552718710237544
# Unweighted search time ( 26  cognate) 2.644670524274364
# Weighted search time ( 26  cognate) 0.13120842742421684
# Unweighted search time ( 27  cognate) 3.194143031181031
# Weighted search time ( 27  cognate) 0.1441011984340803
# Unweighted search time ( 28  cognate) 2.383581172783676
# Weighted search time ( 28  cognate) 0.08854206086820393
# Unweighted search time ( 29  cognate) 2.283301372019062
# Weighted search time ( 29  cognate) 0.06516069453590849
# Unweighted search time ( 30  cognate) 1.578689628355338
# Weighted search time ( 30  cognate) 0.03250609892244914
# Unweighted search time ( 31  cognate) 1.9716553511471235
# Weighted search time ( 31  cognate) 0.025298581739423755
# Unweighted search time ( 32  cognate) 1.8105669378133658
# Weighted search time ( 32  cognate) 0.013106488363320573
# Unweighted search time ( 33  cognate) 1.2461504157368486
# Weighted search time ( 33  cognate) 0.004727970141824562
# Transport time:  [7.336487384092189]  +/-  [0.9471834411002669]
# Reaction time:  [1.3855002150574958]  +/-  [0.26445096544318897]
# Search time:  [8.721474982463755]  +/-  [1.0945274430070293]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
    
    
gr_dict = {'gr_1':gr_sim}
search_list = transportRxnCalc(gr_dict)[0]
rxndiff['30'] = transportRxnCalc(gr_dict)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# missing expt
# 597
# test
# missing expt
# 650
# test
# test
# test
# test
# test
# test
# test
# missing expt
# 433
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 145.64275997586913
# Weighted search time ( 1  cognate) 0.046796465781361186
# Unweighted search time ( 2  cognate) 73.38367323411708
# Weighted search time ( 2  cognate) 0.0988008534124292
# Unweighted search time ( 3  cognate) 56.78761922338621
# Weighted search time ( 3  cognate) 0.2157300122181271
# Unweighted search time ( 4  cognate) 36.406707298809
# Weighted search time ( 4  cognate) 0.28493615956871293
# Unweighted search time ( 5  cognate) 27.924023208286666
# Weighted search time ( 5  cognate) 0.3996113060448357
# Unweighted search time ( 6  cognate) 23.398071037318335
# Weighted search time ( 6  cognate) 0.4955024928335309
# Unweighted search time ( 7  cognate) 20.754666351774386
# Weighted search time ( 7  cognate) 0.5855213552381675
# Unweighted search time ( 8  cognate) 15.722937838949678
# Weighted search time ( 8  cognate) 0.5127170140855143
# Unweighted search time ( 9  cognate) 11.759743978783648
# Weighted search time ( 9  cognate) 0.4404168009731584
# Unweighted search time ( 10  cognate) 13.555118200969293
# Weighted search time ( 10  cognate) 0.5211971569731106
# Unweighted search time ( 11  cognate) 11.108243917807792
# Weighted search time ( 11  cognate) 0.4360144272382263
# Unweighted search time ( 12  cognate) 8.939879686715095
# Weighted search time ( 12  cognate) 0.3420614003146948
# Unweighted search time ( 13  cognate) 9.52667018845839
# Weighted search time ( 13  cognate) 0.36010657647689975
# Unweighted search time ( 14  cognate) 7.472400220018786
# Weighted search time ( 14  cognate) 0.2763757287022478
# Unweighted search time ( 15  cognate) 5.873271840944891
# Weighted search time ( 15  cognate) 0.20722698045650673
# Unweighted search time ( 16  cognate) 5.9131909058700085
# Weighted search time ( 16  cognate) 0.20604354842070877
# Unweighted search time ( 17  cognate) 5.994485414311784
# Weighted search time ( 17  cognate) 0.21250815282106642
# Unweighted search time ( 18  cognate) 5.236107928591123
# Weighted search time ( 18  cognate) 0.18734038371093914
# Unweighted search time ( 19  cognate) 5.192557203091634
# Weighted search time ( 19  cognate) 0.1928757530304783
# Unweighted search time ( 20  cognate) 4.588821004415182
# Weighted search time ( 20  cognate) 0.17521291995603505
# Unweighted search time ( 21  cognate) 3.9945256304492416
# Weighted search time ( 21  cognate) 0.1651499928557918
# Unweighted search time ( 22  cognate) 3.314503521642995
# Weighted search time ( 22  cognate) 0.15110181413805507
# Unweighted search time ( 23  cognate) 3.45856253834373
# Weighted search time ( 23  cognate) 0.1659878730435711
# Unweighted search time ( 24  cognate) 2.6118661326882044
# Weighted search time ( 24  cognate) 0.13274586662682705
# Unweighted search time ( 25  cognate) 1.9759873163338146
# Weighted search time ( 25  cognate) 0.10131857156767932
# Unweighted search time ( 26  cognate) 2.7852044660498376
# Weighted search time ( 26  cognate) 0.1381806522555673
# Unweighted search time ( 27  cognate) 2.8149450924564903
# Weighted search time ( 27  cognate) 0.12699398786757818
# Unweighted search time ( 28  cognate) 2.70874668950526
# Weighted search time ( 28  cognate) 0.10062087123243413
# Unweighted search time ( 29  cognate) 2.2363469069921376
# Weighted search time ( 29  cognate) 0.06382071130364209
# Unweighted search time ( 30  cognate) 1.9732976189179774
# Weighted search time ( 30  cognate) 0.040631297280901174
# Unweighted search time ( 31  cognate) 1.2292988288526128
# Weighted search time ( 31  cognate) 0.015773302816748266
# Unweighted search time ( 32  cognate) 1.6325758524497098
# Weighted search time ( 32  cognate) 0.01181803111803864
# Unweighted search time ( 33  cognate) 1.114333074105305
# Weighted search time ( 33  cognate) 0.004227847165064882
# Transport time:  [6.40999323139326]  +/-  [0.8449531090751944]
# Reaction time:  [1.006310749038164]  +/-  [0.21736638792469584]
# Search time:  [7.415366307528649]  +/-  [0.9652074178981159]
# Unweighted search time ( 1  cognate) 145.64275997586913
# Weighted search time ( 1  cognate) 0.046796465781361186
# Unweighted search time ( 2  cognate) 73.38367323411708
# Weighted search time ( 2  cognate) 0.0988008534124292
# Unweighted search time ( 3  cognate) 56.78761922338621
# Weighted search time ( 3  cognate) 0.2157300122181271
# Unweighted search time ( 4  cognate) 36.406707298809
# Weighted search time ( 4  cognate) 0.28493615956871293
# Unweighted search time ( 5  cognate) 27.924023208286666
# Weighted search time ( 5  cognate) 0.3996113060448357
# Unweighted search time ( 6  cognate) 23.398071037318335
# Weighted search time ( 6  cognate) 0.4955024928335309
# Unweighted search time ( 7  cognate) 20.754666351774386
# Weighted search time ( 7  cognate) 0.5855213552381675
# Unweighted search time ( 8  cognate) 15.722937838949678
# Weighted search time ( 8  cognate) 0.5127170140855143
# Unweighted search time ( 9  cognate) 11.759743978783648
# Weighted search time ( 9  cognate) 0.4404168009731584
# Unweighted search time ( 10  cognate) 13.555118200969293
# Weighted search time ( 10  cognate) 0.5211971569731106
# Unweighted search time ( 11  cognate) 11.108243917807792
# Weighted search time ( 11  cognate) 0.4360144272382263
# Unweighted search time ( 12  cognate) 8.939879686715095
# Weighted search time ( 12  cognate) 0.3420614003146948
# Unweighted search time ( 13  cognate) 9.52667018845839
# Weighted search time ( 13  cognate) 0.36010657647689975
# Unweighted search time ( 14  cognate) 7.472400220018786
# Weighted search time ( 14  cognate) 0.2763757287022478
# Unweighted search time ( 15  cognate) 5.873271840944891
# Weighted search time ( 15  cognate) 0.20722698045650673
# Unweighted search time ( 16  cognate) 5.9131909058700085
# Weighted search time ( 16  cognate) 0.20604354842070877
# Unweighted search time ( 17  cognate) 5.994485414311784
# Weighted search time ( 17  cognate) 0.21250815282106642
# Unweighted search time ( 18  cognate) 5.236107928591123
# Weighted search time ( 18  cognate) 0.18734038371093914
# Unweighted search time ( 19  cognate) 5.192557203091634
# Weighted search time ( 19  cognate) 0.1928757530304783
# Unweighted search time ( 20  cognate) 4.588821004415182
# Weighted search time ( 20  cognate) 0.17521291995603505
# Unweighted search time ( 21  cognate) 3.9945256304492416
# Weighted search time ( 21  cognate) 0.1651499928557918
# Unweighted search time ( 22  cognate) 3.314503521642995
# Weighted search time ( 22  cognate) 0.15110181413805507
# Unweighted search time ( 23  cognate) 3.45856253834373
# Weighted search time ( 23  cognate) 0.1659878730435711
# Unweighted search time ( 24  cognate) 2.6118661326882044
# Weighted search time ( 24  cognate) 0.13274586662682705
# Unweighted search time ( 25  cognate) 1.9759873163338146
# Weighted search time ( 25  cognate) 0.10131857156767932
# Unweighted search time ( 26  cognate) 2.7852044660498376
# Weighted search time ( 26  cognate) 0.1381806522555673
# Unweighted search time ( 27  cognate) 2.8149450924564903
# Weighted search time ( 27  cognate) 0.12699398786757818
# Unweighted search time ( 28  cognate) 2.70874668950526
# Weighted search time ( 28  cognate) 0.10062087123243413
# Unweighted search time ( 29  cognate) 2.2363469069921376
# Weighted search time ( 29  cognate) 0.06382071130364209
# Unweighted search time ( 30  cognate) 1.9732976189179774
# Weighted search time ( 30  cognate) 0.040631297280901174
# Unweighted search time ( 31  cognate) 1.2292988288526128
# Weighted search time ( 31  cognate) 0.015773302816748266
# Unweighted search time ( 32  cognate) 1.6325758524497098
# Weighted search time ( 32  cognate) 0.01181803111803864
# Unweighted search time ( 33  cognate) 1.114333074105305
# Weighted search time ( 33  cognate) 0.004227847165064882
# Transport time:  [6.40999323139326]  +/-  [0.8449531090751944]
# Reaction time:  [1.006310749038164]  +/-  [0.21736638792469584]
# Search time:  [7.415366307528649]  +/-  [0.9652074178981159]

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}


colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0.13,0.22,0.30,0.36,0.39,0.42]
markers = ['*','^']

fig,[ax1,ax2,ax]= plt.subplots(1,3,figsize=(25,8))



#######
ax.scatter(phi_list,[rxndiff[d][2][0]*1.1+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='^',color='black')
ax.errorbar(phi_list,[rxndiff[d][2][0]*1.1+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)


ax.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax.set_ylabel(r'$Elongation\: time,\: [ms]$',fontsize=30)
print([rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],expt))
#print(np.subtract(y_hat_sweep_i,1000/1529+1000/209+1000/200+1000/32))


######
for _,axes in enumerate([ax,ax1,ax2]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
ax1.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='^',color='black',label='Rodnina kinetic parameters')
ax1.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Transport\: time\: [ms]$',fontsize=30)
ax1.set_yticks(np.arange(0, 201, 25))

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
print([rxndiff[d][0][0] for d in rxndiff])
#print(y_hat_sweep_i)
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],expt))

#######
ax2.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='^',color='black')
ax2.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')

ax2.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax2.set_ylabel(r'$Reaction\: time\: [ms]$',fontsize=30)

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/1529+1000/209+1000/200+1000/32]*len(x),2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)


ax.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax.set_ylabel(r'$Elongation\: time,\: [ms]$',fontsize=30)
print([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
expt= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print(expt)
print(np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],expt))


ax1 = ax1.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))

ax1 = ax.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))

ax1 = ax2.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))

plt.tight_layout()

#the secondary rise in transport time could be because the
#decrease in crowding is reducing facilitiated mixing of 
#not only cognate away from incorrect repeats,
#but also incorrect cognates repeat reacting and blocking the cognate ribosome!
#I should also get a graph to show that cognate blocking point. Can compare the 
#2nd and 5th point which have same ribosomes, but 2nd has more crowders (though)
#different voxel size. 2nd maybe faster bcz facilitated mixing
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [260.2292865329142, 262.3497111192784, 201.78602008994682, 158.88275632789478, 149.91901779024872, 126.97753363903144]
# [82.44545311560373, 49.07084465480462]
# [3.1563813  2.58763701]
# [201.75154702588188, 183.6316371904295, 129.16587168899656, 94.08236347134613, 90.11746465357828, 72.18083112597533]
# [40.75674188363234, 7.382133422833249]
# [4.95013923 9.77777385]
# [58.51788384933742, 78.81564765178393, 72.46900509379633, 64.65874381799382, 59.92213459509123, 54.83468533988319]
# [41.688711231971375, 41.68871123197137, 41.68871123197137]
# [1.40368656 1.8905753  1.31533654]

# %%
fig, ax = plt.subplots(1,1,figsize=(8,8))

x=np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
y_model,SS_err,_,_,_ = np.polyfit(x,[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)



elong=[259.5387679125794, 261.9626853605742, 200.99823132492574, 158.14946883794846, 149.5797439370685, 126.7114369897665]

elong_sem=[19.019761433736456, 25.03967369749926, 17.15955904335685, 12.091930180964793, 10.72742391147397, 8.62651849552703]


ax.scatter(x,elong,zorder=2,s=250,marker='^',color='black',alpha=0.2)
ax.errorbar(x,elong,elong_sem,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black',alpha=0.2)


spatialbias_elong = [0, 174.35508893323671, 139.06703376883712, 113.19221843335782, 106.50667111874444, 7.41]
spatialbias_elong_sem = [1,1,1,1,1,0.96]

#spatialbiasing = [0,0,0,0,0,20]

ax.scatter(x,spatialbias_elong+np.array([1000/1529+1000/209+1000/200+1000/32]),zorder=2,s=250,marker='^',color='black',linestyle='dashed')
ax.errorbar(x,spatialbias_elong+np.array([1000/1529+1000/209+1000/200+1000/32]),spatialbias_elong_sem,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')



ax1 = ax.twiny()
ax1.set_xlim(0.41,3.18)
ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
x=[0.6,1.0,1.5,2.0,2.5,3.0]
y_model,SS_err,_,_,_ = np.polyfit([0.6,1.0,1.5,2.0,2.5,3.0],[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,x)
x_sweep_i = np.linspace(min(x),max(x),1000)
ax1.set_xlabel('Doubling rate (1/hr)',size=30,color='black')
ax1.set_xticks(np.arange(0.5, 3.1, 0.5))
#ax.set_ylim(45,90)

ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlim(0.11,0.44)
ax.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax.set_ylabel('Elongation time (ms)',size=30,color='black')

elong_empir=[82.44545311560373, 64.80173984744593, 54.953890127858514, 50.92539189171946, 49.42689484353585, 49.07084465480462]
print(np.divide(elong,spatialbias_elong))
print(np.divide(spatialbias_elong,elong_empir))
print(np.divide(elong,elong_empir))
# Out:
# /Users/Akshay/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:54: RuntimeWarning: divide by zero encountered in true_divide
# [        inf  1.50246653  1.44533342  1.39717616  1.40441667 17.10005897]
# [0.         2.69059271 2.53061309 2.22270687 2.15483233 0.15100616]
# [3.14800584 4.04252549 3.65757967 3.10551304 3.02628244 2.5822143 ]

# %%
text_file = open("Output.txt", "w")
for i in range(100,2000):
    text_file.write(str('reaction rxn'+str(i)+ ' crowder + ribosome* -> crowder + ribosome*\n'))
    text_file.write(str('binding_radius rxn'+str(i)+ ' ribosome_RAD+crowder_RAD-(1.97*(10^-6))\n'))
    text_file.write(str('product_placement rxn'+str(i)+' bounce ribosome_RAD+crowder_RAD\n\n'))
text_file.close()
