# %% [markdown]
# ## Calculate cognate ternary complex distribution for a given tRNA and codon distribution (i.e., at a given growth rate)

# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]

rxndiff=dict()

# %%
#Growth rate = 0.6
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191003_2140/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)

search_list = transportRxnResults[0]
rxndiff['06'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 26
# missing expt
# 89
# test
# missing expt
# 107
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 392.6677543731248
# Unweighted search time ( 2  cognate) 172.3212930075946
# Unweighted search time ( 3  cognate) 119.94577961764459
# Unweighted search time ( 4  cognate) 95.41141003495115
# Unweighted search time ( 5  cognate) 89.66566225271986
# Unweighted search time ( 6  cognate) 68.34345535767119
# Transport time:  [149.63675402008653]  +/-  [12.891674115083925]
# Reaction time:  [12.50617590882601]  +/-  [1.7799886062136534]
# Search time:  [161.91992631641966]  +/-  [14.152465112185324]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_0018/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon)

search_list = transportRxnResults[0]
rxndiff['10'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 388.8489608334214
# Unweighted search time ( 2  cognate) 194.95208246258375
# Unweighted search time ( 3  cognate) 115.08174347019106
# Unweighted search time ( 4  cognate) 99.18809069934903
# Unweighted search time ( 5  cognate) 68.68773327028472
# Unweighted search time ( 6  cognate) 51.558580659251795
# Transport time:  [138.5309051779286]  +/-  [15.916946503153707]
# Reaction time:  [27.911406658700997]  +/-  [3.6689824883234614]
# Search time:  [165.97617126774216]  +/-  [18.799078236206725]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_0104/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

search_list = transportRxnResults[0]
rxndiff['15'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 270.88843967772385
# Unweighted search time ( 2  cognate) 145.15771050607938
# Unweighted search time ( 3  cognate) 106.13204012981458
# Unweighted search time ( 4  cognate) 53.478629905429706
# Unweighted search time ( 5  cognate) 55.94221736621862
# Unweighted search time ( 6  cognate) 42.55150365939077
# Transport time:  [95.83656044700284]  +/-  [10.358427741865647]
# Reaction time:  [22.86789843857594]  +/-  [2.8065170680558547]
# Search time:  [118.64235216805574]  +/-  [12.813359617637094]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_1129/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

search_list = transportRxnResults[0]
rxndiff['20'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 199.7826140610641
# Unweighted search time ( 2  cognate) 107.81701566437215
# Unweighted search time ( 3  cognate) 64.49364940695192
# Unweighted search time ( 4  cognate) 55.76466781596225
# Unweighted search time ( 5  cognate) 35.264294927718495
# Unweighted search time ( 6  cognate) 31.799269115342007
# Transport time:  [69.2741148595855]  +/-  [7.122059569493599]
# Reaction time:  [16.839948389257525]  +/-  [1.9709097104453595]
# Search time:  [86.13531270093259]  +/-  [8.972099018849615]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191004_1217/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['25'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# missing expt
# 202
# test
# test
# missing expt
# 462
# test
# Unweighted search time ( 1  cognate) 199.7813832302511
# Unweighted search time ( 2  cognate) 83.59647134348822
# Unweighted search time ( 3  cognate) 60.55541568434648
# Unweighted search time ( 4  cognate) 39.95406561422009
# Unweighted search time ( 5  cognate) 40.26497343699204
# Unweighted search time ( 6  cognate) 25.887989637992664
# Transport time:  [66.38701627098757]  +/-  [6.596599678489371]
# Reaction time:  [13.36776316024801]  +/-  [1.4732770590604944]
# Search time:  [79.69386039392805]  +/-  [7.919856743985011]

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "191003_2210/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# test
# test
# test
# test
# Unweighted search time ( 1  cognate) 145.04104795061184
# Unweighted search time ( 2  cognate) 73.32113803114198
# Unweighted search time ( 3  cognate) 56.66944639909983
# Unweighted search time ( 4  cognate) 36.47725460957345
# Unweighted search time ( 5  cognate) 27.970646687724656
# Unweighted search time ( 6  cognate) 23.36499276469119
# Transport time:  [52.44636088814382]  +/-  [5.233127272835413]
# Reaction time:  [9.499064497822026]  +/-  [1.1990505345992957]
# Search time:  [61.89940028446265]  +/-  [6.33309530774619]

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax1.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax1.set_ylabel(r'$Elongation\: latency,\: [ms]$',fontsize=30)

#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))




####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
ax2.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax2.set_ylabel(r'$Transport\: latency\: [ms]$',fontsize=30)
ax2.set_yticks(np.arange(0, 226, 25))

#Plot inferred experimental values of transport latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
exptl_trans = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
experimental_vals = [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of transport latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))



### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
ax3.scatter(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax3.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax3.set_ylabel(r'$Reaction\: latency\: [ms]$',fontsize=30)

#Plot inferred experimental values of reaction latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/1529+1000/209+1000/200+1000/32]*len(phi_list),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax3.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax3.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
exptl_rxn = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1529+1000/209+1000/200+1000/32)],experimental_vals))





##### Plot Da (Subplot 4) ######

#Plot Damkohler number predicted by our simulation
ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='black')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),0,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax4.set_xlabel('$Voxel\: volume\: fraction\:(\phi_{voxel})$',size=30,color='black')
ax4.set_ylabel(r'$Da$',fontsize=30)

#Plot inferred experimental values of Damkohler number (using data from literature)
ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))


####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Doubling rate (1/hr)',size=35,color='black',labelpad=20)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)


plt.tight_layout(pad=4.0)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [203.60863754839102, 207.6648824997135, 160.3310634000271, 127.82402393290394, 121.3825716258994, 103.58811151643401]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [82.44545311560375, 49.07084465480462]
# 	Predicted/Experimental:  [2.46961633 2.110991  ]
#
#
# Transport latencies:
#  [149.63675402008653, 138.5309051779286, 95.83656044700284, 69.2741148595855, 66.38701627098757, 52.44636088814382]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of transport latency [40.756741883632365, 7.382133422833235]
# 	Predicted/Experimental:  [3.67146016 7.10449919]
#
#
# Reaction latencies:
#  [54.19488714079737, 69.60011789067235, 64.5566096705473, 58.52865962122888, 55.05647439221937, 51.18777572979339]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [41.688711231971354, 41.68871123197134, 41.68871123197134]
# 	Predicted/Experimental:  [1.29998951 1.66951954 1.227857  ]
#
#
# Damkohler number:
#  [2.76108618 1.9903832  1.48453522 1.18359305 1.20579854 1.02458761]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [41.688711231971354, 41.68871123197134]
# 	Predicted/Experimental:  [3.58938306 1.25804707]
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]

# %% [markdown]
# ## Plot Kinetic Scaling Data

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

data = "190916_1101/"
gr_sim = dict()
rxndiff_1=dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=1000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['3000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "191114_2050/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=600)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['1800'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "190917_0105/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['600'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "190918_1046/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['300'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "190921_2357/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=20)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['60'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "190921_2258/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=10)
    gr_sim[i] = (CellLatencies(sim_i))
    
gr_dict = {'gr_1':gr_sim}
rxndiff_1['30'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 199.90073459498925
# Unweighted search time ( 2  cognate) 170.50577337913754
# Unweighted search time ( 3  cognate) 147.99196831561093
# Unweighted search time ( 4  cognate) 78.80214081365986
# Unweighted search time ( 5  cognate) 117.78101179607854
# Unweighted search time ( 6  cognate) 88.22750862929333
# Transport time:  [100.36099956925699]  +/-  [9.96149496027985]
# Reaction time:  [17.932671509228182]  +/-  [2.071397907585566]
# Search time:  [118.3754918233713]  +/-  [11.73811428662061]
# Computing...
# missing expt
# 21
# missing expt
# 49
# missing expt
# 54
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 138.2102566342633
# Unweighted search time ( 2  cognate) 100.65602899618723
# Unweighted search time ( 3  cognate) 63.082804128763286
# Unweighted search time ( 4  cognate) 36.40166485607022
# Unweighted search time ( 5  cognate) 28.529524891650027
# Unweighted search time ( 6  cognate) 26.58505378381066
# Transport time:  [56.364604572017974]  +/-  [5.4596809536942565]
# Reaction time:  [9.762593610826189]  +/-  [1.1502561848396209]
# Search time:  [66.20083592467762]  +/-  [6.4621266141503675]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 152.35082353624833
# Unweighted search time ( 2  cognate) 63.915609406538735
# Unweighted search time ( 3  cognate) 45.832701975943614
# Unweighted search time ( 4  cognate) 34.514951403389176
# Unweighted search time ( 5  cognate) 25.74401833492676
# Unweighted search time ( 6  cognate) 25.035061923650392
# Transport time:  [51.62305365902457]  +/-  [5.184242217055339]
# Reaction time:  [8.856238714612974]  +/-  [1.0153087422660882]
# Search time:  [60.48615133208331]  +/-  [6.116218655574702]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 128.29217351902759
# Unweighted search time ( 2  cognate) 78.76151664765736
# Unweighted search time ( 3  cognate) 42.24279018137585
# Unweighted search time ( 4  cognate) 36.564299755134066
# Unweighted search time ( 5  cognate) 24.705278833235276
# Unweighted search time ( 6  cognate) 22.050707724896448
# Transport time:  [49.08285503387267]  +/-  [5.50297421253034]
# Reaction time:  [8.247663437943858]  +/-  [1.0872561858944987]
# Search time:  [57.257647444007276]  +/-  [6.416106447383998]
# Computing...
# missing expt
# 1
# missing expt
# 2
# missing expt
# 6
# missing expt
# 8
# missing expt
# 11
# missing expt
# 15
# missing expt
# 16
# missing expt
# 20
# missing expt
# 24
# missing expt
# 27
# missing expt
# 51
# missing expt
# 52
# missing expt
# 55
# missing expt
# 58
# missing expt
# 60
# missing expt
# 63
# missing expt
# 64
# missing expt
# 69
# missing expt
# 90
# missing expt
# 93
# missing expt
# 94
# missing expt
# 97
# missing expt
# 99
# Computing...
# missing expt
# 110
# missing expt
# 114
# missing expt
# 117
# missing expt
# 121
# missing expt
# 125
# missing expt
# 126
# missing expt
# 150
# missing expt
# 153
# missing expt
# 154
# missing expt
# 157
# missing expt
# 159
# missing expt
# 161
# missing expt
# 162
# missing expt
# 165
# missing expt
# 168
# missing expt
# 191
# missing expt
# 192
# missing expt
# 195
# missing expt
# 198
# Computing...
# missing expt
# 200
# missing expt
# 204
# missing expt
# 207
# missing expt
# 231
# missing expt
# 235
# missing expt
# 236
# missing expt
# 240
# missing expt
# 243
# missing expt
# 244
# missing expt
# 249
# missing expt
# 271
# missing expt
# 272
# missing expt
# 275
# missing expt
# 278
# missing expt
# 281
# missing expt
# 282
# missing expt
# 285
# missing expt
# 288
# Computing...
# missing expt
# 301
# missing expt
# 302
# missing expt
# 306
# missing expt
# 308
# missing expt
# 330
# missing expt
# 333
# missing expt
# 337
# missing expt
# 339
# missing expt
# 342
# missing expt
# 345
# missing expt
# 346
# missing expt
# 348
# missing expt
# 373
# missing expt
# 374
# missing expt
# 377
# missing expt
# 379
# missing expt
# 383
# missing expt
# 384
# missing expt
# 387
# missing expt
# 389
# Computing...
# missing expt
# 411
# missing expt
# 412
# missing expt
# 416
# missing expt
# 418
# missing expt
# 420
# missing expt
# 423
# missing expt
# 427
# missing expt
# 429
# missing expt
# 452
# missing expt
# 455
# missing expt
# 456
# missing expt
# 458
# missing expt
# 463
# missing expt
# 464
# missing expt
# 467
# missing expt
# 469
# missing expt
# 493
# missing expt
# 494
# missing expt
# 497
# missing expt
# 499
# Computing...
# missing expt
# 510
# missing expt
# 514
# missing expt
# 517
# missing expt
# 521
# missing expt
# 525
# missing expt
# 526
# missing expt
# 550
# missing expt
# 553
# missing expt
# 554
# missing expt
# 559
# missing expt
# 561
# missing expt
# 562
# missing expt
# 565
# missing expt
# 568
# missing expt
# 591
# missing expt
# 592
# missing expt
# 595
# missing expt
# 598
# Unweighted search time ( 1  cognate) 170.1612047091858
# Unweighted search time ( 2  cognate) 75.3017627508869
# Unweighted search time ( 3  cognate) 47.92106140404879
# Unweighted search time ( 4  cognate) 39.96989937017493
# Unweighted search time ( 5  cognate) 29.32998372392403
# Unweighted search time ( 6  cognate) 20.257823847265414
# Transport time:  [57.985864840821286]  +/-  [6.355687009139289]
# Reaction time:  [9.429012084229548]  +/-  [1.2011864158746797]
# Search time:  [67.44813038627808]  +/-  [7.319300700733754]
# Computing...
# missing expt
# 58
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 119.72988277936619
# Unweighted search time ( 2  cognate) 72.36177261257276
# Unweighted search time ( 3  cognate) 50.92486334818963
# Unweighted search time ( 4  cognate) 31.10979442257797
# Unweighted search time ( 5  cognate) 23.363456044170277
# Unweighted search time ( 6  cognate) 20.59349189855854
# Transport time:  [46.25939943436467]  +/-  [4.762575368654587]
# Reaction time:  [8.419887799764338]  +/-  [0.9941151818670109]
# Search time:  [54.67013713306309]  +/-  [5.616220857192076]

# %%
fig, [ax1,ax2,ax3] = plt.subplots(1,3,figsize=(20,6))
x=[3000,1800,600,300,60,30]

ax1.scatter(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],zorder=2,s=250,color='black')
ax1.errorbar(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],[rxndiff_1[d][5][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][2][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax1.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax1.set_ylabel('Elongation latency (ms)',size=25,color='black')

ax2.scatter(x,[rxndiff_1[d][0][0] for d in rxndiff_1],zorder=2,s=250,color='black')
ax2.errorbar(x,[rxndiff_1[d][0][0] for d in rxndiff_1],[rxndiff_1[d][3][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][0][0] for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax2.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax2.set_ylabel('Transport latency (ms)',size=25,color='black')

ax3.scatter(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],zorder=2,s=250,color='black')
ax3.errorbar(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],[rxndiff_1[d][4][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][1][0]+(1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax3.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax3.set_ylabel('Reaction latency (ms)',size=25,color='black')

for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.tick_params(axis='both', which='major',width=4, labelsize=30)
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout(pad=3.0)
