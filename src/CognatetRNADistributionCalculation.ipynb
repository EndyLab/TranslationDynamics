# %% [markdown]
# ## Calculate the distribution of cognate ternary complexes per translation voxel, accounting for non-uniform tRNA and codons

# %%
import pandas as pd
import numpy as np
WS = pd.read_excel('tRNAValues.xlsx',header=None)
WS_np = np.array(WS)
gr04=WS[0]
gr07=WS[1]
gr107=WS[2]
gr16=WS[3]
gr25=WS[4]

COD = pd.read_excel('codonValues.xlsx',header=None)
gr04_cod = COD[0]
gr07_cod = COD[1]
gr107_cod = COD[2]
gr16_cod = COD[3]
gr25_cod = COD[4]

cod_labels = COD[5]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr04
pCodon = gr04_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"0.4 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

ax=inset_axes(ax,width="40%",height="40%", bbox_to_anchor=(-0.065, 0, 1.1, 1.1),bbox_transform=ax.transAxes, loc=4,borderpad=3)
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9647664426813797
# [2.36320823e-01 2.53511813e-01 1.93230783e-01 1.36260051e-01
#  8.07461185e-02 4.44518043e-02 2.02450494e-02 8.16460665e-03
#  3.58401069e-03 8.68653260e-04 1.69272404e-04 1.93358134e-05
#  0.00000000e+00 2.00336565e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.811275391352854
# 0.9647664426813797
# [2.36320823e-01 2.53511813e-01 1.93230783e-01 1.36260051e-01
#  8.07461185e-02 4.44518043e-02 2.02450494e-02 8.16460665e-03
#  3.58401069e-03 8.68653260e-04 1.69272404e-04 1.93358134e-05
#  0.00000000e+00 2.00336565e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.811275391352854
# ([<matplotlib.axis.XTick at 0x7fcc604d40d0>,
#   <matplotlib.axis.XTick at 0x7fcc604d4e50>,
#   <matplotlib.axis.XTick at 0x7fcbf003fc50>,
#   <matplotlib.axis.XTick at 0x7fcc32d83d90>,
#   <matplotlib.axis.XTick at 0x7fcc32d160d0>,
#   <matplotlib.axis.XTick at 0x7fcc32d89290>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr07
pCodon = gr07_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"0.7 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

ax=inset_axes(ax,width="40%",height="40%", bbox_to_anchor=(-0.065, 0, 1.1, 1.1),bbox_transform=ax.transAxes, loc=4,borderpad=3)
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9656615248077218
# [2.29892144e-01 2.52101071e-01 1.95249859e-01 1.39657005e-01
#  8.39073352e-02 4.44108482e-02 2.04432629e-02 7.32751005e-03
#  3.45827456e-03 8.76547966e-04 2.07950694e-04 4.20347636e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.831304549726297
# 0.9656615248077218
# [2.29892144e-01 2.52101071e-01 1.95249859e-01 1.39657005e-01
#  8.39073352e-02 4.44108482e-02 2.04432629e-02 7.32751005e-03
#  3.45827456e-03 8.76547966e-04 2.07950694e-04 4.20347636e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.831304549726297
# ([<matplotlib.axis.XTick at 0x7fcc6050e4d0>,
#   <matplotlib.axis.XTick at 0x7fcc6050ee50>,
#   <matplotlib.axis.XTick at 0x7fcc40b0a7d0>,
#   <matplotlib.axis.XTick at 0x7fcc00133090>,
#   <matplotlib.axis.XTick at 0x7fcc40b1efd0>,
#   <matplotlib.axis.XTick at 0x7fcc40b1ef10>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr107
pCodon = gr107_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(24,0.27,"1.07 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

ax=inset_axes(ax,width="40%",height="40%", bbox_to_anchor=(-0.065, 0, 1.1, 1.1),bbox_transform=ax.transAxes, loc=4,borderpad=3)
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9653007752755141
# [2.23029652e-01 2.53604144e-01 1.96815432e-01 1.41103633e-01
#  8.42352652e-02 4.59527159e-02 2.05599325e-02 7.31751629e-03
#  3.75818821e-03 1.01409892e-03 1.95686264e-04 2.35810993e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.853241409079144
# 0.9653007752755141
# [2.23029652e-01 2.53604144e-01 1.96815432e-01 1.41103633e-01
#  8.42352652e-02 4.59527159e-02 2.05599325e-02 7.31751629e-03
#  3.75818821e-03 1.01409892e-03 1.95686264e-04 2.35810993e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.853241409079144
# ([<matplotlib.axis.XTick at 0x7fcbf00b67d0>,
#   <matplotlib.axis.XTick at 0x7fcbf00b6390>,
#   <matplotlib.axis.XTick at 0x7fcbf009c290>,
#   <matplotlib.axis.XTick at 0x7fcc32bd5c90>,
#   <matplotlib.axis.XTick at 0x7fcc32bd5bd0>,
#   <matplotlib.axis.XTick at 0x7fcc506c0050>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr16
pCodon = gr16_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"1.6 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

ax=inset_axes(ax,width="40%",height="40%", bbox_to_anchor=(-0.065, 0, 1.1, 1.1),bbox_transform=ax.transAxes, loc=4,borderpad=3)
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9624241608727319
# [2.22178480e-01 2.39700769e-01 1.94576656e-01 1.40138782e-01
#  9.12818969e-02 5.05759670e-02 2.39716104e-02 1.00945955e-02
#  3.54631124e-03 1.10763665e-03 2.17760091e-04 2.08056913e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.9245751280999221
# 0.9624241608727319
# [2.22178480e-01 2.39700769e-01 1.94576656e-01 1.40138782e-01
#  9.12818969e-02 5.05759670e-02 2.39716104e-02 1.00945955e-02
#  3.54631124e-03 1.10763665e-03 2.17760091e-04 2.08056913e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.9245751280999221
# ([<matplotlib.axis.XTick at 0x7fcc40c33790>,
#   <matplotlib.axis.XTick at 0x7fcc40c33650>,
#   <matplotlib.axis.XTick at 0x7fcc40c34350>,
#   <matplotlib.axis.XTick at 0x7fcc40cae8d0>,
#   <matplotlib.axis.XTick at 0x7fcc606006d0>,
#   <matplotlib.axis.XTick at 0x7fcc60600b10>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr25
pCodon = gr25_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"2.5 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

ax=inset_axes(ax,width="40%",height="40%", bbox_to_anchor=(-0.065, 0, 1.1, 1.1),bbox_transform=ax.transAxes, loc=4,borderpad=3)
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9630844032150878
# [2.10642118e-01 2.33627346e-01 1.96957158e-01 1.46900068e-01
#  9.57887048e-02 5.33149604e-02 2.58540494e-02 1.01232044e-02
#  3.40412909e-03 1.21527668e-03 3.54323459e-04 7.62609602e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.986510840027352
# 0.9630844032150878
# [2.10642118e-01 2.33627346e-01 1.96957158e-01 1.46900068e-01
#  9.57887048e-02 5.33149604e-02 2.58540494e-02 1.01232044e-02
#  3.40412909e-03 1.21527668e-03 3.54323459e-04 7.62609602e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.986510840027352
# ([<matplotlib.axis.XTick at 0x7fcc40e1a110>,
#   <matplotlib.axis.XTick at 0x7fcc40e1a750>,
#   <matplotlib.axis.XTick at 0x7fcc40e1aad0>,
#   <matplotlib.axis.XTick at 0x7fcc40d5ac50>,
#   <matplotlib.axis.XTick at 0x7fcc40d633d0>,
#   <matplotlib.axis.XTick at 0x7fcbf00775d0>],
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# ## Near-cognate distribution calculation

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr04
pCodon = gr04_cod
p_codon_count_hist_weighted_avg=nearcognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Near-cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"0.4 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))
print(np.sum(np.multiply(p_codon_count_hist_weighted_avg, np.arange(0,42))))
# Out:
# 7.887477497026643

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr07
pCodon = gr07_cod
p_codon_count_hist_weighted_avg=nearcognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Near-cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"0.7 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))
# Out:
# ([<matplotlib.axis.XTick at 0x7fcc1015c650>,
#   <matplotlib.axis.XTick at 0x7fcc1015d050>,
#   <matplotlib.axis.XTick at 0x7fcc1015d390>,
#   <matplotlib.axis.XTick at 0x7fcc32aa9750>,
#   <matplotlib.axis.XTick at 0x7fcc32aa9190>],
#  <a list of 5 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr107
pCodon = gr107_cod
p_codon_count_hist_weighted_avg=nearcognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Near-cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(24,0.27,"1.07 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))
# Out:
# ([<matplotlib.axis.XTick at 0x7fcc2072f250>,
#   <matplotlib.axis.XTick at 0x7fcc2072fb50>,
#   <matplotlib.axis.XTick at 0x7fcc20732d90>,
#   <matplotlib.axis.XTick at 0x7fcc206476d0>,
#   <matplotlib.axis.XTick at 0x7fcc20647850>],
#  <a list of 5 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr16
pCodon = gr16_cod
p_codon_count_hist_weighted_avg=nearcognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Near-cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"1.6 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))
# Out:
# ([<matplotlib.axis.XTick at 0x7fcc33106550>,
#   <matplotlib.axis.XTick at 0x7fcc33106fd0>,
#   <matplotlib.axis.XTick at 0x7fcc3310a190>,
#   <matplotlib.axis.XTick at 0x7fcc60672150>,
#   <matplotlib.axis.XTick at 0x7fcc6066eb50>],
#  <a list of 5 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr25
pCodon = gr25_cod
p_codon_count_hist_weighted_avg=nearcognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel(r'Near-cognate ($\#$)',fontsize=35)
plt.ylabel('Probability',fontsize=35,labelpad=10)
plt.ylim(0,0.3)
plt.xlim(0,42)
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"2.5 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))
# Out:
# ([<matplotlib.axis.XTick at 0x7fcc5089f190>,
#   <matplotlib.axis.XTick at 0x7fcc5089fc10>,
#   <matplotlib.axis.XTick at 0x7fcbf02badd0>,
#   <matplotlib.axis.XTick at 0x7fcc50878250>,
#   <matplotlib.axis.XTick at 0x7fcc5086ec10>],
#  <a list of 5 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


ptRNA = gr16
pCodon = gr16_cod
ribosomeDuplicateProb=matchingRibosomeDistrib(ptRNA,pCodon)

# %%
ribosomeDuplicateProb
# Out:
# 0.46092
