# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]

# %%
#### Sweep of k1r


from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


ribs=[4,8,9,9,8,7]
scalingFactorList = np.logspace(0,5,40)
rxndiff=dict()

#Growth rate = 1.5
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

for i, scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    gr_sim = dict()
    data = "191004_0104/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_0916/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1041/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1206/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

    search_list = transportRxnResults[0]
    rxndiff[scalingFactor] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Starting scaling =  1.0
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 1.9329420968333257
# Unweighted search time ( 2  cognate) 1.05630652540311
# Unweighted search time ( 3  cognate) 0.7292496384732154
# Unweighted search time ( 4  cognate) 0.3684387645641605
# Unweighted search time ( 5  cognate) 0.41228532754602465
# Unweighted search time ( 6  cognate) 0.3194489290959036
# Unweighted search time ( 7  cognate) 0.31413758977949696
# Unweighted search time ( 8  cognate) 0.18649769318307227
# Unweighted search time ( 9  cognate) 0.18633481546252156
# Unweighted search time ( 10  cognate) 0.20702109933311627
# Unweighted search time ( 11  cognate) 0.16848529095179068
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [0.7243090768649635]  +/-  [0.04877238614048234]
# Reaction time:  [0.11300759867204865]  +/-  [0.008512456553434326]
# Search time:  [0.8373166755370118]  +/-  [0.0563383288552661]
# Starting scaling =  1.3433993325989002
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 2.596638755684966
# Unweighted search time ( 2  cognate) 1.4189981528113274
# Unweighted search time ( 3  cognate) 0.9796425413653208
# Unweighted search time ( 4  cognate) 0.4949452085394474
# Unweighted search time ( 5  cognate) 0.5538478054056851
# Unweighted search time ( 6  cognate) 0.42913395634174695
# Unweighted search time ( 7  cognate) 0.42199208791034143
# Unweighted search time ( 8  cognate) 0.25052204259527566
# Unweighted search time ( 9  cognate) 0.2503101317850474
# Unweighted search time ( 10  cognate) 0.2780178458528054
# Unweighted search time ( 11  cognate) 0.2263061712876269
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [0.9730029064014196]  +/-  [0.06551870666793022]
# Reaction time:  [0.1518143326346345]  +/-  [0.01143562845266081]
# Search time:  [1.1248172390360542]  +/-  [0.07568277514799238]
# Starting scaling =  1.8047217668271702
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate)
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [53908.895716616404]  +/-  [3630.0685434167303]
# Reaction time:  [8412.063035153324]  +/-  [633.6504974262846]
# Search time:  [62320.958751769744]  +/-  [4193.259398619693]
# Starting scaling =  100000.0
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 193272.55372698326
# Unweighted search time ( 2  cognate) 105618.03515941452
# Unweighted search time ( 3  cognate) 72915.95510872282
# Unweighted search time ( 4  cognate) 36839.45544380797
# Unweighted search time ( 5  cognate) 41223.86521504797
# Unweighted search time ( 6  cognate) 31940.955316059502
# Unweighted search time ( 7  cognate) 31407.893986278305
# Unweighted search time ( 8  cognate) 18644.284808591972
# Unweighted search time ( 9  cognate) 18630.006050885455
# Unweighted search time ( 10  cognate) 20674.689995458884
# Unweighted search time ( 11  cognate) 16837.796470598805
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [72421.17449342221]  +/-  [4876.63165643001]
# Reaction time:  [11300.759867204866]  +/-  [851.2456553434328]
# Search time:  [83721.93436062706]  +/-  [5633.221875421554]

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload

colors = ['darkblue','#D43F3A']

fig,ax1= plt.subplots(1,1,figsize=(5,5))


ax1.plot(np.array(scalingFactorList)/200,[rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff][::-1],linewidth=2,color='blue')

#Plot experimental measurements of elongation latency from literature
ax1.plot(np.linspace(min(scalingFactorList), max(scalingFactorList),1000)/200,[1000/18]*1000,markevery=199,linewidth=2,alpha=0.3,color='green')
ax1.plot([1]*1000,np.linspace(0,max([rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff]),1000),linestyle='--',color='blue')

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])


ax1.set_xlabel('Kinetic rate scaling',size=20,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=20)
ax1.set_xscale('log')
ax1.set_yscale('log')

for _,axes in enumerate([ax1]):
    axes.spines['left'].set_linewidth(2)
    axes.spines['bottom'].set_linewidth(2)
    axes.spines['top'].set_linewidth(2)
    axes.spines['right'].set_linewidth(2)
    axes.set_ylim(10,20001)
    axes.set_xlim(0.01,100)
    axes.tick_params(which='major',length=6,direction='in')
    axes.tick_params(which='minor',length=4,direction='in')
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [43.203994009203285, 43.49149457270233, 43.87772263782875, 44.39658116275055, 45.09361535884374, 46.03001063267395, 47.28796341858621, 48.97789635162167, 51.24815112599842, 54.298009874725594, 58.395188082286616, 63.899334551862836, 71.29360124561813, 81.22705418706727, 94.57164823901262, 112.49876698219924, 136.5820463372174, 168.93550774954167, 212.39912621812235, 270.7881222611469, 349.2278605764658, 454.6037526784977, 596.1656558003809, 786.3398219757491, 1041.819669893291, 1385.0311270781854, 1846.1011696006685, 2465.5023570067183, 3297.6054987789726, 4415.452304089267, 5917.166956290927, 7934.5694178126305, 10644.746538204261, 14285.596672963173, 19176.712314090953, 25747.433802046042, 34574.53666365811, 46432.8607567296, 62363.32542910341, 83764.30103796071]

# %%
#### Sweep of all other parameters
from analysis_utils import *
# %load_ext autoreload
# %autoreload
def sweepElongTime(NR_scaledRates = {'k1r':718,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}):

    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()
    data = "191004_0104/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 9,scaling=200,NR_scaling = NR_scaledRates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_0916/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 9,scaling=200,NR_scaling = NR_scaledRates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1041/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 9,scaling=200,NR_scaling =NR_scaledRates)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1206/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 9,scaling=200,NR_scaling = NR_scaledRates)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

    search_list = transportRxnResults[0]
    return transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload

scalingFactorList = np.logspace(0,5,40)/200

k1r = 718
k2f=1475
k2r_nr = 1120
k3_nr=6
k3_cog=1529
k4=209
k5_cog=200
k6_cog = 32
colors = ['darkblue','#D43F3A']

##k2f sweep
fig,ax1= plt.subplots(1,1,figsize=(4,4))

elong_time = list()
for i,scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    elong_time.append(sweepElongTime({'k1r':k1r,'k2f':k2f*scalingFactor,'k2r_nr':k2r_nr,'k3_nr':k3_nr,'k4':k4})[2][0] + 
    (1000/(k2f*scalingFactor)+1000/k3_cog+1000/k4+1000/k5_cog+1000/k6_cog))
ax1.plot(np.array(scalingFactorList),elong_time,linewidth=2,color='blue')
print(elong_time)

##k2r sweep
fig2,ax2= plt.subplots(1,1,figsize=(4,4))

elong_time = list()
for i,scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    elong_time.append(sweepElongTime({'k1r':k1r,'k2f':k2f,'k2r_nr':k2r_nr*scalingFactor,'k3_nr':k3_nr,'k4':k4})[2][0] + 
    (1000/(k2f)+1000/k3_cog+1000/k4+1000/k5_cog+1000/k6_cog))
ax2.plot(np.array(scalingFactorList),elong_time,linewidth=2,color='blue')
print(elong_time)

##k3 sweep
fig3,ax3= plt.subplots(1,1,figsize=(4,4))

elong_time = list()
for i,scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    elong_time.append(sweepElongTime({'k1r':k1r,'k2f':k2f,'k2r_nr':k2r_nr,'k3_nr':k3_nr*scalingFactor,'k4':k4})[2][0] + 
    (1000/(k2f)+1000/(k3_cog*scalingFactor)+1000/k4+1000/k5_cog+1000/k6_cog))
ax3.plot(np.array(scalingFactorList),elong_time,linewidth=2,color='blue')
print(elong_time)

##k4 sweep
fig4,ax4= plt.subplots(1,1,figsize=(4,4))

elong_time = list()
for i,scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    elong_time.append(sweepElongTime({'k1r':k1r,'k2f':k2f,'k2r_nr':k2r_nr,'k3_nr':k3_nr,'k4':k4*scalingFactor})[2][0] + 
    (1000/(k2f)+1000/(k3_cog)+1000/(k4*scalingFactor)+1000/k5_cog+1000/k6_cog))
ax4.plot(np.array(scalingFactorList),elong_time,linewidth=2,color='blue')
print(elong_time)

##k5 sweep
fig5,ax5= plt.subplots(1,1,figsize=(4,4))

elong_time = list()
elong = sweepElongTime({'k1r':k1r,'k2f':k2f,'k2r_nr':k2r_nr,'k3_nr':k3_nr,'k4':k4})[2][0]
for i,scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    elong_time.append(elong+ 
    (1000/(k2f)+1000/(k3_cog)+1000/(k4)+1000/(k5_cog*scalingFactor)+1000/k6_cog))
ax5.plot(np.array(scalingFactorList),elong_time,linewidth=2,color='blue')
print(elong_time)

##k6 sweep
fig6,ax6= plt.subplots(1,1,figsize=(4,4))

elong_time = list()
elong = sweepElongTime({'k1r':k1r,'k2f':k2f,'k2r_nr':k2r_nr,'k3_nr':k3_nr,'k4':k4})[2][0]
for i,scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    elong_time.append(elong+ 
    (1000/(k2f)+1000/(k3_cog)+1000/(k4)+1000/(k5_cog)+1000/(k6_cog*scalingFactor)))
ax6.plot(np.array(scalingFactorList),elong_time,linewidth=2,color='blue')
print(elong_time)


for _,axes in enumerate([ax1,ax2,ax3,ax4,ax5,ax6]):
    #Plot experimental measurements of elongation latency from literature
    axes.plot(np.linspace(min(scalingFactorList), max(scalingFactorList),1000),[1000/18]*1000,markevery=199,linewidth=2,alpha=0.3,color='green')
    axes.plot([1]*1000,np.linspace(0,20001,1000),linestyle='--',color='blue')
    
    axes.spines['left'].set_linewidth(2)
    axes.spines['bottom'].set_linewidth(2)
    axes.spines['top'].set_linewidth(2)
    axes.spines['right'].set_linewidth(2)
    axes.set_ylim(10,20001)
    axes.set_xlim(0.01,100)
    axes.tick_params(which='major',length=6,direction='in')
    axes.tick_params(which='minor',length=4,direction='in')
    axes.tick_params(axis='both', which='major', labelsize=12)
    axes.tick_params(axis='both', which='minor', labelsize=8)
    axes.set_xlabel('Kinetic rate scaling',size=18,color='black')
    axes.set_ylabel('Elongation latency (ms)',fontsize=18)
    axes.set_xscale('log')
    axes.set_yscale('log')
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Starting scaling =  0.005
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 327.92259593663056
# Unweighted search time ( 2  cognate) 183.83191482503443
# Unweighted search time ( 3  cognate) 127.52868736790298
# Unweighted search time ( 4  cognate) 63.992969799531416
# Unweighted search time ( 5  cognate) 65.10361931839114
# Unweighted search time ( 6  cognate) 50.42415190864356
# Unweighted search time ( 7  cognate) 53.10323306193125
# Unweighted search time ( 8  cognate) 31.399407088073268
# Unweighted search time ( 9  cognate) 31.640509486725758
# Unweighted search time ( 10  cognate) 33.30716822410912
# Unweighted search time ( 11  cognate) 26.9706580738546
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [122.76831484112722]  +/-  [8.286975979552741]
# Reaction time:  [23.00330708429947]  +/-  [1.7394942942704879]
# Search time:  [145.77162192542667]  +/-  [9.8414886594968]
# Starting scaling =  0.006716996662994501
# Computing...
# /Users/akshay/Documents/TranslationDynamics/src/analysis_utils.py:760: RuntimeWarning: invalid value encountered in double_scalars
#   transport_phi.append(np.sum(transport_vals_list))
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 324.34161870837363
# Unweighted search time ( 2  cognate) 175.58490062392036
# Unweighted search time ( 3  cognate) 123.94888356967361
# Unweighted search time ( 4  cognate) 63.65358514856575
# Unweighted search time ( 5  cognate) 67.10068658817593
# Unweighted search time ( 6  cognate) 50.58184770980679
# Unweighted search time ( 7  cognate) 51.630835201850175
# Unweighted search time ( 8  cognate) 31.580667280570125
# Unweighted search time ( 9  cognate) 34.24163575982
# Unweighted search time ( 10  cognate) 32.72083847600933
# Unweighted search time ( 11  cognate) 28.076278596414916
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [119.85245279441158]  +/-  [8.134114761466549]
# Reaction time:  [23.00330708429947]  +/-  [1.7394942942704879]
# Search time:  [142.855759878711]  +/-  [9.689773229531458]
# Starting scaling =  0.009023608834135851
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate) 322.27734306921604
# Unweighted search time ( 2  cognate) 180.70707819547474
# Unweighted search time ( 3  cognate) 126.07525830802128
# Unweighted search time ( 4  cognate) 65.08016326122848
# Unweighted search time ( 5  cognate) 68.88447416686643
# Unweighted search time ( 6  cognate) 50.871502580036505
# Unweighted search time ( 7  cognate) 53.89110681433098
# Unweighted search time ( 8  cognate) 31.796309194464857
# Unweighted search time ( 9  cognate) 32.83296207442448
# Unweighted search time ( 10  cognate) 32.8637648096852
# Unweighted search time ( 11  cognate) 26.379142561824462
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [120.89103315373183]  +/-  [8.127110156500592]
# Reaction time:  [23.00330708429947]  +/-  [1.7394942942704879]
# Search time:  [143.89434023803128]  +/-  [9.682198826526243]
# Starting scaling =  0.01212231008541164
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 77
# missing expt
# 96
# Computing...
# missing expt
# 100
# missing expt
# 113
# missing expt
# 118
# Computing...
# missing expt
# 219
# missing expt
# 229
# missing expt
# 239
# missing expt
# 245
# missing expt
# 250
# missing expt
# 255
# missing expt
# 261
# missing expt
# 267
# Computing...

# %%
 #Growth rate = 3.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

ribs=[4,8,9,9,8,7]
scalingFactorList = [25,50,100,200,400,800,1600]
scalingFactor=200
rxndiff_list = list()


data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))
    
data = "191105_0951/"
for i in range(16,25):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_1033/"
for i in range(25,34):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 597
# Computing...
# missing expt
# 650
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 433
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 210.00632636510142
# Unweighted search time ( 2  cognate) 108.6487999615441
# Unweighted search time ( 3  cognate) 77.95116323362981
# Unweighted search time ( 4  cognate) 54.32616709514994
# Unweighted search time ( 5  cognate) 41.09436145348846
# Unweighted search time ( 6  cognate) 33.3729226599002
# Unweighted search time ( 7  cognate) 28.726400858810806
# Unweighted search time ( 8  cognate) 23.096406850851725
# Unweighted search time ( 9  cognate) 17.83178138821641
# Unweighted search time ( 10  cognate) 17.917413371435646
# Unweighted search time ( 11  cognate) 17.45563403715502
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [80.98590518140152]  +/-  [5.050074558101678]
# Reaction time:  [9.58388471065582]  +/-  [0.7826025342221099]
# Search time:  [90.56978989205734]  +/-  [5.748272223492831]
# ([132.93646722572362], [5.748272223492831])

# %%
 #Growth rate = 3.0; 
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()


ribs=[4,8,9,9,8,7]
scalingFactorList = [25,50,100,200,400,800,1600]
scalingFactor=200
rxndiff_list = list()


#1x

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['1'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
    

#4x faster k1 rate
data = "200926_2022/"
NR_scaledrates = {'k1r':718*4,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=200,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "200927_1008/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=200,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['4'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)


#8x faster k1 rate
NR_scaledrates = {'k1r':718*8,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}

data = "200928_2058/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=100,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "200928_2345/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=100,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['8'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)

#16x faster k1 rate
NR_scaledrates = {'k1r':718*16,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}

data = "200929_0036/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=50,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "200929_0113/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=50,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['16'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 210.00632636510142
# Unweighted search time ( 2  cognate) 108.6487999615441
# Unweighted search time ( 3  cognate) 77.95116323362981
# Unweighted search time ( 4  cognate) 54.32616709514994
# Unweighted search time ( 5  cognate) 41.09436145348846
# Unweighted search time ( 6  cognate) 33.3729226599002
# Unweighted search time ( 7  cognate) 28.726400858810806
# Unweighted search time ( 8  cognate) 23.096406850851725
# Unweighted search time ( 9  cognate) 17.83178138821641
# Unweighted search time ( 10  cognate) 17.917413371435646
# Unweighted search time ( 11  cognate) 17.45563403715502
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [80.98590518140152]  +/-  [5.050074558101678]
# Reaction time:  [9.58388471065582]  +/-  [0.7826025342221099]
# Search time:  [90.56978989205734]  +/-  [5.748272223492831]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 716
# Computing...
# Unweighted search time ( 1  cognate) 72.19320515838012
# Unweighted search time ( 2  cognate) 29.03437430996237
# Unweighted search time ( 3  cognate) 21.575312401739062
# Unweighted search time ( 4  cognate) 15.023905533657203
# Unweighted search time ( 5  cognate) 12.506291847068885
# Unweighted search time ( 6  cognate) 8.284227428278342
# Unweighted search time ( 7  cognate) 8.442113973784767
# Unweighted search time ( 8  cognate) 7.867413988676456
# Unweighted search time ( 9  cognate) 6.649014415210585
# Unweighted search time ( 10  cognate) 6.327052475724279
# Unweighted search time ( 11  cognate) 5.255683279720317
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [23.684153995976118]  +/-  [1.550268162185409]
# Reaction time:  [4.513135286708005]  +/-  [0.31313535267895953]
# Search time:  [28.19728928268412]  +/-  [1.844673630423258]
# Computing...
# missing expt
# 11
# missing expt
# 33
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 599
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 42.44380219960326
# Unweighted search time ( 2  cognate) 20.51917965838805
# Unweighted search time ( 3  cognate) 13.404846712832185
# Unweighted search time ( 4  cognate) 9.115207274505881
# Unweighted search time ( 5  cognate) 8.746311498372782
# Unweighted search time ( 6  cognate) 5.556064071879559
# Unweighted search time ( 7  cognate) 5.883472770439496
# Unweighted search time ( 8  cognate) 5.265535578143817
# Unweighted search time ( 9  cognate) 5.061397517742958
# Unweighted search time ( 10  cognate) 4.256446921558147
# Unweighted search time ( 11  cognate) 3.41652365112477
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [14.400025545934305]  +/-  [0.7877936654372717]
# Reaction time:  [3.095073267885748]  +/-  [0.17860484877575022]
# Search time:  [17.495098813820057]  +/-  [0.9554421905126528]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 7
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 35.54438187271126
# Unweighted search time ( 2  cognate) 14.607182015901543
# Unweighted search time ( 3  cognate) 11.280500429129717
# Unweighted search time ( 4  cognate) 6.434650530929289
# Unweighted search time ( 5  cognate) 6.372207901932716
# Unweighted search time ( 6  cognate) 4.8900065944817985
# Unweighted search time ( 7  cognate) 4.517498422403192
# Unweighted search time ( 8  cognate) 4.112440456821866
# Unweighted search time ( 9  cognate) 3.9845701939668063
# Unweighted search time ( 10  cognate) 3.4844738568076563
# Unweighted search time ( 11  cognate) 2.157867937516909
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [11.363503170514296]  +/-  [0.6652369303712502]
# Reaction time:  [2.623231460437622]  +/-  [0.1529408340267397]
# Search time:  [13.98673463095192]  +/-  [0.8100860394073004]

# %%
colors = ['darkblue','#D43F3A']

fig,ax1= plt.subplots(1,1,figsize=(5,5))

ax1.plot([16,8,4,1],[rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff][::-1],linewidth=2,color='blue')
#Plot experimental measurements of elongation latency from literature
ax1.plot(np.linspace(min([16,8,4,1]), max([16,8,4,1]),1000),[1000/21]*1000,markevery=199,linewidth=2,alpha=0.3,color='green')
ax1.plot([1]*1000,np.linspace(0,max([rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff]),1000),linestyle='--',color='blue')

#Output predicted and empirical values
print('\nElongation latencies: \n', list(zip([1,4,8,16],[rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff][::-1])))


ax1.set_xlabel('# fold $k_1$ scaling',size=20,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=20)


for _,axes in enumerate([ax1]):
    axes.spines['left'].set_linewidth(2)
    axes.spines['bottom'].set_linewidth(2)
    axes.spines['top'].set_linewidth(2)
    axes.spines['right'].set_linewidth(2)
    axes.set_ylim(10,150)
    axes.set_xlim(1,16)
    axes.tick_params(which='major',length=6,direction='in')
    axes.tick_params(which='minor',length=4,direction='in')
# Out:
# Elongation latencies:
#  [(1, 56.353411964618196), (4, 59.86177614748633), (8, 70.5639666163504), (16, 132.93646722572362)]

# %%
 #Growth rate = 3.0; 
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()


ribs=[4,8,9,9,8,7]
scalingFactorList = [25,50,100,200,400,800,1600]
rxndiff_list = list()


#1x
data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))
gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['1'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
    

#4x faster k1 rate
data = "201221_0238/"
NR_scaledrates = {'k1r':718*4,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=200, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "201221_0149/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=200, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['4'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)


#8x faster k1 rate
NR_scaledrates = {'k1r':718*8,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}

data = "201221_0022/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=100,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "201221_0054/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=100,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['8'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)

#16x faster k1 rate
NR_scaledrates = {'k1r':718*16,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}

data = "201018_1147/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=25,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "201020_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=25,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['16'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)

#32x faster k1 rate
NR_scaledrates = {'k1r':718*16,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209}

data = "201018_1231/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=12.5,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "201019_1031/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=12.5,NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}

transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['32'] = transportRxnResults[1:]

rxndiff_list.append(rxndiff)
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 210.51912935177774
# Unweighted search time ( 2  cognate) 108.7112477415959
# Unweighted search time ( 3  cognate) 80.95775132509071
# Unweighted search time ( 4  cognate) 55.441417519902075
# Unweighted search time ( 5  cognate) 40.69625314169508
# Unweighted search time ( 6  cognate) 32.873536029474124
# Unweighted search time ( 7  cognate) 28.566225138512085
# Unweighted search time ( 8  cognate) 23.632351183323838
# Unweighted search time ( 9  cognate) 18.537488343042497
# Unweighted search time ( 10  cognate) 17.612781794388397
# Unweighted search time ( 11  cognate) 16.966491594742404
# Unweighted search time ( 12  cognate) 13.426658674242612
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [82.80866633138743]  +/-  [5.14038906581571]
# Reaction time:  [9.720963352621542]  +/-  [0.793858163798332]
# Search time:  [92.52962968400897]  +/-  [5.8493064848575615]
# Computing...
# missing expt
# 57
# missing expt
# 63
# missing expt
# 69
# Computing...
# Computing...
# missing expt
# 237
# Computing...
# Computing...
# Computing...
# missing expt
# 555
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 720
# Computing...
# Unweighted search time ( 1  cognate) 98.91215051159128
# Unweighted search time ( 2  cognate) 57.4106676373268
# Unweighted search time ( 3  cognate) 42.05937794904215
# Unweighted search time ( 4  cognate) 32.35593726250378
# Unweighted search time ( 5  cognate) 23.04144527853177
# Unweighted search time ( 6  cognate) 20.32401367973102
# Unweighted search time ( 7  cognate) 13.401474526550716
# Unweighted search time ( 8  cognate) 18.20870743702448
# Unweighted search time ( 9  cognate) 12.873680075300461
# Unweighted search time ( 10  cognate) 11.90099806910029
# Unweighted search time ( 11  cognate) 11.86525167332424
# Unweighted search time ( 12  cognate) 8.50811469058966
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [38.85004394506344]  +/-  [2.0522049765502586]
# Reaction time:  [7.490488745240732]  +/-  [0.45399036234691026]
# Search time:  [46.34053269030417]  +/-  [2.449184664971651]
# Computing...
# missing expt
# 12
# missing expt
# 37
# missing expt
# 47
# missing expt
# 50
# missing expt
# 53
# missing expt
# 55
# missing expt
# 57
# missing expt
# 63
# missing expt
# 81
# missing expt
# 86
# missing expt
# 94
# missing expt
# 95
# missing expt
# 97
# Computing...
# missing expt
# 143
# Computing...
# missing expt
# 212
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 51.38209709309844
# Unweighted search time ( 2  cognate) 36.98691102430712
# Unweighted search time ( 3  cognate) 29.706794040152168
# Unweighted search time ( 4  cognate) 20.0959182654787
# Unweighted search time ( 5  cognate) 13.887258387928473
# Unweighted search time ( 6  cognate) 13.369005534489203
# Unweighted search time ( 7  cognate) 9.97253753426689
# Unweighted search time ( 8  cognate) 11.1050389408671
# Unweighted search time ( 9  cognate) 8.338332517062002
# Unweighted search time ( 10  cognate) 7.206545489347469
# Unweighted search time ( 11  cognate) 8.480307829290581
# Unweighted search time ( 12  cognate) 6.126469517556684
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [22.172094088758517]  +/-  [1.0576184349191786]
# Reaction time:  [5.037765889306068]  +/-  [0.2683398663113191]
# Search time:  [27.209859978064582]  +/-  [1.2946817132815764]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 30.0475032947984
# Unweighted search time ( 2  cognate) 13.541492539678352
# Unweighted search time ( 3  cognate) 10.542032942059297
# Unweighted search time ( 4  cognate) 8.675762771121835
# Unweighted search time ( 5  cognate) 5.630189625360515
# Unweighted search time ( 6  cognate) 5.708875627642692
# Unweighted search time ( 7  cognate) 3.573701084909809
# Unweighted search time ( 8  cognate) 4.49897533662691
# Unweighted search time ( 9  cognate) 3.472331477971984
# Unweighted search time ( 10  cognate) 2.5591664723207765
# Unweighted search time ( 11  cognate) 3.110643675577946
# Unweighted search time ( 12  cognate) 2.4677914510552474
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [10.278696844259434]  +/-  [0.6649179372441048]
# Reaction time:  [2.486793379226675]  +/-  [0.16546450329737716]
# Search time:  [12.765490223486111]  +/-  [0.8254434060580406]
# Computing...
# missing expt
# 54
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 24.52387996731202
# Unweighted search time ( 2  cognate) 14.275375484967306
# Unweighted search time ( 3  cognate) 9.255247304029513
# Unweighted search time ( 4  cognate) 6.966591794121433
# Unweighted search time ( 5  cognate) 5.106292560434351
# Unweighted search time ( 6  cognate) 4.770798627346143
# Unweighted search time ( 7  cognate) 3.2938068303546872
# Unweighted search time ( 8  cognate) 3.5916173464280754
# Unweighted search time ( 9  cognate) 3.1095949262153018
# Unweighted search time ( 10  cognate) 3.0364483219467866
# Unweighted search time ( 11  cognate) 2.909671553419388
# Unweighted search time ( 12  cognate) 2.2864435818856084
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [8.990926468386295]  +/-  [0.512008362868489]
# Reaction time:  [2.1790624782927024]  +/-  [0.12329884319991347]
# Search time:  [11.169988946678995]  +/-  [0.6324549736901497]

# %%
colors = ['darkblue','#D43F3A']

fig,ax1= plt.subplots(1,1,figsize=(4,4))
arr = np.array([rxndiff[scale][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scale in rxndiff])

#ax1.plot([1,4,8,16,32],arr,linewidth=2,marker='o',markersize=6,markeredgewidth=5,color='black')

ax1.scatter([1,4,8,16,32],arr,zorder=2,s=75,color='blue')
ax1.errorbar([1,4,8,16,32],arr,[rxndiff[d][5][0] for d in rxndiff][0:6],zorder=1,linewidth=2,elinewidth=2,color='blue')

#Output predicted and empirical values
print('\nElongation latencies: \n', list(zip([32,16,8,4,1],[rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff][::-1])))


ax1.set_xlabel('# fold $k_1$ scaling',size=25,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=25)


for _,axes in enumerate([ax1]):
    #Plot experimental measurements of elongation latency from literature
    axes.plot(np.linspace(0, 33,1000),[1000/21]*1000,markevery=199,linewidth=2,alpha=0.3,color='green')
    axes.plot([1]*1000,np.linspace(0,20001,1000),linestyle='--',color='blue')
    
    axes.spines['left'].set_linewidth(2)
    axes.spines['bottom'].set_linewidth(2)
    axes.spines['top'].set_linewidth(2)
    axes.spines['right'].set_linewidth(2)
    axes.set_ylim(0,150)
    axes.set_xlim(0,33)
    axes.tick_params(which='major',length=6,direction='in')
    axes.tick_params(which='minor',length=4,direction='in')
    axes.tick_params(axis='both', which='major', labelsize=12)
    axes.tick_params(axis='both', which='minor', labelsize=8)
    axes.set_xlabel('Kinetic rate scaling',size=18,color='black')
    axes.set_ylabel('Elongation latency (ms)',fontsize=18)
# Out:
# Elongation latencies:
#  [(32, 53.53666628034527), (16, 55.132167557152385), (8, 69.57653731173086), (4, 88.70721002397045), (1, 134.89630701767524)]

# %%
data = "191003_2210/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "200926_2022/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "200928_2058/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "201018_1147/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "201018_1231/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));
# Out:
# test
# (16.68, 22.22740650638306)
# test
# (0.3, 0.6557438524302002)
# test
# (32.15, 35.23219408438821)
# test
# (2.21, 2.6506414318047624)
# test
# missing expt
# 11
# missing expt
# 33
# (40.06122448979592, 36.86428954148695)
# test
# missing expt
# 11
# missing expt
# 33
# (3.8469387755102042, 3.575289458286878)
# test
# missing expt
# 47
# missing expt
# 50
# missing expt
# 57
# missing expt
# 66
# missing expt
# 86
# missing expt
# 88
# missing expt
# 94
# (47.46236559139785, 43.11339365769699)
# test
# missing expt
# 47
# missing expt
# 50
# missing expt
# 57
# missing expt
# 66
# missing expt
# 86
# missing expt
# 88
# missing expt
# 94
# (6.365591397849462, 6.716669915797222)
# test
# missing expt
# 3
# missing expt
# 4
# missing expt
# 10
# missing expt
# 12
# missing expt
# 14
# missing expt
# 26
# missing expt
# 31
# missing expt
# 34
# missing expt
# 47
# missing expt
# 50
# missing expt
# 53
# missing expt
# 54
# missing expt
# 57
# missing expt
# 66
# missing expt
# 67
# missing expt
# 73
# missing expt
# 74
# missing expt
# 77
# missing expt
# 84
# missing expt
# 86
# missing expt
# 88
# missing expt
# 94
# missing expt
# 95
# missing expt
# 97
# (55.96052631578947, 44.44791179437889)
# test
# missing expt
# 3
# missing expt
# 4
# missing expt
# 10
# missing expt
# 12
# missing expt
# 14
# missing expt
# 26
# missing expt
# 31
# missing expt
# 34
# missing expt
# 47
# missing expt
# 50
# missing expt
# 53
# missing expt
# 54
# missing expt
# 57
# missing expt
# 66
# missing expt
# 67
# missing expt
# 73
# missing expt
# 74
# missing expt
# 77
# missing expt
# 84
# missing expt
# 86
# missing expt
# 88
# missing expt
# 94
# missing expt
# 95
# missing expt
# 97
# (8.592105263157896, 7.860925403503456)

# %%
data = "191003_2210/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "200926_2022/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "200928_2058/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));


data = "200929_0036/"
print(countIncorrectReactions(path+data, 1e15,8,0,100));
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100));
# Out:
# test
# (16.68, 22.22740650638306)
# test
# (0.3, 0.6557438524302002)
# test
# (32.15, 35.23219408438821)
# test
# (2.21, 2.6506414318047624)
# test
# missing expt
# 11
# missing expt
# 33
# (40.06122448979592, 36.86428954148695)
# test
# missing expt
# 11
# missing expt
# 33
# (3.8469387755102042, 3.575289458286878)
# test
# (68.56, 62.20808950610846)
# test
# (7.81, 6.9766682592767735)

# %%
#### Sweep of k1r
from analysis_utils import *
# %load_ext autoreload
# %autoreload

ribs=[4,8,9,9,8,7]
scalingFactorList = [200,50,25]
rxndiff=dict()

#Growth rate = 3.0
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

for j, scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    gr_sim = dict()
    data = "191003_2210/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = {'k1r':718*scalingFactor/200,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209})
        gr_sim[i] = (CellLatencies(sim_i))
        
    data = "191105_0908/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = {'k1r':718*scalingFactor/200,'k2f':1475,'k2r_nr':1120,'k3_nr':6,'k4':209})
        gr_sim[i] = (CellLatencies(sim_i))

    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

    search_list = transportRxnResults[0]
    rxndiff[scalingFactor] = transportRxnResults[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Starting scaling =  200
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 210.00632636510142
# Unweighted search time ( 2  cognate) 108.6487999615441
# Unweighted search time ( 3  cognate) 77.95116323362981
# Unweighted search time ( 4  cognate) 54.32616709514994
# Unweighted search time ( 5  cognate) 41.09436145348846
# Unweighted search time ( 6  cognate) 33.3729226599002
# Unweighted search time ( 7  cognate) 28.726400858810806
# Unweighted search time ( 8  cognate) 23.096406850851725
# Unweighted search time ( 9  cognate) 17.83178138821641
# Unweighted search time ( 10  cognate) 17.917413371435646
# Unweighted search time ( 11  cognate) 17.45563403715502
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [80.98590518140152]  +/-  [5.050074558101678]
# Reaction time:  [9.58388471065582]  +/-  [0.7826025342221099]
# Search time:  [90.56978989205734]  +/-  [5.748272223492831]
# Starting scaling =  50
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 122.13665338434414
# Unweighted search time ( 2  cognate) 60.932298721828175
# Unweighted search time ( 3  cognate) 42.52267056548389
# Unweighted search time ( 4  cognate) 32.57380857137729
# Unweighted search time ( 5  cognate) 23.99449224151181
# Unweighted search time ( 6  cognate) 17.870553591600842
# Unweighted search time ( 7  cognate) 14.635143413325302
# Unweighted search time ( 8  cognate) 12.922583600190107
# Unweighted search time ( 9  cognate) 9.839432790275703
# Unweighted search time ( 10  cognate) 8.414076345853747
# Unweighted search time ( 11  cognate) 10.353260722958867
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [49.45549421125502]  +/-  [3.3343635650137866]
# Reaction time:  [2.395971177663955]  +/-  [0.19565063355552748]
# Search time:  [51.85146538891897]  +/-  [3.5054289378718164]
# Starting scaling =  25
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 103.58848930874471
# Unweighted search time ( 2  cognate) 55.467540195542696
# Unweighted search time ( 3  cognate) 35.02617612729966
# Unweighted search time ( 4  cognate) 25.93067356032676
# Unweighted search time ( 5  cognate) 19.194206392340188
# Unweighted search time ( 6  cognate) 15.519915155163563
# Unweighted search time ( 7  cognate) 12.272772733696632
# Unweighted search time ( 8  cognate) 10.974970804067965
# Unweighted search time ( 9  cognate) 8.587490724508704
# Unweighted search time ( 10  cognate) 6.577191065408318
# Unweighted search time ( 11  cognate) 9.180760542902718
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [43.15671833044069]  +/-  [2.983207860173827]
# Reaction time:  [1.1979855888319775]  +/-  [0.09782531677776374]
# Search time:  [44.35470391927268]  +/-  [3.0673921112060563]

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload

colors = ['darkblue','#D43F3A']

fig,ax1= plt.subplots(1,1,figsize=(5,5))


ax1.plot(np.array(scalingFactorList)/200,[rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff][::-1],linewidth=2,color='blue')

#Plot experimental measurements of elongation latency from literature
ax1.plot(np.linspace(min(scalingFactorList), max(scalingFactorList),1000)/200,[1000/21]*1000,markevery=199,linewidth=2,alpha=0.3,color='green')
ax1.plot([1]*1000,np.linspace(0,max([rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff]),1000),linestyle='--',color='blue')

#Output predicted and empirical values
print('\nElongation latencies: \n', list(zip(scalingFactorList/200,[rxndiff[scl][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for scl in rxndiff][::-1])))


ax1.set_xlabel('Kinetic rate scaling',size=20,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=20)


for _,axes in enumerate([ax1]):
    axes.spines['left'].set_linewidth(2)
    axes.spines['bottom'].set_linewidth(2)
    axes.spines['top'].set_linewidth(2)
    axes.spines['right'].set_linewidth(2)
    axes.set_ylim(10,300)
    axes.set_xlim(1,50)
    axes.tick_params(which='major',length=6,direction='in')
    axes.tick_params(which='minor',length=4,direction='in')
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [(0.005, 49111.21501766185), (0.006716996662994501, 36568.250800918104), (0.009023608834135851, 27231.51531774758), (0.01212231008541164, 20281.43334539177), (0.016285103278298917, 15107.929232574925), (0.021877396875370922, 11256.874682169291), (0.02939008036137456, 8390.225535518686), (0.039482614342498626, 6256.348379941381), (0.053040917756972415, 4667.93225988185), (0.07125513351514988, 3485.546589802179), (0.09572409880849789, 2605.4019884257136), (0.1285956904529672, 1950.239684843378), (0.1727553647296109, 1462.549771885868), (0.23207944168063885, 1099.5230075253112), (0.31177536706369563, 829.2930352814989), (0.41883882003414574, 628.1391671155577), (0.5626677913003824, 478.4041901174712), (0.7558875353078308, 366.9444228207185), (1.0154588104523674, 283.9759676547284), (1.3641666882433834, 222.2158839977849), (1.8326206185398128, 176.24289431536167), (2.4619413158533683, 142.02150640274064), (3.307370320615073, 116.54777935657827), (4.443119081371699, 97.58563874208082), (5.968883208572179, 83.47059479769099), (8.018593718756646, 72.96363413314809), (10.772173450159412, 65.14245958766395), (14.471330623583745, 59.320531322779715), (19.440775901540427, 54.98680260667169), (26.11672537133419, 51.76086031911365), (35.085191433519114, 49.35953242704359), (47.13342275589422, 47.57203124716395), (63.31900867337011, 46.24145058026605), (85.06271399262928, 45.25099254250314), (114.27319320674943, 44.51371508990325), (153.5145314878925, 43.964900277576696), (206.2313191450674, 43.55637334220534), (277.051016500474, 43.25227393895416), (372.1901506625841, 43.025908333529244), (500.0, 42.856223535165455)]

# %%
path = "/Users/Akshay/Documents/TranslationDynamics/data/"
data = "191003_2210/"
print(countIncorrectReactions(path+data, 1e15,8,0,100))
print(countUnsuccesfulCognateReactions(path+data, 1e15,8,0,100))
# Out:
# test
# (16.68, 22.22740650638306)
# test
# (0.3, 0.6557438524302002)

# %%
#### Effective temperature needed to achieve Rodnina in vivo scaled kinetics

w45_293 = 22
w45_310 = 200
Ea_R = np.log(w45_310/w45_293)/(1/293.15 - 1/310.15)
print(Ea_R)

T2 = (np.log(w45_293/w45_310)/Ea_R+1/293.15)**-1
print(T2)

k1r_293 = 85
k1r_310 = 85
T2 = (np.log(k1r_293/k1r_310)/Ea_R+1/293.15)**-1
print(T2)

k1r_293 = 85
k1r_310 = 700
T2 = (np.log(k1r_293/k1r_310)/Ea_R+1/293.15)**-1
print(T2)
# Out:
# 11805.086943800332
# 310.15
# 293.15
# 309.34664707079065
# 319.3000207393091

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(331)

k1r_293 = 85
k1r_T = [700,1400,1700,2100,2300]
T2 = list()
for _,k1r_T_i in enumerate(k1r_T):
    T2.append((np.log(k1r_293/k1r_T_i)/Ea_R+1/293.15)**-1-273.15)
print(T2)
ax1.plot(k1r_T,T2,'-o')
ax1.set_xlabel('k1r',fontsize=16)
ax1.set_ylabel('Effective temperature (C)',fontsize=16)
ax2 = ax1.twiny()
ax2.set_xlim(ax1.get_xlim())
ax2.set_xticks(k1r_T)
ax2.set_xticklabels(labels=['in vitro','0.7','1.07','1.6','2.5'])
ax2.set_xlabel('Growth rate (dbl/hr)',fontsize=16,labelpad=10)
ax1 = fig.add_subplot(334)

w76_293 = 140
w76_T = [1100,2700,3100,3900,4300]
T2 = list()
for _,w76_T_i in enumerate(w76_T):
    T2.append((np.log(w76_293/w76_T_i)/Ea_R+1/293.15)**-1-273.15)
print(T2)
ax1.plot(w76_T,T2,'-o')
ax1.set_xlabel('w76',fontsize=16)
ax1.set_ylabel('Effective temperature (C)',fontsize=16)
ax2 = ax1.twiny()
ax2.set_xlim(ax1.get_xlim())
ax2.set_xticks(w76_T)
ax2.set_xticklabels(labels=['in vitro','0.7','1.07','1.6','2.5'])
ax2.set_xlabel('Growth rate (dbl/hr)',fontsize=16,labelpad=10)

ax1 = fig.add_subplot(337)

w78_293 = 0.6
w78_T = [7,5,5,4,4]
T2 = list()
for _,w78_T_i in enumerate(w78_T):
    T2.append((np.log(w78_293/w78_T_i)/Ea_R+1/293.15)**-1-273.15)
print(T2)
ax1.plot(w78_T,T2,'-o')
ax1.set_xlabel('w78',fontsize=16)
ax1.set_ylabel('Effective temperature (C)',fontsize=16)
ax1.set_xlim(7.3,3.7)
ax2 = ax1.twiny()
ax2.set_xlim(ax1.get_xlim())
ax2.set_xlim(7.3,3.7)
ax2.set_xticks([7,5,4])
ax2.set_xticklabels(labels=['in vitro','0.7&1.07','1.6&2.5'])
ax2.set_xlabel('Growth rate (dbl/hr)',fontsize=16,labelpad=10)


plt.tight_layout()
# Out:
# [36.196647070790675, 41.919439106077164, 43.56059763475065, 45.366287824937615, 46.15002073930913]
# [35.81607167995014, 43.25188980560978, 44.427794055110496, 46.401330288580084, 47.248133273904045]
# [39.046126691393226, 36.292610265758356, 36.292610265758356, 34.49314895124377, 34.49314895124377]

# %%
200*(0.6/22)**(293.15/310.15)
# Out:
# 6.645072206268029
