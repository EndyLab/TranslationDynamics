# %%
import pandas as pd
WS = pd.read_excel('tRNAValues.xlsx',header=None)
WS_np = np.array(WS)
gr04=WS[0]
gr07=WS[1]
gr107=WS[2]
gr16=WS[3]
gr25=WS[4]

COD = pd.read_excel('codonValues.xlsx',header=None)
gr04_cod = COD[0]
gr07_cod = COD[1]
gr107_cod = COD[2]
gr16_cod = COD[3]
gr25_cod = COD[4]

cod_labels = COD[5]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr04
pCodon = gr04_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon,cod_labels)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel('# of cognate tRNA per TU',fontsize=25)
plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,8)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=20)
plt.text(4.9,0.27,"0.4 dbl/hr",fontsize=25)
# Out:
# 0.9875677647745019
# [2.44022971e-01 2.58200795e-01 2.01160361e-01 1.35231047e-01
#  8.32603458e-02 4.48350957e-02 2.08571496e-02 8.42039968e-03
#  2.99777423e-03 6.43778940e-04 2.75816616e-04 2.64932851e-05
#  6.79724724e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8411586809551104
# Text(4.9, 0.27, '0.4 dbl/hr')

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr07
pCodon = gr07_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon,cod_labels)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel('# of cognate tRNA per TU',fontsize=25)
plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,8)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=20)
plt.text(4.9,0.27,"0.7 dbl/hr",fontsize=25)
# Out:
# 0.9875473130746671
# [2.37243038e-01 2.59002984e-01 1.99773174e-01 1.39814600e-01
#  8.64527096e-02 4.51006433e-02 2.01601637e-02 8.21452056e-03
#  2.96645978e-03 9.90615030e-04 2.10318358e-04 7.07732004e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8632987166924908
# Text(4.9, 0.27, '0.7 dbl/hr')

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr107
pCodon = gr107_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon,cod_labels)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel('# of cognate tRNA per TU',fontsize=25)
plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,8)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=20)
plt.text(4.5,0.27,"1.07 dbl/hr",fontsize=25)
# Out:
# 0.9873266867965235
# [2.29033312e-01 2.56498152e-01 2.04972667e-01 1.41304936e-01
#  8.90402206e-02 4.55724014e-02 2.09049983e-02 8.56099093e-03
#  2.93649217e-03 9.51609897e-04 1.91952488e-04 3.22677204e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8940690052771236
# Text(4.5, 0.27, '1.07 dbl/hr')

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr16
pCodon = gr16_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon,cod_labels)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel('# of cognate tRNA per TU',fontsize=25)
plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,8)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=20)
plt.text(4.9,0.27,"1.6 dbl/hr",fontsize=25)
# Out:
# 0.9849423422154185
# [2.30283645e-01 2.46325273e-01 1.96664688e-01 1.42302399e-01
#  9.34212104e-02 5.16045419e-02 2.43405844e-02 1.00770542e-02
#  3.44172617e-03 1.20028808e-03 2.72362398e-04 5.28445683e-05
#  1.33823420e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.9566541882407282
# Text(4.9, 0.27, '1.6 dbl/hr')

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr25
pCodon = gr25_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon,cod_labels)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
plt.xlabel('# of cognate tRNA per TU',fontsize=25)
plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,8)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=20)
plt.text(4.9,0.27,"2.5 dbl/hr",fontsize=25)
# Out:
# 0.9839259884036524
# [2.14665374e-01 2.44540739e-01 1.97701266e-01 1.50706357e-01
#  9.70509725e-02 5.40385039e-02 2.52227762e-02 1.08033910e-02
#  3.76796161e-03 1.04747646e-03 3.40814002e-04 8.85566820e-05
#  2.06490008e-05 5.16282321e-06 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 2.021687293732068
# Text(4.9, 0.27, '2.5 dbl/hr')
