# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]

# %%
#3 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or3'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 211.00146341363575
# Unweighted search time ( 2  cognate) 108.97058438771204
# Unweighted search time ( 3  cognate) 81.14001683109859
# Unweighted search time ( 4  cognate) 55.58236841495304
# Unweighted search time ( 5  cognate) 40.78912479557734
# Unweighted search time ( 6  cognate) 32.941929200122274
# Unweighted search time ( 7  cognate) 28.622005248665197
# Unweighted search time ( 8  cognate) 23.689239725751502
# Unweighted search time ( 9  cognate) 18.585319093136118
# Unweighted search time ( 10  cognate) 17.64028915285567
# Unweighted search time ( 11  cognate) 17.007847019537866
# Unweighted search time ( 12  cognate) 13.45698738548096
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [83.02328180376576]  +/-  [5.155009095424843]
# Reaction time:  [9.720963352621542]  +/-  [0.793858163798332]
# Search time:  [92.74424515638732]  +/-  [5.863884903244429]

# %%
#1 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210108_1534/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210108_1605/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or1'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# missing expt
# 250
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 53
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 406
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 208.65230085651254
# Unweighted search time ( 2  cognate) 89.85718098584753
# Unweighted search time ( 3  cognate) 63.64499403649834
# Unweighted search time ( 4  cognate) 37.15123062673886
# Unweighted search time ( 5  cognate) 39.67780153263243
# Unweighted search time ( 6  cognate) 27.48960487315469
# Unweighted search time ( 7  cognate) 24.006157245412055
# Unweighted search time ( 8  cognate) 23.048813374722673
# Unweighted search time ( 9  cognate) 17.379621968336814
# Unweighted search time ( 10  cognate) 13.574066341521492
# Unweighted search time ( 11  cognate) 16.34951210855389
# Unweighted search time ( 12  cognate) 13.13619826909429
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [75.19426263123128]  +/-  [4.211372949027546]
# Reaction time:  [8.50589464951882]  +/-  [0.5451258396813176]
# Search time:  [83.70015728075005]  +/-  [4.678745394187739]

# %%
#2 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_1101/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210109_1138/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or2'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 99
# Computing...
# Computing...
# Computing...
# missing expt
# 308
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 295
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 738
# Computing...
# Unweighted search time ( 1  cognate) 229.82247267797874
# Unweighted search time ( 2  cognate) 104.22108688033256
# Unweighted search time ( 3  cognate) 64.7044063476832
# Unweighted search time ( 4  cognate) 49.3105651250172
# Unweighted search time ( 5  cognate) 41.589702738357786
# Unweighted search time ( 6  cognate) 31.57782341187129
# Unweighted search time ( 7  cognate) 34.10356963594906
# Unweighted search time ( 8  cognate) 24.98721584202664
# Unweighted search time ( 9  cognate) 23.16075918089039
# Unweighted search time ( 10  cognate) 15.502399254564736
# Unweighted search time ( 11  cognate) 14.259778740723451
# Unweighted search time ( 12  cognate) 12.682211615789893
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [83.49383322318455]  +/-  [5.034240989282896]
# Reaction time:  [9.762707452499043]  +/-  [0.6080447854034189]
# Search time:  [93.25654067568357]  +/-  [5.566875248713676]

# %%
#4 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_1303/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210109_1832/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or2'] = transportRxnResults[1:]
#79
# Out:
# Computing...
# missing expt
# 88
# Computing...
# missing expt
# 196
# Computing...
# Computing...
# Computing...
# missing expt
# 408
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 219.17440651518737
# Unweighted search time ( 2  cognate) 104.03973615115261
# Unweighted search time ( 3  cognate) 63.68493220335261
# Unweighted search time ( 4  cognate) 57.35997995856723
# Unweighted search time ( 5  cognate) 42.503369462117895
# Unweighted search time ( 6  cognate) 37.17259193539441
# Unweighted search time ( 7  cognate) 30.115333166544442
# Unweighted search time ( 8  cognate) 25.977111657706267
# Unweighted search time ( 9  cognate) 18.82007071179856
# Unweighted search time ( 10  cognate) 19.06691509955652
# Unweighted search time ( 11  cognate) 17.81456079248583
# Unweighted search time ( 12  cognate) 16.312125746004103
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [81.89852564964407]  +/-  [5.148487854074347]
# Reaction time:  [9.620687066588326]  +/-  [0.6596338637753724]
# Search time:  [91.51921271623242]  +/-  [5.712207910613778]

# %%
#5 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_1224/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210109_1918/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or2'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# missing expt
# 151
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 899
# Unweighted search time ( 1  cognate) 254.24919218149307
# Unweighted search time ( 2  cognate) 119.89380870036416
# Unweighted search time ( 3  cognate) 64.66801351442666
# Unweighted search time ( 4  cognate) 53.06285855759018
# Unweighted search time ( 5  cognate) 42.64692105410418
# Unweighted search time ( 6  cognate) 32.99887440177933
# Unweighted search time ( 7  cognate) 27.367962266740104
# Unweighted search time ( 8  cognate) 23.02529115743813
# Unweighted search time ( 9  cognate) 22.133166885421893
# Unweighted search time ( 10  cognate) 17.591939457502498
# Unweighted search time ( 11  cognate) 17.426148208108394
# Unweighted search time ( 12  cognate) 15.33949704677892
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [91.92970212407589]  +/-  [5.546222307700816]
# Reaction time:  [10.574218709105299]  +/-  [0.6962499881740044]
# Search time:  [102.50392083318117]  +/-  [6.151732641745693]

# %%
#10 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210111_0055/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210111_0126/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or2'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 14
# missing expt
# 19
# missing expt
# 21
# missing expt
# 25
# missing expt
# 40
# missing expt
# 41
# missing expt
# 42
# missing expt
# 44
# missing expt
# 66
# missing expt
# 72
# missing expt
# 95
# Computing...
# missing expt
# 185
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 584
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 191.10058328352545
# Unweighted search time ( 2  cognate) 109.98767465130241
# Unweighted search time ( 3  cognate) 81.98226496043806
# Unweighted search time ( 4  cognate) 70.33275263690933
# Unweighted search time ( 5  cognate) 46.534984933429826
# Unweighted search time ( 6  cognate) 31.892995164016355
# Unweighted search time ( 7  cognate) 30.563341453226023
# Unweighted search time ( 8  cognate) 26.867075932231536
# Unweighted search time ( 9  cognate) 22.70792298831299
# Unweighted search time ( 10  cognate) 19.06045477019845
# Unweighted search time ( 11  cognate) 18.355941628287525
# Unweighted search time ( 12  cognate) 15.592862069587902
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [81.40936176303629]  +/-  [4.361812291772418]
# Reaction time:  [8.747531292980838]  +/-  [0.6198610519457569]
# Search time:  [90.15689305601714]  +/-  [4.856731110279115]

# %%
#20 overlap resolutions, gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210112_1410/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or20'] = transportRxnResults[1:]

# %%
#3 overlap corrections, ts = 0.5e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_2134/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210111_1747/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 0
# missing expt
# 9
# missing expt
# 54
# missing expt
# 55
# missing expt
# 58
# missing expt
# 69
# missing expt
# 76
# missing expt
# 84
# missing expt
# 86
# missing expt
# 90
# Computing...
# missing expt
# 125
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 410
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 160.5369548485695
# Unweighted search time ( 2  cognate) 98.52620341741981
# Unweighted search time ( 3  cognate) 66.78061738557156
# Unweighted search time ( 4  cognate) 57.8466630465975
# Unweighted search time ( 5  cognate) 38.44532876169067
# Unweighted search time ( 6  cognate) 37.41432958841746
# Unweighted search time ( 7  cognate) 25.677188494175432
# Unweighted search time ( 8  cognate) 21.630432245740174
# Unweighted search time ( 9  cognate) 21.75830312913143
# Unweighted search time ( 10  cognate) 16.190823373156718
# Unweighted search time ( 11  cognate) 16.79359256671652
# Unweighted search time ( 12  cognate) 15.49885270145128
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [68.57574005381652]  +/-  [3.7580263811964083]
# Reaction time:  [8.189130370716972]  +/-  [0.5262893745909258]
# Search time:  [76.7648704245335]  +/-  [4.179364246853088]

# %%
#3 overlap corrections, ts = 0.667e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_2301/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210111_2047/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 9
# missing expt
# 20
# missing expt
# 37
# missing expt
# 38
# missing expt
# 40
# missing expt
# 47
# missing expt
# 52
# missing expt
# 69
# missing expt
# 75
# missing expt
# 78
# missing expt
# 91
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 154.54847252957805
# Unweighted search time ( 2  cognate) 113.23280001192113
# Unweighted search time ( 3  cognate) 73.32586286188919
# Unweighted search time ( 4  cognate) 48.30880256093834
# Unweighted search time ( 5  cognate) 50.433025184732024
# Unweighted search time ( 6  cognate) 27.81098463854267
# Unweighted search time ( 7  cognate) 25.349244567975106
# Unweighted search time ( 8  cognate) 18.77887479906867
# Unweighted search time ( 9  cognate) 18.721003789532112
# Unweighted search time ( 10  cognate) 16.34244501768932
# Unweighted search time ( 11  cognate) 17.111904236598754
# Unweighted search time ( 12  cognate) 16.554750553969875
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [70.63801359411715]  +/-  [3.877331869723256]
# Reaction time:  [7.9648174840584085]  +/-  [0.5347389378763148]
# Search time:  [78.60283107817556]  +/-  [4.31838884994889]

# %%
#3 overlap corrections, ts = 1.5e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210110_0007/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2152/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 35
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 406
# Computing...
# Unweighted search time ( 1  cognate) 204.14019297584585
# Unweighted search time ( 2  cognate) 111.24829744257814
# Unweighted search time ( 3  cognate) 85.93741456764198
# Unweighted search time ( 4  cognate) 63.959755724280896
# Unweighted search time ( 5  cognate) 36.08907490630781
# Unweighted search time ( 6  cognate) 30.664501095322507
# Transport time:  [83.01567704138782]  +/-  [5.140251891063567]
# Reaction time:  [9.356177613719145]  +/-  [0.666765779088742]
# Search time:  [92.37185465510699]  +/-  [5.7344694307515685]

# %%
#3 overlap corrections, ts = 2e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_2335/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 264.1344636042665
# Unweighted search time ( 2  cognate) 119.24144965815357
# Unweighted search time ( 3  cognate) 66.23524293837059
# Unweighted search time ( 4  cognate) 53.353797968867916
# Unweighted search time ( 5  cognate) 38.45351123737431
# Unweighted search time ( 6  cognate) 24.8162979650671
# Transport time:  [93.51289799503579]  +/-  [6.57596953801235]
# Reaction time:  [10.590913841512466]  +/-  [0.8452057572490642]
# Search time:  [104.10381183654829]  +/-  [7.35847897277403]

# %%
#3 overlap corrections, ts = 10e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210112_1307/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]

# %%
#3 overlap corrections, ts = 20e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210109_2219/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# missing expt
# 189
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 175.50064428185811
# Unweighted search time ( 2  cognate) 73.16451445264029
# Unweighted search time ( 3  cognate) 50.85570475642518
# Unweighted search time ( 4  cognate) 34.09344944651201
# Unweighted search time ( 5  cognate) 26.138570287710063
# Unweighted search time ( 6  cognate) 27.70850997393454
# Transport time:  [61.50883323955]  +/-  [4.098340892178388]
# Reaction time:  [7.723632813656324]  +/-  [0.5976132248379484]
# Search time:  [69.23246605320634]  +/-  [4.637790795036139]

# %%
#3 overlap corrections, no crowders, ts = 0.125e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210112_0205/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 6
# missing expt
# 26
# missing expt
# 30
# missing expt
# 37
# missing expt
# 40
# missing expt
# 47
# missing expt
# 49
# missing expt
# 58
# missing expt
# 64
# missing expt
# 72
# missing expt
# 73
# missing expt
# 77
# missing expt
# 78
# missing expt
# 99
# Computing...
# missing expt
# 114
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 140.08324261666175
# Unweighted search time ( 2  cognate) 91.05321059847368
# Unweighted search time ( 3  cognate) 51.229611554778735
# Unweighted search time ( 4  cognate) 32.55383695274407
# Unweighted search time ( 5  cognate) 33.42841361789952
# Unweighted search time ( 6  cognate) 22.790171094945816
# Transport time:  [58.060551984740115]  +/-  [3.2338142781969426]
# Reaction time:  [6.420745056449605]  +/-  [0.39689202011270147]
# Search time:  [64.48129704118973]  +/-  [3.55549143260582]

# %%
#3 overlap corrections, no crowders, ts = 0.25e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210111_1703/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2258/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 63
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 520
# Unweighted search time ( 1  cognate) 136.52945252806896
# Unweighted search time ( 2  cognate) 77.6483668017814
# Unweighted search time ( 3  cognate) 50.664742885068414
# Unweighted search time ( 4  cognate) 37.426222932146665
# Unweighted search time ( 5  cognate) 25.480479672863684
# Unweighted search time ( 6  cognate) 22.981637343058104
# Transport time:  [54.80188597015478]  +/-  [3.6060523995311136]
# Reaction time:  [6.193338481421293]  +/-  [0.44427758018757646]
# Search time:  [60.99522445157606]  +/-  [4.0037584494081315]

# %%
#3 overlap corrections, no crowders, ts = 0.5e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210111_1535/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210112_0124/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 147.07702634672307
# Unweighted search time ( 2  cognate) 63.7781605969154
# Unweighted search time ( 3  cognate) 39.74419958142443
# Unweighted search time ( 4  cognate) 39.088928400319425
# Unweighted search time ( 5  cognate) 29.77904418223809
# Unweighted search time ( 6  cognate) 22.195355946435345
# Transport time:  [53.11606052669154]  +/-  [3.5098099715219537]
# Reaction time:  [6.414873988901648]  +/-  [0.470517639163826]
# Search time:  [59.53093451559319]  +/-  [3.928057067342125]

# %%
#3 overlap corrections, no crowders, ts = 0.1e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210112_0233/"#"191007_1601/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2258/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 164.28870030074373
# Unweighted search time ( 2  cognate) 83.65640546570273
# Unweighted search time ( 3  cognate) 50.82729247487952
# Unweighted search time ( 4  cognate) 37.771573486320065
# Unweighted search time ( 5  cognate) 26.420330565725934
# Unweighted search time ( 6  cognate) 16.338246598181875
# Transport time:  [61.60408672254223]  +/-  [4.337027930265198]
# Reaction time:  [7.071648967925684]  +/-  [0.5543573859255542]
# Search time:  [68.67573569046792]  +/-  [4.83259888915187]

# %%
#3 overlap corrections, no crowders, ts = 2e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210111_1618/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 599
# Unweighted search time ( 1  cognate) 160.1771336168418
# Unweighted search time ( 2  cognate) 77.7158452854074
# Unweighted search time ( 3  cognate) 57.70533378658751
# Unweighted search time ( 4  cognate) 31.68476107982759
# Unweighted search time ( 5  cognate) 24.64835114906592
# Unweighted search time ( 6  cognate) 17.686925082941887
# Transport time:  [60.00724126450603]  +/-  [4.13826430451724]
# Reaction time:  [6.89476362650332]  +/-  [0.5320592404095227]
# Search time:  [66.90200489100934]  +/-  [4.6228837526561986]

# %%
#3 overlap corrections, no crowders, ts = 4e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210112_0309/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 179.00654274429303
# Unweighted search time ( 2  cognate) 75.53782936241238
# Unweighted search time ( 3  cognate) 57.80823365340245
# Unweighted search time ( 4  cognate) 33.021736005236335
# Unweighted search time ( 5  cognate) 23.939413058049507
# Unweighted search time ( 6  cognate) 22.933816461837548
# Transport time:  [63.824359498797435]  +/-  [3.6413602686239273]
# Reaction time:  [7.382108725135093]  +/-  [0.5136352157827826]
# Search time:  [71.20646822393253]  +/-  [4.090088668882171]

# %%
#3 overlap corrections, no crowders, ts = 10e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210112_1339/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_ts0.5e-4'] = transportRxnResults[1:]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

##### Measurements made from translation voxels with a single cognate ternary complex

##########



repeatreactions_overlapcheck = list()
repeatreactions_overlapcheck_err = list()

#No crowders, 0.125e-4 ts, 3 overlap resolution steps
data = "210112_0205/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

#No crowders, 0.25e-4 ts, 3 overlap resolution steps
data = "210111_1703/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

#No crowders, 0.5e-4 ts, 3 overlap resolution steps
data = "210111_1535/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

#No crowders, 1e-4 ts, 3 overlap resolution steps
data = "210112_0233/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

#No crowders, 2e-4 ts, 3 overlap resolution steps
data = "210111_1618/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

#No crowders, 4e-4 ts, 3 overlap resolution steps
data = "210112_0309/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# missing expt
# 6
# missing expt
# 26
# missing expt
# 30
# missing expt
# 37
# missing expt
# 40
# missing expt
# 47
# missing expt
# 49
# missing expt
# 58
# missing expt
# 64
# missing expt
# 72
# missing expt
# 73
# missing expt
# 77
# missing expt
# 78
# (0.7483588621444202, 0.05524703234242765)
# missing expt
# 63
# (0.780718336483932, 0.05225082601602218)
# (0.8350340136054422, 0.048233591293974386)
# (0.7799043062200957, 0.04641607686981619)
# (0.7541729893778453, 0.041147593882696606)
# (0.6719367588932806, 0.039973855069396325)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

##### Measurements made from translation voxels with a single cognate ternary complex

##########

###Crowders, gr = 3.0, 3 overlap

repeatreaction_list = list()

repeatreactions_overlapcheck = list()
repeatreactions_overlapcheck_err = list()
data = "191003_2210/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])

###Crowders, gr = 3.0, only 1 overlap resolution step #New run
data = "210108_1534/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, 2 overlap resolution step #New run
data = "210109_1101/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, 4 overlap resolution step #New run
data = "210109_1303/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, 5 overlap resolution step #New run
data = "210109_1224/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, 10 overlap resolution step #New run
data = "210111_0055/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, 20 overlap resolution step #New run
data = "210112_1410/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])

plt.plot([1,2,3,4,5,10,20],repeatreaction_list,color='black',linewidth=4)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (1.8375, 0.09977313423898326)
# (1.337941628264209, 0.06629316692935995)
# (1.5911854103343466, 0.07314672658613412)
# (2.03770197486535, 0.10957257356954374)
# (1.8611111111111112, 0.09444180158659515)
# missing expt
# 14
# missing expt
# 66
# (2.4416342412451364, 0.13718951299074378)
# missing expt
# 1
# missing expt
# 18
# missing expt
# 28
# missing expt
# 42
# missing expt
# 52
# missing expt
# 56
# missing expt
# 74
# missing expt
# 77
# missing expt
# 90
# missing expt
# 92
# missing expt
# 94
# missing expt
# 97
# (2.5444126074498565, 0.17925552414180512)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

##### Measurements made from translation voxels with a single cognate ternary complex

##########

###Crowders, gr = 3.0, 3 overlap, ts = 0.5e-4 

repeatreaction_list = list()

repeatreactions_overlapcheck = list()
repeatreactions_overlapcheck_err = list()
data = "210109_2134/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])

###Crowders, gr = 3.0, ts = 0.667e-4
data = "210109_2301/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 1e-4
data = "191003_2210/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 1.5e-4
data = "210110_0007/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 2e-4
data = "210109_2335/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 10e-4
data = "210112_1307/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 20e-4
data = "210109_2219/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])

plt.plot([0.5e-4,0.667e-4,1e-4,1.5e-4,2e-4,10e-4,20e-4],repeatreaction_list,color='black',linewidth=2,marker='o')
plt.xscale('log')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# missing expt
# 58
# (1.8336673346693386, 0.09286794544521366)
# (1.8173758865248226, 0.09139207629363504)
# (1.8375, 0.09977313423898326)
# (1.7047970479704797, 0.08827195252447416)
# (1.678622668579627, 0.08406207864734334)
# (1.2234910277324633, 0.06432700225024358)
# (0.9545454545454546, 0.051117595141162174)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

##Repeat reactions varying timesteps in voxels WITHOUT crowders.

##### Measurements made from translation voxels with a single cognate ternary complex

##########

###Crowders, gr = 3.0, 3 overlap, ts = 0.125e-4

repeatreaction_list = list()

repeatreactions_overlapcheck = list()
repeatreactions_overlapcheck_err = list()
data = "210112_0205/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])

###Crowders, gr = 3.0, ts = 0.25e-4
data = "210111_1703/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 0.5e-4
data = "210111_1535/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 1e-4
data = "210112_0233/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 2e-4
data = "210111_1618/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 4e-4
data = "210112_0309/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])


###Crowders, gr = 3.0, ts = 10e-4
data = "210112_1339/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])
repeatreaction_list.append(sim_i[0])

plt.plot([0.5e-4,0.667e-4,1e-4,1.5e-4,2e-4,10e-4,20e-4],repeatreaction_list,color='black',linewidth=2,marker='o')
plt.xscale('log')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (0.8210659898477157, 0.04434948215546684)
# missing expt
# 63
# (0.780718336483932, 0.05225082601602218)
# (0.8350340136054422, 0.048233591293974386)
# (0.7799043062200957, 0.04641607686981619)
# (0.7541729893778453, 0.041147593882696606)
# (0.6719367588932806, 0.039973855069396325)
# (0.7191358024691358, 0.04510295676932966)

# %%
##Varying overlaps with timestep fixed
#3 overlap corrections, ts = 1e-4  

#1 overlap resolutions, ts=1e-4,  gr = 3.0

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
rxndiff_list = list()
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff=dict()

data = "210108_1534/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210108_1605/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or1'] = transportRxnResults[1:]

#2 overlap resolutions,  ts=1e-4, gr = 3.0
data = "210109_1101/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210109_1138/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or2'] = transportRxnResults[1:]

#3 overlap resolutions,ts=1e-4, gr = 3.0
data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "191105_0908/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or3'] = transportRxnResults[1:]

#4 overlap resolutions, ts=1e-4, gr = 3.0
data = "210109_1303/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210109_1832/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or4'] = transportRxnResults[1:]

#5 overlap resolutions, ts=1e-4, gr = 3.0
data = "210109_1224/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210109_1918/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or5'] = transportRxnResults[1:]

#10 overlap resolutions, ts=1e-4 gr = 3.0
data = "210111_0055/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210111_0126/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or10'] = transportRxnResults[1:]

#20 overlap resolutions, ts=1e-4, gr=3.0
data = "210112_1410/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210112_1654/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff['30_or20'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# missing expt
# 250
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 53
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 406
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 210.94332942433553
# Unweighted search time ( 2  cognate) 88.54431213208623
# Unweighted search time ( 3  cognate) 65.89638281609753
# Unweighted search time ( 4  cognate) 37.885813894283146
# Unweighted search time ( 5  cognate) 40.32251935560157
# Unweighted search time ( 6  cognate) 27.588736564426966
# Unweighted search time ( 7  cognate) 24.18833469078299
# Unweighted search time ( 8  cognate) 23.401872674466997
# Unweighted search time ( 9  cognate) 17.454394841921424
# Unweighted search time ( 10  cognate) 13.729373592021012
# Unweighted search time ( 11  cognate) 16.52955757745004
# Unweighted search time ( 12  cognate) 13.11507644176913
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [75.93552824849662]  +/-  [4.25045184971721]
# Reaction time:  [8.50589464951882]  +/-  [0.5451258396813176]
# Search time:  [84.44142289801542]  +/-  [4.717788584160013]
# Computing...
# /Users/akshay/Documents/TranslationDynamics/src/analysis_utils.py:760: RuntimeWarning: invalid value encountered in double_scalars
#   print('Unweighted search time (', str(i), ' cognate)', np.array(search_vals/p_codon_count_hist_weighted_avg[i]))
# missing expt
# 99
# Computing...
# Computing...
# Computing...
# missing expt
# 308
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 295
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 738
# Computing...
# Unweighted search time ( 1  cognate) 229.82247267797874
# Unweighted search time ( 2  cognate) 104.22108688033256
# Unweighted search time ( 3  cognate) 64.7044063476832
# Unweighted search time ( 4  cognate) 49.3105651250172
# Unweighted search time ( 5  cognate) 41.589702738357786
# Unweighted search time ( 6  cognate) 31.57782341187129
# Unweighted search time ( 7  cognate) 34.10356963594906
# Unweighted search time ( 8  cognate) 24.98721584202664
# Unweighted search time ( 9  cognate) 23.16075918089039
# Unweighted search time ( 10  cognate) 15.502399254564736
# Unweighted search time ( 11  cognate) 14.259778740723451
# Unweighted search time ( 12  cognate) 12.682211615789893
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [83.49383322318455]  +/-  [5.034240989282896]
# Reaction time:  [9.762707452499043]  +/-  [0.6080447854034189]
# Search time:  [93.25654067568357]  +/-  [5.566875248713676]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 211.00146341363575
# Unweighted search time ( 2  cognate) 108.97058438771204
# Unweighted search time ( 3  cognate) 81.14001683109859
# Unweighted search time ( 4  cognate) 55.58236841495304
# Unweighted search time ( 5  cognate) 40.78912479557734
# Unweighted search time ( 6  cognate) 32.941929200122274
# Unweighted search time ( 7  cognate) 28.622005248665197
# Unweighted search time ( 8  cognate) 23.689239725751502
# Unweighted search time ( 9  cognate) 18.585319093136118
# Unweighted search time ( 10  cognate) 17.64028915285567
# Unweighted search time ( 11  cognate) 17.007847019537866
# Unweighted search time ( 12  cognate) 13.45698738548096
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [83.02328180376576]  +/-  [5.155009095424843]
# Reaction time:  [9.720963352621542]  +/-  [0.793858163798332]
# Search time:  [92.74424515638732]  +/-  [5.863884903244429]
# Computing...
# Computing...
# missing expt
# 196
# Computing...
# Computing...
# Computing...
# missing expt
# 408
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 229.4885560724002
# Unweighted search time ( 2  cognate) 104.03973615115261
# Unweighted search time ( 3  cognate) 63.68493220335261
# Unweighted search time ( 4  cognate) 57.35997995856723
# Unweighted search time ( 5  cognate) 42.503369462117895
# Unweighted search time ( 6  cognate) 37.17259193539441
# Unweighted search time ( 7  cognate) 30.115333166544442
# Unweighted search time ( 8  cognate) 25.977111657706267
# Unweighted search time ( 9  cognate) 18.82007071179856
# Unweighted search time ( 10  cognate) 19.06691509955652
# Unweighted search time ( 11  cognate) 17.81456079248583
# Unweighted search time ( 12  cognate) 16.312125746004103
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [84.14707687902643]  +/-  [5.5784825854027895]
# Reaction time:  [9.819653343474574]  +/-  [0.6839610120036884]
# Search time:  [93.966730222501]  +/-  [6.170449758435906]
# Computing...
# Computing...
# missing expt
# 151
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 899
# Unweighted search time ( 1  cognate) 254.24919218149307
# Unweighted search time ( 2  cognate) 119.89380870036416
# Unweighted search time ( 3  cognate) 64.66801351442666
# Unweighted search time ( 4  cognate) 53.06285855759018
# Unweighted search time ( 5  cognate) 42.64692105410418
# Unweighted search time ( 6  cognate) 32.99887440177933
# Unweighted search time ( 7  cognate) 27.367962266740104
# Unweighted search time ( 8  cognate) 23.02529115743813
# Unweighted search time ( 9  cognate) 22.133166885421893
# Unweighted search time ( 10  cognate) 17.591939457502498
# Unweighted search time ( 11  cognate) 17.426148208108394
# Unweighted search time ( 12  cognate) 15.33949704677892
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [91.92970212407589]  +/-  [5.546222307700816]
# Reaction time:  [10.574218709105299]  +/-  [0.6962499881740044]
# Search time:  [102.50392083318117]  +/-  [6.151732641745693]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 584
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 274.3767485537036
# Unweighted search time ( 2  cognate) 115.21441296154451
# Unweighted search time ( 3  cognate) 78.61598050507187
# Unweighted search time ( 4  cognate) 68.34747980608417
# Unweighted search time ( 5  cognate) 46.734715005419396
# Unweighted search time ( 6  cognate) 31.85819239379342
# Unweighted search time ( 7  cognate) 30.437300069365996
# Unweighted search time ( 8  cognate) 26.762373649206587
# Unweighted search time ( 9  cognate) 22.437979598662217
# Unweighted search time ( 10  cognate) 19.051588069574233
# Unweighted search time ( 11  cognate) 18.10391043810606
# Unweighted search time ( 12  cognate) 15.505993518651925
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [99.14602665460853]  +/-  [6.738581369524128]
# Reaction time:  [11.09477652548546]  +/-  [0.9238824679348175]
# Search time:  [110.240803180094]  +/-  [7.553671307216997]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 897
# missing expt
# 898
# missing expt
# 899
# Unweighted search time ( 1  cognate) 294.77374206174653
# Unweighted search time ( 2  cognate) 128.48070471593007
# Unweighted search time ( 3  cognate) 103.42849695581545
# Unweighted search time ( 4  cognate) 71.8907669053669
# Unweighted search time ( 5  cognate) 48.685477962444814
# Unweighted search time ( 6  cognate) 35.96605527324954
# Unweighted search time ( 7  cognate) 36.470733462278424
# Unweighted search time ( 8  cognate) 27.02844264571776
# Unweighted search time ( 9  cognate) 32.46264972163444
# Unweighted search time ( 10  cognate) 25.50301591480748
# Unweighted search time ( 11  cognate) 16.338536489992094
# Unweighted search time ( 12  cognate) 17.30674606300471
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [109.61414056550547]  +/-  [6.8574185550238465]
# Reaction time:  [12.445681073015733]  +/-  [0.9234091580434597]
# Search time:  [122.05982163852119]  +/-  [7.635643508522296]

# %%
#[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]
[rxndiff[d][0][0] for d in rxndiff]
83.02328180376576/96.19081325169066
[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]
# Out:
# 1.0164569724026535

# %%
overlap_list = [1,2,3,4,5,10,20]

#Elongation latency
fig,ax3=plt.subplots(1,1,figsize=(7,6))
ax3.errorbar(overlap_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],np.array([rxndiff[d][5][0] for d in rxndiff]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=0,elinewidth=2,mfc='white',color='black')
y_model= np.polyfit(overlap_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],3)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(1, 20, 100),trendpoly(np.linspace(0, 20, 100)),zorder=1,linewidth=4,color='black')
ax3.set_ylabel('Elongation Latency (ms)',size=30)
ax3.set_ylim(0,170)
ax3.plot(np.linspace(min(overlap_list), max(overlap_list), 100), [1000/21]*100, color='green', linewidth=3)
ax3.plot([3]*100,np.linspace(0,165, 100) , color='black',linestyle='dashed', linewidth=3)
#ax3.plot(np.linspace(min(overlap_list), max(overlap_list), 100), [157.5]*100, color='orange', linewidth=3)

##Transport latency
fig,ax1=plt.subplots(1,1,figsize=(7,6))
ax1.errorbar(overlap_list,[rxndiff[d][0][0] for d in rxndiff],np.array([rxndiff[d][3][0] for d in rxndiff]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=4,elinewidth=2,mfc='white',color='black')
ax1.set_ylabel('Transport Latency (ms)',size=30)
ax1.set_xlabel('Overlap resolution steps',size=30)
ax1.set_xlim(0.5,20.5)
ax1.set_ylim(0,170)
ax1.plot([3]*100,np.linspace(0,160, 100) , color='black',linestyle='dashed', linewidth=3)

#Reaction latency
fig,ax=plt.subplots(1,1,figsize=(7,6))
ax.errorbar(overlap_list,[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],np.array([rxndiff[d][4][0] for d in rxndiff]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=0,elinewidth=2,mfc='white',color='black')
y_model= np.polyfit(overlap_list,[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],1)
trendpoly=np.poly1d(y_model)
ax.plot(np.linspace(1, 20, 100),trendpoly(np.linspace(0, 20, 100)),zorder=1,linewidth=4,color='black')
ax.set_ylabel('Reaction Latency (ms)',size=30)
ax.set_ylim(0,160)
ax.plot([3]*100,np.linspace(0,160, 100) , color='black',linestyle='dashed', linewidth=3)

#Overlap error
fig,ax2=plt.subplots(1,1,figsize=(7,6))
ax2.set_ylabel("Overlaps resolved (%)",size=30, labelpad=10)
ax2.set_ylim(80,100.5)
overlap_error = [0.0691, 0.01491, 0.00860, 0.00270, 0.00159, 0.00056, 0]
ax2.scatter(overlap_list, 100*(1-np.array(overlap_error)), linewidth=4,color='black')
y_model= np.polyfit(overlap_list,100*(1-np.array(overlap_error)),2)
trendpoly=np.poly1d(y_model)
ax2.plot([3]*100,np.linspace(0,160, 100) , color='black',linestyle='dashed', linewidth=3)

#ax2.plot(np.linspace(1, 20, 100),trendpoly(np.linspace(0, 20, 100)),zorder=1,linewidth=4,color='black')

for _,ax in enumerate([ax,ax1,ax2,ax3]):
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['top'].set_linewidth(4)
    ax.spines['right'].set_linewidth(4)
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.set_xlim(0.5,20.5)
    ax.tick_params(axis = 'x', which='major',length=15,direction='in')
    ax.tick_params(axis = 'x', which='minor',length=10,direction='in')
    ax.set_xlabel('Overlap resolution steps',size=30)

# %%
##Varying timestep with overlaps fixed
#3 overlap corrections, ts = 0.5e-4  

scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff1=dict()

data = "210109_2134/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_1747/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts0.5e-4'] = transportRxnResults[1:]

#3 overlap corrections, ts = 0.667e-4  
data = "210109_2301/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2047/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts0.667e-4'] = transportRxnResults[1:]

#3 overlap resolutions, ts = 1e-4
data = "191003_2210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "191105_0908/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts1e-4'] = transportRxnResults[1:]


#3 overlap corrections, ts = 1.5e-4  
data = "210110_0007/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2152/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts1.5e-4'] = transportRxnResults[1:]

#3 overlap corrections, ts = 2e-4  
data = "210109_2335/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts2e-4'] = transportRxnResults[1:]

#3 overlap corrections, ts = 10e-4  
data = "210112_1307/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts10e-4'] = transportRxnResults[1:]

#3 overlap corrections, ts = 20e-4  
data = "210109_2219/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff1['30_ts20e-4'] = transportRxnResults[1:]
# Out:
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 199.76061657789225
# Unweighted search time ( 2  cognate) 102.15674062190315
# Unweighted search time ( 3  cognate) 66.78061738557156
# Unweighted search time ( 4  cognate) 57.8466630465975
# Unweighted search time ( 5  cognate) 38.44532876169067
# Unweighted search time ( 6  cognate) 37.41432958841746
# Transport time:  [77.11110918828894]  +/-  [4.38402760886873]
# Reaction time:  [9.276502347805502]  +/-  [0.6154985025742999]
# Search time:  [86.38761153609445]  +/-  [4.905062063415999]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 223.75983753723276
# Unweighted search time ( 2  cognate) 113.23280001192113
# Unweighted search time ( 3  cognate) 73.32586286188919
# Unweighted search time ( 4  cognate) 48.30880256093834
# Unweighted search time ( 5  cognate) 50.433025184732024
# Unweighted search time ( 6  cognate) 27.81098463854267
# Transport time:  [84.99691861299313]  +/-  [5.66792937558142]
# Reaction time:  [9.654657201738916]  +/-  [0.7117661643371649]
# Search time:  [94.65157581473201]  +/-  [6.306431543275757]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 211.00146341363575
# Unweighted search time ( 2  cognate) 108.97058438771204
# Unweighted search time ( 3  cognate) 81.14001683109859
# Unweighted search time ( 4  cognate) 55.58236841495304
# Unweighted search time ( 5  cognate) 40.78912479557734
# Unweighted search time ( 6  cognate) 32.941929200122274
# Transport time:  [82.6369095161979]  +/-  [5.154881562006373]
# Reaction time:  [9.678075682546131]  +/-  [0.7938342298020548]
# Search time:  [92.31498519874404]  +/-  [5.86374332346587]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 406
# Computing...
# Unweighted search time ( 1  cognate) 219.82122746098543
# Unweighted search time ( 2  cognate) 111.24829744257814
# Unweighted search time ( 3  cognate) 85.93741456764198
# Unweighted search time ( 4  cognate) 63.959755724280896
# Unweighted search time ( 5  cognate) 36.08907490630781
# Unweighted search time ( 6  cognate) 30.664501095322507
# Transport time:  [86.31891129184271]  +/-  [6.0786635250095875]
# Reaction time:  [9.77400695710571]  +/-  [0.7828736134692951]
# Search time:  [96.09291824894844]  +/-  [6.800927525661755]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 264.1344636042665
# Unweighted search time ( 2  cognate) 119.24144965815357
# Unweighted search time ( 3  cognate) 66.23524293837059
# Unweighted search time ( 4  cognate) 53.353797968867916
# Unweighted search time ( 5  cognate) 38.45351123737431
# Unweighted search time ( 6  cognate) 24.8162979650671
# Transport time:  [93.51289799503579]  +/-  [6.57596953801235]
# Reaction time:  [10.590913841512466]  +/-  [0.8452057572490642]
# Search time:  [104.10381183654829]  +/-  [7.35847897277403]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 429
# Computing...
# Unweighted search time ( 1  cognate) 185.10464683809116
# Unweighted search time ( 2  cognate) 98.69428406927615
# Unweighted search time ( 3  cognate) 64.66717760126423
# Unweighted search time ( 4  cognate) 40.35873349194968
# Unweighted search time ( 5  cognate) 31.620041069717345
# Unweighted search time ( 6  cognate) 27.155334946034333
# Transport time:  [71.55770752097824]  +/-  [4.550147122051949]
# Reaction time:  [7.928819217179782]  +/-  [0.5348586764361019]
# Search time:  [79.486526738158]  +/-  [5.026710474757585]
# Computing...
# Computing...
# missing expt
# 189
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 175.50064428185811
# Unweighted search time ( 2  cognate) 73.16451445264029
# Unweighted search time ( 3  cognate) 50.85570475642518
# Unweighted search time ( 4  cognate) 34.09344944651201
# Unweighted search time ( 5  cognate) 26.138570287710063
# Unweighted search time ( 6  cognate) 27.70850997393454
# Transport time:  [61.50883323955]  +/-  [4.098340892178388]
# Reaction time:  [7.723632813656324]  +/-  [0.5976132248379484]
# Search time:  [69.23246605320634]  +/-  [4.637790795036139]

# %%
#[rxndiff1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff1]
#[rxndiff1[d][0][0] for d in rxndiff1]

77.11110918828894
9.276502347805502
86.38761153609445+(1000/1475+1000/1529+1000/209+1000/200+1000/32)

82.6369095161979
9.678075682546131
92.31498519874404+(1000/1475+1000/1529+1000/209+1000/200+1000/32)

print((92.31498519874404+(1000/1475+1000/1529+1000/209+1000/200+1000/32))/(86.38761153609445+(1000/1475+1000/1529+1000/209+1000/200+1000/32)))
# Out:
# 1.0460363201465492

# %%
rxndiff1
ts_list = np.array([0.5e-4, 0.667e-4, 1e-4, 1.5e-4, 2e-4, 10e-4,20e-4])*((0.0059**2/(56)))
print(ts_list)
#Elongation latency
fig,ax3=plt.subplots(1,1,figsize=(7,6))
ax3.errorbar(ts_list,[rxndiff1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff1],np.array([rxndiff1[d][5][0] for d in rxndiff1]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=0,elinewidth=2,mfc='white',color='black')
y_model= np.polyfit(ts_list,[rxndiff1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff1],2)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(min(ts_list), max(ts_list), 100),trendpoly(np.linspace(min(ts_list), max(ts_list), 100)),zorder=1,linewidth=4,color='black')
ax3.set_ylabel('Elongation Latency (ms)',size=30)
ax3.plot(np.linspace(min(ts_list), max(ts_list), 100), [1000/21]*100, color='green', linewidth=3)
ax3.plot([1e-4]*100,np.linspace(0,160, 100) , color='black',linestyle='dashed', linewidth=3)
ax3.set_ylim(0,160)

#Transport latency
fig,ax1=plt.subplots(1,1,figsize=(7,6))
ax1.errorbar(ts_list,[rxndiff1[d][0][0] for d in rxndiff1],np.array([rxndiff1[d][3][0] for d in rxndiff1]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=0,elinewidth=2,mfc='white',color='black')
y_model= np.polyfit(ts_list,[rxndiff1[d][0][0] for d in rxndiff1],2)
trendpoly=np.poly1d(y_model)
ax1.plot(np.linspace(min(ts_list), max(ts_list), 100),trendpoly(np.linspace(min(ts_list), max(ts_list), 100)),zorder=1,linewidth=4,color='black')
ax1.set_ylabel('Transport Latency (ms)',size=30)
ax1.set_ylim(0,160)

#Reaction latency
fig,ax=plt.subplots(1,1,figsize=(7,6))
ax.errorbar(ts_list,[rxndiff1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff1],np.array([rxndiff1[d][4][0] for d in rxndiff1]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=0,elinewidth=2,mfc='white',color='black')
y_model= np.polyfit(ts_list,[rxndiff1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff1],2)
trendpoly=np.poly1d(y_model)
ax.plot(np.linspace(min(ts_list), max(ts_list), 100),trendpoly(np.linspace(min(ts_list), max(ts_list), 100)),zorder=1,linewidth=4,color='black')
ax.set_ylabel('Reaction Latency (ms)',size=30)
ax.plot([1e-4]*100,np.linspace(0,160, 100) , color='black',linestyle='dashed', linewidth=3)
ax.set_ylim(0,160)

#Overlaps resolved
fig,ax2=plt.subplots(1,1,figsize=(7,6))
ax2.set_ylabel("Overlaps resolved (%)",size=30, labelpad=10)
ax2.set_ylim(45,101)
overlap_error = [0.00086, 0.00097, 0.00860, 0.00465, 0.02980, 0.14488, 0.50142]
ax2.scatter(ts_list, 100*(1-np.array(overlap_error)), linewidth=4,color='black')
y_model= np.polyfit(ts_list,100*(1-np.array(overlap_error)),2)
trendpoly=np.poly1d(y_model)
ax2.plot(np.linspace(min(ts_list), max(ts_list), 100),trendpoly(np.linspace(min(ts_list), max(ts_list), 100)),zorder=1,linewidth=4,color='black')
ax2.plot([1e-4]*100,np.linspace(0,100, 100) , color='black',linestyle='dashed', linewidth=3)


for _,ax in enumerate([ax,ax1,ax2,ax3]):
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['top'].set_linewidth(4)
    ax.spines['right'].set_linewidth(4)
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.tick_params(axis = 'x', which='major',length=15,direction='in')
    ax.tick_params(axis = 'x', which='minor',length=10,direction='in')
    ax.set_xlabel('Timestep (s)',size=30)
    ax.set_xscale('log')
    ax.set_xlim(2e-11,2.1e-9) #ax.set_xlim(4e-5,2.5e-3)
    ax.tick_params(axis = 'x', which='major',length=15,direction='in')
    ax.tick_params(axis = 'x', which='minor',length=10,direction='in')
# Out:
# [3.10803571e-11 4.14611964e-11 6.21607143e-11 9.32410714e-11
#  1.24321429e-10 6.21607143e-10 1.24321429e-09]

# %%
##Varying timestep with overlaps fixed (no crowders)
scalingFactor=200
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff2=dict()

#3 overlap corrections, no crowders, ts = 0.125e-4
data = "210112_0205/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts0.125e-4'] = transportRxnResults[1:]


#3 overlap corrections, no crowders, ts = 0.25e-4  

data = "210111_1703/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2258/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts0.25e-4'] = transportRxnResults[1:]


#3 overlap corrections, no crowders, ts = 0.5e-4  
data = "210111_1535/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210112_0124/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts0.5e-4'] = transportRxnResults[1:]

#3 overlap corrections, no crowders, ts = 1e-4  
data = "210112_0233/"#"191007_1601/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "210111_2258/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts1e-4'] = transportRxnResults[1:]


#3 overlap corrections, no crowders, ts = 2e-4  
data = "210111_1618/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts2e-4'] = transportRxnResults[1:]

#3 overlap corrections, no crowders, ts = 4e-4  

data = "210112_0309/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts4e-4'] = transportRxnResults[1:]

#3 overlap corrections, no crowders, ts = 10e-4  
data = "210112_1339/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

#data = "/"
#for i in range(7,16):
#    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
#    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff2['30_ts10e-4'] = transportRxnResults[1:]

# %%
rxndiff2
fig,ax=plt.subplots(1,1,figsize=(7,6))
ts_list = [0.125e-4, 0.25e-4, 0.5e-4, 1e-4, 2e-4, 4e-4, 10e-4]
ax.errorbar(ts_list,[rxndiff2[d][0][0] for d in rxndiff],np.array([rxndiff2[d][5][0] for d in rxndiff2]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=4,elinewidth=2,mfc='white',color='black')

ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_ylim(20,80)
ax.set_xscale('log')
ax.set_xlim(1e-5,1.3e-3)
ax.tick_params(axis = 'x', which='major',length=15,direction='in')
ax.tick_params(axis = 'x', which='minor',length=10,direction='in')
ax.set_ylabel('Transport Latency (ms)',size=30)
ax.set_xlabel('Timestep (dimensionless)',size=30)


fig,ax=plt.subplots(1,1,figsize=(7,6))
ax.errorbar(ts_list,[rxndiff2[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff2],np.array([rxndiff[d][5][0] for d in rxndiff2]),marker='o',markersize=12,markeredgewidth=5,zorder=10,linewidth=0,elinewidth=2,mfc='white',color='black')
ax.set_ylabel('Elongation Latency (ms)',size=30)
ax.set_xlabel('Timestep (dimensionless)',size=30)
y_model= np.polyfit(ts_list,[rxndiff2[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff2],2)
trendpoly=np.poly1d(y_model)
ax.plot(np.linspace(min(ts_list), max(ts_list), 100),trendpoly(np.linspace(min(ts_list), max(ts_list), 100)),zorder=1,linewidth=4,color='black')
ax.set_ylim(0,140)


#ax2 = ax.twinx()
#ax2.set_ylabel("Overlaps resolved (%)",size=30, labelpad=10)
#ax2.set_ylim(80,100.5)
#overlap_error = [0, 0.0086, 0.00465, 0.01439, 0.09958, 0.17627]
#overlap_error_xaxis = [0.5e-4, 1e-4, 1.5e-4, 2e-4, 10e-4,20e-4]
#ax2.scatter(overlap_error_xaxis, 100*(1-np.array(overlap_error)), linewidth=4,color='green')
#y_model= np.polyfit(overlap_error_xaxis,100*(1-np.array(overlap_error)),2)
#trendpoly=np.poly1d(y_model)
#ax2.plot(np.linspace(1, 20, 100),trendpoly(np.linspace(0, 20, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')


for _,ax in enumerate([ax,ax2]):
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['top'].set_linewidth(4)
    ax.spines['right'].set_linewidth(4)
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.set_xscale('log')
    ax.tick_params(axis = 'x', which='major',length=15,direction='in')
    ax.tick_params(axis = 'x', which='minor',length=10,direction='in')
    ax.set_xlabel('Timestep (dimensionless)',size=30)
    ax.set_xscale('log')
    ax.set_xlim(1e-5,1.3e-3)
    ax.tick_params(axis = 'x', which='major',length=15,direction='in')
    ax.tick_params(axis = 'x', which='minor',length=10,direction='in')

# %%
x = sqrt(6Dt), t = x^2/6D

# %%
(((0.0059**2/(56)))) seconds/BT
# Out:
#   File "<ipython-input-50-b549b7760866>", line 1
#     (((0.0059**2/(56)))) seconds/BT
#                                ^
# SyntaxError: invalid syntax

# %%
(717/1608733)
# Out:
# 0.00044569235541261354

# %%
1/(1608733*1000)
# Out:
# 6.216071902546912e-10

# %%
1e-4*((0.0059**2/(56)))
# Out:
# 6.216071428571429e-11

# %%
1/(((0.0059**2/(56)))) ---> BT/1 second
# Out:
#   File "<ipython-input-54-d195a88676c8>", line 1
#     1/(((0.0059**2/(56)))) ---> BT/1 second
#                               ^
# SyntaxError: invalid syntax

# %%
1-((1-((((200*717)/1608733)*1e-4)))**(1e4*60))
# Out:
# 0.995243922961302

# %%
1-((1-((((600*717)/1608733)*1e-4)))**(1e4*20))
# Out:
# 0.9952441497026195

# %%
(1.56*(10**-6))
# Out:
# 1.5599999999999999e-06

# %%
np.sqrt(6*1.0*1e-11*1e-4)
# Out:
# 7.745966692414834e-08

# %%
# Out:
# 6.216071428571429e-07

# %%
##Varying timestep with overlaps fixed
#3 overlap corrections, ts = 0.5e-4  

scalingFactor=600
NR_scaledrates = {'k1r':718*200/scalingFactor,'k2f':1475*200/scalingFactor,'k2r_nr':1120*200/scalingFactor,'k3_nr':6*200/scalingFactor,'k4':209*200/scalingFactor}
from analysis_utils import *
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff_new=dict()

data = "210122_1436/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))

data = "210122_2022/"
for i in range(7,16):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor, NR_scaling = NR_scaledrates)
    gr_sim[i] = (CellLatencies(sim_i))


gr_dict = {'gr_1':gr_sim}
transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

search_list = transportRxnResults[0]
rxndiff_new['gr3_new'] = transportRxnResults[1:]
# Out:
# Computing...
# missing expt
# 37
# missing expt
# 49
# missing expt
# 82
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 249.0948254508652
# Unweighted search time ( 2  cognate) 129.66173159277378
# Unweighted search time ( 3  cognate) 82.3862059440267
# Unweighted search time ( 4  cognate) 73.4966695839984
# Unweighted search time ( 5  cognate) 51.06327449712965
# Unweighted search time ( 6  cognate) 31.293775054248922
# Unweighted search time ( 7  cognate) 32.760941514240145
# Unweighted search time ( 8  cognate) 29.461888362922334
# Unweighted search time ( 9  cognate) 28.85893733436592
# Unweighted search time ( 10  cognate) 23.352514288088404
# Unweighted search time ( 11  cognate) 18.343919857764245
# Unweighted search time ( 12  cognate) 16.860852157053177
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Transport time:  [98.02487466848538]  +/-  [5.479318072054431]
# Reaction time:  [10.38867685835112]  +/-  [0.6867281251861167]
# Search time:  [108.41355152683647]  +/-  [6.066865380775843]
