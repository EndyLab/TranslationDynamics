# %%
import numpy as np

ptRNA = [0.0521, 0.0099, 0.0762, 0.0102, 0.0139, 0.0067, 0.0191, 0.0384, 0.0255, 0.0123, 0.0141,\
 0.0757, 0.0343, 0.0699, 0.0102, 0.0557, 0.0717, 0.0151, 0.0107, 0.0307, \
 0.0165, 0.0309, 0.0113, 0.0166, 0.0144, 0.0115, 0.0093, 0.0035, 0.0208, 0.0055, 0.0226, \
 0.0123, 0.0017, 0.0087, 0.0176, 0.0147, 0.0151, 0.0326, 0.0616,0.0203]
ptRNA = np.divide(ptRNA,sum(ptRNA))

tRNA_tags = ["Ala1B", "Ala2", "Arg2", "Arg3", "Arg4", "Arg5", "Asn", "Asp1", "Cys", "Gln1", "Gln2", \
"Glu2", "Gly2", "Gly3", "His", "Ile1", "Leu1", "Leu2", "Leu3", "Leu4", "Leu5", "Lys", \
"Met_m", "Phe", "Pro1", "Pro2", "Pro3", "Sel_Cys", "Ser1", "Ser2", "Ser3", "Ser5", "Thr1", \
"Thr2", "Thr3", "Thr4", "Trp", "Tyr1pTyr2", "Val1", "Val2ApB"]

ptRNA_dict = dict(zip(tRNA_tags, ptRNA))

codons_Ec = ["GGG", "GGA", "GGU", "GGC", "GAG", "GAA", "GAU", "GAC", "GUG", "GUA", "GUU", \
"GUC", "GCG", "GCA", "GCU", "GCC", "AGG", "AGA", "AGU", "AGC", "AAG", "AAA", \
"AAU", "AAC", "AUG", "AUA", "AUU", "AUC", "ACG", "ACA", "ACU", "ACC", "UGG", \
"UGA", "UGU", "UGC", "UAU", "UAC", "UUG", "UUA", "UUU", "UUC", "UCG", "UCA", \
"UCU", "UCC", "CGG", "CGA", "CGU", "CGC", "CAG", "CAA", "CAU", "CAC", "CUG", \
"CUA", "CUU", "CUC", "CCG", "CCA", "CCU", "CCC"]

pcodons_Ec =[0.00483, 0.00272, 0.03847, 0.03579, 0.01665, 0.05335, 0.02436, \
0.02885, 0.02150, 0.01594, 0.03146, 0.01130, 0.03047, 0.02223, \
0.02898, 0.01989, 0.00009, 0.00113, 0.00401, 0.01203, 0.01214, \
0.04464, 0.00984, 0.02808, 0.02247, 0.00093, 0.02148, 0.03685, \
0.00757, 0.00350, 0.01394, 0.02663, 0.00981, 0.00031, 0.00425, \
0.00531, 0.01073, 0.01628, 0.00666, 0.00616, 0.01261, 0.02279, \
0.00608, 0.00391, 0.01318, 0.01120, 0.00176, 0.00133, 0.03126, \
0.02235, 0.02938, 0.01024, 0.00927, 0.01396, 0.06041, 0.00216, \
0.00573, 0.00622, 0.02965, 0.00655, 0.00501, 0.00332]
pcodons_Ec = np.divide(pcodons_Ec,sum(pcodons_Ec))

pcodon_dict = dict(zip(codons_Ec, pcodons_Ec))

#Note AUA does not have an assigned tRNA
codon_dict={'GGG': ['Gly2'], 'GGA': ['Gly2'], 'GGU': ['Gly3'], 'GGC': ['Gly3'], \
'GAG': ['Glu2'], 'GAA': ['Glu2'], 'GAU': ['Asp1'], 'GAC': ['Asp1'], \
'GUG': ['Val1'], 'GUA': ['Val1'], 'GUU': ['Val1','Val2ApB'], \
'GUC': ['Val2ApB'], 'GCG': ['Ala1B'], 'GCA': ['Ala1B'], 'GCU': ['Ala1B'], \
'GCC': ['Ala2'], 'AGG': ['Arg5'], 'AGA': ['Arg4'], 'AGU': ['Ser3'], \
'AGC': ['Ser3'], 'AAG': ['Lys'], 'AAA': ['Lys'], 'AAU': ['Asn'], \
'AAC': ['Asn'], 'AUG': ['Met_m'], 'AUA': [], 'AUU': ['Ile1'], \
'AUC': ['Ile1'], 'ACG': ['Thr2','Thr4'], 'ACA': ['Thr4'], \
'ACU': ['Thr1','Thr4','Thr3'], 'ACC': ['Thr3','Thr1'], \
'UGG': ['Trp'], 'UGA': ['Sel_Cys'], 'UGU': ['Cys'], 'UGC': ['Cys'], \
'UAU': ['Tyr1pTyr2'], 'UAC': ['Tyr1pTyr2'], 'UUG': ['Leu5','Leu4'], \
'UUA': ['Leu5'], 'UUU': ['Phe'], 'UUC': ['Phe'], 'UCG': ['Ser1','Ser2'], \
'UCA': ['Ser1'], 'UCU': ['Ser5','Ser1'], 'UCC': ['Ser5'], 'CGG': ['Arg3'], \
'CGA': ['Arg2'], 'CGU': ['Arg2'], 'CGC': ['Arg2'], 'CAG': ['Gln2'], \
'CAA': ['Gln1'], 'CAU': ['His'], 'CAC': ['His'], 'CUG': ['Leu1','Leu3'], \
'CUA': ['Leu3'], 'CUU': ['Leu2'], 'CUC': ['Leu2'], 'CCG': ['Pro1','Pro3'], \
'CCA': ['Pro3'], 'CCU': ['Pro2','Pro3'], 'CCC': ['Pro2']}

cells = 1
TU = 9500*20
time = 180
tRNA_distrib_arr = list()
codon_count = {}
codon_time = {}
codon_time_avg = {}
codon_time_weighted_avg={}
codon_count_hist = {}
codon_count_hist_weighted_avg = np.zeros(42)
p_codon_tRNA = {}

for key in codon_dict:
    codon_count[key] = []
    codon_time[key] = []
    codon_time_avg[key] = []
    codon_time_weighted_avg[key]=[]
    codon_count_hist[key]=[]
    p_codon_tRNA[key] = []

# Construct dictionary that assigns probability of all tRNA specific to a certain codon
# to that codon (p_codon_tRNA)
for codon in codon_dict:
    p_codon_tRNA_i = 0
    for tRNA in codon_dict[codon]:
        p_codon_tRNA_i += ptRNA_dict[tRNA]
    p_codon_tRNA[codon].append(p_codon_tRNA_i)

for cell in range(cells):
    # Generate distribution for cognate tRNA count for each codon
    for i in range(TU):
            
        #Construct translation unit with random tRNA (weighted by specific tRNA abundances)
        #and 1 random codon (weighted by codon probabilities).
        tRNA_vox = list(np.random.choice(tRNA_tags,42,p=ptRNA))
        codon_vox = np.random.choice(codons_Ec, 1, p=pcodons_Ec)

        #Count how many cognate tRNA appeared in the translation unit (for given codon) and record in codon_count
        codon_count_i = 0
        for tRNA in codon_dict[codon_vox[0]]:
            codon_count_i += tRNA_vox.count(tRNA)
        codon_count[codon_vox[0]].append(codon_count_i)
    
    for codon in codon_count:
        #Generate histogram of cognate tRNA counts for each codon
        codon_count_hist[codon] = np.histogram(codon_count[codon], bins=np.arange(0,43))[0]
        
        #Weight histogram by codon probabilities to generate weighted average histogram for all codon
        codon_count_hist_weighted_avg += codon_count_hist[codon]*pcodon_dict[codon]
    p_codon_count_hist_weighted_avg = codon_count_hist_weighted_avg/sum(codon_count_hist_weighted_avg)
    print(p_codon_count_hist_weighted_avg)
# Out:
# [1.83788206e-01 2.27041970e-01 2.03131797e-01 1.63305237e-01
#  1.09050070e-01 6.38604384e-02 3.05460226e-02 1.30493919e-02
#  4.25076255e-03 1.51376517e-03 3.54034742e-04 1.08303801e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr30_0crowder = dict()
data = "190422_0042/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30_0crowder[i] = (CellLatencies(sim_i))
    
gr30 = dict()
data = "190404_0933/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30[i] = (CellLatencies(sim_i))
    
gr30_1230crowder = dict()
data = "190421_0301/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30_1230crowder[i] = (CellLatencies(sim_i))

gr30_1640crowder = dict()
data = "190422_0139/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30_1640crowder[i] = (CellLatencies(sim_i))
    
gr = {0:gr30_0crowder,1:gr30,1.5:gr30_1230crowder,2:gr30_1640crowder}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 147
# test
# test
# test
# missing expt
# 456
# test
# test
# test
# missing expt
# 120
# missing expt
# 137
# test
# missing expt
# 231
# missing expt
# 261
# test
# test
# missing expt
# 582
# missing expt
# 586
# test
# test
# missing expt
# 839
# missing expt
# 899
# test
# test
# test
# test
# missing expt
# 488
# test
# missing expt
# 621
# test
# missing expt
# 899
# test
# test
# test
# missing expt
# 342
# test
# test
# test
# missing expt
# 796

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)
for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A','green']
gr_i_list = gr.keys()
print(gr_i_list)
markers = ['*','^','x']

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 10

for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += (gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i])/(1-p_codon_count_hist_weighted_avg[0])
        weighted_avg_elongT += weighted_avg_rxnT+weighted_avg_transportT
    
    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT)
    weighted_elongT_list.append(weighted_elongT_data)

    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)
print(np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[2]))


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,100)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Brownian discovery time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83-42,83-42],[0,0.5],color='green',linewidth=4)
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)

gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))

ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83-42,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83-42)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax2.set_xlabel("Brownian discovery time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59-42,59-42],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
ax1.scatter(np.mean(weighted_elongT_list[0]),0.2,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.2,s=100,marker=markers[1],color='black',zorder=10)

ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59-42,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59-42)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

t = ax1.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83-42)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59-42)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

print(len(weighted_elongT_list))
print(np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[2]))
print(np.mean(weighted_elongT_list[0])/(83-42))
print(np.mean(weighted_elongT_list[1])/(59-42))
#(83-42),59-42

plt.tight_layout()
#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# dict_keys([0, 1, 1.5])
# 96.34197823759298 52.324951309206256 58.119325613603316
# 3
# 96.34197823759298 52.324951309206256 58.119325613603316
# 2.3498043472583654
# 3.0779383123062503

# %%
gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 10

empty_frac = p_codon_count_hist_weighted_avg[0]

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()

for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = list()
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = list()
        transport_vals = list()
        rxn_vals = np.array(gr[gr_i][i].rxnT)*1000*p_codon_count_hist_weighted_avg[i]
        transport_vals = np.array(gr[gr_i][i].transportT)*1000/(1-empty_frac)*p_codon_count_hist_weighted_avg[i]
        weighted_elongT_data = np.append(weighted_elongT_data,(rxn_vals+transport_vals))
    weighted_avg_rxnT_list.append(sum(rxn_vals))
    weighted_avg_transportT_list.append(sum(transport_vals))
    weighted_elongT_list.append(np.sum(weighted_elongT_data)/150)

print(weighted_elongT_list)

## This metthod isn't good becausee end up downweighting the slower 0 cognate cases, since they get scaled down substanntially because they are unlikely.
## Also end up downweighting t he 6 cognate et case; really, emphasize the median cases, because those times get scaled down the least. This would be fine 
#given just averages w/ gaussian distributions, but here we have very slow outliers that end up pulling up the average time; these long average timess
# for the 0 case get significantly downweighted.
# Out:
# [77.35793197669372, 47.042328103496715, 45.10250743384573, 46.18449120586306]

# %%
gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 10

empty_frac = p_codon_count_hist_weighted_avg[0]

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()

for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = list()
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = list()
        transport_vals = list()
        rxn_vals = np.array(gr[gr_i][i].rxnT)*1000
        transport_vals = np.array(gr[gr_i][i].transportT)*1000/(1-empty_frac)
        weighted_elongT_data = np.append(weighted_elongT_data,(rxn_vals+transport_vals)[sample_i])
    weighted_avg_rxnT_list.append(sum(rxn_vals))
    weighted_avg_transportT_list.append(sum(transport_vals))
    weighted_elongT_list.append(np.average(weighted_elongT_data))

print(weighted_elongT_list)

fig,ax = plt.subplots(1,1,figsize=(7,5))
ax.plot(gr_i_list,weighted_elongT_list,color='blue',linewidth=6)
ax.set_xlabel("$\phi_{crowder}/\phi_{crowder,dbl=1}$",fontsize=25)
ax.set_ylabel("Elongation time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim(50,110)
# Out:
# [92.35321008346439, 58.24178712692163, 54.29231435398623, 63.82322348589375]
# (50, 110)

# %%
gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 10

for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        
    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT)
    weighted_elongT_list.append(weighted_elongT_data)
    
print(np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[2]),np.mean(weighted_elongT_list[3]))
# Out:
# 101.72670947451414 59.752232303836756 59.34771307953494 54.93362507687202

# %%
# Topics: line, color, LineCollection, cmap, colorline, codex
# %pylab inline
'''
Defines a function colorline that draws a (multi-)colored 2D line with coordinates x and y.
The color is taken from optional data in z, and creates a LineCollection.

z can be:
- empty, in which case a default coloring will be used based on the position along the input arrays
- a single number, for a uniform color [this can also be accomplished with the usual plt.plot]
- an array of the length of at least the same length as x, to color according to this data
- an array of a smaller length, in which case the colors are repeated along the curve

The function colorline returns the LineCollection created, which can be modified afterwards.

See also: plt.streamplot
'''

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm


# Data manipulation:

def make_segments(x, y):
    '''
    Create list of line segments from x and y coordinates, in the correct format for LineCollection:
    an array of the form   numlines x (points per line) x 2 (x and y) array
    '''

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    
    return segments


# Interface to LineCollection:

def colorline(x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0), linewidth=3, alpha=1.0):
    '''
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    '''
    
    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))
           
    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])
        
    z = np.asarray(z)
    
    segments = make_segments(x, y)
    lc = LineCollection(segments, array=z, cmap=cmap, norm=norm, linewidth=linewidth, alpha=alpha)
    
    ax = plt.gca()
    ax.add_collection(lc)

    
    return lc
        
    
def clear_frame(ax=None): 
    # Taken from a post by Tony S Yu
    if ax is None: 
        ax = plt.gca() 
    ax.xaxis.set_visible(False) 
    ax.yaxis.set_visible(False) 
    for spine in ax.spines.itervalues(): 
        spine.set_visible(False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('Molpos-tRNA' , 'Molpos-ribosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('Molpos-tRNA' , 'Molpos-tRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('Molpos-tRNA' , 'Molpos-crowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    print(len(r2_lists[0]))
    return r2_lists,np.add.reduce(r2_lists)/(len(r2_lists)),np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS

# %%
path='/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/'
data = "190423_1514/"

cmap = plt.cm.get_cmap('viridis')
interv = 25
expts = np.arange(0,75,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print(D3)

expts = np.arange(75,150,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print(D3)

expts = np.arange(150,225,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print(D3)

expts = np.arange(225,300,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print(D3)

expts = np.arange(300,375,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print(D3)
# Out:
# 201
# 201
# 201
# 201
# 201
# 201
# [41.72952338575033, 43.39650931469617, 38.3017622985828]
# 201
# 201
# 201
# 201
# 201
# 201
# [42.00511699475829, 17.751111978256642, 15.466825131430788]
# 201
# 201
# 201
# 201
# 201
# 201
# [45.30847487478159, 24.203577852844102, 8.43797043447874]
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# ...

# %%
path='/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/'
data = "190423_1514/"

fig,ax=plt.subplots(4,1,figsize=(7,20))

labels = ['0','1','1.5','2','2.5']
cmap = plt.cm.get_cmap('viridis')
interv = 25
expts = np.arange(0,150,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
    ax[0].plot(x,y,color=cmap((start-expts[0])/(expts[-1]-expts[0])),label=labels[i])

ax[0].legend()
ax[0].set_title('MSD across conditions')
ax[0].set_xlabel("time (s)")
ax[0].set_ylabel("MSD")
print(D3)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr30_0crowder_1x = dict()
data = "190424_0123/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=1)
    gr30_0crowder_1x[i] = (CellLatencies(sim_i))

gr30_0crowder_10x = dict()
data = "190422_0042/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30_0crowder_10x[i] = (CellLatencies(sim_i))

gr30_0crowder_100x = dict()
data = "190424_1147/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=100)
    gr30_0crowder_100x[i] = (CellLatencies(sim_i))
    
gr30_0crowder_100x200 = dict()
data = "190424_1353/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder_100x200[i] = (CellLatencies(sim_i))
    
gr30_0crowder_100x500 = dict()
data = "190424_1807/"
for i in range(1,4):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 500*(i-1),500*(i-1)+200,scaling=100)
    gr30_0crowder_100x500[i] = (CellLatencies(sim_i))
    
data = "190424_1940/"
for i in range(1,4):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 500*(i-1),500*(i-1)+200,scaling=100)
    gr30_0crowder_100x500[i+3] = (CellLatencies(sim_i))

print("2000 scaling")
gr30_0crowder_2000 = dict()
data = "190425_1018/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=2000/717)
    gr30_0crowder_2000[i] = (CellLatencies(sim_i))
    
gr30_0crowder_100_1e10 = dict()    
data = "190426_0210/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_0crowder_100_1e10[i] = (CellLatencies(sim_i))
    
gr = {1:gr30_0crowder_1x,10:gr30_0crowder_10x,100:gr30_0crowder_100x,1002: gr30_0crowder_100x200,1005:gr30_0crowder_100x500,2000:gr30_0crowder_2000,1001e10:gr30_0crowder_100_1e10}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 147
# test
# test
# test
# missing expt
# 456
# test
# test
# test
# missing expt
# 1
# missing expt
# 60
# missing expt
# 61
# missing expt
# 64
# missing expt
# 96
# test
# test
# test
# test
# test
# test
# missing expt
# 50
# missing expt
# 51
# missing expt
# 66
# test
# test
# test
# missing expt
# 578
# test
# test
# test
# missing expt
# 26
# test
# missing expt
# 347
# test
# test
# missing expt
# 664
# test
# test
# missing expt
# 1002
# missing expt
# 1177
# test
# test
# test
# missing expt
# 1015
# missing expt
# 1091
# missing expt
# 1124
# test
# test
# missing expt
# 686
# test
# missing expt
# 1110
# missing expt
# 1176
# 2000 scaling
# test
# missing expt
# 127
# missing expt
# 130
# missing expt
# 197
# test
# missing expt
# 277
# missing expt
# 421
# test
# missing expt
# 711
# test
# test
# missing expt
# 1006
# missing expt
# 1052
# missing expt
# ...

# %%
gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 100

empty_frac = p_codon_count_hist_weighted_avg[0]

bootstrapped_elongrate=list()
for i in range(bootstrap_num):
    weighted_avg_rxnT_list=list()
    weighted_avg_transportT_list=list()
    weighted_elongT_list = list()
    for j,gr_i in enumerate(gr_i_list):
        weighted_avg_elongT = 0
        weighted_avg_rxnT = 0
        weighted_avg_transportT = 0
        weighted_elongT_data = list()
        for i in range(1,7):
            sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
            rxn_vals = list()
            transport_vals = list()
            rxn_vals = np.array(gr[gr_i][i].rxnT)*1000
            transport_vals = np.array(gr[gr_i][i].transportT)*1000/(1-empty_frac)
            weighted_elongT_data = np.append(weighted_elongT_data,(rxn_vals+transport_vals)[sample_i])
        weighted_avg_rxnT_list.append(sum(rxn_vals))
        weighted_avg_transportT_list.append(sum(transport_vals))
        weighted_elongT_list.append(np.average(weighted_elongT_data))
    bootstrapped_elongrate.append(weighted_elongT_list)

fig,ax = plt.subplots(1,1,figsize=(7,5))
ax.plot(gr_i_list,weighted_elongT_list,color='blue',linewidth=6)
ax.set_xlabel("$\phi_{crowder}/\phi_{crowder,dbl=1}$",fontsize=25)
ax.set_ylabel("Elongation time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim(50,110)
# Out:
# (50, 110)

# %%
print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# [104.78684696  97.57945302 113.73672786 117.98298845 118.43581142
#   84.02433586 266.16481528]
# [5.01143793 4.19899454 5.54448469 4.86135041 4.92468784 3.22894886
#  9.80819524]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline
# %load_ext autoreload
# %autoreload
gr30_0crowder_100_1e10 = dict()
data = "190426_0002/"
for i in range(1,2):
    sim_i = countIncorrectReactions(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    print(sim_i)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# 2
# 0
# 15
# 5
# 0
# 61
# 13
# 28
# 51
# 53
# 15
# 16
# 7
# 60
# 38
# 75
# 8
# 7
# 58
# 23
# 3
# 45
# 0
# 33
# 31
# 0
# missing expt
# 26
# 0
# 59
# 0
# 20
# 1
# 6
# 52
# 0
# 9
# 13
# 16
# 2
# 0
# 59
# 11
# 47
# 25
# 48
# 4
# 69
# 4
# 32
# 4
# 29
# 3
# 33
# 24
# 63
# 25
# 30
# 10
# 4
# 24
# 0
# 26
# 19
# 9
# 0
# 31
# 21
# 25
# 0
# 18
# 0
# 7
# 6
# 10
# 3
# 5
# 33
# 7
# 6
# 59
# 15
# 24
# 10
# 1
# 15
# 30
# 0
# 15
# 50
# 0
# 1
# 19
# 3
# 3
# 8
# 6
# 27
# 1
# 46
# 3
# 5
# 43
# 22
# 16
# 0
# 6
# 8
# 7
# 77
# 0
# 9
# 32
# 1
# 12
# 7
# 20
# 7
# 0
# 16
# 14
# 16
# 2
# 62
# 8
# 13
# 48
# 23
# 16
# 21
# 32
# 60
# 1
# 0
# 8
# 22
# 23
# 6
# 12
# 4
# 32
# 6
# 10
# 20
# 0
# 25
# 2
# 2
# 0
# 20
# 5
# 8
# 10
# 31
# 13
# 2
# 74
# 36
# 0
# 20
# 85
# 66
# 0
# 44
# 11
# 4
# 64
# 33
# 19
# 8
# 40
# 18
# 40
# 25
# 60
# 33
# 51
# 70
# 0
# 37
# 4
# 2
# 13
# 55
# 19
# 0
# 7
# 27
# 7
# 31
# 8
# 36
# 33
# 26
# ...

# %%
path='/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/'
data = "190426_1542/"

cmap = plt.cm.get_cmap('viridis')
interv = 23
expts = np.arange(0,161,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print("0 crowders ", D3)

expts = np.arange(161,161*2,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print("205 crowders ", D3)

expts = np.arange(161*2,161*3,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print("410 crowders ",D3)

expts = np.arange(161*3,161*4,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print("820 crowders ",D3)

expts = np.arange(161*5,161*6,interv)
D3=list()
for i,start in enumerate(expts):
    x = MSD(path+data,start,start+interv,'tRNA')[2][100:]
    y = MSD(path+data,start,start+interv,'tRNA')[1][100:]
    y_model = np.polyfit(x,y,1)
    D3.append(y_model[0]/6)
print("1025 crowders ",D3)
# Out:
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 0 crowders  [41.85728486659406, 43.47598056941243, 40.619034117478236, 42.332037746997194, 44.5888694892507, 39.008449773366074, 38.059703054704435]
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 205 crowders  [44.42593072683226, 31.966255146742284, 30.588780253728704, 38.717877448870205, 40.19569442826634, 30.285163919205203, 26.72110155056426]
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 410 crowders  [41.124226406016554, 27.528823267748766, 28.22027084652198, 37.196751479239985, 32.57963178952164, 23.403233040439584, 24.051535394562464]
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 820 crowders  [43.309056755547665, 17.39941198416516, 27.861610012407883, 32.77092021810876, 36.436177897073584, 14.887543091674893, 15.608634670346829]
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# ...

# %%
gr30_0crowder5e10 = dict()
data = "190428_1757/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_0crowder5e10[i] = (CellLatencies(sim_i))
    
gr30_0crowder1e10 = dict()
data = "190428_1336/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_0crowder1e10[i] = (CellLatencies(sim_i))
    
gr30_100crowder5e10 = dict()
data = "190428_1959/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_100crowder5e10[i] = (CellLatencies(sim_i))
    
gr30_100crowder1e10 = dict()
data = "190428_0343/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_100crowder1e10[i] = (CellLatencies(sim_i))
    
gr30_400crowder1e10 = dict()
data = "190501_1327/"
for i in range(1,6):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_400crowder1e10[i] = (CellLatencies(sim_i))
    
data = "190501_1327/"
for i in range(1,2):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_400crowder1e10[i+5] = (CellLatencies(sim_i))

    
gr = {5e10:gr30_0crowder5e10,1e10:gr30_0crowder1e10, 1005e10:gr30_100crowder5e10,1001e10:gr30_100crowder1e10,4001e10:gr30_400crowder1e10}

gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 100

empty_frac = p_codon_count_hist_weighted_avg[0]
bootstrapped_elongrate = bootstrap_elong(gr,empty_frac)

print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# test
# missing expt
# 48
# test
# missing expt
# 287
# test
# test
# test
# test
# missing expt
# 1422
# missing expt
# 1489
# missing expt
# 1490
# missing expt
# 1491
# missing expt
# 1492
# missing expt
# 1493
# missing expt
# 1494
# missing expt
# 1495
# missing expt
# 1496
# missing expt
# 1497
# missing expt
# 1498
# missing expt
# 1499
# test
# test
# test
# test
# test
# test
# missing expt
# 1357
# missing expt
# 1447
# test
# test
# missing expt
# 254
# test
# test
# test
# test
# missing expt
# 1263
# test
# test
# test
# test
# test
# test
# missing expt
# 1499
# test
# missing expt
# 23
# missing expt
# 217
# test
# missing expt
# 420
# test

# %%
gr30_0crowder5e10_twonm = dict()
data = "190429_0935/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_0crowder5e10_twonm[i] = (CellLatencies(sim_i))
    
gr30_0crowder1e10_twonm = dict()
data = "190429_0228/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 250*(i-1),250*i,scaling=100)
    gr30_0crowder1e10_twonm[i] = (CellLatencies(sim_i))
    
gr = {5e10:gr30_0crowder5e10_twonm,1e10:gr30_0crowder1e10_twonm}

gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 100

empty_frac = p_codon_count_hist_weighted_avg[0]
bootstrapped_elongrate = bootstrap_elong(gr,empty_frac)

print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# test
# missing expt
# 148
# test
# test
# test
# test
# test
# missing expt
# 1450
# missing expt
# 1451
# missing expt
# 1452
# missing expt
# 1454
# missing expt
# 1455
# missing expt
# 1456
# missing expt
# 1457
# missing expt
# 1458
# missing expt
# 1459
# missing expt
# 1460
# missing expt
# 1461
# missing expt
# 1462
# missing expt
# 1463
# missing expt
# 1464
# missing expt
# 1465
# missing expt
# 1466
# missing expt
# 1467
# missing expt
# 1468
# missing expt
# 1469
# missing expt
# 1470
# missing expt
# 1471
# missing expt
# 1472
# missing expt
# 1473
# missing expt
# 1474
# missing expt
# 1475
# missing expt
# 1476
# missing expt
# 1477
# missing expt
# 1478
# missing expt
# 1479
# missing expt
# 1480
# missing expt
# 1481
# missing expt
# 1482
# missing expt
# 1483
# missing expt
# 1484
# missing expt
# 1485
# missing expt
# 1486
# missing expt
# 1487
# missing expt
# 1488
# missing expt
# 1489
# missing expt
# 1490
# missing expt
# 1491
# missing expt
# 1492
# ...

# %%
gr30_0crowder5e10_sevennm = dict()
data = "190429_1602/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder5e10_sevennm[i] = (CellLatencies(sim_i))
    
gr30_0crowder1e10_sevennm = dict()
data = "190429_1717/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder1e10_sevennm[i] = (CellLatencies(sim_i))
    
gr30_100crowder1e10_sevennm = dict()
data = "190501_0114/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_100crowder1e10_sevennm[i] = (CellLatencies(sim_i))
    
gr = {5e10:gr30_0crowder5e10_sevennm,1e10:gr30_0crowder1e10_sevennm,1e10100:gr30_100crowder1e10_sevennm}

gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 100

empty_frac = p_codon_count_hist_weighted_avg[0]
bootstrapped_elongrate = bootstrap_elong(gr,empty_frac)

print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# test
# missing expt
# 174
# test
# missing expt
# 251
# test
# missing expt
# 494
# test
# missing expt
# 602
# test
# test
# missing expt
# 1199
# test
# missing expt
# 10
# missing expt
# 81
# missing expt
# 103
# missing expt
# 109
# test
# test
# missing expt
# 595
# test
# test
# test
# missing expt
# 1063
# missing expt
# 1199
# test
# missing expt
# 194
# missing expt
# 195
# test
# missing expt
# 287
# test
# test
# test
# test
# [211.40899428 210.82359766 221.31937649]
# [8.90111174 9.36070262 9.62644236]

# %%
gr30_0crowder5e10_twonm = dict()
data = "190429_1836/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder5e10_twonm[i] = (CellLatencies(sim_i))
    
gr30_0crowder1e10_twonm = dict()
data = "190429_2250/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder1e10_twonm[i] = (CellLatencies(sim_i))
    
gr = {5e10:gr30_0crowder5e10_twonm,1e10:gr30_0crowder1e10_twonm}

gr_i_list = gr.keys()

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
bootstrap_num = 100

empty_frac = p_codon_count_hist_weighted_avg[0]
bootstrapped_elongrate = bootstrap_elong(gr,empty_frac)

print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# [224.41949349 217.82823095]
# [9.44030138 9.82023918]

# %%
gr30_0crowder5e10_twoang = dict()
data = "190430_0200/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder5e10_twoang[i] = (CellLatencies(sim_i))
    
gr30_0crowder1e10_twoang = dict()
data = "190430_0015/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder1e10_twoang[i] = (CellLatencies(sim_i))
    
gr = {5e10:gr30_0crowder5e10_twoang,1e10:gr30_0crowder1e10_twoang}

gr_i_list = gr.keys()

empty_frac = p_codon_count_hist_weighted_avg[0]
bootstrapped_elongrate = bootstrap_elong(gr,empty_frac)

print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# test
# test
# test
# missing expt
# 426
# test
# test
# test
# missing expt
# 1116
# test
# test
# test
# test
# missing expt
# 665
# test
# test
# [286.38326919 316.47785772]
# [10.28132018 15.37814763]

# %%
gr30_0crowder5e10_fiveang = dict()
data = "190430_1632/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder5e10_fiveang[i] = (CellLatencies(sim_i))
    
gr30_0crowder1e10_fiveang = dict()
data = "190430_2232/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=100)
    gr30_0crowder1e10_fiveang[i] = (CellLatencies(sim_i))
    
gr = {5e10:gr30_0crowder5e10_fiveang,1e10:gr30_0crowder1e10_fiveang}

gr_i_list = gr.keys()


empty_frac = p_codon_count_hist_weighted_avg[0]
bootstrapped_elongrate = bootstrap_elong(gr,empty_frac)

print(np.array(bootstrapped_elongrate).mean(axis=0))
print(np.array(bootstrapped_elongrate).std(axis=0))
# Out:
# test
# test
# missing expt
# 226
# test
# test
# missing expt
# 646
# test
# test
# missing expt
# 1173
# missing expt
# 1192
# test
# test
# test
# missing expt
# 412
# test
# test
# missing expt
# 959
# test
# missing expt
# 1071
# missing expt
# 1076
# missing expt
# 1116
# missing expt
# 1176
# missing expt
# 1196
# missing expt
# 1199
# [257.76309463 292.33167339]
# [10.93035194 12.24443527]

# %%
def bootstrap_elong(gr,empty_frac):
    
    bootstrap_num = 100
    bootstrapped_elongrate=list()
    for i in range(bootstrap_num):
        weighted_avg_rxnT_list=list()
        weighted_avg_transportT_list=list()
        weighted_elongT_list = list()
        for j,gr_i in enumerate(gr.keys()):
            weighted_avg_elongT = 0
            weighted_avg_rxnT = 0
            weighted_avg_transportT = 0
            weighted_elongT_data = list()
            for i in range(1,7):
                sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
                rxn_vals = list()
                transport_vals = list()
                rxn_vals = np.array(gr[gr_i][i].rxnT)*1000
                transport_vals = np.array(gr[gr_i][i].transportT)*1000/(1-empty_frac)
                weighted_elongT_data = np.append(weighted_elongT_data,(rxn_vals+transport_vals)[sample_i])
            weighted_avg_rxnT_list.append(sum(rxn_vals))
            weighted_avg_transportT_list.append(sum(transport_vals))
            weighted_elongT_list.append(np.average(weighted_elongT_data))
        bootstrapped_elongrate.append(weighted_elongT_list)
    return bootstrapped_elongrate
