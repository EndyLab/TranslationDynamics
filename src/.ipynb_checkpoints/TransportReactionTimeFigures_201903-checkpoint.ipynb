# %%
import numpy as np

ptRNA = [0.0521, 0.0099, 0.0762, 0.0102, 0.0139, 0.0067, 0.0191, 0.0384, 0.0255, 0.0123, 0.0141,\
 0.0757, 0.0343, 0.0699, 0.0102, 0.0557, 0.0717, 0.0151, 0.0107, 0.0307, \
 0.0165, 0.0309, 0.0113, 0.0166, 0.0144, 0.0115, 0.0093, 0.0035, 0.0208, 0.0055, 0.0226, \
 0.0123, 0.0017, 0.0087, 0.0176, 0.0147, 0.0151, 0.0326, 0.0616,0.0203]
ptRNA = np.divide(ptRNA,sum(ptRNA))

tRNA_tags = ["Ala1B", "Ala2", "Arg2", "Arg3", "Arg4", "Arg5", "Asn", "Asp1", "Cys", "Gln1", "Gln2", \
"Glu2", "Gly2", "Gly3", "His", "Ile1", "Leu1", "Leu2", "Leu3", "Leu4", "Leu5", "Lys", \
"Met_m", "Phe", "Pro1", "Pro2", "Pro3", "Sel_Cys", "Ser1", "Ser2", "Ser3", "Ser5", "Thr1", \
"Thr2", "Thr3", "Thr4", "Trp", "Tyr1pTyr2", "Val1", "Val2ApB"]

ptRNA_dict = dict(zip(tRNA_tags, ptRNA))

codons_Ec = ["GGG", "GGA", "GGU", "GGC", "GAG", "GAA", "GAU", "GAC", "GUG", "GUA", "GUU", \
"GUC", "GCG", "GCA", "GCU", "GCC", "AGG", "AGA", "AGU", "AGC", "AAG", "AAA", \
"AAU", "AAC", "AUG", "AUA", "AUU", "AUC", "ACG", "ACA", "ACU", "ACC", "UGG", \
"UGA", "UGU", "UGC", "UAU", "UAC", "UUG", "UUA", "UUU", "UUC", "UCG", "UCA", \
"UCU", "UCC", "CGG", "CGA", "CGU", "CGC", "CAG", "CAA", "CAU", "CAC", "CUG", \
"CUA", "CUU", "CUC", "CCG", "CCA", "CCU", "CCC"]

pcodons_Ec =[0.00483, 0.00272, 0.03847, 0.03579, 0.01665, 0.05335, 0.02436, \
0.02885, 0.02150, 0.01594, 0.03146, 0.01130, 0.03047, 0.02223, \
0.02898, 0.01989, 0.00009, 0.00113, 0.00401, 0.01203, 0.01214, \
0.04464, 0.00984, 0.02808, 0.02247, 0.00093, 0.02148, 0.03685, \
0.00757, 0.00350, 0.01394, 0.02663, 0.00981, 0.00031, 0.00425, \
0.00531, 0.01073, 0.01628, 0.00666, 0.00616, 0.01261, 0.02279, \
0.00608, 0.00391, 0.01318, 0.01120, 0.00176, 0.00133, 0.03126, \
0.02235, 0.02938, 0.01024, 0.00927, 0.01396, 0.06041, 0.00216, \
0.00573, 0.00622, 0.02965, 0.00655, 0.00501, 0.00332]
pcodons_Ec = np.divide(pcodons_Ec,sum(pcodons_Ec))

pcodon_dict = dict(zip(codons_Ec, pcodons_Ec))

#Note AUA does not have an assigned tRNA
codon_dict={'GGG': ['Gly2'], 'GGA': ['Gly2'], 'GGU': ['Gly3'], 'GGC': ['Gly3'], \
'GAG': ['Glu2'], 'GAA': ['Glu2'], 'GAU': ['Asp1'], 'GAC': ['Asp1'], \
'GUG': ['Val1'], 'GUA': ['Val1'], 'GUU': ['Val1','Val2ApB'], \
'GUC': ['Val2ApB'], 'GCG': ['Ala1B'], 'GCA': ['Ala1B'], 'GCU': ['Ala1B'], \
'GCC': ['Ala2'], 'AGG': ['Arg5'], 'AGA': ['Arg4'], 'AGU': ['Ser3'], \
'AGC': ['Ser3'], 'AAG': ['Lys'], 'AAA': ['Lys'], 'AAU': ['Asn'], \
'AAC': ['Asn'], 'AUG': ['Met_m'], 'AUA': [], 'AUU': ['Ile1'], \
'AUC': ['Ile1'], 'ACG': ['Thr2','Thr4'], 'ACA': ['Thr4'], \
'ACU': ['Thr1','Thr4','Thr3'], 'ACC': ['Thr3','Thr1'], \
'UGG': ['Trp'], 'UGA': ['Sel_Cys'], 'UGU': ['Cys'], 'UGC': ['Cys'], \
'UAU': ['Tyr1pTyr2'], 'UAC': ['Tyr1pTyr2'], 'UUG': ['Leu5','Leu4'], \
'UUA': ['Leu5'], 'UUU': ['Phe'], 'UUC': ['Phe'], 'UCG': ['Ser1','Ser2'], \
'UCA': ['Ser1'], 'UCU': ['Ser5','Ser1'], 'UCC': ['Ser5'], 'CGG': ['Arg3'], \
'CGA': ['Arg2'], 'CGU': ['Arg2'], 'CGC': ['Arg2'], 'CAG': ['Gln2'], \
'CAA': ['Gln1'], 'CAU': ['His'], 'CAC': ['His'], 'CUG': ['Leu1','Leu3'], \
'CUA': ['Leu3'], 'CUU': ['Leu2'], 'CUC': ['Leu2'], 'CCG': ['Pro1','Pro3'], \
'CCA': ['Pro3'], 'CCU': ['Pro2','Pro3'], 'CCC': ['Pro2']}

cells = 1
TU = 9500*20
time = 180
tRNA_distrib_arr = list()
codon_count = {}
codon_time = {}
codon_time_avg = {}
codon_time_weighted_avg={}
codon_count_hist = {}
codon_count_hist_weighted_avg = np.zeros(42)
p_codon_tRNA = {}

for key in codon_dict:
    codon_count[key] = []
    codon_time[key] = []
    codon_time_avg[key] = []
    codon_time_weighted_avg[key]=[]
    codon_count_hist[key]=[]
    p_codon_tRNA[key] = []

# Construct dictionary that assigns probability of all tRNA specific to a certain codon
# to that codon (p_codon_tRNA)
for codon in codon_dict:
    p_codon_tRNA_i = 0
    for tRNA in codon_dict[codon]:
        p_codon_tRNA_i += ptRNA_dict[tRNA]
    p_codon_tRNA[codon].append(p_codon_tRNA_i)

for cell in range(cells):
    # Generate distribution for cognate tRNA count for each codon
    for i in range(TU):
            
        #Construct translation unit with random tRNA (weighted by specific tRNA abundances)
        #and 1 random codon (weighted by codon probabilities).
        tRNA_vox = list(np.random.choice(tRNA_tags,42,p=ptRNA))
        codon_vox = np.random.choice(codons_Ec, 1, p=pcodons_Ec)

        #Count how many cognate tRNA appeared in the translation unit (for given codon) and record in codon_count
        codon_count_i = 0
        for tRNA in codon_dict[codon_vox[0]]:
            codon_count_i += tRNA_vox.count(tRNA)
        codon_count[codon_vox[0]].append(codon_count_i)
    
    for codon in codon_count:
        #Generate histogram of cognate tRNA counts for each codon
        codon_count_hist[codon] = np.histogram(codon_count[codon], bins=np.arange(0,43))[0]
        
        #Weight histogram by codon probabilities to generate weighted average histogram for all codon
        codon_count_hist_weighted_avg += codon_count_hist[codon]*pcodon_dict[codon]
    p_codon_count_hist_weighted_avg = codon_count_hist_weighted_avg/sum(codon_count_hist_weighted_avg)
    print(p_codon_count_hist_weighted_avg)
# Out:
# [1.82137883e-01 2.25791861e-01 2.06955598e-01 1.62739999e-01
#  1.09585779e-01 6.27701986e-02 3.09038414e-02 1.27228441e-02
#  4.43113964e-03 1.52360240e-03 3.86045528e-04 3.95178185e-05
#  1.16911846e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg)
plt.xlabel('# of cognate tRNA per TU',fontsize=20)
plt.ylabel('Probability',fontsize=20)
# Out:
# Text(0, 0.5, 'Probability')

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr06 = dict()
data = "190317_1947/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr06[i] = (CellLatencies(sim_i))

gr15 = dict()
data = "190317_1704/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr15[i] = (CellLatencies(sim_i))
    
gr30 = dict()
data = "190317_1536/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30[i] = (CellLatencies(sim_i))
    
gr = {0.6:gr06,1.5:gr15,3.0:gr30}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 1
# missing expt
# 3
# missing expt
# 6
# missing expt
# 7
# missing expt
# 8
# missing expt
# 9
# missing expt
# 11
# missing expt
# 12
# missing expt
# 13
# missing expt
# 14
# missing expt
# 15
# missing expt
# 16
# missing expt
# 18
# missing expt
# 20
# missing expt
# 21
# missing expt
# 22
# missing expt
# 23
# missing expt
# 26
# missing expt
# 27
# missing expt
# 28
# missing expt
# 29
# missing expt
# 30
# missing expt
# 31
# missing expt
# 32
# missing expt
# 33
# missing expt
# 34
# missing expt
# 35
# missing expt
# 36
# missing expt
# 37
# missing expt
# 38
# missing expt
# 39
# missing expt
# 40
# missing expt
# 41
# missing expt
# 42
# missing expt
# 44
# missing expt
# 45
# missing expt
# 47
# missing expt
# 50
# missing expt
# 51
# missing expt
# 52
# missing expt
# 53
# missing expt
# 55
# missing expt
# 56
# missing expt
# 57
# missing expt
# 58
# ...

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax,ax1] = plt.subplots(1,2,figsize=(10,5))

ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Average Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,20):
    ax.plot([0,50*k],[50*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*k)

ax.plot([0,59],[59,0],color='black',linewidth=3,alpha=0.4)
ax.plot([0,83],[83,0],color='black',linewidth=3,alpha=0.5)

####Draw experimental line for Elong time vs. growth rate###
ax1.plot([0.6,3.0],[83,59],color='black',linewidth=3)
t = ax1.text(0.29, 0.16, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='black', rotation = -5)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))

#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['blue','orange','red']
gr_i_list = [0.6,1.5,3.0]
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(20*p_codon_count_hist_weighted_avg[i]))
        ax.scatter(np.add(np.multiply(gr[gr_i][i].rxnT,1000)[sample_i],42),
                    np.multiply(gr[gr_i][i].transportT,1000)[sample_i],
                    color=colors[j],alpha=(1-0.15*i))

        ax1.scatter(gr_i,(gr[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42,color=colors[j],alpha=(1-0.15*i))
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
    ax1.scatter(gr_i,weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0])+42,color='black',alpha=1,linewidth=2)
    
#############################################################################
blue_patch = mpatches.Patch(color='blue', label='Growth rate = 0.6')
orange_patch = mpatches.Patch(color='orange', label='Growth rate = 1.5')
red_patch = mpatches.Patch(color='red', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,orange_patch,red_patch])

ax.set_xlim(0,300)
ax.set_ylim(0,700)

ax1.set_ylim(0,350)
    
plt.tight_layout()

vals=[0,1/6,2/6,3/6,4/6,5/6]
cmap = mpl.colors.ListedColormap(['#0000FF','#0000FF','#0000FF','#0000FF','#0000FF','#0000FF'])
# Set alpha
my_cmap = cmap(np.arange(cmap.N))

# Set alpha
my_cmap[:,-1] = np.array([0.1,0.25,0.4,0.55,0.7,0.85])

# Create new colormap
cmap = mpl.colors.ListedColormap(my_cmap)


cax, _ = mpl.colorbar.make_axes(ax1)
cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                spacing='uniform',
                                orientation='vertical',
                                extend='neither',
                                ticks=vals)
cax.set_yticklabels(['1','2','3','4','5','6'])

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)
                
#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr06_noc = dict()
data = "190314_1808/"
for i in range(1,4):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=10)
    gr06_noc[i] = (CellLatencies(sim_i))

data = "190314_1850/"
for i in range(4,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-4),150*(i-3),scaling=10)
    gr06_noc[i] = (CellLatencies(sim_i))


gr30_noc = dict()
data = "190317_1536/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30_noc[i] = (CellLatencies(sim_i))
    
gr_noc = {0.6:gr06_noc,3.0:gr30_noc}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 46
# missing expt
# 76
# missing expt
# 77
# missing expt
# 168
# missing expt
# 194
# test
# missing expt
# 318
# test
# missing expt
# 561
# missing expt
# 599
# test
# missing expt
# 138
# test
# test
# test
# missing expt
# 0
# missing expt
# 1
# missing expt
# 2
# missing expt
# 7
# missing expt
# 17
# missing expt
# 18
# missing expt
# 19
# missing expt
# 20
# missing expt
# 25
# missing expt
# 42
# test
# test
# test
# test
# test
# missing expt
# 899

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax,ax1] = plt.subplots(1,2,figsize=(10,5))



ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Average Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

#ax.plot([0,59],[59,0],color='orange',linewidth=3)
#ax.plot([0,83],[83,0],color='orange',linewidth=3)
#ax.plot([0,10],[59,73],color='orange',linewidth=3)
#ax.plot([20,30],[39,53],color='orange',linewidth=3)
#ax.plot([40,50],[19,33],color='orange',linewidth=3)
#ax.plot([59,69],[0,14],color='orange',linewidth=3)

####Draw experimental line for Elong time vs. growth rate###
ax1.plot([0.6,3.0],[83,59],color='darkorange',linewidth=3)
t = ax1.text(0.25, 0.165, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='darkorange', rotation = -5.5)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))

t = ax1.text(0.25, 0.34, 'Simulated time', style='italic', transform=ax1.transAxes, fontsize=12,color='green', rotation = -11)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['blue','red']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    for i in range(1,7):
        sample_i = np.random.choice(len(gr_noc[gr_i][i].rxnT),int(len(gr_noc[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.add(np.multiply(gr_noc[gr_i][i].rxnT,1000),42)
        transport_vals = np.multiply(gr_noc[gr_i][i].transportT,1000)
        print(np.average(rxn_vals),np.average(transport_vals))

        ax.scatter(rxn_vals[sample_i],transport_vals[sample_i],color=colors[j])
        print()
        ax1.scatter(gr_i_list[j],(gr_noc[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42,color=colors[j])
        
        weighted_avg_elongT += gr_noc[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0])+42)
ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])
for i in range(1,7):
    weighted_avg_elongT = 0
    point = []
    for j,gr_i in enumerate(gr_i_list):
        point.append((gr_noc[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42)
    
    ax1.plot(gr_i_list,point,color='black',alpha=alpha[i-1],linestyle='--')

#############################################################################


blue_patch = mpatches.Patch(color='blue', label='Growth rate = 0.6')
orange_patch = mpatches.Patch(color='orange', label='Growth rate = 1.5')
red_patch = mpatches.Patch(color='red', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch])

ax.set_xlim(0,300)
ax.set_ylim(0,700)

ax1.set_ylim(0,350)
    
plt.tight_layout()

vals=[0,1/6,2/6,3/6,4/6,5/6]
cmap = mpl.colors.ListedColormap(['#000000','#000000','#000000','#000000','#000000','#000000'])
# Set alpha
my_cmap = cmap(np.arange(cmap.N))

# Set alpha
my_cmap[:,-1] = np.array([0.25,0.4,0.55,0.7,0.85,1])

# Create new colormap
cmap = mpl.colors.ListedColormap(my_cmap)


cax, _ = mpl.colorbar.make_axes(ax1)
cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                spacing='uniform',
                                orientation='vertical',
                                extend='neither',
                                ticks=vals)
cax.set_yticklabels(['1','2','3','4','5','6'])

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)

print(np.cumsum(p_codon_count_hist_weighted_avg)[0:7])

left, bottom, width, height = [0.76, 0.75, 0.13, 0.15]
ax1a = fig.add_axes([left, bottom, width, height])
ax1a.plot(np.cumsum(p_codon_count_hist_weighted_avg)[0:7],color='black')
ax1a.set_xlabel('# cognate tRNA')
ax1a.set_ylabel('Cum. prob.')
ax1a.set_xticks([0,3,6])

x = np.linspace(95, 71, 200)
y = x
colorline(x, y,cmap='gray')
    
#ax.annotate('', xy = (0.8, 0.8),  xycoords = 'axes fraction', \
#    xytext = (0.5, 0.5), textcoords = 'axes fraction', fontsize = 16, \
#    color = '#303030', arrowprops=dict(edgecolor='black', arrowstyle = '->', shrinkA = 0, shrinkB = 0,linewidth=4))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 59.21222256410256 188.74881641025638
#
# 49.332449748743706 97.0023768844221
#
# 47.277463636363635 69.83957626262627
#
# 45.58750604026845 52.724291275167786
#
# 45.091352666666666 44.224598666666665
#
# 44.387981333333336 32.033204
#
# 59.949879285714296 100.2868342857143
#
# 49.01576 41.556682
#
# 47.81798933333333 33.502022
#
# 45.65792533333333 23.982640666666665
#
# 44.64392333333333 17.217822666666663
#
# 44.42995369127517 17.886534899328858
#
# [0.18144102 0.40848523 0.61326954 0.77650945 0.88669479 0.95003376
#  0.98063991]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-06f9eefb1fe6> in <module>
#     125 x = np.linspace(95, 71, 200)
#     126 y = x
# --> 127 colorline(x, y,cmap='gray')
#     128
# ...

# %%
##with no crowder:
59.21222256410256 188.74881641025638

49.332449748743706 97.0023768844221

47.277463636363635 69.83957626262627

45.58750604026845 52.724291275167786

45.091352666666666 44.224598666666665

44.387981333333336 32.033204

###With crowder:
49.99534466666667 104.20611066666666

45.28953945578232 43.44973197278912

44.24692617449664 31.304091946308723

44.05222666666666 27.791402666666666

43.57229266666666 20.51869

43.39585472972973 17.557762837837835
# Out:
#   File "<ipython-input-19-3f69db3d19e4>", line 2
#     59.21222256410256 188.74881641025638
#                                        ^
# SyntaxError: invalid syntax

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from matplotlib import gridspec
import scipy.stats as stats


# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.figure(figsize=(13,7))
gs = gridspec.GridSpec(2, 3, width_ratios=[1, 6,6],height_ratios=[6,3]) 
ax0 = plt.subplot(gs[0])
ax = plt.subplot(gs[1])
ax1 = plt.subplot(gs[2])
ax2 = plt.subplot(gs[4])

ax2.set_xlim(0,200)
ax2.set_ylim(0,1)
#ax2.tick_params(axis='both', which='both',bottom=False,labelbottom=False) 
ax2.set_ylabel('Probability',fontsize=15)

ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Average Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

ax0.set_xlim(0,0.5)
ax0.set_ylim(0,700)
ax0.invert_xaxis()


for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

####Draw experimental line for Elong time vs. growth rate###
ax1.plot([0.6,3.0],[83,59],color='darkorange',linewidth=3)
t = ax1.text(0.25, 0.165, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='darkorange', rotation = -5.5)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))

t = ax1.text(0.25, 0.34, 'Simulated time', style='italic', transform=ax1.transAxes, fontsize=12,color='green', rotation = -11)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['blue','red']
gr_i_list = [0.6,3.0]
alpha_list = np.array([0.25,0.4,0.55,0.7,0.85,1])
weighted_avg_elongT_list=list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    hist_sum_rxn = 0
    hist_sum_transport = 0
    for i in range(1,7):
        sample_i = np.random.choice(len(gr_noc[gr_i][i].rxnT),int(len(gr_noc[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.add(np.multiply(gr_noc[gr_i][i].rxnT,1000),0)
        transport_vals = np.multiply(gr_noc[gr_i][i].transportT,1000)

        ax.scatter(rxn_vals[sample_i],transport_vals[sample_i],color=colors[j],alpha=alpha_list[i-1])
        
        hist_sum_rxn += np.histogram(rxn_vals[sample_i],bins=100,range=(0,200))[0]
        hist_sum_transport += np.histogram(transport_vals[sample_i],bins=100,range=(0,700))[0]
        
        ax1.scatter(gr_i_list[j],(gr_noc[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42,color=colors[j])
        weighted_avg_elongT += gr_noc[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0])+42)
    
    ax2.bar(np.histogram(np.array(gr_noc[gr_i][i].rxnT)*1000,bins=100,range=(0,200))[1][:-1],hist_sum_rxn/sum(hist_sum_rxn),align='edge',width=2,alpha=0.5,color='none',edgecolor=colors[j])
    ax0.barh(np.histogram(np.array(gr_noc[gr_i][i].transportT)*1000,bins=100,range=(0,700))[1][:-1],hist_sum_transport/sum(hist_sum_transport),align='edge',height=2,alpha=0.5,color='none',edgecolor=colors[j])
    print(hist_sum/sum(hist_sum))
    print(sum(hist_sum/sum(hist_sum)))

    #ax1.scatter(gr_i_list[j],weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0])+42,color='green')

ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])
for i in range(1,7):
    weighted_avg_elongT = 0
    point = []
    for j,gr_i in enumerate(gr_i_list):
        point.append((gr_noc[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42)
    
    ax1.plot(gr_i_list,point,color='black',alpha=alpha[i-1],linestyle='--')

#############################################################################
blue_patch = mpatches.Patch(color='blue', label='Growth rate = 0.6')
orange_patch = mpatches.Patch(color='orange', label='Growth rate = 1.5')
red_patch = mpatches.Patch(color='red', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch])

ax.set_xlim(0,200)
ax.set_ylim(0,700)

ax1.set_ylim(0,350)
    
plt.tight_layout()

vals=[0,1/6,2/6,3/6,4/6,5/6]
cmap = mpl.colors.ListedColormap(['#000000','#000000','#000000','#000000','#000000','#000000'])
# Set alpha
my_cmap = cmap(np.arange(cmap.N))

# Set alpha
my_cmap[:,-1] = np.array([0.25,0.4,0.55,0.7,0.85,1])

# Create new colormap
cmap = mpl.colors.ListedColormap(my_cmap)

cax, _ = mpl.colorbar.make_axes(ax1)
cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                spacing='uniform',
                                orientation='vertical',
                                extend='neither',
                                ticks=vals)
cax.set_yticklabels(['1','2','3','4','5','6'])

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)


#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9bf3f707e8fa> in <module>
#      78     ax2.bar(np.histogram(np.array(gr_noc[gr_i][i].rxnT)*1000,bins=100,range=(0,200))[1][:-1],hist_sum_rxn/sum(hist_sum_rxn),align='edge',width=2,alpha=0.5,color='none',edgecolor=colors[j])
#      79     ax0.barh(np.histogram(np.array(gr_noc[gr_i][i].transportT)*1000,bins=100,range=(0,700))[1][:-1],hist_sum_transport/sum(hist_sum_transport),align='edge',height=2,alpha=0.5,color='none',edgecolor=colors[j])
# ---> 80     print(hist_sum/sum(hist_sum))
#      81     print(sum(hist_sum/sum(hist_sum)))
#      82
#
# NameError: name 'hist_sum' is not defined

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
data = "190317_1536/"
#computeTransportRxnTimes(path+data, 1000, 1000, 681,682,scaling=10)
computeTransportRxnTimes(path+data, 1000, 1000, 3,4,scaling=10)

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr06 = dict()
data = "190404_0410/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr06[i] = (CellLatencies(sim_i))
    
gr30 = dict()
data = "190404_0933/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30[i] = (CellLatencies(sim_i))
    
gr = {0.6:gr06,3.0:gr30}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# missing expt
# 168
# missing expt
# 176
# missing expt
# 188
# test
# missing expt
# 320
# test
# test
# test
# missing expt
# 838
# missing expt
# 899
# test
# missing expt
# 120
# missing expt
# 137
# test
# missing expt
# 231
# missing expt
# 261
# test
# test
# missing expt
# 582
# missing expt
# 586
# test
# test
# missing expt
# 839
# missing expt
# 899

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax,ax1] = plt.subplots(1,2,figsize=(10,5))



ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Average Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

#ax.plot([0,59],[59,0],color='orange',linewidth=3)
#ax.plot([0,83],[83,0],color='orange',linewidth=3)
#ax.plot([0,10],[59,73],color='orange',linewidth=3)
#ax.plot([20,30],[39,53],color='orange',linewidth=3)
#ax.plot([40,50],[19,33],color='orange',linewidth=3)
#ax.plot([59,69],[0,14],color='orange',linewidth=3)

####Draw experimental line for Elong time vs. growth rate###
ax1.plot([0.6,3.0],[83,59],color='darkorange',linewidth=3)
t = ax1.text(0.25, 0.165, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='darkorange', rotation = -5.5)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))

t = ax1.text(0.25, 0.34, 'Simulated time', style='italic', transform=ax1.transAxes, fontsize=12,color='green', rotation = -11)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['blue','red']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)))
        rxn_vals = np.add(np.multiply(gr[gr_i][i].rxnT,1000),42)
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)
        print(np.average(rxn_vals),np.average(transport_vals))

        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        print()
        ax1.scatter(gr_i_list[j],(gr[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42,color=colors[j])
        
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0])+42)
ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])
for i in range(1,7):
    weighted_avg_elongT = 0
    point = []
    for j,gr_i in enumerate(gr_i_list):
        point.append((gr[gr_i][i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42)
        #Note here I scaled all #cognate simulations by the 0 cognate scaling factor
    ax1.plot(gr_i_list,point,color='black',alpha=alpha[i-1],linestyle='--')

#############################################################################


blue_patch = mpatches.Patch(color='blue', label='Growth rate = 0.6')
orange_patch = mpatches.Patch(color='orange', label='Growth rate = 1.5')
red_patch = mpatches.Patch(color='red', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch])

ax.set_xlim(0,150)
ax.set_ylim(0,500)

ax1.set_ylim(0,350)
    
plt.tight_layout()

vals=[0,1/6,2/6,3/6,4/6,5/6]
cmap = mpl.colors.ListedColormap(['#000000','#000000','#000000','#000000','#000000','#000000'])
# Set alpha
my_cmap = cmap(np.arange(cmap.N))

# Set alpha
my_cmap[:,-1] = np.array([0.25,0.4,0.55,0.7,0.85,1])

# Create new colormap
cmap = mpl.colors.ListedColormap(my_cmap)


cax, _ = mpl.colorbar.make_axes(ax1)
cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                spacing='uniform',
                                orientation='vertical',
                                extend='neither',
                                ticks=vals)
cax.set_yticklabels(['1','2','3','4','5','6'])

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)

print(np.cumsum(p_codon_count_hist_weighted_avg)[0:7])

left, bottom, width, height = [0.76, 0.75, 0.13, 0.15]
ax1a = fig.add_axes([left, bottom, width, height])
ax1a.plot(np.cumsum(p_codon_count_hist_weighted_avg)[0:7],color='black')
ax1a.set_xlabel('# cognate tRNA')
ax1a.set_ylabel('Cum. prob.')
ax1a.set_xticks([0,3,6])

x = np.linspace(95, 71, 200)
y = x
colorline(x, y,cmap='gray')
    
#ax.annotate('', xy = (0.8, 0.8),  xycoords = 'axes fraction', \
#    xytext = (0.5, 0.5), textcoords = 'axes fraction', fontsize = 16, \
#    color = '#303030', arrowprops=dict(edgecolor='black', arrowstyle = '->', shrinkA = 0, shrinkB = 0,linewidth=4))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 49.99534466666667 104.20611066666666
#
# 45.28953945578232 43.44973197278912
#
# 44.24692617449664 31.304091946308723
#
# 44.05222666666666 27.791402666666666
#
# 43.57229266666666 20.51869
#
# 43.39585472972973 17.557762837837835
#
# 54.749832432432434 77.80031418918918
#
# 49.50311081081081 40.499904054054056
#
# 46.654390666666664 29.676804
#
# 44.8274304054054 19.543785135135135
#
# 44.143144666666664 13.668493333333336
#
# 44.01882229729729 13.936306756756759
#
# [0.18213788 0.40792974 0.61488534 0.77762534 0.88721112 0.94998132
#  0.98088516]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6b5f6f98064d> in <module>
#     125 x = np.linspace(95, 71, 200)
#     126 y = x
# --> 127 colorline(x, y,cmap='gray')
#     128
# ...

# %%
#Figure 3
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax,ax1] = plt.subplots(1,2,figsize=(10,5))



ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Average Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

#ax.plot([0,59],[59,0],color='orange',linewidth=3)
#ax.plot([0,83],[83,0],color='orange',linewidth=3)
#ax.plot([0,10],[59,73],color='orange',linewidth=3)
#ax.plot([20,30],[39,53],color='orange',linewidth=3)
#ax.plot([40,50],[19,33],color='orange',linewidth=3)
#ax.plot([59,69],[0,14],color='orange',linewidth=3)

####Draw experimental line for Elong time vs. growth rate###
ax1.plot([0.6,3.0],[(83-42),59-42],color='darkorange',linewidth=3)
t = ax1.text(0.25, 0.165, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='darkorange', rotation = -5.5)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))

t = ax1.text(0.25, 0.34, 'Simulated time', style='italic', transform=ax1.transAxes, fontsize=12,color='green', rotation = -11)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['blue','red']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)
        print(np.average(rxn_vals),np.average(transport_vals))

        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        print()
        
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))

ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')
print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])

#############################################################################


blue_patch = mpatches.Patch(color='blue', label='Growth rate = 0.6')
orange_patch = mpatches.Patch(color='orange', label='Growth rate = 1.5')
red_patch = mpatches.Patch(color='red', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=12)

ax.set_xlim(0,150)
ax.set_ylim(0,500)

ax1.set_ylim(0,60)
    
plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)

print(np.cumsum(p_codon_count_hist_weighted_avg)[0:7])


x = np.linspace(95, 71, 200)
y = x
colorline(x, y,cmap='gray')
    
#ax.annotate('', xy = (0.8, 0.8),  xycoords = 'axes fraction', \
#    xytext = (0.5, 0.5), textcoords = 'axes fraction', fontsize = 16, \
#    color = '#303030', arrowprops=dict(edgecolor='black', arrowstyle = '->', shrinkA = 0, shrinkB = 0,linewidth=4))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 7.995344666666667 104.20611066666666
#
# 3.289539455782313 43.44973197278912
#
# 2.246926174496645 31.304091946308723
#
# 2.0522266666666664 27.791402666666666
#
# 1.5722926666666668 20.51869
#
# 1.3958547297297297 17.557762837837835
#
# 12.74983243243243 77.80031418918918
#
# 7.503110810810807 40.499904054054056
#
# 4.654390666666666 29.676804
#
# 2.827430405405406 19.543785135135135
#
# 2.143144666666667 13.668493333333336
#
# 2.018822297297297 13.936306756756759
#
# [55.88968270285016, 48.79083894768112]
# [3.935213899926066, 6.964298418634795]
# [51.95446880292408, 41.82654052904633]
# [0.18213788 0.40792974 0.61488534 0.77762534 0.88721112 0.94998132
#  0.98088516]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e72d25264f6e> in <module>
# ...

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax,ax1] = plt.subplots(1,2,figsize=(10,5))

ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

####Draw experimental line for Elong time vs. growth rate###
t = ax1.text(0.3, 0.06, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='darkorange', rotation = -3.5)
t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['deepskyblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].elongT),int(len(gr[gr_i][i].elongT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)
        #print(np.average(rxn_vals),np.average(transport_vals))
        weighted_elongT_data = np.append(weighted_elongT_data,np.array(gr[gr_i][i].elongT)[sample_i]*1000)
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_elongT_list.append(weighted_elongT_data)
#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='deepskyblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=12)

ax.set_xlim(0,100)
ax.set_ylim(0,500)
#############################################################################


ax1.plot([0.6,3.0],[(83-42),59-42],color='darkorange',linewidth=3)

parts = ax1.violinplot(weighted_elongT_list[0],[1.0], showmeans=False, showmedians=False,
        showextrema=False)
for pc in parts['bodies']:
    pc.set_facecolor('deepskyblue')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
quartile1, medians, quartile3 = np.percentile(weighted_elongT_list[0], [25, 50, 75])
ax1.scatter(1.0, np.mean(weighted_elongT_list[0]), marker='o', color='white', s=30, zorder=3)
ax1.vlines(1.0, quartile1, quartile3, color='k', linestyle='-', lw=5)
ax1.vlines(1.0, min(weighted_elongT_list[0]), max(weighted_elongT_list[1]), color='k', linestyle='-', lw=1)
print(np.median(weighted_elongT_list[0]))


parts = ax1.violinplot(weighted_elongT_list[1],[3.0], showmeans=False, showmedians=False,
        showextrema=False)
for pc in parts['bodies']:
    pc.set_facecolor('#D43F3A')
    pc.set_edgecolor('black')
    pc.set_alpha(1)
quartile1, medians, quartile3 = np.percentile(weighted_elongT_list[1], [25, 50, 75])
ax1.scatter(3.0, np.mean(weighted_elongT_list[1]), marker='o', color='white', s=30, zorder=3)
ax1.vlines(3.0, quartile1, quartile3, color='k', linestyle='-', lw=5)
ax1.vlines(3.0, min(weighted_elongT_list[1]), max(weighted_elongT_list[1]), color='k', linestyle='-', lw=1)
print(np.median(weighted_elongT_list[1]))


ax1.set_ylim(0,500)
    
plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [55.940590658571374, 48.80304355057803]
# [3.9388306646669826, 6.96364190250605]
# [52.0017599939044, 41.83940164807198]
# 31.0589
# 27.3994

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax,ax1] = plt.subplots(1,2,figsize=(10,5))

ax.set_xlabel("Reaction time (ms)",fontsize=20)
ax.set_ylabel("Transport time (ms)",fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel("Growth rate ($hr^{-1}$)",fontsize=20)
ax1.set_ylabel("Elongation time (ms)",fontsize=20)
ax1.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)

####Draw experimental line for Elong time vs. growth rate###
#t = ax1.text(0.3, 0.06, 'Experimental time', style='italic', transform=ax1.transAxes, fontsize=12,color='darkorange', rotation = -3.5)
#t.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='white'))


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['deepskyblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].elongT),int(len(gr[gr_i][i].elongT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)
        #print(np.average(rxn_vals),np.average(transport_vals))
        weighted_elongT_data = np.append(weighted_elongT_data,np.array(gr[gr_i][i].elongT)[sample_i]*1000)
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_elongT_list.append(weighted_elongT_data)
#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='deepskyblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=12)

ax.set_xlim(0,100)
ax.set_ylim(0,500)
#############################################################################


ax1.plot([0.6,3.0],[(83-42),59-42],color='green',linewidth=3,linestyle='--')
ax1.boxplot(weighted_elongT_list,positions=[1,3],showmeans=True)

print(np.median(weighted_elongT_list[1]))


ax1.set_ylim(0,500)
    
plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [55.88968270285016, 48.79083894768112]
# [3.935213899926066, 6.964298418634795]
# [51.95446880292408, 41.82654052904633]
# 30.8209

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)
for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]
markers = ['*','^']

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += (gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i])/(1-p_codon_count_hist_weighted_avg[0])
        weighted_avg_elongT += weighted_avg_rxnT+weighted_avg_transportT
    
    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT)
    weighted_elongT_list.append(weighted_elongT_data)
    
    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,100)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Discovery time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83-42,83-42],[0,0.5],color='green',linewidth=4)
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)

gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))

ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83-42,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83-42)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax2.set_xlabel("Discovery time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59-42,59-42],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
ax1.scatter(np.mean(weighted_elongT_list[0]),0.2,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.2,s=100,marker=markers[1],color='black',zorder=10)

ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59-42,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59-42)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)


t = ax1.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83-42)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59-42)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)


print(np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[1]))
print(np.mean(weighted_elongT_list[0])/(83-42))
print(np.mean(weighted_elongT_list[1])/(59-42))
#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 69.04352903327127 56.89764692047158
# 1.6839885130066163
# 3.3469204070865635

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax1,ax2,ax]= plt.subplots(1,3,figsize=(25,7))




#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]
markers = ['*','^']

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    transport_vals_list = list()
    reaction_vals_list = list()

    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += (gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i])/(1-p_codon_count_hist_weighted_avg[0])
        weighted_avg_elongT += weighted_avg_rxnT+weighted_avg_transportT
        transport_vals_list.append(np.array(transport_vals[sample_i]))
        reaction_vals_list.append(np.array(rxn_vals[sample_i]))
        
    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT)
    weighted_elongT_list.append(weighted_elongT_data)
    
    ax.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    ax.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    ax.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)
    
    ax1.hist([item for sublist in transport_vals_list for item in sublist],bins=10,range=(0,500),zorder=j,color=colors[j],histtype='step', linewidth=4)
    #ax1.plot([weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],[400,0],linewidth=4,linestyle='dotted',color='white',zorder=10)
    
    ax2.hist([item for sublist in reaction_vals_list for item in sublist],bins=10,range=(0,70),zorder=j,color=colors[j],histtype='step', linewidth=4)#edgecolor='black',alpha=0.5)
    #ax2.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[400,0],linewidth=4,linestyle='dotted',color='white',zorder=10)
    print(weighted_avg_transportT_list[j])
    
#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])

blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

#ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,100)
ax.set_ylim(0,500)

for _,axes in enumerate([ax,ax1,ax2]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=15)
    
ax.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)

ax1.set_xlabel("Transport time (ms)",fontsize=25)
ax1.set_ylabel("Probability",fontsize=25)


ax2.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax2.set_ylabel("Probability",fontsize=25)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 51.95446880292409
# 41.826540529046326
# Text(0, 0.5, 'Probability')

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Reaction time (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)



for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)



#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].elongT),int(len(gr[gr_i][i].elongT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)  
        rxn_vals = np.array([rxn_vals_i+np.random.exponential(42) for rxn_vals_i in rxn_vals])
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])

        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        #weighted_elongT_data = np.append(weighted_elongT_data,np.array(gr[gr_i][i].elongT)[sample_i]*1000)
    
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += np.average(rxn_vals)*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_elongT_list.append(weighted_avg_rxnT_list[-1]+weighted_avg_transportT_list[-1])

    weighted_elongT_list.append(weighted_elongT_data)
    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,500)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Elongation time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83,83],[0,0.5],color='green',linewidth=4)
print(np.mean(weighted_elongT_list[0])/(83))
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)
gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))
ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax1.scatter(np.mean(weighted_elongT_list[0]),0.2,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.2,s=100,marker=markers[1],color='black',zorder=10)

ax2.set_xlabel("Elongation time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59,59],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
print(np.mean(weighted_elongT_list[1])/(59))
ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

t = ax1.text(0.1, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.1, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [90.5130892725943, 82.17859572015111]
# [38.51132927868991, 40.33919407207913]
# [52.0017599939044, 41.83940164807198]
# 1.3250159016442746
# 1.7603746150216393

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Reaction time (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)



for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)



#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].elongT),int(len(gr[gr_i][i].elongT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)  
        rxn_vals = np.array([rxn_vals_i+np.random.exponential(42) for rxn_vals_i in rxn_vals])
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])

        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        #weighted_elongT_data = np.append(weighted_elongT_data,np.array(gr[gr_i][i].elongT)[sample_i]*1000)
    
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_elongT_list.append(weighted_elongT_data)
#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,300)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Elongation time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83,83],[0,0.5],color='green',linewidth=4)
print(np.mean(weighted_elongT_list[0])/(83))
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)
gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))
ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax2.set_xlabel("Elongation time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59,59],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
print(np.mean(weighted_elongT_list[1])/(59))
ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)


#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [55.940590658571374, 48.80304355057803]
# [3.9388306646669826, 6.96364190250605]
# [52.0017599939044, 41.83940164807198]
# 1.2044999781359538
# 1.5399621986595264

# %%
gr3hist[0]/sum(gr3hist[0])
# Out:
# array([0.14643545, 0.17148362, 0.20038536, 0.18882466, 0.0655106 ,
#        0.05780347, 0.04624277, 0.04816956, 0.01348748, 0.01156069,
#        0.01156069, 0.01734104, 0.00385356, 0.00963391, 0.        ,
#        0.00770713, 0.        , 0.        , 0.        , 0.        ])

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr06 = dict()
data = "190404_0410/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr06[i] = (CellLatencies(sim_i))
    
gr30 = dict()
#190419_1747
data = "190422_0042/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30[i] = (CellLatencies(sim_i))
    
gr = {0.6:gr06,3.0:gr30}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# test
# missing expt
# 168
# missing expt
# 176
# missing expt
# 188
# test
# missing expt
# 320
# test
# test
# test
# missing expt
# 838
# missing expt
# 899
# test
# missing expt
# 1
# missing expt
# 60
# missing expt
# 61
# missing expt
# 64
# missing expt
# 96
# test
# test
# test
# test
# test

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)
for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]
markers = ['*','^']

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += (gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i])/(1-p_codon_count_hist_weighted_avg[0])
        weighted_avg_elongT += weighted_avg_rxnT+weighted_avg_transportT
    
    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT)
    weighted_elongT_list.append(weighted_elongT_data)
    
    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,100)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Brownian discovery time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83-42,83-42],[0,0.5],color='green',linewidth=4)
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)

gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))

ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83-42,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83-42)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax2.set_xlabel("Brownian discovery time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59-42,59-42],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
ax1.scatter(np.mean(weighted_elongT_list[0]),0.2,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.2,s=100,marker=markers[1],color='black',zorder=10)

ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59-42,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59-42)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)


t = ax1.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83-42)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59-42)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)


print(np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[1]))
print(np.mean(weighted_elongT_list[0])/(83-42))
print(np.mean(weighted_elongT_list[1])/(59-42))
#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 69.54468543841982 104.94208621006489
# 1.696211839961459
# 6.173063894709699

# %%
#Try bootstrapping results...maybe 100 is enough. See if bootstrapping works.

# Try with normal crowding levels.
# Then boost up crowding for 3.0 until jams?
#try super dilute to get transport limited in a big voxel
#then super crowded in small voxel too to get transport limited
#but, i suspect crowding won't ever slow down transport until gets to exact glass state
#Try a fixed volume with fixed number of ribs and trna, and keep boosting up crowding
#until glass. use small volume so isn't slow sim

##3a -- 1 tRNA show the trans vs. rxn all data spread fig 1 plot. No,
#this should show spread of weigheted; calculate 1,2,3,4,5,6 distrib
#transport for each growth rate as well as rxn? Or just show 1 tRNA...?
##3b -- ^Calculate this for 1,2,3,4,5,6 tRNA for each growth rate,
# and take the codon weighted average, and then plot each 1,2,3,4,5,6 (w/ 1).
#Can plot weighted distribution of elongation times

#can ask labduring lab meeting

# %%
# Topics: line, color, LineCollection, cmap, colorline, codex
# %pylab inline
'''
Defines a function colorline that draws a (multi-)colored 2D line with coordinates x and y.
The color is taken from optional data in z, and creates a LineCollection.

z can be:
- empty, in which case a default coloring will be used based on the position along the input arrays
- a single number, for a uniform color [this can also be accomplished with the usual plt.plot]
- an array of the length of at least the same length as x, to color according to this data
- an array of a smaller length, in which case the colors are repeated along the curve

The function colorline returns the LineCollection created, which can be modified afterwards.

See also: plt.streamplot
'''

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm


# Data manipulation:

def make_segments(x, y):
    '''
    Create list of line segments from x and y coordinates, in the correct format for LineCollection:
    an array of the form   numlines x (points per line) x 2 (x and y) array
    '''

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    
    return segments


# Interface to LineCollection:

def colorline(x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0), linewidth=3, alpha=1.0):
    '''
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    '''
    
    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))
           
    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])
        
    z = np.asarray(z)
    
    segments = make_segments(x, y)
    lc = LineCollection(segments, array=z, cmap=cmap, norm=norm, linewidth=linewidth, alpha=alpha)
    
    ax = plt.gca()
    ax.add_collection(lc)

    
    return lc
        
    
def clear_frame(ax=None): 
    # Taken from a post by Tony S Yu
    if ax is None: 
        ax = plt.gca() 
    ax.xaxis.set_visible(False) 
    ax.yaxis.set_visible(False) 
    for spine in ax.spines.itervalues(): 
        spine.set_visible(False)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/Akshay/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['TU', 'time']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload

transCells = list()
for i in range(1,3):
    sim_i = computeTransportRxnTimes(path+data, simtime, 1000, 400*(i-1),400*i-200,scaling=10)
    transCells.append(CellLatencies(sim_i))
print(transCells[0].avg_elongT)
print(transCells[0].bootavg_elongT)
print(transCells[0].bootstd_elongT)


#Try gr=0.6 and 1 w/ 250 samples
data = "190314_1144/"

no_crowder_times_distrib = list()
no_crowder_times_avg = list()

for i in range(1,3):
    sim_i_results = list()
    sim_i = computeTransportRxnTimes(path+data, simtime, 1000, 400*(i-1),400*i-50,scaling=10)
    sim_i_results.append([i for trans_i in sim_i[0] for i in trans_i])
    sim_i_results.append([i for reac_i in sim_i[1] for i in reac_i])
    sim_i_results.append(np.add(sim_i_results[0],sim_i_results[1]))
    no_crowder_times_distrib.append(sim_i_results)
    no_crowder_times_avg.append([np.average(sim_i_results[0]),np.average(sim_i_results[1]),np.average(sim_i_results[2])])

    #0=rxn distrib, 1=transport distrib, 2=elong time distrib
print([sim[-1] for sim in no_crowder_times_avg])
bootstrapped=list()
for i in range(10000):
    bootstrapped.append(np.average(np.random.choice(no_crowder_times_distrib[0][2],len(no_crowder_times_distrib[0][2]))))
print(np.average(bootstrapped),np.std(bootstrapped))
print(no_crowder_times_avg[0][2])

gr06 = dict()
data = "190314_1808/"
weighted_avg_elongT=0
for i in range(1,4):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-1),200*i,scaling=10)
    gr06[i] = (CellLatencies(sim_i))
    sample_i = np.random.choice(len(gr06[i].rxnT),int(20*p_codon_count_hist_weighted_avg[i]))
    ax.scatter(np.add(np.multiply(gr06[i].rxnT,1000)[sample_i],np.random.exponential(42)),
                np.multiply(gr06[i].transportT,1000)[sample_i],
                color='blue',alpha=(1-0.15*i))
    ax1.scatter(0.6,(gr06[i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42,color='blue',alpha=(1-0.15*i))
    weighted_avg_elongT += gr06[i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]

data = "190314_1850/"
for i in range(4,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 200*(i-4),200*(i-3),scaling=10)
    gr06[i] = (CellLatencies(sim_i))
    sample_i = np.random.choice(len(gr06[i].rxnT),int(20*p_codon_count_hist_weighted_avg[i]))
    ax.scatter(np.add(np.multiply(gr06[i].rxnT,1000)[sample_i],np.random.exponential(42)),
                np.multiply(gr06[i].transportT,1000)[sample_i],
                color='blue',alpha=(1-0.15*i))
    ax1.scatter(0.6,(gr06[i].avg_elongT*1000)/(1-p_codon_count_hist_weighted_avg[0])+42,color='blue',alpha=(1-0.15*i))
    weighted_avg_elongT += gr06[i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
ax1.scatter(0.6,weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0])+42,color='black',alpha=1,linewidth=2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5926d6d3cd85> in <module>
#       7 transCells = list()
#       8 for i in range(1,3):
# ----> 9     sim_i = computeTransportRxnTimes(path+data, simtime, 1000, 400*(i-1),400*i-200,scaling=10)
#      10     transCells.append(CellLatencies(sim_i))
#      11 print(transCells[0].avg_elongT)
#
# NameError: name 'simtime' is not defined

# %%
#190410_1741
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr06 = dict()
data = "190410_1741/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr06[i] = (CellLatencies(sim_i))
    
gr30 = dict()
data = "190410_2006/"
for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=10)
    gr30[i] = (CellLatencies(sim_i))
    
gr = {0.6:gr06,3.0:gr30}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 6
# test
# missing expt
# 238
# missing expt
# 261
# test
# test
# test
# missing expt
# 675
# missing expt
# 676
# test
# test
# missing expt
# 12
# missing expt
# 40
# test
# missing expt
# 229
# test
# test
# test
# test
# missing expt
# 820
# missing expt
# 862

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)

for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)


#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    for i in range(1,7):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_elongT_list.append(weighted_elongT_data)
    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')


alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,100)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Brownian discovery time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83-32,83-32],[0,0.5],color='green',linewidth=4)
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)
gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))
ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83-32,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83-32)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)


ax2 = plt.subplot2grid((2,2),(1,1))

ax1.scatter(np.mean(weighted_elongT_list[0]),0.3,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.3,s=100,marker=markers[1],color='black',zorder=10)

ax2.set_xlabel("Brownian discovery time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59-32,59-32],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)

ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59-32,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59-32)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)



t = ax1.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83-32)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.01, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59-32)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

print(np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[1]))
print(np.mean(weighted_elongT_list[0])/(83-32))
print(np.mean(weighted_elongT_list[1])/(59-32))
#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 36.597697511955325 31.9201381727994
# 0.717601911999124
# 1.1822273397333112

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Reaction time (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)



for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)



#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].elongT),int(len(gr[gr_i][i].elongT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)  
        rxn_vals = np.array([rxn_vals_i+np.random.exponential(32) for rxn_vals_i in rxn_vals])
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])

        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        #weighted_elongT_data = np.append(weighted_elongT_data,np.array(gr[gr_i][i].elongT)[sample_i]*1000)
    
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += np.average(rxn_vals)*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]

    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_elongT_list.append(weighted_elongT_data)
    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15,loc=1)

ax.set_xlim(0,300)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Elongation time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83,83],[0,0.5],color='green',linewidth=4)
print(np.mean(weighted_elongT_list[0])/(83))
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)
gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))
ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax1.scatter(np.mean(weighted_elongT_list[0]),0.2,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.2,s=100,marker=markers[1],color='black',zorder=10)

ax2.set_xlabel("Elongation time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59,59],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
print(np.mean(weighted_elongT_list[1])/(59))
ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

t = ax1.text(0.1, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.1, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [29.757860878155025, 25.40953156591856]
# [32.47057649344176, 34.4759211253657]
# [27.608637253592004, 21.57777318341698]
# 0.8268359167707666
# 1.0412255349527049

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Dropbox/Life/EndyLab/Research/TranslationDynamics/data/"

gr06 = dict()
data = "190711_0056/"
for i in range(1,2):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=100)
    gr06[i] = (CellLatencies(sim_i))
    
gr06_5nm = dict()
data = "190714_1222/"
for i in range(1,2):
    sim_i = computeTransportRxnTimes(path+data, 1000, 1000, 150*(i-1),150*i,scaling=100)
    gr06_5nm[i] = (CellLatencies(sim_i))
    
gr = {0.6:gr06,3.0:gr06_5nm}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# test
# missing expt
# 23
# missing expt
# 58
# test
# missing expt
# 76

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig,[ax1,ax2,ax]= plt.subplots(1,3,figsize=(25,7))




#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]
markers = ['*','^']

weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    transport_vals_list = list()
    reaction_vals_list = list()

    for i in range(1,2):
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)
        transport_vals = (np.multiply(gr[gr_i][i].transportT,1000))/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])
        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        weighted_avg_rxnT += gr[gr_i][i].avg_rxnT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += (gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i])/(1-p_codon_count_hist_weighted_avg[0])
        weighted_avg_elongT += weighted_avg_rxnT+weighted_avg_transportT
        transport_vals_list.append(np.array(transport_vals[sample_i]))
        reaction_vals_list.append(np.array(rxn_vals[sample_i]))
        
    weighted_avg_rxnT_list.append(weighted_avg_rxnT)
    weighted_avg_transportT_list.append(weighted_avg_transportT)
    weighted_elongT_list.append(weighted_elongT_data)
    
    ax.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    ax.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    ax.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)
    
    ax1.hist([item for sublist in transport_vals_list for item in sublist],bins=10,range=(0,500),zorder=j,color=colors[j],alpha=0.1, linewidth=4)
    #ax1.plot([weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],[400,0],linewidth=4,linestyle='dotted',color='white',zorder=10)
    
    ax2.hist([item for sublist in reaction_vals_list for item in sublist],bins=10,range=(0,70),zorder=j,color=colors[j],histtype='step', linewidth=4)#edgecolor='black',alpha=0.5)
    #ax2.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[400,0],linewidth=4,linestyle='dotted',color='white',zorder=10)
    print(weighted_avg_transportT_list[j])
    print(weighted_avg_rxnT_list[j])
    print(weighted_avg_elongT_list[j])
    
#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])

blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

#ax.legend(handles=[blue_patch,red_patch],fontsize=15)

ax.set_xlim(0,100)
ax.set_ylim(0,500)

for _,axes in enumerate([ax,ax1,ax2]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=15)
    
ax.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)

ax1.set_xlabel("Transport time (ms)",fontsize=25)
ax1.set_ylabel("Probability",fontsize=25)


ax2.set_xlabel("Time spent incorrectly bound (ms)",fontsize=25)
ax2.set_ylabel("Probability",fontsize=25)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 39.992424759199906
# 2.6458808798849933
# 92.35087405529006
# 21.715084895720395
# 3.0622593167783356
# 51.38489085255814
# Text(0, 0.5, 'Probability')

# %%
#Figure 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))

from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %matplotlib inline
# %load_ext autoreload
# %autoreload
hfont = {'fontname':'Helvetica'}
####### Draw base contour plot with 2 lines for experimental elongation rate #####
fig = plt.subplots(1,2,figsize=(14,7))


ax = plt.subplot2grid((2,2),(0,0),rowspan=2)

ax.set_xlabel("Reaction time (ms)",fontsize=25)
ax.set_ylabel("Transport time (ms)",fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15)



for k in range(1,10):
    ax.plot([0,100*k],[100*k,0],color='black',linewidth=2,linestyle='dotted',alpha=0.1+0.047*2*k)



#############################################################################

####### transport vs. reaction for different growth rates #####

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,3.0]

weighted_avg_elongT_list=list()
weighted_avg_rxnT_list=list()
weighted_avg_transportT_list=list()
weighted_elongT_list = list()
for j,gr_i in enumerate(gr_i_list):
    weighted_avg_elongT = 0
    weighted_avg_rxnT = 0
    weighted_avg_transportT = 0
    weighted_elongT_data = np.empty([0,0])
    
    for i in range(1,7):
        #sample_i = np.random.choice(len(gr[gr_i][i].elongT),int(len(gr[gr_i][i].elongT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        sample_i = np.random.choice(len(gr[gr_i][i].rxnT),int(len(gr[gr_i][i].rxnT)*(p_codon_count_hist_weighted_avg/max(p_codon_count_hist_weighted_avg))[i]))
        rxn_vals = np.multiply(gr[gr_i][i].rxnT,1000)  
        rxn_vals = np.array([rxn_vals_i+np.random.exponential(32) for rxn_vals_i in rxn_vals])
        transport_vals = np.multiply(gr[gr_i][i].transportT,1000)/(1-p_codon_count_hist_weighted_avg[0])
        weighted_elongT_data = np.append(weighted_elongT_data,rxn_vals[sample_i]+transport_vals[sample_i])

        ax.scatter(rxn_vals,transport_vals,color=colors[j])
        #weighted_elongT_data = np.append(weighted_elongT_data,np.array(gr[gr_i][i].elongT)[sample_i]*1000)
    
        weighted_avg_elongT += gr[gr_i][i].avg_elongT*1000*p_codon_count_hist_weighted_avg[i]
        weighted_avg_rxnT += np.average(rxn_vals)*p_codon_count_hist_weighted_avg[i]
        weighted_avg_transportT  += gr[gr_i][i].avg_transportT*1000*p_codon_count_hist_weighted_avg[i]
        
        

    weighted_avg_elongT_list.append(weighted_avg_elongT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_rxnT_list.append(weighted_avg_rxnT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_avg_transportT_list.append(weighted_avg_transportT/(1-p_codon_count_hist_weighted_avg[0]))
    weighted_elongT_list.append(weighted_elongT_data)
    plt.plot([weighted_avg_rxnT_list[j],weighted_avg_rxnT_list[j]],[0,weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.plot([0,weighted_avg_rxnT_list[j]],[weighted_avg_transportT_list[j],weighted_avg_transportT_list[j]],linewidth=3,linestyle='dotted',color='black',zorder=1)
    plt.scatter(weighted_avg_rxnT_list[j],weighted_avg_transportT_list[j],s=100,marker=markers[j],color='black',zorder=10)


#ax1.plot(gr_i_list,weighted_avg_elongT_list,color='green',alpha=1,linewidth=2,marker='*')

print(weighted_avg_elongT_list)
print(weighted_avg_rxnT_list)
print(weighted_avg_transportT_list)
alpha=np.array([0.25,0.4,0.55,0.7,0.85,1])


blue_patch = mpatches.Patch(color='darkblue', label='Growth rate = 0.6')
red_patch = mpatches.Patch(color='#D43F3A', label='Growth rate = 3.0')

ax.legend(handles=[blue_patch,red_patch],fontsize=15,loc=1)

ax.set_xlim(0,300)
ax.set_ylim(0,500)
#############################################################################

ax1 = plt.subplot2grid((2,2),(0,1))
ax1.set_xlabel("Elongation time (ms)",fontsize=25)
ax1.set_ylabel("",fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.plot([83,83],[0,0.5],color='green',linewidth=4)
print(np.mean(weighted_elongT_list[0])/(83))
ax1.plot([np.mean(weighted_elongT_list[0]),np.mean(weighted_elongT_list[0])],[0,0.5],color='darkblue',linewidth=3,linestyle=':',zorder=6)
gr06hist = np.histogram(weighted_elongT_list[0],bins=20,range=(0,500))
ax1.bar(gr06hist[1][0:-1],gr06hist[0]/sum(gr06hist[0]),align='edge',width=25,color='darkblue')
ax1.fill_between([83,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax1.hist(weighted_elongT_list[0],bins=20,color='skyblue')
ax1.set_xlim(0,500)
ax1.set_ylim(0,0.5)
ax1.set_ylabel('Probability')
t = ax1.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[0]>83)[0])/len(weighted_elongT_list[0])*100))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)

ax2 = plt.subplot2grid((2,2),(1,1))
ax1.scatter(np.mean(weighted_elongT_list[0]),0.2,s=100,marker=markers[0],color='black',zorder=10)
ax2.scatter(np.mean(weighted_elongT_list[1]),0.2,s=100,marker=markers[1],color='black',zorder=10)

ax2.set_xlabel("Elongation time (ms)",fontsize=25)
ax2.set_ylabel("",fontsize=25)
ax2.plot([59,59],[0,0.5],color='green',linewidth=4)
ax2.plot([np.mean(weighted_elongT_list[1]),np.mean(weighted_elongT_list[1])],[0,0.5],color='#D43F3A',linewidth=3,linestyle=':',zorder=6)
print(np.mean(weighted_elongT_list[1])/(59))
ax2.tick_params(axis='both', which='major', labelsize=15)
gr3hist = np.histogram(weighted_elongT_list[1],bins=20,range=(0,500))
ax2.bar(gr3hist[1][0:-1],gr3hist[0]/sum(gr3hist[0]),align='edge',width=25,color='#D43F3A')
ax2.fill_between([59,500],[0],[0.5],color='red',alpha=0.05,zorder=5)
#ax2.hist(weighted_elongT_list[1],bins=20,color='#D43F3A')
ax2.set_xlim(0,500)
ax2.set_ylim(0,0.5)
ax2.set_ylabel('Probability')
t = ax2.text(0.85, 0.85, str(round(len(np.where(weighted_elongT_list[1]>59)[0])/len(weighted_elongT_list[1])*100))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

t = ax1.text(0.1, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[0])/(83)*100)))+'%'
             , transform=ax1.transAxes, fontsize=20,color='red', rotation = 0)
t = ax2.text(0.1, 1.05, 'x'+str(int(round(np.mean(weighted_elongT_list[1])/(59)*100)))+'%'
             , transform=ax2.transAxes, fontsize=20,color='red', rotation = 0)

#(83-42),59-42

plt.tight_layout()

cb.set_label('# cognate tRNA per TU', rotation=-90, labelpad=20,fontsize=15)

#plt.savefig('fig3.pdf', format='pdf', dpi=1000,transparent=True)
# Out:
# <style>.container { width:60% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [92.35087405529006, 51.38489085255814]
# [37.105012922364615, 39.30218055219766]
# [85.81454501046649, 43.98607885321738]
# 1.726886624250926
# 1.5228515895681618
