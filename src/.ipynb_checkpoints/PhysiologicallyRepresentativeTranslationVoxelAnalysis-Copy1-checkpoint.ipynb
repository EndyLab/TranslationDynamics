# %% [markdown]
# ## Calculate cognate ternary complex distribution for a given tRNA and codon distribution (i.e., at a given growth rate)

# %%
from analysis_utils import *
import numpy as np
# %load_ext autoreload
import pandas as pd
ptRNA = pd.read_excel('tRNAValues.xlsx',header=None)
gr04_ptRNA=ptRNA[0]
gr07_ptRNA=ptRNA[1]
gr107_ptRNA=ptRNA[2]
gr16_ptRNA=ptRNA[3]
gr25_ptRNA=ptRNA[4]

pCodon = pd.read_excel('codonValues.xlsx',header=None)
gr04_pCodon = pCodon[0]
gr07_pCodon = pCodon[1]
gr107_pCodon = pCodon[2]
gr16_pCodon = pCodon[3]
gr25_pCodon = pCodon[4]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Growth rate = 0.6
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"


ribs=[4,8,9,9,8,7]
scalingFactorList = [20,40,50,67,100,200,1000]
rxndiff_list = list()

for i, scalingFactor in enumerate(scalingFactorList):
    print('Starting scaling = ', scalingFactor)
    rxndiff=dict()

    gr_sim = dict()

    data = "191003_2140/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1738/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1817/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1934/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 4,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr07_ptRNA,gr07_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['06'] = transportRxnResults[1:]


    #Growth rate = 1.0
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_0018/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_2012/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_2115/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_2238/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr107_ptRNA,gr107_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['10'] = transportRxnResults[1:]

    #Growth rate = 1.5
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_0104/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_0916/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1041/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1206/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['15'] = transportRxnResults[1:]

    #Growth rate = 2.0
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_1129/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1348/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1428/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1506/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 9,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr16_ptRNA,gr16_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['20'] = transportRxnResults[1:]

    #Growth rate = 2.5
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191004_1217/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1556/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1714/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191106_1757/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 8,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}

    transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['25'] = transportRxnResults[1:]

    #Growth rate = 3.0
    from analysis_utils import *
    path = "/Users/Akshay/Documents/TranslationDynamics/data/"

    gr_sim = dict()

    data = "191003_2210/"
    for i in range(1,7):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_0908/"
    for i in range(7,16):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-6),100*(i-1-6)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_0951/"
    for i in range(16,25):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-15),100*(i-1-15)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))

    data = "191105_1033/"
    for i in range(25,34):
        sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1-24),100*(i-1-24)+100,cogtRNANum=i, ribosomeNum = 7,scaling=scalingFactor)
        gr_sim[i] = (CellLatencies(sim_i))
    gr_dict = {'gr_1':gr_sim}


    transportRxnResults = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)

    search_list = transportRxnResults[0]
    rxndiff['30'] = transportRxnResults[1:]

    rxndiff_list.append(rxndiff)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Starting scaling =  20
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 545
# Computing...
# Computing...
# Computing...
# missing expt
# 804
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 59.14973107130612
# Unweighted search time ( 2  cognate) 24.591094594171786
# Unweighted search time ( 3  cognate) 16.350056595982338
# Unweighted search time ( 4  cognate) 13.532754927813023
# Unweighted search time ( 5  cognate) 12.250894613628198
# Unweighted search time ( 6  cognate) 10.103461016390098
# Unweighted search time ( 7  cognate) 7.226657916240992
# Unweighted search time ( 8  cognate) 6.887248036468527
# Unweighted search time ( 9  cognate) 4.216476475868337
# Unweighted search time ( 10  cognate) 5.159665659340229
# Unweighted search time ( 11  cognate) 4.039914435354562
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [22.643098432590275]  +/-  [1.4083601113572384]
# Reaction time:  [1.321247649039605]  +/-  [0.11485588023363069]
# Search time:  [23.964346081629888]  +/-  [1.4872659615493067]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 218
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 53.52168014651587
# Unweighted search time ( 2  cognate) 27.496234137425617
# Unweighted search time ( 3  cognate) 15.88651399673672
# Unweighted search time ( 4  cognate) 13.436696876830673
# Unweighted search time ( 5  cognate) 9.435118443117108
# Unweighted search time ( 6  cognate) 6.973794609641744
# Unweighted search time ( 7  cognate) 6.243939220977781
# Unweighted search time ( 8  cognate) 4.5522606791717966
# Unweighted search time ( 9  cognate) 4.500854866749664
# Unweighted search time ( 10  cognate) 4.671406667367716
# Unweighted search time ( 11  cognate) 3.289169270268316
# Unweighted search time ( 12  cognate) nan
# Unweighted search time ( 13  cognate) nan
# Unweighted search time ( 14  cognate) nan
# Unweighted search time ( 15  cognate) nan
# Unweighted search time ( 16  cognate) nan
# Unweighted search time ( 17  cognate) nan
# Unweighted search time ( 18  cognate) nan
# Unweighted search time ( 19  cognate) nan
# Unweighted search time ( 20  cognate) nan
# Unweighted search time ( 21  cognate) nan
# Unweighted search time ( 22  cognate) nan
# Unweighted search time ( 23  cognate) nan
# Unweighted search time ( 24  cognate) nan
# Unweighted search time ( 25  cognate) nan
# Unweighted search time ( 26  cognate) nan
# Unweighted search time ( 27  cognate) nan
# Unweighted search time ( 28  cognate) nan
# Unweighted search time ( 29  cognate) nan
# Unweighted search time ( 30  cognate) nan
# Unweighted search time ( 31  cognate) nan
# Unweighted search time ( 32  cognate) nan
# Unweighted search time ( 33  cognate) nan
# Transport time:  [20.208097500827396]  +/-  [1.5751390507265024]
# Reaction time:  [2.795698625157086]  +/-  [0.23639393175927753]
# Search time:  [23.00379612598448]  +/-  [1.7881791555331532]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 830
# Computing...
# Computing...
# missing expt
# 116
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# missing expt
# 728
# missing expt
# 792
# Computing...
# Unweighted search time ( 1  cognate)
[2.2386101308085737]), '30': ([25.9496821378538], [3.2106013780697], [29.1602835159235], [1.6090988858610151], [0.2621718489644068], [1.8433432887692769])}, {'06': ([113.21514216666425], [6.606238245198027], [119.8213804118623], [7.041781034760728], [0.5742794011681536], [7.436310227653072]), '10': ([101.03999820322055], [13.97849312578543], [115.018491329006], [7.875661221735653], [1.1819696587963875], [8.940861607000913]), '15': ([69.256099685858], [11.300759867204867], [80.55685955306286], [4.661186677937321], [0.8512456553434327], [5.418882036892061]), '20': ([51.666752053314795], [8.412717853062475], [60.079469906377255], [3.27705916826681], [0.6128140799059514], [3.832034929381465]), '25': ([47.52175454275143], [6.625660345231189], [54.14741488798262], [2.9471571320271974], [0.4406313983222758], [3.3412072827126296]), '30': ...

# %%
### Plotting Figure 6 ###
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %matplotlib inline
# %load_ext autoreload
# %autoreload
#hfont = {'fontname':'Arial'}

colors = ['darkblue','#D43F3A']
gr_i_list = [0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])
markers = ['*','^']

fig,[[ax1,ax2],[ax3,ax4]]= plt.subplots(2,2,figsize=(16,16))


###Plot Elongation latency (Subplot 1) ######

# Plot elongation latency predicted by our simulation 
#ax1.scatter(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')

#for _,rxndiff in enumerate(rxndiff_list[4:6]):

rxndiff = rxndiff_list[3]
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=0,elinewidth=2,color='black')
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
     
rxndiff = rxndiff_list[5]
ax1.errorbar(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][5][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=0,elinewidth=2,color='black')
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i_2 = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i_2,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i,y_hat_sweep_i, y_hat_sweep_i_2, color = 'gray',alpha=0.1)


#ax1.fill_between(phi_list,[rxndiff_list[4][d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],
#                 [rxndiff_list[5][d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff], color = 'gray',alpha=0.1)

ax1.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')
ax1.set_ylabel('Elongation latency (ms)',fontsize=30)
#ax1.set_yscale('log')

#Plot experimental measurements of elongation latency from literature
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/12,1000/15,1000/18,1000/19,1000/20,1000/21],2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax1.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax1.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)

#Output predicted and empirical values
print('\nElongation latencies: \n', [rxndiff[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print([rxndiff[d][5][0] for d in rxndiff])
experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of elongation latency: ',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



####### Plot Transport latency (Subplot 2) #####

#Plot transport latency predicted by our simulation
#ax2.scatter(phi_list,[rxndiff[d][0][0] for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax2.errorbar(phi_list,[rxndiff[d][0][0] for d in rxndiff],[rxndiff[d][3][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax2.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')
ax2.set_ylabel('Transport latency (ms)',fontsize=30)
ax2.set_yticks(np.arange(0, 226, 25))

#Plot inferred experimental values of transport latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,np.subtract([1000/12,1000/16,1000/18,1000/19,1000/20,1000/21],(1000/1475+1000/1529+1000/209+1000/200+1000/32)),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax2.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax2.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')
exptl_trans = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nTransport latencies: \n',[rxndiff[d][0][0] for d in rxndiff])
print('\n\nTransport latency SEM: \n', [rxndiff[d][3][0] for d in rxndiff])
experimental_vals = [y_hat_sweep_i[0],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of transport latency', experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0],rxndiff['30'][0][0]],experimental_vals))


### Plot Reaction latency (Subplot 3) ###

#Plot reaction latency predicted by our simulation
#ax3.scatter(phi_list,[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],zorder=2,s=250,marker='o',color='black')
ax3.errorbar(phi_list,[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff],[rxndiff[d][4][0] for d in rxndiff],marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='black')
ax3.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')
ax3.set_ylabel('Reaction latency (ms)',fontsize=30)

#Plot inferred experimental values of reaction latency (using data from literature)
y_model,SS_err,_,_,_ = np.polyfit(phi_list,[1000/1475+1000/1529+1000/209+1000/200+1000/32]*len(phi_list),2,full=True)
y_hat = np.polyval(y_model,phi_list)
x_sweep_i = np.linspace(min(phi_list),max(phi_list),1000)
y_hat_sweep_i = np.polyval(y_model, x_sweep_i)
ax3.plot(x_sweep_i,y_hat_sweep_i,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black')
ax3.fill_between(x_sweep_i, y_hat_sweep_i, 0*y_hat_sweep_i, color='green',alpha=0.3)
exptl_rxn = y_hat_sweep_i

#Output predicted and empirical values
print('\n\nReaction latencies: \n',[rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
print('\n\nReaction latency SEM: \n',[rxndiff[d][4][0] for d in rxndiff])

experimental_vals= [y_hat_sweep_i[0],y_hat_sweep_i[-1],y_hat_sweep_i[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of reaction latency',experimental_vals)
print('\tPredicted/Experimental: ', np.divide([rxndiff['06'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32),rxndiff['10'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32),rxndiff['30'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)],experimental_vals))



##### Plot Da (Subplot 4) ######

##Plot Damkohler number predicted by our simulation
bmTrans = np.array([rxndiff[d][0][0] for d in rxndiff])
bmRxn = np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
bmTransSEM = np.array([rxndiff[d][3][0] for d in rxndiff])
bmRxnSEM = np.array([rxndiff[d][4][0] for d in rxndiff])
bm_Da_var = (bmTrans**2/bmRxn**2)*(bmTransSEM**2/bmTrans**2+bmRxnSEM**2/bmRxn**2)
print(bm_Da_var)
#ax4.scatter(phi_list, np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),zorder=2,s=250,marker='o',color='lightgray')
ax4.errorbar(phi_list,np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]),bm_Da_var,marker='o',markersize=12,markeredgewidth=5,zorder=1,linewidth=4,elinewidth=2,linestyle='dashed',color='lightgray')
ax4.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=30,color='black')

ax4.set_ylabel('Da',fontsize=30)

## Plot pre-load Da
preload_trans = np.array([33.74284457225605, 30.79535421491456, 28.41837423120376, 28.41837423120376, 29.880803131700848, 30.348156273430067]  )
preload_rxn =  np.array([3.4728765998532096, 7.223193723596804, 7.698872192697686, 7.698872192697686, 7.028604657612665, 5.981192103230661] )
#ax4.scatter(phi_list, preload_trans/(preload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='^',color='#0683b4')
ax4.errorbar(phi_list, preload_trans/(preload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),0,marker='^',markersize=12,markeredgewidth=5,zorder=2,linewidth=4,elinewidth=2,linestyle='dashed',color='#0683b4')

### Plot pre-sort+pre-load Da
presortpreload_trans=np.array([33.74284457225605,20.687161489577235,11.799669483397304,8.526157833741172, 6.793431015552404,  4.365653617395993 ])
presortpreload_rxn = np.array([3.4728765998532096 ,3.7044491956164287,2.0154935837434715 ,1.4734473402223076,1.197461275409742,0.995607322412692])
#ax4.scatter(phi_list, presortpreload_trans /(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),zorder=2,s=250,marker='s',color='#bf7200')
ax4.errorbar(phi_list, presortpreload_trans/(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),0,marker='s',markersize=12,markeredgewidth=5,zorder=2,linewidth=4,elinewidth=2,linestyle='dashed',color='#bf7200')


#Plot inferred experimental values of Damkohler number (using data from literature)
ax4.plot(x_sweep_i,exptl_trans/exptl_rxn,marker='o',markersize=0,markeredgewidth=5,markevery=199,linewidth=4,color='black',label='Empirical bulk elongation')
ax4.fill_between(x_sweep_i, exptl_trans/exptl_rxn, 0*y_hat_sweep_i,edgecolor='black',alpha=0.3,facecolor='green')

#Output predicted and empirical values
print('\n\nDamkohler number BM-only: \n',np.array([rxndiff[d][0][0] for d in rxndiff])/np.array([rxndiff[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff]))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([rxndiff['06'][0][0]/(rxndiff['06'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),rxndiff['30'][0][0]/(rxndiff['30'][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32))],experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload: \n',preload_trans/(preload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide(np.array( [34.01663109406401, 30.805382022214264] 
)/(np.array([3.537059926602166,  6.120797969362092] 
)+(1000/1475+1000/1529+1000/209+1000/200+1000/32)),experimental_vals))

#Output predicted and empirical values
print('\n\nDamkohler number preload-presort: \n',presortpreload_trans/(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32)))
experimental_vals= [exptl_trans[0]/exptl_rxn[0],exptl_trans[-1]/exptl_rxn[-1]]
print('\n\tFor lowest and highest growth rates:')
print('\tExperimentally predicted values of Da',experimental_vals)
print('\tPredicted/Experimental: ',np.divide([presortpreload_trans/(presortpreload_rxn+(1000/1475+1000/1529+1000/209+1000/200+1000/32))][0],experimental_vals[0]))

##Gap in time
print('\nGap in time: ',np.array([1000/12,1000/15,1000/18,1000/19,1000/20,1000/21])-(1000/1475+1000/1529+1000/209+1000/200+1000/32))

####Plot building/Axis labeling####
for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)
    axes.set_xlim(0.11,0.44)
    
    ax1 = axes.twiny()
    ax1.set_xlim(0.11,0.44)
    ax1.tick_params(axis='both', which='major',width=4, labelsize=20)
    ax1.set_xticks(phi_list)
    ax1.set_xlabel('Growth rate (dbl/hr)',size=30,color='black',labelpad=20)
    labels = [item.get_text() for item in ax1.get_xticklabels()]
    labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
    ax1.set_xticklabels(labels)


plt.tight_layout(pad=4.0)
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Elongation latencies:
#  [282.009350658319, 272.4035376664492, 203.48029910688797, 162.52554150786938, 150.6614444843504, 129.41221956542466]
# [14.872615560285396, 17.881714671340482, 10.837757954735789, 7.66406537053053, 6.682410773331049, 5.5025122336669625]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of elongation latency:  [83.2585613612184, 48.3136725138132]
# 	Predicted/Experimental:  [3.38715138 2.67858378]
#
#
# Transport latencies:
#  [226.43019683425672, 202.07987408121204, 138.51210203881197, 103.3334284680782, 95.04344646022177, 77.46165752110258]
#
#
# Transport latency SEM:
#  [14.083557189017899, 15.751313935502791, 9.322367276336859, 6.554113885418624, 5.894310486864056, 4.803275225216275]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of transport latency [40.07877578193747, 6.704167321138343]
# 	Predicted/Experimental:  [ 5.64962857 11.55425481]
#
#
# Reaction latencies:
#  [55.57915382406233, 70.32366358523714, 64.96819706807601, 59.192113039791224, 55.61799802412865, 51.9505620443221]
#
#
# Reaction latency SEM:
#  [1.1485588023363071, 2.363939317592775, 1.7024913106868653, 1.2256281598119028, 0.8812627966445516, 0.7826025342221099]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of reaction latency [42.36667733366628, 42.36667733366625, 42.36667733366625]
# 	Predicted/Experimental:  [1.31186011 1.65988149 1.2262128 ]
# [0.07129779 0.05949911 0.02371108 0.01356688 0.01196459 0.00905313]
#
#
# Damkohler number BM-only:
#  [4.07401303 2.87356864 2.13199855 1.74572968 1.70886134 1.49106486]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9459976166242626, 0.15824151769888603]
# 	Predicted/Experimental:  [4.30657853 9.42271587]
#
#
# Damkohler number preload:
#  [0.73610761 0.62100089 0.56762334 0.56762334 0.60493233 0.62770411]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9459976166242626, 0.15824151769888603]
# 	Predicted/Experimental:  [0.78334525 4.01491715]
#
#
# Damkohler number preload-presort:
#  [0.73610761 0.4490266  0.26586508 0.19448297 0.1559409  0.10067859]
#
# 	For lowest and highest growth rates:
# 	Experimentally predicted values of Da [0.9459976166242626, 0.15824151769888603]
# 	Predicted/Experimental:  [0.7781284  0.47465934 0.28104202 0.20558506 0.16484281 0.10642584]
#
# Gap in time:  [40.966656   24.29998933 13.18887822 10.26490161  7.63332267  5.25237029]

# %%
trans_std = np.array([rxndiff[d][3][0] for d in rxndiff])
rxn_std = np.array([rxndiff[d][4][0] for d in rxndiff])
trans_mean = np.array([rxndiff[d][0][0] for d in rxndiff])
rxn_mean = np.array([rxndiff[d][1][0]+(1000/1529+1000/209+1000/200+1000/32) for d in rxndiff])
(trans_std**2)/(rxn_std)**2-(trans_mean*rxn_mean)**2
# Out:
# array([-77040162.87010546, -93142106.17532182, -37382949.01491204,
#        -16506994.64600998, -13184403.81670385,  -7476241.68346991])

# %% [markdown]
# ## Plot Kinetic Scaling Data

# %%
from analysis_utils import *
# %load_ext autoreload
# %autoreload
path = "/Users/Akshay/Documents/TranslationDynamics/data/"

gr_sim = dict()
rxndiff_1=dict()

data = "200511_1738/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=3000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['3000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2104/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=2000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['2000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2155/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=1000)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['1000'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200511_2229/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=800)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['800'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "200511_2302/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=600)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['600'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "200512_0110/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=400)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['400'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]


data = "191003_2210/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=200)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['200'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_1452/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=100)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['100'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_1716/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=50)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['50'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]

data = "200512_2150/"
gr_sim = dict()

for i in range(1,7):
    sim_i = computeTransportRxnTimes(path+data, 1e15, 1e15, 100*(i-1),100*(i-1)+100,scaling=25)
    gr_sim[i] = (CellLatencies(sim_i))

gr_dict = {'gr_1':gr_sim}
rxndiff_1['25'] = transportRxnCalc(gr_dict,gr25_ptRNA,gr25_pCodon)[1:]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 205.13237429774028
# Unweighted search time ( 2  cognate) 144.59190505119136
# Unweighted search time ( 3  cognate) 81.26668864745206
# Unweighted search time ( 4  cognate) 60.837067379907914
# Unweighted search time ( 5  cognate) 37.67149050362579
# Unweighted search time ( 6  cognate) 33.502621291680235
# Transport time:  [83.00273006465618]  +/-  [5.128892871459936]
# Reaction time:  [14.040431101089634]  +/-  [1.0637191479136798]
# Search time:  [97.04316116574583]  +/-  [6.057245897554654]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 233.0755660515408
# Unweighted search time ( 2  cognate) 112.33663469145259
# Unweighted search time ( 3  cognate) 69.54496412891159
# Unweighted search time ( 4  cognate) 45.11193326985821
# Unweighted search time ( 5  cognate) 36.562188491663214
# Unweighted search time ( 6  cognate) 26.15598344749219
# Transport time:  [79.68907370008289]  +/-  [5.288586018211895]
# Reaction time:  [14.052179742337698]  +/-  [1.034045956262458]
# Search time:  [93.7412534424206]  +/-  [6.1817809266218235]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 201.71869284145254
# Unweighted search time ( 2  cognate) 79.3992234705854
# Unweighted search time ( 3  cognate) 62.15088623842763
# Unweighted search time ( 4  cognate) 43.153371933199715
# Unweighted search time ( 5  cognate) 33.88109420332051
# Unweighted search time ( 6  cognate) 28.767473230605365
# Transport time:  [67.27457178624564]  +/-  [4.599993561645173]
# Reaction time:  [11.30437625870506]  +/-  [0.8536246515953735]
# Search time:  [78.57894804495072]  +/-  [5.381739870068445]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 186.05093489002348
# Unweighted search time ( 2  cognate) 84.18759884945815
# Unweighted search time ( 3  cognate) 67.09328169745778
# Unweighted search time ( 4  cognate) 41.00906763481337
# Unweighted search time ( 5  cognate) 36.881942665968936
# Unweighted search time ( 6  cognate) 24.187734776134423
# Transport time:  [64.88034794902589]  +/-  [4.13846206865662]
# Reaction time:  [11.54351162185677]  +/-  [0.8013880781137824]
# Search time:  [76.42385957088264]  +/-  [4.856999975325134]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 140.34092273218627
# Unweighted search time ( 2  cognate) 71.4931269647863
# Unweighted search time ( 3  cognate) 61.41263142425755
# Unweighted search time ( 4  cognate) 42.054356281571636
# Unweighted search time ( 5  cognate) 31.618682444770453
# Unweighted search time ( 6  cognate) 25.68371328268472
# Transport time:  [53.245746866701346]  +/-  [2.9841791542211227]
# Reaction time:  [9.022442314466183]  +/-  [0.5845183940786575]
# Search time:  [62.26818918116752]  +/-  [3.4913365977507755]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 153.05134811932254
# Unweighted search time ( 2  cognate) 80.83378966411786
# Unweighted search time ( 3  cognate) 65.76581480289174
# Unweighted search time ( 4  cognate) 43.868017340077245
# Unweighted search time ( 5  cognate) 34.62510152287846
# Unweighted search time ( 6  cognate) 26.237783080878017
# Transport time:  [57.796699879006546]  +/-  [3.1113548643705218]
# Reaction time:  [10.268525862814958]  +/-  [0.6738272473431568]
# Search time:  [68.06522574182151]  +/-  [3.6792778398765993]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 145.7835388506996
# Unweighted search time ( 2  cognate) 73.66729336133365
# Unweighted search time ( 3  cognate) 57.147918956792
# Unweighted search time ( 4  cognate) 36.894644278725536
# Unweighted search time ( 5  cognate) 28.287419667432513
# Unweighted search time ( 6  cognate) 23.846215413415507
# Transport time:  [53.078347885981785]  +/-  [3.174778624814215]
# Reaction time:  [9.543761303785754]  +/-  [0.782580817628262]
# Search time:  [62.622109189767556]  +/-  [3.874767963679098]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 155.9585584245457
# Unweighted search time ( 2  cognate) 74.57706814501806
# Unweighted search time ( 3  cognate) 45.90484661976368
# Unweighted search time ( 4  cognate) 39.0713670355514
# Unweighted search time ( 5  cognate) 29.824910921935775
# Unweighted search time ( 6  cognate) 27.12861386811932
# Transport time:  [54.53656617829335]  +/-  [3.079233387720272]
# Reaction time:  [9.365624428730007]  +/-  [0.5591931463189325]
# Search time:  [63.90219060702335]  +/-  [3.560505402086046]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 137.7954631293362
# Unweighted search time ( 2  cognate) 68.22435659482457
# Unweighted search time ( 3  cognate) 48.3306528560722
# Unweighted search time ( 4  cognate) 33.17792073371979
# Unweighted search time ( 5  cognate) 30.114715515431673
# Unweighted search time ( 6  cognate) 21.06666306537495
# Transport time:  [49.62137864686682]  +/-  [3.2349270216405617]
# Reaction time:  [8.436754661197039]  +/-  [0.5979095779967646]
# Search time:  [58.05813330806388]  +/-  [3.7716752758913463]
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Unweighted search time ( 1  cognate) 166.89747699513222
# Unweighted search time ( 2  cognate) 69.32718498127191
# Unweighted search time ( 3  cognate) 49.793420838312294
# Unweighted search time ( 4  cognate) 34.726101161899535
# Unweighted search time ( 5  cognate) 27.608604497971367
# Unweighted search time ( 6  cognate) 23.13243676407771
# Transport time:  [55.58753070188524]  +/-  [3.399382954249518]
# Reaction time:  [9.769813128223051]  +/-  [0.6807903429115956]
# Search time:  [65.35734383010829]  +/-  [4.0037043216476835]

# %%
import matplotlib.pyplot as plt

fig, [ax1,ax2,ax3,ax4] = plt.subplots(1,4,figsize=(27,6))
x=[3000,2000,1000,800,600,400,200,100,50,25]

ax1.scatter(x,[rxndiff_1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],zorder=2,s=250,color='black')
ax1.errorbar(x,[rxndiff_1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],[rxndiff_1[d][5][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][2][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32) for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax1.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax1.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax1.set_ylabel('Elongation latency (ms)',size=25,color='black')
ax1.set_xscale('log')
ax1.set_xticks((10,100,1000))


ax2.scatter(x,[rxndiff_1[d][0][0] for d in rxndiff_1],zorder=2,s=250,color='black')
ax2.errorbar(x,[rxndiff_1[d][0][0] for d in rxndiff_1],[rxndiff_1[d][3][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][0][0] for d in rxndiff_1],3)
trendpoly=np.poly1d(y_model)
ax2.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax2.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax2.set_ylabel('Transport latency (ms)',size=25,color='black')
ax2.set_xscale('log')
ax2.set_xticks((10,100,1000))


ax3.scatter(x,[rxndiff_1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],zorder=2,s=250,color='black')
ax3.errorbar(x,[rxndiff_1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],[rxndiff_1[d][4][0] for d in rxndiff_1],zorder=1,linewidth=0,elinewidth=2,linestyle='dashed',color='black')
y_model= np.polyfit(x,[rxndiff_1[d][1][0]+(1000/1475+1000/1529+1000/209+1000/200+1000/32)  for d in rxndiff_1],2)
trendpoly=np.poly1d(y_model)
ax3.plot(np.linspace(3000, 0, 100),trendpoly(np.linspace(3000, 0, 100)),zorder=1,linewidth=4,linestyle='dashed',color='black')
ax3.set_xlabel('Kinetic rate scaling',size=25,color='black')
ax3.set_ylabel('Reaction latency (ms)',size=25,color='black')
ax3.set_xscale('log')
ax3.set_xticks((10,100,1000))

#######################
voxlen = 0.0677
D = 56*0.284
mixTime = []
t1 = 1/717
scalingTime = []
scaling = np.arange(0,3000,1)

for i in scaling:
    scalingTime.append(t1/i*1e3)
    mixTime.append((0.012)**2/(6*D)*1e3)
    
ax4.plot(scaling,mixTime,'grey',linewidth=4,linestyle='dashed',color='black')
ax4.plot(scaling,scalingTime,'black',linewidth=4)
ax4.set_yscale('log')
ax4.set_xlim(0,3000)
ax4.set_xlabel('Kinetic rate scaling',size=25)
ax4.set_ylabel('Time (ms)',size=25)

print(scalingTime[925:950])
#######################

for _,axes in enumerate([ax1,ax2,ax3,ax4]):
    axes.tick_params(axis='both', which='major',width=4, labelsize=30)
    axes.spines['left'].set_linewidth(4)
    axes.spines['bottom'].set_linewidth(4)
    axes.spines['top'].set_linewidth(4)
    axes.spines['right'].set_linewidth(4)
    axes.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout(pad=3.0)
# Out:
# /Users/akshay/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:47: RuntimeWarning: divide by zero encountered in true_divide
# [0.0015077839345621772, 0.001506155658174961, 0.001504530894789659, 0.001502909633049584, 0.0015012918616469472, 0.0014996775693225956, 0.0014980667448657506, 0.0014964593771137488, 0.0014948554549517835, 0.0014932549673126487, 0.0014916579031764854, 0.0014900642515705276, 0.0014884740015688514, 0.0014868871422921257, 0.001485303662907363, 0.0014837235526276745, 0.001482146800712023, 0.0014805733964649828, 0.001479003329236494, 0.0014774365884216247, 0.0014758731634603322, 0.001474313043837224, 0.001472756219081324, 0.0014712026787658374, 0.0014696524125079177]

# %% [markdown]
# ## Plot MSD

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "190927_0408/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'
time = 6.21607E-07


plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+'190930_1418/',0,20,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

#for i in range(len(slopes)):
#    plt.text(0.3,-0.3,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
#    plt.text(0.32,-0.38-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
#    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
#print(diff_list)

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn',size=30,pad=20)
# Out:
# [55.134, 34.82, 25.175, 20.8, 17.342, 16.581, 15.932]
# Text(0.5, 1.0, 'Smoldyn')

# %%
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "20200511_LAMMPS_MSD/" 
slopes = list()

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

length = 0.0059**2
time = 6.21607E-07
res_steps=1

df_outputs = pd.read_csv(path+data+"MSD_dil.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_06_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_10_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='purple',label="gr=1.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_15_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='blue',label="gr=1.5",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_20_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='red',label="gr=2.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_25_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='brown',label="gr=2.5",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])

df_outputs = pd.read_csv(path+data+"MSD_gr_30_.csv",header=None)
ax.plot(df_outputs[0]*time,df_outputs[2]*length,color='orange',label="gr=3.0",linewidth=3)
slopes.append(np.linalg.lstsq((df_outputs[0]*time)[:,np.newaxis],df_outputs[2]*length,rcond=None)[0][0])


leg = ax.legend(fontsize=15)

ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+'0.0',color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('LAMMPS',size=30,pad=20)
# Out:
# [55.998, 32.721, 25.06, 19.769, 17.368, 15.415, 14.977]
# Text(0.5, 1.0, 'LAMMPS')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "200523_2242/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+'190930_1418/',0,20,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])

ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn (no crowders)',size=30,pad=20)
# Out:
# [55.134, 51.426, 47.636, 40.991, 38.963, 34.479, 31.233]
# Text(0.5, 1.0, 'Smoldyn (no crowders)')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "200524_1247/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=1
k=0
start=0
end=-1
species = 'tRNA'

plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['green','purple','blue','red','brown','orange']

#MSD_vals=MSD(path+'190930_1418/',0,20,species)
#ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='black',label="Dilute limit",linewidth=3)
#slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
#slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k,k+n,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals = MSD(path+data,k+n,k+2*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps*1),MSD_vals[1][start:end],color='purple',label="gr=1.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+2*n,k+3*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='blue',label="gr=1.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+3*n,k+4*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='red',label="gr=2.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+4*n,k+5*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='brown',label="gr=2.5",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

MSD_vals=MSD(path+data,k+5*n,k+6*n,species)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='orange',label="gr=3.0",linewidth=3)
slope_sems.append(MSD_noise(MSD_vals))

leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)
ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn (No overlap resolution)',size=30,pad=20)
# Out:
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# Error (e.g., Missing expt or incorrect input)
# [31.931, 25.412, 21.14, 19.246, 18.604, 17.75]
# Text(0.5, 1.0, 'Smoldyn (No overlap resolution)')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import linregress

# %matplotlib inline
def MSD(path,expt_start,expt_end,moltype=''):
    df_outputs = pd.read_csv(path+"outputMolPosList.txt",sep=" ",header=None) #Add batch processing here potentially
    if moltype=="ribosome":
         df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposRibosome')
    if moltype=="tRNA":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolpostRNA')
    if moltype=="crowder":
        df_outputs = df_outputs.iloc[:,0].str.replace('MolpostRNA' , 'MolposCrowder')
    r2_lists=list()
    for expt_num, row in enumerate(df_outputs):
        if(expt_num>=expt_start and expt_num<expt_end):
            try:
                df = pd.read_csv(path+row,delimiter=" ",header=None)
                params = pd.read_csv(path+"expt_"+str(expt_num)+'.txt',delim_whitespace=True,names=['var','param','val'])
                molposTS = float(params.loc[params['param']=='Z_molPosTS_']['val'].values[0])
                df.columns=["time","r2","r4"]
                r2_lists.append(np.array(df['r2'].tolist()))
            except:
                print("Error (e.g., Missing expt or incorrect input)")
    return np.array(r2_lists)*0.0059**2,np.add.reduce(r2_lists)/(len(r2_lists))*0.0059**2,np.arange(0,len(np.add.reduce(r2_lists)/(len(r2_lists))))*molposTS*6.21607E-07

def MSD_noise(MSD_vals):
    MSD_list = list()
    for sim in MSD_vals[0]:
        MSD_list.append(linregress(MSD_vals[2][0:-1],sim[0:-1])[0]/2)
    #N = 1000
    #bootstrap_MSD=list()
    #for i in range(N):
    #    bootstrap_MSD.append(np.average((np.random.choice(MSD_list,len(MSD_list)))))        
    return np.std(MSD_list/np.sqrt(len(MSD_list)))
#crowder,ribosome,tRNA
path='/Users/Akshay/Documents/TranslationDynamics/data/'
data = "190927_0408/" 
n = 10
slopes = list()
slope_sems = list()
res_steps=3
k=0
start=0
end=-1
species = 'tRNA'
time = 6.21607E-07


plt.rc('mathtext', fontset="cm")
fig,ax=plt.subplots(1,1,figsize=(7,6))
colors = ['black','green','purple','blue','red','brown','orange']

MSD_vals=MSD(path+data,10,11,species)
ax.plot(MSD_vals[2][start:end]/(res_steps),MSD_vals[1][start:end],color='green',label="gr=0.6",linewidth=3)
slopes.append(np.linalg.lstsq(MSD_vals[2][start:end][:,np.newaxis],MSD_vals[1][start:end],rcond=None)[0][0])
slope_sems.append(MSD_noise(MSD_vals))


leg = ax.legend(fontsize=15)


ax.set_xlabel("Time (s)",size=30,labelpad=10)
ax.set_ylabel(r"MSD ($\mu^2$)",size=30,labelpad=10)

diff_list = list()
gr_list = [0,0.6,1.0,1.5,2.0,2.5,3.0]
phi_list = [0,0.132,0.224,0.302,0.356,0.395,0.423]

#for i in range(len(slopes)):
#    plt.text(0.3,-0.3,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
#    plt.text(0.32,-0.38-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
#    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
#print(diff_list)

for i in range(len(slopes)):
    plt.text(1.02,0.93,r"Diffusivity ($\mu^2/s$)",color='black',transform=plt.gca().transAxes,fontsize=20)
    plt.text(1.04,0.85-0.07*i,str(np.round(np.array(slopes)*res_steps/6,1)[i])+' +/- '+str(np.round(slope_sems[i],1)),color=colors[i],transform=plt.gca().transAxes,fontsize=20)
    diff_list.append(np.round(np.array(slopes)*res_steps/6,3)[i])
print(diff_list)

ax.set_xticklabels([0,0.0001,0.0002,0.0003])


ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(0,500*time)
ax.set_ylim(0,0.10)
ax.set_title('Smoldyn',size=30,pad=20)
# Out:
