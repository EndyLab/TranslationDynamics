# %% [markdown]
# ## Calculate the distribution of cognate ternary complexes per translation voxel, accounting for non-uniform tRNA and codons

# %%
import pandas as pd
import numpy as np
WS = pd.read_excel('tRNAValues.xlsx',header=None)
WS_np = np.array(WS)
gr04=WS[0]
gr07=WS[1]
gr107=WS[2]
gr16=WS[3]
gr25=WS[4]

COD = pd.read_excel('codonValues.xlsx',header=None)
gr04_cod = COD[0]
gr07_cod = COD[1]
gr107_cod = COD[2]
gr16_cod = COD[3]
gr25_cod = COD[4]

cod_labels = COD[5]

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr04
pCodon = gr04_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"0.4 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

fig,ax=plt.subplots(1,1,figsize=(2.5,2.5))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9661884554447484
# [2.34429774e-01 2.54734815e-01 1.93231967e-01 1.35190716e-01
#  8.36953643e-02 4.40683030e-02 2.08375153e-02 7.64602151e-03
#  2.63719298e-03 8.24779028e-04 2.32857032e-04 6.30491633e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8119837804680172
# 0.9661884554447484
# [2.34429774e-01 2.54734815e-01 1.93231967e-01 1.35190716e-01
#  8.36953643e-02 4.40683030e-02 2.08375153e-02 7.64602151e-03
#  2.63719298e-03 8.24779028e-04 2.32857032e-04 6.30491633e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8119837804680172
# ([<matplotlib.axis.XTick at 0x7f86b816d510>,
#   <matplotlib.axis.XTick at 0x7f86b8166c10>,
#   <matplotlib.axis.XTick at 0x7f86b8166ad0>,
#   <matplotlib.axis.XTick at 0x7f86d9213790>,
#   <matplotlib.axis.XTick at 0x7f86d921d190>,
#   <matplotlib.axis.XTick at 0x7f86b8189d10>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr07
pCodon = gr07_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"0.7 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

fig,ax=plt.subplots(1,1,figsize=(2.5,2.5))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))

#plt.savefig('fig.jpg', bbox_inches = "tight")
# Out:
# 0.9653460028040975
# [2.29850927e-01 2.50518210e-01 1.94323987e-01 1.37383678e-01
#  8.84858652e-02 4.43914545e-02 2.03918821e-02 8.41485134e-03
#  2.76151291e-03 8.20794428e-04 1.48980982e-04 6.30604795e-05
#  1.86398933e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8403596082122702
# 0.9653460028040975
# [2.29850927e-01 2.50518210e-01 1.94323987e-01 1.37383678e-01
#  8.84858652e-02 4.43914545e-02 2.03918821e-02 8.41485134e-03
#  2.76151291e-03 8.20794428e-04 1.48980982e-04 6.30604795e-05
#  1.86398933e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.8403596082122702
# ([<matplotlib.axis.XTick at 0x7f86a820d510>,
#   <matplotlib.axis.XTick at 0x7f86a8237090>,
#   <matplotlib.axis.XTick at 0x7f86a8237a90>,
#   <matplotlib.axis.XTick at 0x7f86b83fcc90>,
#   <matplotlib.axis.XTick at 0x7f86e0524f10>,
#   <matplotlib.axis.XTick at 0x7f86b83fc3d0>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr107
pCodon = gr107_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(24,0.27,"1.07 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

fig,ax=plt.subplots(1,1,figsize=(2.5,2.5))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9651028325702184
# [2.21590455e-01 2.48184025e-01 2.02081288e-01 1.38415742e-01
#  8.74139091e-02 4.52835204e-02 2.21338919e-02 8.38297252e-03
#  3.09583813e-03 7.04768289e-04 1.54078772e-04 1.34911998e-04
#  1.36747509e-05 2.07690290e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.869719760126339
# 0.9651028325702184
# [2.21590455e-01 2.48184025e-01 2.02081288e-01 1.38415742e-01
#  8.74139091e-02 4.52835204e-02 2.21338919e-02 8.38297252e-03
#  3.09583813e-03 7.04768289e-04 1.54078772e-04 1.34911998e-04
#  1.36747509e-05 2.07690290e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.869719760126339
# ([<matplotlib.axis.XTick at 0x7f86b826c610>,
#   <matplotlib.axis.XTick at 0x7f86b826cbd0>,
#   <matplotlib.axis.XTick at 0x7f86b8272250>,
#   <matplotlib.axis.XTick at 0x7f86e050c8d0>,
#   <matplotlib.axis.XTick at 0x7f86e9590490>,
#   <matplotlib.axis.XTick at 0x7f86e9590bd0>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr16
pCodon = gr16_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"1.6 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

fig,ax=plt.subplots(1,1,figsize=(2.5,2.5))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9628198712150067
# [2.20731422e-01 2.40278573e-01 1.94794049e-01 1.42590539e-01
#  8.83109001e-02 5.22105832e-02 2.39038042e-02 9.53572905e-03
#  3.72278157e-03 9.46596775e-04 3.55840143e-04 2.17702547e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.9263624866772766
# 0.9628198712150067
# [2.20731422e-01 2.40278573e-01 1.94794049e-01 1.42590539e-01
#  8.83109001e-02 5.22105832e-02 2.39038042e-02 9.53572905e-03
#  3.72278157e-03 9.46596775e-04 3.55840143e-04 2.17702547e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.9263624866772766
# ([<matplotlib.axis.XTick at 0x7f86e0528090>,
#   <matplotlib.axis.XTick at 0x7f86e0528290>,
#   <matplotlib.axis.XTick at 0x7f86b8399fd0>,
#   <matplotlib.axis.XTick at 0x7f86b828ea50>,
#   <matplotlib.axis.XTick at 0x7f86e935d450>,
#   <matplotlib.axis.XTick at 0x7f86b8253150>],
#  <a list of 6 Text xticklabel objects>)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
# %matplotlib inline

ptRNA = gr25
pCodon = gr25_cod
p_codon_count_hist_weighted_avg=cognateDistrib(ptRNA,pCodon)

fig,ax=plt.subplots(1,1,figsize=(6,6))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,42)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(4)
plt.gca().spines['bottom'].set_linewidth(4)
plt.gca().spines['top'].set_linewidth(4)
plt.gca().spines['right'].set_linewidth(4)
plt.gca().tick_params(axis='both', which='major', labelsize=25)
plt.text(26,0.27,"2.5 dbl/hr",fontsize=25)
plt.xticks(np.arange(0,43,10))

fig,ax=plt.subplots(1,1,figsize=(2.5,2.5))
plt.bar(np.arange(0,42),p_codon_count_hist_weighted_avg,linewidth=4,color='darkblue',align='edge')
#plt.xlabel('# of cognate tRNA per TU',fontsize=25)
#plt.ylabel('Probability',fontsize=25)
plt.ylim(0,0.3)
plt.xlim(0,10)
print(sum(p_codon_count_hist_weighted_avg[0:7]))
print(p_codon_count_hist_weighted_avg)
print(sum(np.multiply(p_codon_count_hist_weighted_avg,np.arange(0,42))))
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(0,11,2))
# Out:
# 0.9628666856311866
# [2.09853191e-01 2.37824403e-01 1.94245140e-01 1.46302043e-01
#  9.54302032e-02 5.26173716e-02 2.65943340e-02 1.06756662e-02
#  3.12002198e-03 1.19774772e-03 2.38003728e-04 7.38855818e-05
#  8.55869675e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.984283877504122
# 0.9628666856311866
# [2.09853191e-01 2.37824403e-01 1.94245140e-01 1.46302043e-01
#  9.54302032e-02 5.26173716e-02 2.65943340e-02 1.06756662e-02
#  3.12002198e-03 1.19774772e-03 2.38003728e-04 7.38855818e-05
#  8.55869675e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# 1.984283877504122
# ([<matplotlib.axis.XTick at 0x7f86c83c0bd0>,
#   <matplotlib.axis.XTick at 0x7f86c83c2450>,
#   <matplotlib.axis.XTick at 0x7f86c83c26d0>,
#   <matplotlib.axis.XTick at 0x7f86b83ce4d0>,
#   <matplotlib.axis.XTick at 0x7f86b8373c10>,
#   <matplotlib.axis.XTick at 0x7f86e96779d0>],
#  <a list of 6 Text xticklabel objects>)

# %%
from matplotlib.font_manager import findfont, FontProperties
font = findfont(FontProperties(family=['sans-serif']))
font
# Out:
# '/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
