# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

crowder_repeatreaction = list()
crowder_repeatreaction_stderr = list()
nocrowder_repeatreaction = list()
nocrowder_repeatreaction_stderr = list()

##### Measurements made from translation voxels with a single cognate ternary complex

##########

data = "191003_2140/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])

data = "191004_0018/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])


data = "191004_0104/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])

data = "191004_1129/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])


data = "191004_1217/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])


data = "191003_2210/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
crowder_repeatreaction.append(sim_i[0])
crowder_repeatreaction_stderr.append(sim_i[1])




###No crowder.

data = "191009_1223/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])


data = "191009_1256/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])


data = "191009_1333/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])

data = "191009_1410/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])

data = "191009_1447/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])

data = "191007_1601/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
nocrowder_repeatreaction.append(sim_i[0])
nocrowder_repeatreaction_stderr.append(sim_i[1])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of analysis_utils failed: Traceback (most recent call last):
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/akshay/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     frame = next(frame_nfo.frame for frame_nfo in inspect.stack()
# StopIteration
# ]
# (9.808988764044944, 0.8040695391832502)
# (5.773139745916516, 0.28012679187989353)
# (4.17339312406577, 0.18255878150007618)
# (2.920656634746922, 0.12601106631062414)
# (2.1863270777479893, 0.0926340578439691)
# (1.8375, 0.09977313423898326)
# (4.793706293706293, 0.31819691743379347)
# (3.1376404494382024, 0.13677663490607622)
# (1.998792270531401, 0.08910697389005746)
# missing expt
# 65
# (1.248968363136176, 0.060060748451209026)
# missing expt
# 90
# (0.9463350785340314, 0.053086410893688415)
# missing expt
# 85
# (0.7840909090909091, 0.0470400417034676)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload
fig, ax = plt.subplots(1,1,figsize=(12,10))
ax2 = ax.twinx()
phi_list = np.array([0.13172292, 0.22350473, 0.30181037, 0.35583449, 0.3945994 ,
       0.42317604])

norm_nearesttRNARib_edgeedge=(np.array([7.36321052937, 5.36100007967, 4.75078286349, 4.47186186636, 4.35073230336, 4.27016077761])-3.2)*5.9
norm_nearesttRNARib_edgeedge_std = np.sqrt((np.array([0.04173045315231537,0.026240150303848235,0.021085308765082404,0.01824045988556131,0.01753975660524464,0.019313940075522597]))**2*5.9**2)
ax.errorbar(phi_list,norm_nearesttRNARib_edgeedge, norm_nearesttRNARib_edgeedge_std,marker='s',markersize=12,markeredgewidth=5,linewidth=4,color='black')
ax.set_ylabel('Nearest ribosome (nm)$\:\u25A0} $',size=40,color='black',labelpad=20)
ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax2.set_xlim(0.11,0.44)
ax2.set_xticks(np.arange(0.15,0.41, 0.05))
ax.set_ylim(4.9,26)


ax.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=40,color='black',labelpad=10)

viscosity = np.array([1.39863657335865,1.83806930502154,2.33803169161992,2.76564578636052,3.15041649073887,3.41838735611281
])/1.39863657335865
ax2.tick_params(axis='both', which='major',width=4, labelsize=30)
ax2.set_ylabel('Viscosity ($\eta_{0}/\eta_{0,\mu=0.6}}$) $\: \u25B2$',size=40,color='black',labelpad=20)
ax2.plot(phi_list,viscosity,marker='^',markersize=12,markeredgewidth=5,linewidth=4,color='black')
ax2.set_ylim(0.9,2.6)
ax2.set_yticks(np.arange(1.0,2.6,0.5))

ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(5)
ax.spines['right'].set_linewidth(5)


ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=30)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=40,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)

plt.tight_layout()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig, ax = plt.subplots(1,1,figsize=(12,10))
ax2 = ax.twinx()

ax2.plot(phi_list,[4-1,8-1,9-1,9-1,8-1,7-1],marker='^',markersize=12,markeredgewidth=5,linewidth=4,color='black')
ax2.set_ylabel('Mismatching ribosomes $(\#) \\: \u25B2$',size=40,color='black',labelpad=20)
ax2.tick_params(axis='both', which='major',width=4, labelsize=30)
ax2.set_xlim(0.11,0.44)
ax2.set_ylim(2.5,8.5)
ax2.set_xticks(np.arange(0.15,0.41,0.05))


ax.errorbar(phi_list,crowder_repeatreaction,
            crowder_repeatreaction_stderr, marker='s',markersize=12,markeredgewidth=5,linewidth=4,color='black')
ax.set_ylabel('Repeat reactions $(\#)\\: \u25A0 $',size=40,color='black',labelpad=20)
ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=40,color='black',labelpad=10)



#0.0322, 0.0909, 0.141, 0.175, 0.200, 0.218

ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(5)
ax.spines['right'].set_linewidth(5)

#ax.set_title('Reaction Time Trade-off',size=45,y=1.05)


ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=30)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=40,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)

plt.tight_layout()

# %%
from analysis_utils import *
from itertools import groupby

# %load_ext autoreload
# %reload_ext autoreload

rib_gr = [4,8,9,9,8,7]
repeatreactions_preload = list()
repeatreactions_preload_stderr=list()
for i in rib_gr:
    results = eventbased_sim(1,1,True, bias=1, repeatTracker=True)
    count_repeats = [sum(1 for _ in group) for _, group in groupby(results[-1])]
    repeatreactions_preload.append(np.average(count_repeats)-1)
    repeatreactions_preload_stderr.append(np.std(count_repeats)/np.sqrt(len(count_repeats)-1))
    print(np.average(count_repeats)-1)
    print(repeatreactions_preload_stderr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.024698437404001794
# [0.0005114224980323537]
# 0.02573220470988491
# [0.0005114224980323537, 0.0005185435887464487]
# 0.025181846122323437
# [0.0005114224980323537, 0.0005185435887464487, 0.0005155236548020789]
# 0.025451004510045117
# [0.0005114224980323537, 0.0005185435887464487, 0.0005155236548020789, 0.000518601643647414]
# 0.024971855490737882
# [0.0005114224980323537, 0.0005185435887464487, 0.0005155236548020789, 0.000518601643647414, 0.0005118303295469088]
# 0.0245699491409217
# [0.0005114224980323537, 0.0005185435887464487, 0.0005155236548020789, 0.000518601643647414, 0.0005118303295469088, 0.0005081729229005247]

# %%
fig, ax = plt.subplots(1,1,figsize=(12,10))

#phi_list = [0.132,0.224,0.302,0.356,0.395,0.423]
gr_list = [0.6,1.0,1.5,2.0,2.5,3.0]
ax.errorbar(phi_list,np.array(crowder_repeatreaction),np.array(crowder_repeatreaction_stderr),marker='o',markersize=12,markeredgewidth=5,linewidth=5,color='black',linestyle='dashed',label='Crowders')
ax.errorbar(phi_list,np.array(nocrowder_repeatreaction),np.array(nocrowder_repeatreaction_stderr),marker='x',markersize=12,markeredgewidth=5,linewidth=5,color='red',linestyle='dashed',label='No Crowders')
ax.errorbar(phi_list,repeatreactions_preload,repeatreactions_preload_stderr,marker='^',markersize=12,markeredgewidth=5,linewidth=5,color='#0683b4',linestyle='dashed',label='Preload')

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.set_ylim(-0.5,11)
ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(5)
ax.spines['right'].set_linewidth(5)

ax.set_xlabel('Voxel volume fraction $(\phi_{\mathrm{vox}})$',size=40,color='black',labelpad=10)
#ax.set_xlabel('$\phi_{\mathrm{voxel}}$',size=45,color='black')
ax.set_ylabel('Repeat Reactions $(\#)$',size=40,color='black')
print(np.array(crowder_repeatreaction),np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)-np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)/np.array(nocrowder_repeatreaction))
ax.set_xlim(0.11,0.44)

ax1 = ax.twiny()
ax1.set_xlim(0.11,0.44)
ax1.tick_params(axis='both', which='major',width=4, labelsize=30)
#ax1.scatter(x_sweep_i,y_hat_sweep_i)
ax1.set_xticks(phi_list)
ax1.set_xlabel('Growth rate ($\mu$, dbl/hr)',size=40,color='black',labelpad=20)
labels = [item.get_text() for item in ax1.get_xticklabels()]
labels = ['0.6','1.0','1.5','2.0','2.5','3.0']
ax1.set_xticklabels(labels)

ax.legend(bbox_to_anchor=(1.05, 1.35), prop={'size': 25},ncol=3)
# Out:
# [10.04069767  5.77313975  4.17339312  2.92065663  2.18632708  1.8375    ] [4.79370629 3.13764045 1.99879227 1.24896836 0.94633508 0.78409091]
# [5.24699138 2.6354993  2.17460085 1.67168827 1.239992   1.05340909]
# [2.09455838 1.83996218 2.08795741 2.33845526 2.31030966 2.34347826]

# %%
fig, ax = plt.subplots(1,1,figsize=(12,10))

#phi_list = [0.132,0.224,0.302,0.356,0.395,0.423]
gr_list = [0.6,1.0,1.5,2.0,2.5,3.0]
ax.errorbar(gr_list,repeatreactions_preload,repeatreactions_preload_stderr,marker='^',markersize=12,markeredgewidth=5,linewidth=5,color='#0683b4',linestyle='dashed',label='Preload')

ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.set_ylim(0,0.05)
ax.spines['left'].set_linewidth(4)
ax.spines['bottom'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)

print(np.array(crowder_repeatreaction),np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)-np.array(nocrowder_repeatreaction))
print(np.array(crowder_repeatreaction)/np.array(nocrowder_repeatreaction))
ax.set_xlim(0.4,3.2)
# Out:
# [10.04069767  5.77313975  4.17339312  2.92065663  2.18632708  1.8375    ] [4.79370629 3.13764045 1.99879227 1.24896836 0.94633508 0.78409091]
# [5.24699138 2.6354993  2.17460085 1.67168827 1.239992   1.05340909]
# [2.09455838 1.83996218 2.08795741 2.33845526 2.31030966 2.34347826]
# (0.4, 3.2)

# %%
from analysis_utils import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload

path = "/Users/Akshay/Documents/TranslationDynamics/data/"

##### Measurements made from translation voxels with a single cognate ternary complex

##########

###Crowders, gr = 3.0
repeatreactions_overlapcheck = list()
repeatreactions_overlapcheck_err = list()
data = "191003_2210/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

###No crowders, gr = 3.0
data = "191007_1601/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)

###No crowders, gr = 3.0, only 1 overlap resolution step
data = "200524_1328/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)

###Crowders, gr = 3.0, only 1 overlap resolution step
data = "200524_1408/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
repeatreactions_overlapcheck.append(sim_i[0])
repeatreactions_overlapcheck_err.append(sim_i[1])

###Crowders, gr = 3.0, only 1 overlap resolution step, no small threshold after overlap correction
data = "200525_2126/"
sim_i = countIncorrectRepeatReactions(path+data,6400,19,0,99)
print(sim_i)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (1.8375, 0.09977313423898326)
# missing expt
# 85
# (0.7840909090909091, 0.0470400417034676)
# (0.8189300411522634, 0.053397006172789065)
# missing expt
# 94
# (1.3414239482200647, 0.06868689416341653)
# missing expt
# 1
# missing expt
# 2
# missing expt
# 13
# missing expt
# 16
# missing expt
# 21
# missing expt
# 23
# missing expt
# 26
# missing expt
# 28
# missing expt
# 32
# missing expt
# 34
# missing expt
# 35
# missing expt
# 36
# missing expt
# 37
# missing expt
# 44
# missing expt
# 46
# missing expt
# 47
# missing expt
# 48
# missing expt
# 49
# missing expt
# 50
# missing expt
# 64
# missing expt
# 68
# missing expt
# 77
# missing expt
# 79
# missing expt
# 83
# missing expt
# 85
# missing expt
# 89
# missing expt
# 91
# missing expt
# 93
# missing expt
# 95
# (1.3, 0.10969208545424315)

# %%
fig,ax = plt.subplots(1,1,figsize=(4,9.3))
errorkw=dict(lw=5, capsize=0, capthick=0)

bars = ax.bar(['+','-'],repeatreactions_overlapcheck,yerr=repeatreactions_overlapcheck_err,color=['grey','grey'],error_kw=errorkw)
bars[0].set_edgecolor("black")
bars[0].set_linewidth(5)
#bars[1].set_hatch('/')
bars[1].set_edgecolor("black")
bars[1].set_linewidth(5)


ax.tick_params(axis='both', which='major',width=4, labelsize=30)
ax.spines['left'].set_linewidth(5)
ax.spines['bottom'].set_linewidth(5)
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

ax.set_xlabel('Overlap resolution',fontsize=40,labelpad=10)
ax.set_ylabel('Repeat Reactions $(\#)$',fontsize=40,labelpad=10)
# Out:
# Text(0, 0.5, 'Repeat Reactions $(\\#)$')

# %%
# Out:
# (1.706806282722513, 0.09313083757455272)
